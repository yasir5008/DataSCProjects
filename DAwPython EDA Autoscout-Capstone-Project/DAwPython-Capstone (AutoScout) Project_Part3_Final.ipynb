# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 10)
pd.set_option('display.max_colwidth', 50)

# %%
data = pd.read_csv('AutoScout_data_filling-outlier.csv')
data.head(3)
# Out:
#    make  \
# 0  Audi
# 1  Audi
# 2  Audi
#
#   model  \
# 0    A1
# 1    A1
# 2    A1
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#         km  \
# 0  56013.0
# 1  80000.0
# 2  83450.0
#
#    registration  \
# 0        2016.0
# 1        2017.0
# 2        2016.0
#
#    prev_owner  \
# 0         2.0
# 1         1.0
# 2         1.0
#
#    power_hp  \
# 0      66.0
# 1     141.0
# 2      85.0
#
#   vehicle_condition  \
# 0              Used
# 1              Used
# 2              Used
#
#   Inspection_new  \
# 0            Yes
# 1             No
# 2             No
#
#   body_color  \
# 0      Black
# 1        Red
# 2      Black
#
#   paintwork  \
# 0  Metallic
# 1  Metallic
# 2  Metallic
#
#   upholstery  \
# 0      Cloth
# 1      Cloth
# 2      Cloth
#
#    door_nr  \
# 0      5.0
# 1      3.0
# 2      4.0
#
#    seat_nr  \
# ...

# %%
data["consumption_comb"].value_counts(dropna=False)
# Out:
# 5.0     2791
# 5.4     1845
# 4.6     1040
# 5.5     1032
# 5.1      749
# 4.0      714
# 4.4      623
# 5.6      618
# 4.7      602
# 4.8      587
# 4.5      526
# 5.2      457
# 4.2      435
# 4.9      393
# 5.3      381
# 5.9      369
# 4.1      342
# 5.7      342
# 6.0      331
# 4.3      307
# 6.2      216
# 6.3      181
# 6.1      175
# 5.8      164
# 6.6      148
# 6.8      136
# 6.4       75
# 7.4       66
# 6.7       45
# 6.5       43
# 7.1       39
# 10.0      34
# 6.9       27
# 8.3       21
# 7.6       15
# 7.0       10
# 7.8        6
# 8.4        6
# 7.2        6
# 8.0        5
# 8.6        4
# 8.7        3
# 7.9        3
# 8.1        3
# 7.3        2
# 7.5        1
# 9.1        1
# Name: consumption_comb, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Columns: 119 entries, make to Xenon headlights
# dtypes: float64(12), int64(95), object(12)
# memory usage: 14.5+ MB

# %%
data_final = pd.get_dummies(data)

# %%
data_final
# Out:
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#             km  \
# 0      56013.0
# 1      80000.0
# 2      83450.0
# 3      73000.0
# 4      16200.0
# ...        ...
# 15914      0.0
# 15915   9900.0
# 15916     15.0
# 15917     10.0
# 15918   8064.8
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914        2019.0
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         0.0
# 15915         1.0
# 15916         1.0
# 15917         1.0
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 2          85.0
# ...

# %%
data_final.isnull().sum().sum()
# Out:
# 0

# %%
data_final.to_csv("Autoscout_data_final_ML.csv", index=False)

# %%
data = pd.read_csv('AutoScout_data_final_ML.csv')
data.isnull().sum().sum()
# Out:
# 0
