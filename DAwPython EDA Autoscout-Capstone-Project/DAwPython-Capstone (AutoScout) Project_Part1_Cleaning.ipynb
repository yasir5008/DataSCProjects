# %% [markdown]
# ## Introduction
# AutoScout Data Analysis Project, ikinci el araba fiyatlarına etki eden hususları inceleyerek iyi bir fiyat tahmini modülü oluşturabilmek için gerekli veriyi hazır hale getirebilmek ve sonuçta iyi bir fiyat tahmini yapabilmektir. Burada online satış yapan bir firmadan alınan ve 9 farklı araba modeline ait farklı ve dağınık bir veri seti mevcuttur. Burada yapılacak işlemler 3 aşamada değerlendirebiliriz.
#
# The project consists of 3 parts:
# * First part is related with 'data cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, Dropping useless columns.
# * Second part is related with 'filling data'. It deals with Missing Values. Categorical to numeric transformation is done.
# * Third part is related with 'handling outliers of data' via Visualisation libraries. Some insights are extracted.
#
# In this project, Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy kullanarak hem dataset temizliği hem de elde ettiğimiz dataseti üzerinden analysis yapma imkanı bulacağız.

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)
pd.set_option('display.max_colwidth', 100)

# %%
df = pd.read_json('scout_car.json', lines=True, orient='records', convert_axes=True, dtype=True,convert_dates=True)
df.head(3)
# Out:
#                                                                                                    url  \
# 0  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-b...
# 1  https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b2547f8a-e83f-6237-e053-...
# 2  https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einparkhilfe-plus-music-d...
#
#   make_model                                   short_description body_type  price  \
# 0    Audi A1         Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1    Audi A1                                      1.8 TFSI sport    Sedans  14500
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+music    Sedans  14640
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
#
#                                       Type Previous Owners                        Next Inspection  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n  [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                     [, Used, , Gasoline]             NaN                                    NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n                                    NaN
#
#           Inspection new                          Warranty Full Service Non-smoking Vehicle null  \
# 0  [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []
# 1                    NaN                               NaN          NaN                 NaN   []
# 2                    NaN  [\n, \n, \n99 g CO2/km (comb)\n]          NaN                 NaN   []
#
#        Make         Model     Offer Number First Registration       Body Color      Paint Type  \
# 0  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1  \nAudi\n  [\n, A1, \n]              NaN     [\n, 2017, \n]    [\n, Red, \n]             NaN
# 2  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
#
#             Body Color Original          Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0           [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1                           NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2  [\nmythosschwarz metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
#
#        Model Code         Gearing Type    Displacement Cylinders          Weight  Drive chain  \
# 0  [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
# 2             NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN             NaN  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
# 2  [\n, Diesel (Particulate Filter), \n]
#
#                                                                 Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)], [4.7 l/100 km (country)]]
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)], [3.4 l/100 km (country)]]
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                                                              \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, ...
# 1  [Air conditioning, Automatic climate control, Hill Holder, Leather steering wheel, Lumbar suppor...
# 2  [Air conditioning, Cruise control, Electrical side mirrors, Hill Holder, Leather steering wheel,...
#
#                                                    \nEntertainment & Media\n  \
# 0                [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 1  [Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system]
# 2                                                   [MP3, On-board computer]
#
#                                                      \nExtras\n  \
# 0            [Alloy wheels, Catalytic Converter, Voice Control]
# 1  [Alloy wheels, Sport seats, Sport suspension, Voice Control]
# 2                                 [Alloy wheels, Voice Control]
#
#                                                                                  \nSafety & Security\n  \
# 0  [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability contro...
# 1  [ABS, Central door lock, Central door lock with remote control, Daytime running lights, Driver-s...
# 2  [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability contro...
#
#                                                                                            description  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahrer-Airbag,  , ESC mit elektronischer Quersperre,  ...
# 1  [\nLangstreckenfahrzeug daher die hohe Kilometerleistung. , Bremsen neu bei 62000 km. , Gut gepf...
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 24.640 EUR,  , Komfort,  , Klimaanlage,  , Elektris...
#
#     Emission Label    Gears Country version Electricity consumption Last Service Date  \
# 0              NaN      NaN             NaN                     NaN               NaN
# 1  [\n4 (Green)\n]  [\n7\n]             NaN                     NaN               NaN
# 2  [\n4 (Green)\n]      NaN             NaN                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN
# 2              NaN          NaN                           NaN            NaN

# %%
# df.tail(20)
# Out:
#                                                                                                        url  \
# 15899  https://www.autoscout24.com//offers/renault-espace-2-0-blue-dci-200-initiale-paris-edc-eu6-2-die...
# 15900  https://www.autoscout24.com//offers/renault-espace-espace-initiale-paris-tce-225-edc-gpf-gasolin...
# 15901  https://www.autoscout24.com//offers/renault-espace-blue-dci-160cv-edc-executive-4control-nuova-d...
# 15902  https://www.autoscout24.com//offers/renault-espace-blue-dci-200-edc-initiale-paris-diesel-black-...
# 15903  https://www.autoscout24.com//offers/renault-espace-1-8-tce-225ch-fap-initiale-paris-edc-gasoline...
# 15904  https://www.autoscout24.com//offers/renault-espace-blue-dci-160-edc-limited-deluxe-diesel-grey-3...
# 15905  https://www.autoscout24.com//offers/renault-espace-energy-tce-225-edc-limited-gasoline-grey-40e6...
# 15906  https://www.autoscout24.com//offers/renault-espace-v-tce-225-edc-fap-initiale-paris-gasoline-whi...
# 15907  https://www.autoscout24.com//offers/renault-espace-1-8-tce-225-initiale-paris-winter-cruising-pa...
# 15908  https://www.autoscout24.com//offers/renault-espace-1-8-tce-225ch-energy-initiale-paris-edc-gasol...
# 15909  https://www.autoscout24.com//offers/renault-espace-limited-blue-dci-200-edc-diesel-black-44aa029...
# 15910  https://www.autoscout24.com//offers/renault-espace-tce-225-edc-initiale-pdc-shz-bose-klima-gasol...
# 15911  https://www.autoscout24.com//offers/renault-espace-elysee-energy-dci-160-edc-diesel-white-d888d4...
# 15912  https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-executive-4control-diesel-...
# 15913  https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-acc-eu6-gasoli...
# 15914  https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-executive-4control-diesel-...
# 15915  https://www.autoscout24.com//offers/renault-espace-tce-225-edc-gpf-lim-deluxe-pano-rfk-gasoline-...
# 15916  https://www.autoscout24.com//offers/renault-espace-blue-dci-200-edc-initiale-paris-leder-led-nav...
# 15917  https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-business-nuova-da-immatric...
# 15918  https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-g...
#
#            make_model                                   short_description      body_type  price  \
# 15899  Renault Espace         2.0 Blue dCi 200 Initiale Paris EDC (EU6.2)            Van  41395
# 15900  Renault Espace               ESPACE INITIALE PARIS TCe 225 EDC GPF            Van  41480
# 15901  Renault Espace  Blue dCi 160CV EDC Executive 4Control , NUOVA DA I            Van  41400
# 15902  Renault Espace                     BLUE dCi 200 EDC Initiale Paris         Sedans  41043
# 15903  Renault Espace                1.8 TCe 225ch FAP Initiale Paris EDC            Van  39990
# 15904  Renault Espace                     BLUE dCi 160 EDC LIMITED Deluxe  Station wagon  41390
# 15905  Renault Espace                          Energy TCe 225 EDC LIMITED        Compact  39990
# 15906  Renault Espace                    V Tce 225 EDC FAP Initiale Paris            Van  39990
# 15907  Renault Espace  1.8 TCE 225 INITIALE PARIS, WINTER-, CRUISING-PAKE            Van  39990
# 15908  Renault Espace             1.8 TCe 225ch energy Initiale Paris EDC            Van  39990
# 15909  Renault Espace                            Limited Blue dCi 200 EDC            Van  39990
# 15910  Renault Espace             TCe 225 EDC INITIALE PDC SHZ BOSE KLIMA            Van  39980
# 15911  Renault Espace                           ELYSEE ENERGY dCi 160 EDC            Van  39980
# 15912  Renault Espace               Blue dCi 200CV EDC Executive 4Control            Van  39950
# 15913  Renault Espace              INITIALE Paris TCe 225 EDC GPF ACC EU6            Van  39950
# 15914  Renault Espace               Blue dCi 200CV EDC Executive 4Control            Van  39950
# 15915  Renault Espace                 TCe 225 EDC GPF LIM Deluxe Pano,RFK            Van  39885
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi Key            Van  39875
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRICOLA            Van  39700
# 15918  Renault Espace         INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX            Van  40999
#
#                   vat        km registration        prev_owner  kW      hp  \
# 15899  VAT deductible  5,000 km      03/2019  1 previous owner NaN  147 kW
# 15900  VAT deductible  8,500 km      01/2019              None NaN  165 kW
# 15901  VAT deductible     10 km      06/2019              None NaN  118 kW
# 15902  VAT deductible      - km          -/-              None NaN  147 kW
# 15903            None     10 km      01/2019              None NaN  168 kW
# 15904  VAT deductible     50 km      04/2019              None NaN  118 kW
# 15905  VAT deductible    500 km      01/2019  1 previous owner NaN  165 kW
# 15906  VAT deductible     10 km      01/2019              None NaN    - kW
# 15907  VAT deductible     50 km          -/-              None NaN  165 kW
# 15908            None     10 km      02/2019              None NaN  167 kW
# 15909  VAT deductible  3,500 km      05/2019              None NaN  147 kW
# 15910  VAT deductible  8,500 km      02/2019  1 previous owner NaN  165 kW
# 15911  VAT deductible    100 km      02/2019  1 previous owner NaN  118 kW
# 15912  VAT deductible      - km          -/-              None NaN  147 kW
# 15913  VAT deductible  1,000 km      04/2019              None NaN  165 kW
# 15914  VAT deductible      - km          -/-              None NaN  147 kW
# 15915  VAT deductible  9,900 km      01/2019  1 previous owner NaN  165 kW
# 15916  VAT deductible     15 km      03/2019  1 previous owner NaN  146 kW
# 15917  VAT deductible     10 km      06/2019              None NaN  147 kW
# 15918  VAT deductible      - km      01/2019  1 previous owner NaN  165 kW
#
#                                                                                               Type  \
# 15899                                                                  [, Demonstration, , Diesel]
# 15900                                                                [, Demonstration, , Super 95]
# 15901                                                                 [, Pre-registered, , Diesel]
# 15902                                                       [, New, , Diesel (Particulate Filter)]
# 15903                                                                         [, Used, , Gasoline]
# 15904                                            [, Pre-registered, , Diesel (Particulate Filter)]
# 15905                                                                [, Demonstration, , Super 95]
# 15906                                                                         [, Used, , Gasoline]
# 15907  [, New, , Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)]
# 15908                                                                         [, Used, , Gasoline]
# 15909                                             [, Demonstration, , Diesel (Particulate Filter)]
# 15910                                                  [, Demonstration, , Regular/Benzine E10 91]
# 15911                                            [, Pre-registered, , Diesel (Particulate Filter)]
# 15912                                                       [, New, , Diesel (Particulate Filter)]
# 15913                                                                [, Demonstration, , Super 95]
# 15914                                                       [, New, , Diesel (Particulate Filter)]
# 15915                                    [, Used, , Super 95 / Super Plus 98 (Particulate Filter)]
# 15916                                                                 [, Pre-registered, , Diesel]
# 15917                                                                 [, Pre-registered, , Diesel]
# 15918                                                                [, Demonstration, , Super 95]
#
#                                                                                  Previous Owners  \
# 15899                                                                                      \n1\n
# 15900                                                                                        NaN
# 15901                                                                                        NaN
# 15902                                                                                        NaN
# 15903                                                                                        NaN
# 15904                                                                                        NaN
# 15905                                                                                      \n1\n
# 15906                                                                                        NaN
# 15907                                                                                        NaN
# 15908                                                                                        NaN
# 15909                                                                                        NaN
# 15910                                                                                      \n1\n
# 15911                                                                                      \n1\n
# 15912                                                                                        NaN
# 15913                                                                                        NaN
# 15914                                                                                        NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (city), \n, 6.3 l/100 km (country), \n]
# 15916                                                           [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                                                        NaN
# 15918                                                                                      \n1\n
#
#                               Next Inspection                      Inspection new  \
# 15899                                     NaN                                 NaN
# 15900                                     NaN                             \nYes\n
# 15901                                     NaN                                 NaN
# 15902                                     NaN                                 NaN
# 15903                                     NaN                                 NaN
# 15904                                     NaN                                 NaN
# 15905  [\n01/2022\n, \n153 g CO2/km (comb)\n]                                 NaN
# 15906                                     NaN                                 NaN
# 15907                                     NaN                                 NaN
# 15908                                     NaN                                 NaN
# 15909                                     NaN                                 NaN
# 15910                                     NaN                                 NaN
# 15911                                     NaN                                 NaN
# 15912                                     NaN                                 NaN
# 15913                                     NaN                                 NaN
# 15914                                     NaN                                 NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]                                 NaN
# 15916                                     NaN         [\nYes\n, \nEuro 6d-TEMP\n]
# 15917                                     NaN                                 NaN
# 15918                                     NaN  [\nYes\n, \n153 g CO2/km (comb)\n]
#
#                                                                                               Warranty  \
# 15899                                                         [\n48 months\n, \n139 g CO2/km (comb)\n]
# 15900                                                                                              NaN
# 15901                                                                                               \n
# 15902                                                                                              NaN
# 15903                                                                                    \n12 months\n
# 15904                                                                                              NaN
# 15905                                                                             [\n, \n, \nEuro 6\n]
# 15906                                                                                    \n12 months\n
# 15907  [\n36 months\n, \n, 7.4 l/100 km (comb), \n, 9.6 l/100 km (city), \n, 6 l/100 km (country), \n]
# 15908                                                                                    \n12 months\n
# 15909                                                                                    \n48 months\n
# 15910                                                                                              NaN
# 15911                                                                                              NaN
# 15912                                                                                    \n24 months\n
# 15913                                                                                              NaN
# 15914                                                                                    \n24 months\n
# 15915                                                                             [\n, \n, \nEuro 6\n]
# 15916                                                                          [\n, \n, \n4 (Green)\n]
# 15917                                                                                               \n
# 15918                                                                                              NaN
#
#                             Full Service                Non-smoking Vehicle null         Make  \
# 15899                                NaN                                NaN   []  \nRenault\n
# 15900                                NaN  [\n, \n, \n175 g CO2/km (comb)\n]   []  \nRenault\n
# 15901                                NaN                                NaN   []  \nRenault\n
# 15902                                NaN  [\n, \n, \n139 g CO2/km (comb)\n]   []  \nRenault\n
# 15903                                NaN                                NaN   []  \nRenault\n
# 15904                                NaN                                NaN   []  \nRenault\n
# 15905            [\n, \n, \n4 (Green)\n]                           [\n, \n]   []  \nRenault\n
# 15906                                NaN                                NaN   []  \nRenault\n
# 15907                                NaN                                NaN   []  \nRenault\n
# 15908                                NaN                                NaN   []  \nRenault\n
# 15909                                NaN                                NaN   []  \nRenault\n
# 15910  [\n, \n, \n153 g CO2/km (comb)\n]               [\n, \n, \nEuro 6\n]   []  \nRenault\n
# 15911                                NaN  [\n, \n, \n123 g CO2/km (comb)\n]   []  \nRenault\n
# 15912                                NaN                                NaN   []  \nRenault\n
# 15913                                NaN                                NaN   []  \nRenault\n
# 15914                                NaN                                NaN   []  \nRenault\n
# 15915                                NaN            [\n, \n, \n4 (Green)\n]   []  \nRenault\n
# 15916                           [\n, \n]                           [\n, \n]   []  \nRenault\n
# 15917                                NaN                                NaN   []  \nRenault\n
# 15918                                NaN                                NaN   []  \nRenault\n
#
#                   Model             Offer Number First Registration       Body Color  \
# 15899  [\n, Espace, \n]                      NaN     [\n, 2019, \n]   [\n, Grey, \n]
# 15900  [\n, Espace, \n]              [\nC0306\n]     [\n, 2019, \n]  [\n, Black, \n]
# 15901  [\n, Espace, \n]            [\n2691300\n]     [\n, 2019, \n]   [\n, Grey, \n]
# 15902  [\n, Espace, \n]          [\nIM 157730\n]                NaN  [\n, Black, \n]
# 15903  [\n, Espace, \n]   [\nre62c9-FD-691-GF\n]     [\n, 2019, \n]  [\n, Black, \n]
# 15904  [\n, Espace, \n]        [\nkom61853441\n]     [\n, 2019, \n]   [\n, Grey, \n]
# 15905  [\n, Espace, \n]  [\n506186_1136934433\n]     [\n, 2019, \n]   [\n, Grey, \n]
# 15906  [\n, Espace, \n]           [\nVO190299\n]     [\n, 2019, \n]  [\n, White, \n]
# 15907  [\n, Espace, \n]             [\n078265\n]                NaN   [\n, Grey, \n]
# 15908  [\n, Espace, \n]   [\nre74c2-FE-210-EB\n]     [\n, 2019, \n]  [\n, Black, \n]
# 15909  [\n, Espace, \n]            [\n1-15447\n]     [\n, 2019, \n]  [\n, Black, \n]
# 15910  [\n, Espace, \n]            [\n1720LR8\n]     [\n, 2019, \n]   [\n, Blue, \n]
# 15911  [\n, Espace, \n]          [\nVB1_12468\n]     [\n, 2019, \n]  [\n, White, \n]
# 15912  [\n, Espace, \n]           [\n10988276\n]                NaN  [\n, Black, \n]
# 15913  [\n, Espace, \n]             [\nNW9766\n]     [\n, 2019, \n]  [\n, White, \n]
# 15914  [\n, Espace, \n]           [\n10988301\n]                NaN   [\n, Grey, \n]
# 15915  [\n, Espace, \n]        [\n507370_3223\n]     [\n, 2019, \n]   [\n, Grey, \n]
# 15916  [\n, Espace, \n]           [\nEspace16\n]     [\n, 2019, \n]  [\n, White, \n]
# 15917  [\n, Espace, \n]            [\n2691331\n]     [\n, 2019, \n]   [\n, Grey, \n]
# 15918  [\n, Espace, \n]     [\nRe_30000008029\n]     [\n, 2019, \n]   [\n, Grey, \n]
#
#            Paint Type                  Body Color Original                 Upholstery  \
# 15899  [\nMetallic\n]                                  NaN  [\nFull leather, Brown\n]
# 15900  [\nMetallic\n]                        [\nSchwarz\n]  [\nFull leather, Brown\n]
# 15901             NaN                         [\nGrigio\n]         [\nFull leather\n]
# 15902             NaN                [\nGNE Noir Etoile\n]                [\nBrown\n]
# 15903             NaN                    [\nNOIR ETOILE\n]                        NaN
# 15904  [\nMetallic\n]                  [\nTitanium-grau\n]         [\nCloth, Other\n]
# 15905  [\nMetallic\n]              [\nGrau - Stahl Grau\n]                [\nCloth\n]
# 15906             NaN                          [\nblanc\n]                        NaN
# 15907  [\nMetallic\n]           [\ntitaniumgraumetallic\n]         [\nFull leather\n]
# 15908             NaN                          [\nNOIRE\n]                        NaN
# 15909  [\nMetallic\n]                    [\nBlack-Pearl\n]                        NaN
# 15910  [\nMetallic\n]                    [\nKosmos-Blau\n]  [\nFull leather, Other\n]
# 15911  [\nMetallic\n]  [\nPerlmutt-Weiß Metallic (Weiß)\n]   [\nFull leather, Grey\n]
# 15912  [\nMetallic\n]                           [\nNero\n]                        NaN
# 15913  [\nMetallic\n]                 [\nperlmutt-weiss\n]  [\nFull leather, Brown\n]
# 15914  [\nMetallic\n]                   [\nGrigio scuro\n]                        NaN
# 15915  [\nMetallic\n]            [\nStahl-Grau Metallic\n]                [\nCloth\n]
# 15916             NaN                    [\narktis-weiß\n]  [\nFull leather, Black\n]
# 15917             NaN                         [\nGrigio\n]         [\nPart leather\n]
# 15918  [\nMetallic\n]         [\nTitanium-Grau Metallic\n]  [\nFull leather, Brown\n]
#
#                           Body Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 15899            [\n, Van, \n]      [\n5\n]      [\n7\n]             NaN  [\n, Automatic, \n]
# 15900            [\n, Van, \n]      [\n5\n]      [\n7\n]  [\n3333/BHJ\n]  [\n, Automatic, \n]
# 15901            [\n, Van, \n]      [\n5\n]      [\n7\n]             NaN  [\n, Automatic, \n]
# 15902         [\n, Sedans, \n]      [\n4\n]      [\n5\n]  [\n3333/BDR\n]  [\n, Automatic, \n]
# 15903            [\n, Van, \n]      [\n5\n]      [\n5\n]             NaN  [\n, Automatic, \n]
# 15904  [\n, Station wagon, \n]      [\n5\n]      [\n7\n]             NaN  [\n, Automatic, \n]
# 15905        [\n, Compact, \n]      [\n5\n]      [\n7\n]  [\n3333/BHJ\n]  [\n, Automatic, \n]
# 15906            [\n, Van, \n]      [\n5\n]          NaN             NaN  [\n, Automatic, \n]
# 15907            [\n, Van, \n]      [\n5\n]      [\n7\n]  [\n3333/BHJ\n]  [\n, Automatic, \n]
# 15908            [\n, Van, \n]      [\n5\n]      [\n5\n]             NaN  [\n, Automatic, \n]
# 15909            [\n, Van, \n]      [\n5\n]      [\n5\n]             NaN  [\n, Automatic, \n]
# 15910            [\n, Van, \n]      [\n5\n]      [\n5\n]  [\n3333/BHJ\n]  [\n, Automatic, \n]
# 15911            [\n, Van, \n]      [\n5\n]      [\n7\n]  [\n3333/BDQ\n]  [\n, Automatic, \n]
# 15912            [\n, Van, \n]      [\n5\n]      [\n5\n]             NaN  [\n, Automatic, \n]
# 15913            [\n, Van, \n]      [\n5\n]      [\n7\n]             NaN  [\n, Automatic, \n]
# 15914            [\n, Van, \n]      [\n5\n]      [\n5\n]             NaN  [\n, Automatic, \n]
# 15915            [\n, Van, \n]      [\n5\n]      [\n5\n]  [\n0000/000\n]  [\n, Automatic, \n]
# 15916            [\n, Van, \n]      [\n5\n]      [\n7\n]             NaN  [\n, Automatic, \n]
# 15917            [\n, Van, \n]      [\n5\n]      [\n7\n]             NaN  [\n, Automatic, \n]
# 15918            [\n, Van, \n]      [\n5\n]      [\n5\n]  [\n3333/BHJ\n]  [\n, Automatic, \n]
#
#          Displacement Cylinders          Weight  Drive chain  \
# 15899  [\n1,997 cc\n]   [\n4\n]  [\n1,840 kg\n]  [\nfront\n]
# 15900  [\n1,798 cc\n]       NaN  [\n1,843 kg\n]  [\nfront\n]
# 15901  [\n1,997 cc\n]   [\n4\n]  [\n1,758 kg\n]  [\nfront\n]
# 15902  [\n1,997 cc\n]       NaN             NaN          NaN
# 15903  [\n1,798 cc\n]       NaN             NaN          NaN
# 15904  [\n1,997 cc\n]   [\n4\n]  [\n1,833 kg\n]  [\nfront\n]
# 15905  [\n1,798 cc\n]       NaN  [\n1,760 kg\n]          NaN
# 15906             NaN       NaN             NaN          NaN
# 15907  [\n1,798 cc\n]       NaN  [\n1,708 kg\n]          NaN
# 15908  [\n1,798 cc\n]       NaN             NaN          NaN
# 15909  [\n1,997 cc\n]       NaN  [\n1,779 kg\n]          NaN
# 15910  [\n1,798 cc\n]   [\n4\n]             NaN  [\nfront\n]
# 15911  [\n1,598 cc\n]   [\n4\n]  [\n1,734 kg\n]          NaN
# 15912  [\n1,997 cc\n]   [\n4\n]  [\n1,758 kg\n]  [\nfront\n]
# 15913  [\n1,798 cc\n]   [\n4\n]             NaN  [\nfront\n]
# 15914  [\n1,997 cc\n]   [\n4\n]  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,798 cc\n]   [\n4\n]  [\n1,708 kg\n]  [\nfront\n]
# 15916  [\n1,997 cc\n]   [\n4\n]             NaN  [\nfront\n]
# 15917  [\n1,997 cc\n]   [\n4\n]  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,798 cc\n]   [\n4\n]  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                                                              Fuel  \
# 15899                                                                            [\n, Diesel, \n]
# 15900                                                                          [\n, Super 95, \n]
# 15901                                                                            [\n, Diesel, \n]
# 15902                                                       [\n, Diesel (Particulate Filter), \n]
# 15903                                                                          [\n, Gasoline, \n]
# 15904                                                       [\n, Diesel (Particulate Filter), \n]
# 15905                                                                          [\n, Super 95, \n]
# 15906                                                                          [\n, Gasoline, \n]
# 15907  [\n, Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter), \n]
# 15908                                                                          [\n, Gasoline, \n]
# 15909                                                       [\n, Diesel (Particulate Filter), \n]
# 15910                                                            [\n, Regular/Benzine E10 91, \n]
# 15911                                                       [\n, Diesel (Particulate Filter), \n]
# 15912                                                       [\n, Diesel (Particulate Filter), \n]
# 15913                                                                          [\n, Super 95, \n]
# 15914                                                       [\n, Diesel (Particulate Filter), \n]
# 15915                                     [\n, Super 95 / Super Plus 98 (Particulate Filter), \n]
# 15916                                                                            [\n, Diesel, \n]
# 15917                                                                            [\n, Diesel, \n]
# 15918                                                                          [\n, Super 95, \n]
#
#                                                                               Consumption  \
# 15899            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)], [4.7 l/100 km (country)]]
# 15900              [[7.4 l/100 km (comb)], [9.6 l/100 km (city)], [6 l/100 km (country)]]
# 15901            [[5.1 l/100 km (comb)], [5.7 l/100 km (city)], [4.8 l/100 km (country)]]
# 15902            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)], [4.7 l/100 km (country)]]
# 15903                                                                                 NaN
# 15904                [[5.3 l/100 km (comb)], [6 l/100 km (city)], [5 l/100 km (country)]]
# 15905            [[6.8 l/100 km (comb)], [8.7 l/100 km (city)], [5.7 l/100 km (country)]]
# 15906                                                     [[7.4 l/100 km (comb)], [], []]
# 15907    [\n, 7.4 l/100 km (comb), \n, 9.6 l/100 km (city), \n, 6 l/100 km (country), \n]
# 15908                                                                                 NaN
# 15909                                                                                 NaN
# 15910                  [[6 l/100 km (comb)], [8 l/100 km (city)], [5 l/100 km (country)]]
# 15911            [[4.7 l/100 km (comb)], [5.1 l/100 km (city)], [4.4 l/100 km (country)]]
# 15912            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)], [4.7 l/100 km (country)]]
# 15913            [[6.8 l/100 km (comb)], [8.7 l/100 km (city)], [5.7 l/100 km (country)]]
# 15914            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)], [4.7 l/100 km (country)]]
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (city), \n, 6.3 l/100 km (country), \n]
# 15916            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)], [4.7 l/100 km (country)]]
# 15917            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)], [4.7 l/100 km (country)]]
# 15918            [[6.8 l/100 km (comb)], [8.7 l/100 km (city)], [5.7 l/100 km (country)]]
#
#                     CO2 Emission      Emission Class  \
# 15899  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15900  [\n175 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15901  [\n135 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15902  [\n139 g CO2/km (comb)\n]       [\nEuro 6c\n]
# 15903                        NaN                 NaN
# 15904  [\n135 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15905  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15906                        NaN                 NaN
# 15907  [\n168 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15908                        NaN                 NaN
# 15909               [[], [], []]                 NaN
# 15910  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15911  [\n123 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15912  [\n139 g CO2/km (comb)\n]                 NaN
# 15913  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                                                                  \nComfort & Convenience\n  \
# 15899  [Air conditioning, Air suspension, Armrest, Automatic climate control, Cruise control, Electrica...
# 15900  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15901  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15902  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrically adjustable s...
# 15903  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15904  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, ...
# 15905  [Air conditioning, Armrest, Automatic climate control, Electrically adjustable seats, Electrical...
# 15906                                                                      [Cruise control, Power windows]
# 15907  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrically adjustable s...
# 15908  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15909  [Air conditioning, Automatic climate control, Cruise control, Electrically heated windshield, El...
# 15910  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15911  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrically adjustable s...
# 15912  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15913  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrically adjustable s...
# 15914  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15915  [Air conditioning, Automatic climate control, Cruise control, Electrically heated windshield, El...
# 15916  [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrically heated winds...
# 15917  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
# 15918  [Air conditioning, Automatic climate control, Cruise control, Electrically adjustable seats, Ele...
#
#                                                                                 \nEntertainment & Media\n  \
# 15899         [Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Sound system, USB]
# 15900                                                                                      [Sound system]
# 15901                                                              [Bluetooth, Digital radio, Radio, USB]
# 15902                            [Bluetooth, Digital radio, Hands-free equipment, On-board computer, USB]
# 15903                                         [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 15904                     [Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB]
# 15905                [Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB]
# 15906                                                                                                 NaN
# 15907  [Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB]
# 15908                                         [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 15909                             [Bluetooth, Hands-free equipment, On-board computer, Sound system, USB]
# 15910                                         [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 15911       [Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB]
# 15912                     [Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB]
# 15913                [Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB]
# 15914                     [Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB]
# 15915                                        [Bluetooth, Digital radio, Hands-free equipment, Radio, USB]
# 15916                                         [Bluetooth, Hands-free equipment, On-board computer, Radio]
# 15917                                                              [Bluetooth, Digital radio, Radio, USB]
# 15918                                                                                               [USB]
#
#                                                                                \nExtras\n  \
# 15899                    [Alloy wheels, Catalytic Converter, Touch screen, Voice Control]
# 15900                                                                      [Alloy wheels]
# 15901                                                        [Alloy wheels, Touch screen]
# 15902                              [Alloy wheels, Roof rack, Touch screen, Voice Control]
# 15903                                                                      [Alloy wheels]
# 15904                                                        [Alloy wheels, Touch screen]
# 15905                                                        [Alloy wheels, Touch screen]
# 15906                                                                      [Alloy wheels]
# 15907                                         [Alloy wheels, Touch screen, Voice Control]
# 15908                                                                      [Alloy wheels]
# 15909                                                        [Alloy wheels, Touch screen]
# 15910                                                                      [Alloy wheels]
# 15911                                         [Alloy wheels, Touch screen, Voice Control]
# 15912                                                        [Alloy wheels, Touch screen]
# 15913  [Alloy wheels, Catalytic Converter, Sport suspension, Touch screen, Voice Control]
# 15914                                                        [Alloy wheels, Touch screen]
# 15915                                         [Alloy wheels, Touch screen, Voice Control]
# 15916                                                                      [Alloy wheels]
# 15917                                                        [Alloy wheels, Touch screen]
# 15918                                                        [Alloy wheels, Touch screen]
#
#                                                                                      \nSafety & Security\n  \
# 15899  [ABS, Adaptive Cruise Control, Blind spot monitor, Driver-side airbag, Electronic stability cont...
# 15900  [ABS, Adaptive headlights, Blind spot monitor, Central door lock, Daytime running lights, Driver...
# 15901  [ABS, Blind spot monitor, Driver-side airbag, Electronic stability control, Emergency brake assi...
# 15902  [ABS, Blind spot monitor, Central door lock, Daytime running lights, Driver-side airbag, Electro...
# 15903  [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability contro...
# 15904  [ABS, Blind spot monitor, Central door lock, Daytime running lights, Driver-side airbag, Electro...
# 15905  [ABS, Adaptive Cruise Control, Blind spot monitor, Central door lock, Daytime running lights, Dr...
# 15906                      [ABS, Driver-side airbag, Passenger-side airbag, Side airbag, Traction control]
# 15907  [ABS, Adaptive Cruise Control, Adaptive headlights, Blind spot monitor, Central door lock, Dayti...
# 15908  [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability contro...
# 15909  [ABS, Blind spot monitor, Central door lock, Daytime running lights, Driver-side airbag, Electro...
# 15910  [ABS, Adaptive headlights, Central door lock, Daytime running lights, Electronic stability contr...
# 15911  [ABS, Adaptive Cruise Control, Central door lock, Daytime running lights, Driver-side airbag, El...
# 15912  [ABS, Central door lock, Central door lock with remote control, Driver-side airbag, Electronic s...
# 15913  [ABS, Adaptive Cruise Control, Blind spot monitor, Central door lock, Daytime running lights, Dr...
# 15914  [ABS, Central door lock, Central door lock with remote control, Driver-side airbag, Electronic s...
# 15915  [ABS, Adaptive Cruise Control, Blind spot monitor, Central door lock, Daytime running lights, Dr...
# 15916  [ABS, Adaptive Cruise Control, Blind spot monitor, Central door lock, Daytime running lights, Dr...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, Electronic stability control, Emergency brake assi...
# 15918  [ABS, Blind spot monitor, Daytime running lights, Driver-side airbag, Electronic stability contr...
#
#                                                                                                description  \
# 15899  [\n, ..::Renault Espace Initiale Paris Dci 200 EDC (Boite auto)::.., Véhicule de direction,état ...
# 15900  [\n, Unfallfrei, Euro6, Klimaautomatik 2-fach, Fahrerairbag, Beifahrerairbag, Fenster-/Kopfairba...
# 15901  [\nDEK:[2691300], Renault Espace Blue dCi 160CV EDC Executive 4Control, Nuova da Immatricolare, ...
# 15902  [\n12V Anschluss, 19" Leichtmetallfelgen, ABS, ASR, elektr. Außenspiegel klappbar, einstellbar u...
# 15903  [\nMarque: RENAULTModèle: EspaceVersion: 1.8 TCe 225ch FAP Initiale Paris EDCEnergie: EssenceAnn...
# 15904  [\n, Easy-Park-Assistent mit Rückfahrkamera,  , Elektrische Heckklappe mit Fußsensor,  , Zwei Ei...
# 15905  [\n, Fahrersitz eleektrisch, Adaptiver Tempopilot ACC (bis 150km/h), Beheizbare Sitze in der 2. ...
# 15906  [\nV Tce 225 EDC FAP Initiale Paris, essence, blanc nacré, 29/01/2019, ABS, Affichage tête haute...
# 15907  [\n, Sonderausstattung, 3.Sitzreihe mit Einzelsitzen , Cruising-Paket , Adaptive Geschwindigkeit...
# 15908  [\nMarque: RENAULTModèle: EspaceVersion: 1.8 TCe 225ch energy Initiale Paris EDCEnergie: Essence...
# 15909  [\nHallo!, Das Beratungsteam der Fa. Sonnleitner freut sich auf ihre Anfrage und bietet Ihnen mi...
# 15910  [\n, Warum ist dieses Auto das Richtige für mich?, Der Große für Familie oder Job, Zubehör Highl...
# 15911  [\n, Komfort:,  , abgedunkelte Scheiben im Fond,  , Abstandswarner,  , Android Auto,  , Außenspi...
# 15912  [\nVettura visionabile nella sede in Via Roma 141 a Villorba (TV)., Prezzo escluse spese immatri...
# 15913  [\nFahrzeug-Nr.: NW9766., Ausstattungslinie/ -paket:, Winterpaket., Media:, 8 Zoll Farbdisplay, ...
# 15914  [\nVettura visionabile nella sede in Via Roma 141 a Villorba (TV)., Prezzo escluse spese immatri...
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung: Metallic, Paket: CRUISING - Adaptiver Tempopilot...
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcomputer, Assistenten:,  Totwinkel-Assistent, Verkehr...
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200CV EDC Business, Nuova da Immatricolare, COLORE: Gr...
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , Fahrerairbag,  , Beifahrerairbag,  , Sicherheit:, ...
#
#         Emission Label    Gears       Country version Electricity consumption Last Service Date  \
# 15899              NaN  [\n6\n]         [\nBelgium\n]                     NaN               NaN
# 15900  [\n4 (Green)\n]      NaN         [\nGermany\n]                     NaN               NaN
# 15901              NaN  [\n6\n]                   NaN                     NaN               NaN
# 15902              NaN      NaN         [\nBelgium\n]                     NaN               NaN
# 15903              NaN      NaN                   NaN                     NaN               NaN
# 15904  [\n4 (Green)\n]  [\n6\n]         [\nGermany\n]                     NaN               NaN
# 15905              NaN      NaN                   NaN                     NaN               NaN
# 15906              NaN      NaN                   NaN                     NaN               NaN
# 15907  [\n4 (Green)\n]  [\n7\n]  [\nEuropean Union\n]                     NaN               NaN
# 15908              NaN      NaN                   NaN                     NaN               NaN
# 15909              NaN  [\n7\n]         [\nAustria\n]                     NaN               NaN
# 15910  [\n4 (Green)\n]  [\n7\n]                   NaN                     NaN               NaN
# 15911  [\n4 (Green)\n]      NaN         [\nGermany\n]                     NaN               NaN
# 15912              NaN  [\n6\n]                   NaN                     NaN               NaN
# 15913  [\n4 (Green)\n]      NaN                   NaN                     NaN               NaN
# 15914              NaN  [\n6\n]                   NaN                     NaN               NaN
# 15915              NaN  [\n7\n]         [\nGermany\n]                     NaN               NaN
# 15916              NaN  [\n6\n]         [\nAustria\n]                     NaN               NaN
# 15917              NaN  [\n6\n]                   NaN                     NaN               NaN
# 15918  [\n4 (Green)\n]      NaN         [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability Last Timing Belt Service Date Available from
# 15899              NaN                            NaN                           NaN            NaN
# 15900              NaN                            NaN                           NaN            NaN
# 15901              NaN                            NaN                           NaN            NaN
# 15902              NaN                            NaN                           NaN   \n03/08/19\n
# 15903              NaN                            NaN                           NaN            NaN
# 15904              NaN                            NaN                           NaN            NaN
# 15905              NaN                            NaN                           NaN            NaN
# 15906              NaN                            NaN                           NaN            NaN
# 15907     [[], [], []]   \nin 14 days from ordering\n                           NaN            NaN
# 15908              NaN                            NaN                           NaN            NaN
# 15909              NaN                            NaN                           NaN            NaN
# 15910              NaN                            NaN                           NaN            NaN
# 15911              NaN                            NaN                           NaN            NaN
# 15912              NaN                            NaN                           NaN            NaN
# 15913              NaN                            NaN                           NaN            NaN
# 15914              NaN                            NaN                           NaN            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n                           NaN            NaN
# 15916              NaN  \nin 120 days from ordering\n                           NaN            NaN
# 15917              NaN                            NaN                           NaN            NaN
# 15918              NaN                            NaN                           NaN            NaN

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
# # Part-1: Data Cleanings

# %% [markdown]
# ### Veri setimizi incelemeye başlamadan önce ilk olarak boş bir dataframe oluşturuyoruz. Sırasıyla her bir feature inceleyerek bu dataframe ekleyecek ve işlemlerimizi bunun üzerinden yapacağız.

# %%
data  = pd.DataFrame()

# %% [markdown]
# ### Veri setimizin sütunlarını tek tek inceleyeceğiz. Çünkü veri setindeki eksik verileri doldururken bunlardan faydalanabileceğimiz ve bize net bilgi verebilecek değerler olabilir.
#
# ### İlk olarak "make_model" sütunu iki parçaya bölerek başlıyoruz. Dataframe içinde ilave olarak "make" ve "model" olmak üzere iki sütun mevcut. Bunları da duplicate olacağından dolayı sileceğiz.

# %%
temp = df["make_model"].copy()

# %%
data["make"] = temp.str.split(' ', expand=True)[0]

# %%
data["model"] = temp.str.split(' ', expand=True)[1]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   make    15919 non-null  object
#  1   model   15919 non-null  object
# dtypes: object(2)
# memory usage: 248.9+ KB

# %% [markdown]
# ### Veri setimizde kullanmayacağımız feature incelesek dahi bunları yeni oluşturduğumuz dataframe dahil etmeyeceğimizden dolayı herhangi bir silme işlemi yapmayacağız. "url" sütunu fiyatlara etki eden bir bilgiye sahip olmadığından dolayı bunu kullanmayacağız.

# %%
# df.drop(["url","make_model"], axis=1).head(2)  # düşülecek.
# Out:
#                short_description  \
# 0  Sportback 1.4 TDI S-tronic...
# 1                 1.8 TFSI sport
#
#   body_type  \
# 0    Sedans
# 1    Sedans
#
#    price  \
# 0  15770
# 1  14500
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
#
#           km  \
# 0  56,013 km
# 1  80,000 km
#
#   registration  \
# 0      01/2016
# 1      03/2017
#
#           prev_owner  \
# 0  2 previous owners
# 1               None
#
#    kW  \
# 0 NaN
# 1 NaN
#
#        hp  \
# 0   66 kW
# 1  141 kW
#
#                             Type  \
# 0  [, Used, , Diesel (Particu...
# 1           [, Used, , Gasoline]
#
#   Previous Owners  \
# 0           \n2\n
# 1             NaN
#
#                  Next Inspection  \
# 0  [\n06/2021\n, \n99 g CO2/k...
# 1                            NaN
#
#           Inspection new  \
# 0  [\nYes\n, \nEuro 6\n]
# 1                    NaN
#
#                   Warranty  \
# 0  [\n, \n, \n4 (Green)\n]
# 1                      NaN
#
#   Full Service  \
# 0     [\n, \n]
# 1          NaN
#
#   Non-smoking Vehicle  \
# 0            [\n, \n]
# 1                 NaN
#
#   null  \
# 0   []
# 1   []
#
#        Make  \
# 0  \nAudi\n
# 1  \nAudi\n
#
#           Model  \
# 0  [\n, A1, \n]
# 1  [\n, A1, \n]
#
#       Offer Number  \
# 0  [\nLR-062483\n]
# 1              NaN
#
#   First Registration  \
# 0     [\n, 2016, \n]
# 1     [\n, 2017, \n]
#
#         Body Color  \
# 0  [\n, Black, \n]
# 1    [\n, Red, \n]
#
#        Paint Type  \
# 0  [\nMetallic\n]
# 1             NaN
#
#    Body Color Original  \
# 0  [\nMythosschwarz\n]
# 1                  NaN
#
#            Upholstery  \
# 0  [\nCloth, Black\n]
# 1   [\nCloth, Grey\n]
#
#                Body  \
# 0  [\n, Sedans, \n]
# 1  [\n, Sedans, \n]
#
#   Nr. of Doors  \
# 0      [\n5\n]
# 1      [\n3\n]
#
#   Nr. of Seats  \
# 0      [\n5\n]
# 1      [\n4\n]
#
#        Model Code  \
# 0  [\n0588/BDF\n]
# 1  [\n0588/BCY\n]
#
#           Gearing Type  \
# 0  [\n, Automatic, \n]
# 1  [\n, Automatic, \n]
#
#      Displacement  \
# 0  [\n1,422 cc\n]
# 1  [\n1,798 cc\n]
#
#   Cylinders  \
# 0   [\n3\n]
# 1   [\n4\n]
#
#            Weight  \
# 0  [\n1,220 kg\n]
# 1  [\n1,255 kg\n]
#
#    Drive chain  \
# 0  [\nfront\n]
# 1  [\nfront\n]
#
#                             Fuel  \
# 0  [\n, Diesel (Particulate F...
# 1             [\n, Gasoline, \n]
#
#                      Consumption  \
# 0  [[3.8 l/100 km (comb)], [4...
# 1  [[5.6 l/100 km (comb)], [7...
#
#                 CO2 Emission  \
# 0   [\n99 g CO2/km (comb)\n]
# 1  [\n129 g CO2/km (comb)\n]
#
#   Emission Class  \
# 0   [\nEuro 6\n]
# 1   [\nEuro 6\n]
#
#        \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest...
# 1  [Air conditioning, Automat...
#
#        \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equ...
# 1  [Bluetooth, Hands-free equ...
#
#                       \nExtras\n  \
# 0  [Alloy wheels, Catalytic C...
# 1  [Alloy wheels, Sport seats...
#
#            \nSafety & Security\n  \
# 0  [ABS, Central door lock, D...
# 1  [ABS, Central door lock, C...
#
#                      description  \
# 0  [\n, Sicherheit:,  , Deakt...
# 1  [\nLangstreckenfahrzeug da...
#
#     Emission Label  \
# 0              NaN
# 1  [\n4 (Green)\n]
#
#      Gears  \
# 0      NaN
# 1  [\n7\n]
#
#   Country version  \
# 0             NaN
# 1             NaN
#
#   Electricity consumption  \
# 0                     NaN
# 1                     NaN
#
#   Last Service Date  \
# 0               NaN
# 1               NaN
#
#   Other Fuel Types  \
# 0              NaN
# 1              NaN
#
#   Availability  \
# 0          NaN
# 1          NaN
#
#   Last Timing Belt Service Date  \
# 0                           NaN
# 1                           NaN
#
#   Available from
# 0            NaN
# 1            NaN

# %%
temp = df["body_type"].copy()  # 60 tane eksik veri var.

# %%
temp.value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
data["body_type"] = temp

# %%
data[data["body_type"].notna()]
# Out:
#           make   model body_type
# 0         Audi      A1    Sedans
# 1         Audi      A1    Sedans
# 2         Audi      A1    Sedans
# 3         Audi      A1    Sedans
# 4         Audi      A1    Sedans
# ...        ...     ...       ...
# 15914  Renault  Espace       Van
# 15915  Renault  Espace       Van
# 15916  Renault  Espace       Van
# 15917  Renault  Espace       Van
# 15918  Renault  Espace       Van
#
# [15859 rows x 3 columns]

# %%
data[~data["body_type"].notna()]
# Out:
#           make     model body_type
# 3175      Audi        A3      None
# 3255      Audi        A3      None
# 3975      Audi        A3      None
# 3997      Audi        A3      None
# 4206      Audi        A3      None
# 4297      Audi        A3      None
# 4298      Audi        A3      None
# 5718      Opel     Astra      None
# 5938      Opel     Astra      None
# 5940      Opel     Astra      None
# 6920      Opel     Astra      None
# 6922      Opel     Astra      None
# 6927      Opel     Astra      None
# 7709      Opel     Astra      None
# 8408      Opel     Corsa      None
# 8584      Opel     Corsa      None
# 10837     Opel  Insignia      None
# 10838     Opel  Insignia      None
# 10857     Opel  Insignia      None
# 13430  Renault      Clio      None
# 13470  Renault      Clio      None
# 13576  Renault      Clio      None
# 13703  Renault      Clio      None
# 13725  Renault      Clio      None
# 13852  Renault      Clio      None
# 13900  Renault      Clio      None
# 14107  Renault      Clio      None
# 14124  Renault      Clio      None
# 14127  Renault      Clio      None
# 14134  Renault      Clio      None
# 14135  Renault      Clio      None
# 14480  Renault      Clio      None
# 14869  Renault      Clio      None
# 14870  Renault      Clio      None
# 14928  Renault    Espace      None
# 14990  Renault    Espace      None
# 15058  Renault    Espace      None
# 15059  Renault    Espace      None
# 15060  Renault    Espace      None
# 15124  Renault    Espace      None
# 15269  Renault    Espace      None
# 15275  Renault    Espace      None
# 15289  Renault    Espace      None
# 15307  Renault    Espace      None
# 15378  Renault    Espace      None
# 15437  Renault    Espace      None
# 15452  Renault    Espace      None
# 15456  Renault    Espace      None
# 15457  Renault    Espace      None
# 15488  Renault    Espace      None
# 15489  Renault    Espace      None
# 15491  Renault    Espace      None
# 15499  Renault    Espace      None
# 15544  Renault    Espace      None
# 15556  Renault    Espace      None
# 15589  Renault    Espace      None
# 15696  Renault    Espace      None
# 15712  Renault    Espace      None
# 15736  Renault    Espace      None
# 15770  Renault    Espace      None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   make       15919 non-null  object
#  1   model      15919 non-null  object
#  2   body_type  15859 non-null  object
# dtypes: object(3)
# memory usage: 373.2+ KB

# %% [markdown]
# ### Short_description inceleyelim.

# %%
temp = df["short_description"].copy()

# %%
temp.head(50)
# Out:
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1                                         1.8 TFSI sport
# 2     Sportback 1.6 TDI S tronic Einparkhilfe plus+music
# 3                                1.4 TDi Design S tronic
# 4     Sportback 1.4 TDI S-Tronic S-Line Ext. admired, Xe
# 5            1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*
# 6          Sportback 1.6 TDI S-TRONIC S-LINE*NAVI|XENON*
# 7                     Sportback 1.4 TDI admired S tronic
# 8                 SPB 1.6 TDI S-tronic Metal plus + Xeno
# 9                  SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.
# 10           SPORTBACK1.6 TDI 116 CV S tronic Metal plus
# 11    Sportback Sport »1.4 TFSI|Xenon|Navi|EPH+|SHZ|S tr
# 12          Sportback 1.4 TFSI S-tronic *S line*NAV*XEN*
# 13           1.4 TFSI 150ch COD Ambition Luxe S tronic 7
# 14     Sportback 1.0 TFSI S-TRonic*Navi*Xenon*APS* Sport
# 15                     SPB 1.6 TDI 116 CV S tronic Sport
# 16    SPB 1.6 TDI 116 CV Design S-Line SPB 1.6 TDI 116 C
# 17            1.4 TDi S tronic*S-Line*Navigatie*Euro 6b*
# 18                      1.0 TFSI 95pk Automaat Adrenalin
# 19          Sportback 1.6 TDI 116 CV S tronic Metal plus
# 20            SPB 1.6 TDI 116 CV S tronic Admired S-Line
# 21          Sportback Sport 1.4 TFSI S tronic XENON NAVI
# 22                                     1.4 TFSI S tronic
# 23                SPB 1.6 TDI 116 CV S tronic Metal plus
# 24    SPB 1.0 TFSI ultra S tronic!! 3.000KM! COME NUOVA!
# 25                      1.0 TFSI ultra Sportback TÜV NEU
# 26                     1.0 TFSI *PDC*SHZ*Klimaautomatik*
# 27                         Sportback 1.0 TFSI Attraction
# 28                      /S1 SPB 1.4 TDI S tronic Admired
# 29                                       Sportback basis
# 30                           Sportback 1.4TDI Attraction
# 31                    1.4 TDI ultra Klimaautomatik Xenon
# 32                            1.0 TFSI ultra KLIMA LM ZV
# 33                           Sportback 1.4TDI Attraction
# 34                   SPB 1.4 TDI 90cv EURO6 NEOPATENTATI
# 35                      1.0 TFSI ultra KLIMA FSE SHZ EU6
# 36                            1.0 TFSI ultra *GRA*Klima*
# 37                           Sportback 1.4TDI Attraction
# 38                                  1.0 TFSI ultra sport
# 39     (€8950,-excl.VAT/Guarantee) SB 1.4 TDi Ultra Eur6
# 40       3-Türer 1.0 TFSI 5-Gang GRA Sportlenkrad EURO 6
# 41             1.4 TDI ultra Sportback *1.Hand*Navi*Pdc*
# 42             1.4 TDI ultra Sportback *1.Hand*Navi*Pdc*
# 43    (€8900,-excl.VAT/Guarantee) SB 1.4TDI Ultra Eur6 N
# 44                               Sportback 1.0 TDI ultra
# 45            1.0 TFSI Ultra*EURO6*Klimaautomatik*LM16"*
# 46                                               1.4 TDi
# 47                           Sportback 1.6TDI Attraction
# 48                SPORT KLIMA+SHZ+PDC+16-ZOLL-ALU+EURO 6
# 49                                        1.0 TFSI basis
# Name: short_description, dtype: object

# %%
data["cc"] = temp.str.extract("(\d\.\d)").astype("float")  # bu şekilde alınca 5068 tane eksik değer var.

# %%
data["cc"].value_counts(dropna=False)
# Out:
# NaN    5068
# 1.6    3891
# 1.4    2535
# 1.0    1334
# 1.2     957
# 1.5     890
# 2.0     888
# 1.3     135
# 1.8      60
# 0.9      49
# 4.0      28
# 2.5      21
# 4.3       9
# 5.7       8
# 5.5       3
# 1.7       3
# 5.0       3
# 1.1       3
# 0.8       2
# 3.0       2
# 6.0       2
# 9.8       2
# 3.9       2
# 6.1       1
# 5.1       1
# 7.8       1
# 5.6       1
# 8.9       1
# 0.2       1
# 4.2       1
# 2.2       1
# 9.6       1
# 5.3       1
# 8.5       1
# 0.7       1
# 7.9       1
# 0.0       1
# 4.6       1
# 0.6       1
# 9.9       1
# 7.3       1
# 8.8       1
# 8.4       1
# 2.8       1
# 4.5       1
# 2.3       1
# 0.3       1
# Name: cc, dtype: int64

# %%
data[~data["cc"].notna()]
# Out:
#           make   model body_type  cc
# 9         Audi      A1    Sedans NaN
# 29        Audi      A1   Compact NaN
# 48        Audi      A1   Compact NaN
# 55        Audi      A1   Compact NaN
# 63        Audi      A1    Sedans NaN
# ...        ...     ...       ...  ..
# 15914  Renault  Espace       Van NaN
# 15915  Renault  Espace       Van NaN
# 15916  Renault  Espace       Van NaN
# 15917  Renault  Espace       Van NaN
# 15918  Renault  Espace       Van NaN
#
# [5068 rows x 4 columns]

# %% [markdown]
# ### Price inceleyelim.

# %%
temp = df["price"].copy()

# %%
data["price"]=temp

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   make       15919 non-null  object
#  1   model      15919 non-null  object
#  2   body_type  15859 non-null  object
#  3   cc         10851 non-null  float64
#  4   price      15919 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 622.0+ KB

# %% [markdown]
# ### vat inceleyelim.

# %%
temp = df["vat"].copy()   # ???? autoscout24 sitesinde vat deductible seçmeden 1.6 milyon araba varken bunu seçince 600 bine düşüyor.

# %%
data["vat"] = temp

# %%
data["vat"].value_counts(dropna=False)
# Out:
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %% [markdown]
# ### km inceleyelim.

# %%
temp = df["km"].copy()

# %%
temp
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
data["km"] = temp.str.replace(r'\D+', '', regex=True)

# %%
data[data["km"]==""]   # 1024 tane "" değer var.
# Out:
#           make   model      body_type   cc  price             vat km
# 743       Audi      A1         Sedans  NaN  25900            None
# 869       Audi      A1         Sedans  1.0  21300  VAT deductible
# 946       Audi      A1        Compact  NaN  21406            None
# 977       Audi      A1        Compact  1.0  21200  VAT deductible
# 980       Audi      A1        Compact  NaN  21100            None
# ...        ...     ...            ...  ...    ...             ... ..
# 15890  Renault  Espace  Station wagon  NaN  42490  VAT deductible
# 15902  Renault  Espace         Sedans  NaN  41043  VAT deductible
# 15912  Renault  Espace            Van  NaN  39950  VAT deductible
# 15914  Renault  Espace            Van  NaN  39950  VAT deductible
# 15918  Renault  Espace            Van  NaN  40999  VAT deductible
#
# [1024 rows x 7 columns]

# %%
data.km.value_counts(dropna=False)
# Out:
# 10        1045
#           1024
# 1          367
# 5          170
# 50         148
#           ...
# 35152        1
# 93307        1
# 178000       1
# 25902        1
# 231879       1
# Name: km, Length: 6690, dtype: int64

# %% [markdown]
# ### registration inceleyelim. diğer bir sütun olan "first_registration" ile aynı veriye sahip olduğundan duplicate oluşuyor ve birini df dahil etmeyeceğiz.

# %%
temp = df["registration"].copy()    # 1597 tane eksik değer var.

# %%
temp
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        -/-
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15919, dtype: object

# %%
data["registration"] = temp.str.extract('(\d{4})')

# %%
data["registration"] = data["registration"].astype("float")

# %%
data["registration"].value_counts(dropna=False)
# Out:
# 2018.0    4522
# 2016.0    3674
# 2017.0    3273
# 2019.0    2853
# NaN       1597
# Name: registration, dtype: int64

# %% [markdown]
# ### prev_owner inceleyelim. Aşağıdaki "previos_owner" ile duplicate olacağından biri df dahil edilmeyecek.

# %%
temp = df["prev_owner"].copy()    # 6828 tane eksik veri var. Aşağıdaki previous_owners bundan farklı olarak 0 değerler var.

# %%
temp.value_counts(dropna=False)
# Out:
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
data["prev_owner"] = temp.str.extract("(\d+)")

# %%
data["prev_owner"] = data["prev_owner"].astype("float")

# %%
data["prev_owner"].value_counts(dropna=False)   # 6828 tane eksik veri var.
# Out:
# 1.0    8294
# NaN    6828
# 2.0     778
# 3.0      17
# 4.0       2
# Name: prev_owner, dtype: int64

# %% [markdown]
# ### hp inceleyelim.

# %%
temp = df["hp"].copy()

# %%
temp.value_counts(dropna=False)  # 88 eksik var.(-)
# Out:
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 52 kW       22
# 82 kW       22
# 1 kW        20
# 78 kW       20
# 146 kW      18
# 294 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# 65 kW        4
# 76 kW        4
# 168 kW       3
# 149 kW       3
# 80 kW        3
# 98 kW        3
# 93 kW        3
# 127 kW       2
# 270 kW       2
# 53 kW        2
# 167 kW       2
# 40 kW        2
# 63 kW        2
# 89 kW        2
# 228 kW       2
# 143 kW       2
# 86 kW        2
# 150 kW       2
# 140 kW       2
# 239 kW       1
# 4 kW         1
# 75 kW        1
# 84 kW        1
# 44 kW        1
# 132 kW       1
# 137 kW       1
# 163 kW       1
# 195 kW       1
# 123 kW       1
# 133 kW       1
# 115 kW       1
# 9 kW         1
# Name: hp, dtype: int64

# %%
data["power_hp"] = temp.str.extract("(\d+)")

# %%
data["power_hp"] = data["power_hp"].astype("float")

# %%
data["power_hp"].value_counts(dropna=False)
# Out:
# 85.0     2542
# 66.0     2122
# 81.0     1402
# 100.0    1308
# 110.0    1112
# 70.0      888
# 125.0     707
# 51.0      695
# 55.0      569
# 118.0     516
# 92.0      466
# 121.0     392
# 147.0     380
# 77.0      345
# 56.0      286
# 54.0      276
# 103.0     253
# 87.0      232
# 165.0     194
# 88.0      177
# 60.0      160
# 162.0      98
# NaN        88
# 74.0       81
# 96.0       72
# 71.0       59
# 101.0      47
# 67.0       40
# 154.0      39
# 122.0      35
# 119.0      30
# 164.0      27
# 135.0      24
# 82.0       22
# 52.0       22
# 1.0        20
# 78.0       20
# 146.0      18
# 294.0      18
# 141.0      16
# 57.0       10
# 120.0       8
# 104.0       8
# 191.0       7
# 112.0       7
# 155.0       6
# 117.0       6
# 184.0       5
# 90.0        4
# 76.0        4
# 65.0        4
# 149.0       3
# 98.0        3
# 93.0        3
# 80.0        3
# 168.0       3
# 150.0       2
# 63.0        2
# 140.0       2
# 86.0        2
# 89.0        2
# 40.0        2
# 167.0       2
# 53.0        2
# 228.0       2
# 127.0       2
# 143.0       2
# 270.0       2
# 9.0         1
# 44.0        1
# 123.0       1
# 195.0       1
# 132.0       1
# 137.0       1
# 84.0        1
# 133.0       1
# 239.0       1
# 115.0       1
# 163.0       1
# 4.0         1
# 75.0        1
# Name: power_hp, dtype: int64

# %% [markdown]
# ### Type inceleyelim.

# %%
temp = df["Type"].copy()   # buradan vehicle condition ve fuel_type çıkardık.

# %%
temp.apply(pd.Series)[1]
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: 1, Length: 15919, dtype: object

# %%
data["vehicle_condition"] = temp.apply(pd.Series)[1]

# %%
data["vehicle_condition"].value_counts(dropna=False)  # 2 tane eksik değer var.
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: vehicle_condition, dtype: int64

# %%
data[~data["vehicle_condition"].notna()]
# Out:
#       make model body_type   cc  price   vat      km  registration  prev_owner  power_hp  \
# 2765  Audi    A3    Sedans  2.0  17900  None  115137        2016.0         NaN     110.0
# 5237  Audi    A3    Sedans  1.6  25400  None                   NaN         NaN      85.0
#
#      vehicle_condition
# 2765               NaN
# 5237               NaN

# %%
temp.apply(pd.Series)[3]  # 2 tane veri eksik
# Out:
# 0                          Diesel (Particulate Filter)
# 1                                             Gasoline
# 2                          Diesel (Particulate Filter)
# 3                          Diesel (Particulate Filter)
# 4                          Diesel (Particulate Filter)
#                              ...
# 15914                      Diesel (Particulate Filter)
# 15915    Super 95 / Super Plus 98 (Particulate Filter)
# 15916                                           Diesel
# 15917                                           Diesel
# 15918                                         Super 95
# Name: 3, Length: 15919, dtype: object

# %%
data["fuel_1"] = temp.apply(pd.Series)[3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-45f3c8dfdb10> in <module>
# ----> 1 data["fuel_1"] = temp.apply(pd.Series)[3]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351                     return self._range.index(new_key)
#     352                 except ValueError as err:
# --> 353                     raise KeyError(key) from err
#     354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 3

# %%
data["fuel_1"].value_counts(dropna=False)

# %%
data
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 2         Audi
# 3         Audi
# 4         Audi
# ...        ...
# 15914  Renault
# 15915  Renault
# 15916  Renault
# 15917  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1
# ...       ...
# 15914  Espace
# 15915  Espace
# 15916  Espace
# 15917  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
# ...         ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 2      1.6
# 3      1.4
# 4      1.4
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 2        VAT deductible
# 3                  None
# 4                  None
# ...                 ...
# 15914    VAT deductible
# 15915    VAT deductible
# 15916    VAT deductible
# 15917    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 2      83450
# 3      73000
# 4      16200
# ...      ...
# 15914
# 15915   9900
# 15916     15
# 15917     10
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914           NaN
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner
# 0             2.0
# 1             NaN
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         NaN
# 15915         1.0
# 15916         1.0
# 15917         NaN
# 15918         1.0
#
# [15919 rows x 9 columns]

# %% [markdown]
# ### Previos Owner inceleyelim.

# %%
temp = df["Previous Owners"].copy()   # burada yukarıdaki prev_owner dan farklı olarak 0 olan değerler var. Bunlara göre bu sütunlardan birini düşürüceğiz.

# %%
data["previous_owners"]= temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data["previous_owners"].value_counts(dropna=False)
# Out:
# 1      8294
# NaN    6640
# 2       778
# 0       188
# 3        17
# 4         2
# Name: previous_owners, dtype: int64

# %%
data[data["previous_owners"]=="0"]
# Out:
#           make   model body_type   cc  price             vat     km  registration  prev_owner  \
# 47        Audi      A1    Sedans  1.6  11790            None  60000        2016.0         NaN
# 418       Audi      A1    Sedans  1.6  15900            None  58000        2016.0         NaN
# 586       Audi      A1    Sedans  1.0  13500            None  50707        2016.0         NaN
# 648       Audi      A1    Sedans  1.4  12900            None  64000        2016.0         NaN
# 734       Audi      A1    Sedans  NaN  30000            None      0           NaN         NaN
# ...        ...     ...       ...  ...    ...             ...    ...           ...         ...
# 15301  Renault  Espace       Van  NaN  37290            None                  NaN         NaN
# 15408  Renault  Espace       Van  NaN  24900            None  91883        2016.0         NaN
# 15668  Renault  Espace       Van  NaN  39290            None      0           NaN         NaN
# 15853  Renault  Espace       Van  2.0  43950  VAT deductible    100           NaN         NaN
# 15860  Renault  Espace       Van  2.0  43545  VAT deductible     10           NaN         NaN
#
#        power_hp vehicle_condition previous_owners
# 47         85.0              Used               0
# 418        66.0              Used               0
# 586        70.0              Used               0
# 648        66.0              Used               0
# 734        85.0               New               0
# ...         ...               ...             ...
# 15301     146.0               New               0
# 15408     118.0              Used               0
# 15668     118.0               New               0
# 15853     147.0               New               0
# 15860     150.0               New               0
#
# [188 rows x 12 columns]

# %% [markdown]
# ### Next_Inspection inceleyelim. Eksik veri sayısı % 78 olduğundan dolayı kullanmadık.

# %%
temp = df["Next Inspection"].copy()  # bu sütün silinebilir. Eksik veri sayısı 12384. Ayrıca araba alırken önemli hususlar arasında yok.

# %%
data["Next_Inspection"]= temp.apply(pd.Series)[0].str.extract('(\d{4})')

# %%
data["Next_Inspection"].value_counts(dropna=False)
# Out:
# NaN     12384
# 2021     1601
# 2020      694
# 2022      688
# 2019      438
# 2023       47
# 2018       38
# 2017       13
# 2016        6
# 2001        5
# 1955        1
# 1999        1
# 1921        1
# 2014        1
# 2024        1
# Name: Next_Inspection, dtype: int64

# %%
data.drop("Next_Inspection", axis=1, inplace=True)

# %% [markdown]
# ### Inspection_new inceleyelim.

# %%
temp = df["Inspection new"].copy()     # bu sütün silinebilir veya boş olanları bakılıp bunlar No ile doldurulabilir. Eksik veri sayısı 11987 veya boş olan değerlere No yazılabilir.

# %%
temp.apply(pd.Series)[0].str.extract('(\w+)')
# Out:
#          0
# 0      Yes
# 1      NaN
# 2      NaN
# 3      NaN
# 4      Yes
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  Yes
# 15917  NaN
# 15918  Yes
#
# [15919 rows x 1 columns]

# %%
data["Inspection_new"] = temp.apply(pd.Series)[0].str.extract('(\w+)')

# %%
data["Inspection_new"].value_counts(dropna=False)
# Out:
# NaN    11987
# Yes     3932
# Name: Inspection_new, dtype: int64

# %%
data[~data["Inspection_new"].notna()]
# Out:
#           make   model body_type   cc  price               vat     km  registration  prev_owner  \
# 1         Audi      A1    Sedans  1.8  14500  Price negotiable  80000        2017.0         NaN
# 2         Audi      A1    Sedans  1.6  14640    VAT deductible  83450        2016.0         1.0
# 3         Audi      A1    Sedans  1.4  14500              None  73000        2016.0         1.0
# 5         Audi      A1    Sedans  1.6  15090              None  63668        2016.0         1.0
# 8         Audi      A1    Sedans  1.6  16700              None  57000        2016.0         1.0
# ...        ...     ...       ...  ...    ...               ...    ...           ...         ...
# 15912  Renault  Espace       Van  NaN  39950    VAT deductible                  NaN         NaN
# 15913  Renault  Espace       Van  NaN  39950    VAT deductible   1000        2019.0         NaN
# 15914  Renault  Espace       Van  NaN  39950    VAT deductible                  NaN         NaN
# 15915  Renault  Espace       Van  NaN  39885    VAT deductible   9900        2019.0         1.0
# 15917  Renault  Espace       Van  NaN  39700    VAT deductible     10        2019.0         NaN
#
#        power_hp vehicle_condition previous_owners Inspection_new
# 1         141.0              Used             NaN            NaN
# 2          85.0              Used               1            NaN
# 3          66.0              Used               1            NaN
# 5          85.0              Used               1            NaN
# 8          85.0              Used               1            NaN
# ...         ...               ...             ...            ...
# 15912     147.0               New             NaN            NaN
# 15913     165.0     Demonstration             NaN            NaN
# 15914     147.0               New             NaN            NaN
# 15915     165.0              Used               1            NaN
# 15917     147.0    Pre-registered             NaN            NaN
#
# [11987 rows x 13 columns]

# %% [markdown]
# ### Warranty inceleyelim.

# %%
temp = df["Warranty"].copy()   #11066 eksik veri silinebilir veya boş olanlar için guarantee yok denilebilir.

# %%
temp.apply(pd.Series)[0].str.extract('(\d{1,3})')
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914   24
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
# [15919 rows x 1 columns]

# %%
data["guarante"] = temp.apply(pd.Series)[0].str.extract('(\d{1,3})')

# %%
data["guarante"].value_counts(dropna=False)
# Out:
# NaN    11066
# 12      2594
# 24      1118
# 60       401
# 36       279
# 48       149
# 6        125
# 72        59
# 3         33
# 23        11
# 18        10
# 20         7
# 25         6
# 2          5
# 50         4
# 16         4
# 26         4
# 34         3
# 13         3
# 4          3
# 19         3
# 1          3
# 11         2
# 14         2
# 9          2
# 46         2
# 28         2
# 45         2
# 17         2
# 22         2
# 21         2
# 30         1
# 7          1
# 65         1
# 10         1
# 33         1
# 8          1
# 49         1
# 15         1
# 40         1
# 47         1
# 56         1
# Name: guarante, dtype: int64

# %% [markdown]
# ### Full Service inceleyelim.

# %%
temp = df["Full Service"].copy()   # bunu düşebiliriz. Kullanılacak veri yok.

# %%
temp.apply(pd.Series)[0].str.extract("(\w+)")
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
# [15919 rows x 1 columns]

# %% [markdown]
# ### Non-smoking Vehicle inceleyelim.

# %%
temp = df["Non-smoking Vehicle"].copy()  # düşülebilir. Veri yok.

# %%
temp.apply(pd.Series)[0]
# Out:
# 0         \n
# 1        NaN
# 2        NaN
# 3         \n
# 4         \n
#         ...
# 15914    NaN
# 15915     \n
# 15916     \n
# 15917    NaN
# 15918    NaN
# Name: 0, Length: 15919, dtype: object

# %% [markdown]
# ### Null inceleyelim. İçinde değer olmadığından dolayı düşülecek.

# %% [markdown]
# ### Make inceleyelim. Yukarıda çektiğimiz için düşülecek.

# %% [markdown]
# ### Model inceleyelim. Yukarıda çektiğimiz için düşülecek.

# %% [markdown]
# ### offer_number inceleyelim. Düşülecek. Kullanım yeri olmayan gereksiz bir bilgi.

# %% [markdown]
# ### First Registration inceleyelim. Ancak yukarıda çektiğimiz registration ile aynı veriye sahip olduğundan dolayı duplicate olacak ve bunlardan birinin düşülmesi gerekir.

# %%
temp = df['First Registration'].copy()

# %%
temp.apply(pd.Series)[1].str.extract('(\d{4})')
# Out:
#           0
# 0      2016
# 1      2017
# 2      2016
# 3      2016
# 4      2016
# ...     ...
# 15914   NaN
# 15915  2019
# 15916  2019
# 15917  2019
# 15918  2019
#
# [15919 rows x 1 columns]

# %%
data["first_registration"] = temp.apply(pd.Series)[1].str.extract('(\d{4})')

# %%
data["first_registration"].value_counts(dropna=False)  # 1597 eksik veri var. Yukarıdaki registration ile aynı veriye sahip olduğundan dolayı birini kullanmamız yeterli.
# Out:
# 2018    4522
# 2016    3674
# 2017    3273
# 2019    2853
# NaN     1597
# Name: first_registration, dtype: int64

# %%
data[~data["first_registration"].notna()][["first_registration","registration"]]
# Out:
#       first_registration  \
# 122                  NaN
# 710                  NaN
# 734                  NaN
# 741                  NaN
# 743                  NaN
# ...                  ...
# 15896                NaN
# 15902                NaN
# 15907                NaN
# 15912                NaN
# 15914                NaN
#
#        registration
# 122             NaN
# 710             NaN
# 734             NaN
# 741             NaN
# 743             NaN
# ...             ...
# 15896           NaN
# 15902           NaN
# 15907           NaN
# 15912           NaN
# 15914           NaN
#
# [1597 rows x 2 columns]

# %% [markdown]
# ### Body Color inceleyelim.

# %%
temp = df['Body Color'].copy()

# %%
temp.apply(pd.Series)[1].str.extract('(\w+)')
# Out:
#            0
# 0      Black
# 1        Red
# 2      Black
# 3      Brown
# 4      Black
# ...      ...
# 15914   Grey
# 15915   Grey
# 15916  White
# 15917   Grey
# 15918   Grey
#
# [15919 rows x 1 columns]

# %%
data["body_color"] = temp.apply(pd.Series)[1].str.extract('(\w+)')

# %%
data["body_color"].value_counts(dropna=False)   # 597 eksik veri var. Bunlardan 1000 üzerin olanlar kalabilir diğerlerini other olarak atayabiliriz.
# Out:
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64

# %% [markdown]
# ### Paint Type inceleyelim.

# %%
temp = df['Paint Type'].copy()

# %%
temp.apply(pd.Series)[0].str.extract("(\w+)")
# Out:
#               0
# 0      Metallic
# 1           NaN
# 2      Metallic
# 3      Metallic
# 4      Metallic
# ...         ...
# 15914  Metallic
# 15915  Metallic
# 15916       NaN
# 15917       NaN
# 15918  Metallic
#
# [15919 rows x 1 columns]

# %%
data["paintwork"] = temp.apply(pd.Series)[0].str.extract("(\w+.\w+)")

# %%
data["paintwork"].value_counts(dropna=False)   # 5772 eksik veri var. Bunları metallic olanlar ve olmayanlar diye 2 gruba ayırabiliriz.
# Out:
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paintwork, dtype: int64

# %%
data.head(3)
# Out:
#    make  \
# 0  Audi
# 1  Audi
# 2  Audi
#
#   model  \
# 0    A1
# 1    A1
# 2    A1
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#     cc  \
# 0  1.4
# 1  1.8
# 2  1.6
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#    registration  \
# 0        2016.0
# 1        2017.0
# 2        2016.0
#
#    prev_owner  \
# 0         2.0
# 1         NaN
# 2         1.0
#
#    power_hp  \
# 0      66.0
# 1     141.0
# 2      85.0
#
#   vehicle_condition  \
# 0              Used
# 1              Used
# 2              Used
#
#   previous_owners  \
# 0               2
# 1             NaN
# 2               1
#
#   Inspection_new  \
# 0            Yes
# 1            NaN
# 2            NaN
#
#   body_color  \
# 0      Black
# 1        Red
# 2      Black
#
#   paintwork
# 0  Metallic
# 1       NaN
# 2  Metallic

# %% [markdown]
# ### Body Color Original inceleyelim.

# %%
temp = df['Body Color Original'].copy()   # 3759 eksik veri var. Bu sütunun dolu olanları ile eksik veri olanların fiyata etkisine baktığımız zaman dikkate değer bir fark olduğu görüldü.

# %%
temp.apply(pd.Series)[0].str.extract("(\w+.\w+)")
# Out:
#                             0
# 0               Mythosschwarz
# 1                         NaN
# 2      mythosschwarz metallic
# 3                         NaN
# 4      Mythosschwarz Metallic
# ...                       ...
# 15914            Grigio scuro
# 15915              Stahl-Grau
# 15916             arktis-weiß
# 15917                  Grigio
# 15918           Titanium-Grau
#
# [15919 rows x 1 columns]

# %%
data['body_color_original'] = temp.apply(pd.Series)[0].str.extract("(\w+.\w+)")

# %%
data['body_color_original'].value_counts(dropna=False)
# Out:
# NaN                    3759
# Onyx Schwarz            389
# Bianco                  282
# Argon Silber            273
# Quarz Grau              266
#                        ...
# Scuba Blauw               1
# Blauw metallic            1
# CORTINAWIT                1
# Utopiablau metallic       1
# Cassio-Grau               1
# Name: body_color_original, Length: 1416, dtype: int64

# %%
data[~data['body_color_original'].notna()].groupby(["make","model"])["price"].mean()
# Out:
# make     model
# Audi     A1          16852.407692
#          A3          20820.432028
# Opel     Astra       13327.302966
#          Corsa        9423.137500
#          Insignia    17925.170923
# Renault  Clio        11259.698020
#          Duster      13230.176471
#          Espace      24874.170370
# Name: price, dtype: float64

# %%
data[data['body_color_original'].notna()].groupby(["make","model"])["price"].mean()
# Out:
# make     model
# Audi     A1          19364.395893
#          A2          28200.000000
#          A3          21065.331539
# Opel     Astra       16410.844206
#          Corsa       11495.341576
#          Insignia    22325.579703
# Renault  Clio        12274.836172
#          Espace      32029.769764
# Name: price, dtype: float64

# %% [markdown]
# ### Upholstery inceleyelim.

# %%
temp = df['Upholstery'].copy()

# %%
temp
# Out:
# 0               [\nCloth, Black\n]
# 1                [\nCloth, Grey\n]
# 2               [\nCloth, Black\n]
# 3                              NaN
# 4               [\nCloth, Black\n]
#                    ...
# 15914                          NaN
# 15915                  [\nCloth\n]
# 15916    [\nFull leather, Black\n]
# 15917           [\nPart leather\n]
# 15918    [\nFull leather, Brown\n]
# Name: Upholstery, Length: 15919, dtype: object

# %%
data["upholstery"] = temp.apply(pd.Series)[0].str.split(",", n = 1, expand = True)[0].str.extract("(\w+..\w+)")

# %%
data["upholstery"].value_counts(dropna=False)  # 3720 eksik veri. 

# Alcantara is velvety but non-marking fabric when rubbed. 

# Burada ayrıca cloth, Part leather, Full Leather, Velour, Alcantara ve other dışındakiler color olup bunları interior_color atabiliriz.
# Out:
# Cloth           8423
# NaN             3720
# Part leather    1499
# Full leather    1009
# Black            491
# Other            368
# Grey             273
# Velour            60
# alcantara         57
# Brown             12
# Beige              3
# Blue               2
# White              2
# Name: upholstery, dtype: int64

# %%
data["interior_color"] = temp.apply(pd.Series)[0].str.split(",", n = 1, expand = True)[1].str.extract("(\w+..\w+)")

# %%
data["interior_color"].value_counts(dropna=False)  # 5870 eksik veri var.
# Out:
# Black     7710
# NaN       5870
# Grey      1103
# Other      960
# Brown      195
# Beige       51
# Blue        14
# White       11
# Yellow       4
# Orange       1
# Name: interior_color, dtype: int64

# %% [markdown]
# ### Body inceleyelim. Yukarıda body_type ile duplicate olduğundan dolayı düşülecek.

# %%
temp = df['Body']

# %%
temp.apply(pd.Series)[1] #.str.extract("(\w+.\w+)").value_counts()
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#           ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
# Name: 1, Length: 15919, dtype: object

# %%
data["body"] = temp.apply(pd.Series)[1]

# %%
data["body"].value_counts(dropna=False)  # 60 eksik veri var. Ancak yukarıdaki body_type ile aynı olduğundan dolayı düşülecek.
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body, dtype: int64

# %% [markdown]
# ### Nr. of Doors inceleyelim.

# %%
temp = df['Nr. of Doors'].copy()

# %%
data['door_nr'] = temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data['door_nr'].value_counts(dropna=False)  # 212 eksik veri var.
# Out:
# 5      11575
# 4       3079
# 3        832
# 2        219
# NaN      212
# 1          1
# 7          1
# Name: door_nr, dtype: int64

# %% [markdown]
# ### Nr. of Seats inceleyelim.

# %%
temp = df['Nr. of Seats'].copy()

# %%
data['seat_nr'] = temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data['seat_nr'].value_counts(dropna=False)  # 977 eksik veri var.
# Out:
# 5      13336
# 4       1125
# NaN      977
# 7        362
# 2        116
# 6          2
# 3          1
# Name: seat_nr, dtype: int64

# %% [markdown]
# ### Model Code inceleyelim. Bu eksik verilerin tamamlanmasında kullanılabilir. Bu model kodu olanlarda bilgilerin aynı olması gerekir.

# %%
temp = df['Model Code'].copy()

# %%
data["model_code"] = temp.apply(pd.Series)[0].str.extract("(\S+)")

# %%
data["model_code"].value_counts(dropna=False)   # 10941 eksik veri var.
# Out:
# NaN         10941
# 0035/BCB      268
# 0588/BNO      245
# 0588/BDB      206
# 0588/BHX      188
#             ...
# 0035/BGI        1
# 0588/AZZ        1
# 1844/AEG        1
# 1844/AEN        1
# 0035/AVN        1
# Name: model_code, Length: 233, dtype: int64

# %%
data[data["model_code"].notna()]  #["model_code"] =="0035/BCB"
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 4         Audi
# 7         Audi
# 11        Audi
# ...        ...
# 15907  Renault
# 15910  Renault
# 15911  Renault
# 15915  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 4          A1
# 7          A1
# 11         A1
# ...       ...
# 15907  Espace
# 15910  Espace
# 15911  Espace
# 15915  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 4        Sedans
# 7       Compact
# 11       Sedans
# ...         ...
# 15907       Van
# 15910       Van
# 15911       Van
# 15915       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 4      1.4
# 7      1.4
# 11     1.4
# ...    ...
# 15907  1.8
# 15910  NaN
# 15911  NaN
# 15915  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 4      16790
# 7      14480
# 11     17990
# ...      ...
# 15907  39990
# 15910  39980
# 15911  39980
# 15915  39885
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 4                  None
# 7        VAT deductible
# 11                 None
# ...                 ...
# 15907    VAT deductible
# 15910    VAT deductible
# 15911    VAT deductible
# 15915    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 4      16200
# 7      14986
# 11     26415
# ...      ...
# 15907     50
# 15910   8500
# 15911    100
# 15915   9900
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 4            2016.0
# 7            2016.0
# 11           2016.0
# ...             ...
# 15907           NaN
# 15910        2019.0
# 15911        2019.0
# 15915        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             NaN
# 4             1.0
# 7             1.0
# 11            1.0
# ...           ...
# 15907         NaN
# 15910         1.0
# 15911         1.0
# 15915         1.0
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 4          66.0
# 7          66.0
# 11         92.0
# ...         ...
# 15907     165.0
# 15910     165.0
# 15911     118.0
# 15915     165.0
# 15918     165.0
#
#       vehicle_condition  \
# 0                  Used
# 1                  Used
# 4                  Used
# 7                  Used
# 11                 Used
# ...                 ...
# 15907               New
# 15910     Demonstration
# 15911    Pre-registered
# 15915              Used
# 15918     Demonstration
#
#       previous_owners  \
# 0                   2
# 1                 NaN
# 4                   1
# 7                   1
# 11                  1
# ...               ...
# 15907             NaN
# 15910               1
# 15911               1
# 15915               1
# 15918               1
#
#       Inspection_new  \
# 0                Yes
# 1                NaN
# 4                Yes
# 7                Yes
# 11               Yes
# ...              ...
# 15907            NaN
# 15910            NaN
# 15911            NaN
# 15915            NaN
# 15918            Yes
#
#       body_color  \
# 0          Black
# 1            Red
# 4          Black
# 7            Red
# 11        Silver
# ...          ...
# 15907       Grey
# 15910       Blue
# 15911      White
# 15915       Grey
# 15918       Grey
#
#        paintwork  \
# 0       Metallic
# 1            NaN
# 4       Metallic
# 7       Metallic
# 11     Uni/basic
# ...          ...
# 15907   Metallic
# 15910   Metallic
# 15911   Metallic
# 15915   Metallic
# 15918   Metallic
#
#           body_color_original  \
# 0               Mythosschwarz
# 1                         NaN
# 4      Mythosschwarz Metallic
# 7        Misanorot Perleffekt
# 11     Florettsilber Metallic
# ...                       ...
# 15907    titaniumgraumetallic
# 15910             Kosmos-Blau
# 15911           Perlmutt-Weiß
# 15915              Stahl-Grau
# 15918           Titanium-Grau
#
#          upholstery  \
# 0             Cloth
# 1             Cloth
# 4             Cloth
# 7             Cloth
# 11            Cloth
# ...             ...
# 15907  Full leather
# 15910  Full leather
# 15911  Full leather
# 15915         Cloth
# 15918  Full leather
#
#       interior_color  \
# 0              Black
# 1               Grey
# 4              Black
# 7              Black
# 11             Black
# ...              ...
# 15907            NaN
# 15910          Other
# 15911           Grey
# 15915            NaN
# 15918          Brown
#
#       door_nr  \
# 0           5
# 1           3
# 4           5
# 7           5
# 11          4
# ...       ...
# 15907       5
# 15910       5
# 15911       5
# 15915       5
# 15918       5
#
#       seat_nr  \
# 0           5
# 1           4
# 4           5
# 7           5
# 11        NaN
# ...       ...
# 15907       7
# 15910       5
# 15911       7
# 15915       5
# 15918       5
#
#       model_code
# 0       0588/BDF
# 1       0588/BCY
# 4       0588/BDF
# 7       0588/BDF
# 11      0588/BDC
# ...          ...
# 15907   3333/BHJ
# 15910   3333/BHJ
# 15911   3333/BDQ
# 15915   0000/000
# 15918   3333/BHJ
#
# [4978 rows x 21 columns]

# %%
df2[df2["model_code"] =="0035/BCB"
# Out:
#   File "<ipython-input-107-f29486aa047c>", line 1
#     df2[df2["model_code"] =="0035/BCB"
#                                       ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Gearing Type inceleyelim.

# %%
temp = df['Gearing Type'].copy()

# %%
data["gear"] = temp.apply(pd.Series)[1]

# %%
data["gear"].value_counts(dropna=False)   # veri tam.
# Out:
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gear, dtype: int64

# %% [markdown]
# ### Displacement inceleyelim. Bu husus araba fiyatına etki eden bir husus olmadığından dolayı düşülebilir.

# %%
temp = df["Displacement"].copy()

# %%
data["displacement"] = temp.apply(pd.Series)[0].str.extract("(\d+.\d+)")

# %%
data["displacement"].value_counts(dropna=False)  # 535 eksik veri var. Ancak bazı düzeltilmesi gereken veriler var.
# Out:
# 1,598     4761
# 999       2438
# 1,398     1314
# 1,399      749
# 1,229      677
# 1,956      670
# 1,461      595
# 1,490      559
# NaN        535
# 1,422      467
# 1,197      353
# 898        351
# 1,395      320
# 1,968      301
# 1,149      288
# 1,618      212
# 1,798      210
# 1,498      196
# 1,600      130
# 1,248      110
# 1,997      103
# 1,364      102
# 1,400       90
# 998         72
# 1,500       50
# 2,000       46
# 1,000       40
# 1,998       25
# 2,480       20
# 1,984       18
# 1,200       18
# 899         11
# 1,397       11
# 160          6
# 929          5
# 1,499        5
# 1,596        4
# 139          4
# 900          4
# 997          4
# 1,396        3
# 1,199        3
# 1,599        3
# 1,589        2
# 995          2
# 1,495        2
# 1,300        2
# 16,000       1
# 140          1
# 1,390        1
# 1,369        1
# 1,584        1
# 1,100        1
# 973          1
# 996          1
# 1,533        1
# 890          1
# 1,568        1
# 1,580        1
# 1,350        1
# 1,368        1
# 1,696        1
# 1,856        1
# 1,195        1
# 122          1
# 1,800        1
# 1,496        1
# 1,896        1
# 1,198        1
# 1,995        1
# 1,686        1
# 1,239        1
# 2,967        1
# 1,333        1
# 15,898       1
# Name: displacement, dtype: int64

# %%
data
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 2         Audi
# 3         Audi
# 4         Audi
# ...        ...
# 15914  Renault
# 15915  Renault
# 15916  Renault
# 15917  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1
# ...       ...
# 15914  Espace
# 15915  Espace
# 15916  Espace
# 15917  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
# ...         ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 2      1.6
# 3      1.4
# 4      1.4
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 2        VAT deductible
# 3                  None
# 4                  None
# ...                 ...
# 15914    VAT deductible
# 15915    VAT deductible
# 15916    VAT deductible
# 15917    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 2      83450
# 3      73000
# 4      16200
# ...      ...
# 15914
# 15915   9900
# 15916     15
# 15917     10
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914           NaN
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             NaN
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         NaN
# 15915         1.0
# 15916         1.0
# 15917         NaN
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 2          85.0
# 3          66.0
# 4          66.0
# ...         ...
# 15914     147.0
# 15915     165.0
# 15916     146.0
# 15917     147.0
# 15918     165.0
#
#       vehicle_condition  \
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
# ...                 ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
#
#       previous_owners  \
# 0                   2
# 1                 NaN
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 15914             NaN
# 15915               1
# 15916               1
# 15917             NaN
# 15918               1
#
#       Inspection_new  \
# 0                Yes
# 1                NaN
# 2                NaN
# 3                NaN
# 4                Yes
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916            Yes
# 15917            NaN
# 15918            Yes
#
#       body_color  \
# 0          Black
# 1            Red
# 2          Black
# 3          Brown
# 4          Black
# ...          ...
# 15914       Grey
# 15915       Grey
# 15916      White
# 15917       Grey
# 15918       Grey
#
#       paintwork  \
# 0      Metallic
# 1           NaN
# 2      Metallic
# 3      Metallic
# 4      Metallic
# ...         ...
# 15914  Metallic
# 15915  Metallic
# 15916       NaN
# 15917       NaN
# 15918  Metallic
#
#           body_color_original  \
# 0               Mythosschwarz
# 1                         NaN
# 2      mythosschwarz metallic
# 3                         NaN
# 4      Mythosschwarz Metallic
# ...                       ...
# 15914            Grigio scuro
# 15915              Stahl-Grau
# 15916             arktis-weiß
# 15917                  Grigio
# 15918           Titanium-Grau
#
#          upholstery  \
# 0             Cloth
# 1             Cloth
# 2             Cloth
# 3               NaN
# 4             Cloth
# ...             ...
# 15914           NaN
# 15915         Cloth
# 15916  Full leather
# 15917  Part leather
# 15918  Full leather
#
#       interior_color  \
# 0              Black
# 1               Grey
# 2              Black
# 3                NaN
# 4              Black
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916          Black
# 15917            NaN
# 15918          Brown
#
#       door_nr  \
# 0           5
# 1           3
# 2           4
# 3           3
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       5
# 15917       5
# 15918       5
#
#       seat_nr  \
# 0           5
# 1           4
# 2           4
# 3           4
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       7
# 15917       7
# 15918       5
#
#       model_code  \
# 0       0588/BDF
# 1       0588/BCY
# 2            NaN
# 3            NaN
# 4       0588/BDF
# ...          ...
# 15914        NaN
# 15915   0000/000
# 15916        NaN
# 15917        NaN
# 15918   3333/BHJ
#
#             gear  \
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# ...          ...
# 15914  Automatic
# 15915  Automatic
# 15916  Automatic
# 15917  Automatic
# 15918  Automatic
#
#       displacement
# 0            1,422
# 1            1,798
# 2            1,598
# 3            1,422
# 4            1,422
# ...            ...
# 15914        1,997
# 15915        1,798
# 15916        1,997
# 15917        1,997
# 15918        1,798
#
# [15919 rows x 23 columns]

# %% [markdown]
# ### Cylinders inceleyelim.

# %%
temp = df['Cylinders'].copy()

# %%
data['cylinders'] = temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data['cylinders'].value_counts(dropna=False)   # 5680 eksik veri var. Bu sütun silinecek ancak eksik veri doldururken kullanılabilir.
# Out:
# 4      8105
# NaN    5680
# 3      2104
# 5        22
# 6         3
# 8         2
# 2         2
# 1         1
# Name: cylinders, dtype: int64

# %% [markdown]
# ### Weight inceleyelim.

# %%
temp = df['Weight'].copy()

# %%
data['weight'] = temp.apply(pd.Series)[0].str.extract("(\d+.\d+)")

# %%
data['weight'].value_counts(dropna=False)   # 6976 eksik veri var. Bu sütun silinecek ancak eksik veri doldururken kullanılabilir.
# Out:
# NaN      6976
# 1,163     574
# 1,360     356
# 1,165     301
# 1,335     242
#          ...
# 1,277       1
# 1,589       1
# 1,252       1
# 1,891       1
# 1,598       1
# Name: weight, Length: 434, dtype: int64

# %% [markdown]
# ### Drive chain inceleyelim.

# %%
temp = df['Drive chain'].copy()

# %%
temp
# Out:
# 0        [\nfront\n]
# 1        [\nfront\n]
# 2        [\nfront\n]
# 3                NaN
# 4        [\nfront\n]
#             ...
# 15914    [\nfront\n]
# 15915    [\nfront\n]
# 15916    [\nfront\n]
# 15917    [\nfront\n]
# 15918      [\n4WD\n]
# Name: Drive chain, Length: 15919, dtype: object

# %%
data["drive_chain"] = temp.apply(pd.Series)[0].str.extract("(\S+)")

# %%
data["drive_chain"].value_counts(dropna=False)  # 6858 eksik veri var. Bu sütun silinecek ancak eksik veri doldururken kullanılabilir.
# Out:
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64

# %% [markdown]
# ### Fuel inceleyelim. Ancak bu veri yukarıdaki yukarıdan vehicle_condition dan elde edilen fuel_1 ile aynı olabilir. Bu durumda duplicate olacağından dolayı silinecek.

# %%
temp = df["Fuel"].copy()  # eksik veri yok. Ancak buradaki veriyi iki gruba ayıracağız. Bunun için func. yazalım.

# %%
data["fuel"] = temp.apply(pd.Series)[1].str.extract("(\w+)")

# %%
data["fuel"].value_counts(dropna=False)
# Out:
# Diesel      7299
# Super       4790
# Gasoline    3252
# Regular      503
# CNG           36
# LPG           16
# Liquid        10
# Others         6
# Electric       5
# Biogas         1
# Domestic       1
# Name: fuel, dtype: int64

# %%
benzine = ["Gasoline","Super","Super 95","Regular", "Super E10 95","Super Plus 98","Super Plus E10 98","Others"]

lpg = ["LPG","Liquid petroleum gas","CNG","Biogas","Domestic gas H"]


def fueltype(x):
    if x in benzine:
        return "benzine"
    elif x in lpg:
        return "LPG/CNG"
    else :
        return x

data["fuel"] = data.fuel.apply(fueltype)

data["fuel"]
# Out:
# 0         Diesel
# 1        benzine
# 2         Diesel
# 3         Diesel
# 4         Diesel
#           ...
# 15914     Diesel
# 15915    benzine
# 15916     Diesel
# 15917     Diesel
# 15918    benzine
# Name: fuel, Length: 15919, dtype: object

# %%
data["fuel"].value_counts(dropna=False)
# Out:
# benzine     8551
# Diesel      7299
# LPG/CNG       53
# Liquid        10
# Electric       5
# Domestic       1
# Name: fuel, dtype: int64

# %%
# df["Fuel"] = df["Fuel"].str[1].str.split("/").str[0].str.strip()

# df["Fuel"] = df.Fuel.str.split("(").str[0].str.strip()

# %% [markdown]
# ### Consumption inceleyelim. Burada nester list yapısı söz konusu olduğundan önce tüm sütunu bir dataframe atıyoruz. Sütunları yeniden isimlendiriyoruz. Sonra her bir sütunun satırlarındaki list içinden değerleri çıkarıyoruz. Ancak verinin içinde 850 satırda bir kayma durumu söz konusu olduğunu görüyoruz. Bunlar ile ilgili düzeltmeyi yaptıktan sonra ihtiyacımız olan consumption değerlerini çıkararak ortak, city ve country olarak 3 tane sütun elde ediyoruz.

# %%
df['Consumption'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                   1906
# [[3.9 l/100 km (comb)], [4.1 l/100 km (city)], [3.7 l/100 km (country)]]               304
# [[4.2 l/100 km (comb)], [5 l/100 km (city)], [3.7 l/100 km (country)]]                 276
# [[5.4 l/100 km (comb)], [6.8 l/100 km (city)], [4.5 l/100 km (country)]]               257
# [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]               253
#                                                                                       ...
# [[3.1 l/100 km (comb)], [], [3.5 l/100 km (country)]]                                    1
# [[5.2 l/100 km (comb)], [6 l/100 km (city)], [4.8 l/100 km (country)]]                   1
# [[5.3 l/100 km (comb)], [6 l/100 km (city)], [5 l/100 km (country)]]                     1
# [\n, 6.5 l/100 km (comb), \n, 8.1 l/100 km (city), \n, 5.5 l/100 km (country), \n]       1
# [[50 l/100 km (comb)], [64 l/100 km (city)], [42 l/100 km (country)]]                    1
# Name: Consumption, Length: 882, dtype: int64

# %%
temp = df['Consumption'].copy()

# %%
df3 = temp.apply(pd.Series)

# %%
df3
# Out:
#                            0                      1                         2  \
# 0      [3.8 l/100 km (comb)]  [4.3 l/100 km (city)]  [3.5 l/100 km (country)]
# 1      [5.6 l/100 km (comb)]  [7.1 l/100 km (city)]  [4.7 l/100 km (country)]
# 2      [3.8 l/100 km (comb)]  [4.4 l/100 km (city)]  [3.4 l/100 km (country)]
# 3      [3.8 l/100 km (comb)]  [4.3 l/100 km (city)]  [3.5 l/100 km (country)]
# 4      [4.1 l/100 km (comb)]  [4.6 l/100 km (city)]  [3.8 l/100 km (country)]
# ...                      ...                    ...                       ...
# 15914  [5.3 l/100 km (comb)]  [6.2 l/100 km (city)]  [4.7 l/100 km (country)]
# 15915                     \n    7.4 l/100 km (comb)                        \n
# 15916  [5.3 l/100 km (comb)]  [6.2 l/100 km (city)]  [4.7 l/100 km (country)]
# 15917  [5.3 l/100 km (comb)]  [6.2 l/100 km (city)]  [4.7 l/100 km (country)]
# 15918  [6.8 l/100 km (comb)]  [8.7 l/100 km (city)]  [5.7 l/100 km (country)]
#
#                          3    4                       5    6
# 0                      NaN  NaN                     NaN  NaN
# 1                      NaN  NaN                     NaN  NaN
# 2                      NaN  NaN                     NaN  NaN
# 3                      NaN  NaN                     NaN  NaN
# 4                      NaN  NaN                     NaN  NaN
# ...                    ...  ...                     ...  ...
# 15914                  NaN  NaN                     NaN  NaN
# 15915  9.2 l/100 km (city)   \n  6.3 l/100 km (country)   \n
# 15916                  NaN  NaN                     NaN  NaN
# 15917                  NaN  NaN                     NaN  NaN
# 15918                  NaN  NaN                     NaN  NaN
#
# [15919 rows x 7 columns]

# %%
df3.rename(columns={0:"comb",1:"city",2:"country",3:"ccity",4:"free",5:"ccountry",6:"free2"}, inplace=True)

# %%
df3.comb = df3.comb.apply(pd.Series)

# %%
df3.city = df3.city.apply(pd.Series)

# %%
df3.country = df3.country.apply(pd.Series)

# %%
df3.ccity = df3.ccity.apply(pd.Series)

# %%
df3.ccountry = df3.ccountry.apply(pd.Series)

# %%
df3 = df3.replace("\n", np.nan)

# %%
df3
# Out:
#                       comb                 city                 country                ccity  \
# 0      3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)                  NaN
# 1      5.6 l/100 km (comb)  7.1 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 2      3.8 l/100 km (comb)  4.4 l/100 km (city)  3.4 l/100 km (country)                  NaN
# 3      3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)                  NaN
# 4      4.1 l/100 km (comb)  4.6 l/100 km (city)  3.8 l/100 km (country)                  NaN
# ...                    ...                  ...                     ...                  ...
# 15914  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15915                  NaN  7.4 l/100 km (comb)                     NaN  9.2 l/100 km (city)
# 15916  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15917  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15918  6.8 l/100 km (comb)  8.7 l/100 km (city)  5.7 l/100 km (country)                  NaN
#
#        free                ccountry  free2
# 0       NaN                     NaN    NaN
# 1       NaN                     NaN    NaN
# 2       NaN                     NaN    NaN
# 3       NaN                     NaN    NaN
# 4       NaN                     NaN    NaN
# ...     ...                     ...    ...
# 15914   NaN                     NaN    NaN
# 15915   NaN  6.3 l/100 km (country)    NaN
# 15916   NaN                     NaN    NaN
# 15917   NaN                     NaN    NaN
# 15918   NaN                     NaN    NaN
#
# [15919 rows x 7 columns]

# %%
df3.comb.fillna(df3.city, inplace=True)

# %%
df3
# Out:
#                       comb                 city                 country                ccity  \
# 0      3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)                  NaN
# 1      5.6 l/100 km (comb)  7.1 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 2      3.8 l/100 km (comb)  4.4 l/100 km (city)  3.4 l/100 km (country)                  NaN
# 3      3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)                  NaN
# 4      4.1 l/100 km (comb)  4.6 l/100 km (city)  3.8 l/100 km (country)                  NaN
# ...                    ...                  ...                     ...                  ...
# 15914  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15915  7.4 l/100 km (comb)  7.4 l/100 km (comb)                     NaN  9.2 l/100 km (city)
# 15916  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15917  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15918  6.8 l/100 km (comb)  8.7 l/100 km (city)  5.7 l/100 km (country)                  NaN
#
#        free                ccountry  free2
# 0       NaN                     NaN    NaN
# 1       NaN                     NaN    NaN
# 2       NaN                     NaN    NaN
# 3       NaN                     NaN    NaN
# 4       NaN                     NaN    NaN
# ...     ...                     ...    ...
# 15914   NaN                     NaN    NaN
# 15915   NaN  6.3 l/100 km (country)    NaN
# 15916   NaN                     NaN    NaN
# 15917   NaN                     NaN    NaN
# 15918   NaN                     NaN    NaN
#
# [15919 rows x 7 columns]

# %%
df3.country.fillna(df3.ccountry, inplace=True)

# %%
df3.city = np.where(df3.city.str.contains("comb"), df3.ccity, df3.city)

# %%
df3
# Out:
#                       comb                 city                 country                ccity  \
# 0      3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)                  NaN
# 1      5.6 l/100 km (comb)  7.1 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 2      3.8 l/100 km (comb)  4.4 l/100 km (city)  3.4 l/100 km (country)                  NaN
# 3      3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)                  NaN
# 4      4.1 l/100 km (comb)  4.6 l/100 km (city)  3.8 l/100 km (country)                  NaN
# ...                    ...                  ...                     ...                  ...
# 15914  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15915  7.4 l/100 km (comb)  9.2 l/100 km (city)  6.3 l/100 km (country)  9.2 l/100 km (city)
# 15916  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15917  5.3 l/100 km (comb)  6.2 l/100 km (city)  4.7 l/100 km (country)                  NaN
# 15918  6.8 l/100 km (comb)  8.7 l/100 km (city)  5.7 l/100 km (country)                  NaN
#
#        free                ccountry  free2
# 0       NaN                     NaN    NaN
# 1       NaN                     NaN    NaN
# 2       NaN                     NaN    NaN
# 3       NaN                     NaN    NaN
# 4       NaN                     NaN    NaN
# ...     ...                     ...    ...
# 15914   NaN                     NaN    NaN
# 15915   NaN  6.3 l/100 km (country)    NaN
# 15916   NaN                     NaN    NaN
# 15917   NaN                     NaN    NaN
# 15918   NaN                     NaN    NaN
#
# [15919 rows x 7 columns]

# %%
data["consumption_comb"] = df3.comb.str.extract("(\d\d|\d.\d|\d)")

# %%
data["consumption_city"] = df3.city.str.extract("(\d\d|\d.\d|\d)")

# %%
data["consumption_country"] = df3.country.str.extract("(\d\d|\d.\d|\d)")

# %%
data["consumption_comb"].value_counts(dropna=False)
# Out:
# NaN    1925
# 5.4     770
# 3.9     733
# 4       714
# 5.1     657
# 4.4     623
# 5.6     618
# 4.7     602
# 3.8     585
# 5       551
# 4.8     546
# 4.5     526
# 5.2     455
# 4.6     445
# 4.2     435
# 4.9     393
# 5.3     380
# 5.5     380
# 5.9     369
# 3.7     369
# 5.7     342
# 4.1     342
# 6       331
# 3.3     326
# 4.3     307
# 3.5     307
# 6.2     216
# 3.6     194
# 6.3     181
# 6.1     175
# 5.8     164
# 6.6     148
# 3.4     143
# 6.8     136
# 6.4      75
# 3        69
# 7.4      66
# 6.7      45
# 6.5      43
# 7.1      39
# 10       34
# 6.9      27
# 3.2      25
# 8.3      20
# 7.6      14
# 7        10
# 3.1       7
# 7.8       6
# 7.2       6
# 8         5
# 51        4
# 8.6       4
# 7.9       3
# 8.7       3
# 1.6       3
# 7.3       2
# 0         2
# 38        2
# 8.1       2
# 40        2
# 9.1       1
# 7.5       1
# 54        1
# 1.2       1
# 32        1
# 55        1
# 43        1
# 46        1
# 50        1
# 11        1
# 1         1
# 13        1
# 33        1
# Name: consumption_comb, dtype: int64

# %%
data
# Out:
#           make   model body_type   cc  price               vat     km  registration  prev_owner  \
# 0         Audi      A1    Sedans  1.4  15770    VAT deductible  56013        2016.0         2.0
# 1         Audi      A1    Sedans  1.8  14500  Price negotiable  80000        2017.0         NaN
# 2         Audi      A1    Sedans  1.6  14640    VAT deductible  83450        2016.0         1.0
# 3         Audi      A1    Sedans  1.4  14500              None  73000        2016.0         1.0
# 4         Audi      A1    Sedans  1.4  16790              None  16200        2016.0         1.0
# ...        ...     ...       ...  ...    ...               ...    ...           ...         ...
# 15914  Renault  Espace       Van  NaN  39950    VAT deductible                  NaN         NaN
# 15915  Renault  Espace       Van  NaN  39885    VAT deductible   9900        2019.0         1.0
# 15916  Renault  Espace       Van  NaN  39875    VAT deductible     15        2019.0         1.0
# 15917  Renault  Espace       Van  NaN  39700    VAT deductible     10        2019.0         NaN
# 15918  Renault  Espace       Van  NaN  40999    VAT deductible               2019.0         1.0
#
#        power_hp vehicle_condition previous_owners Inspection_new body_color paintwork  \
# 0          66.0              Used               2            Yes      Black  Metallic
# 1         141.0              Used             NaN            NaN        Red       NaN
# 2          85.0              Used               1            NaN      Black  Metallic
# 3          66.0              Used               1            NaN      Brown  Metallic
# 4          66.0              Used               1            Yes      Black  Metallic
# ...         ...               ...             ...            ...        ...       ...
# 15914     147.0               New             NaN            NaN       Grey  Metallic
# 15915     165.0              Used               1            NaN       Grey  Metallic
# 15916     146.0    Pre-registered               1            Yes      White       NaN
# 15917     147.0    Pre-registered             NaN            NaN       Grey       NaN
# 15918     165.0     Demonstration               1            Yes       Grey  Metallic
#
#           body_color_original    upholstery interior_color door_nr seat_nr model_code       gear  \
# 0               Mythosschwarz         Cloth          Black       5       5   0588/BDF  Automatic
# 1                         NaN         Cloth           Grey       3       4   0588/BCY  Automatic
# 2      mythosschwarz metallic         Cloth          Black       4       4        NaN  Automatic
# 3                         NaN           NaN            NaN       3       4        NaN  Automatic
# 4      Mythosschwarz Metallic         Cloth          Black       5       5   0588/BDF  Automatic
# ...                       ...           ...            ...     ...     ...        ...        ...
# 15914            Grigio scuro           NaN            NaN       5       5        NaN  Automatic
# 15915              Stahl-Grau         Cloth            NaN       5       5   0000/000  Automatic
# 15916             arktis-weiß  Full leather          Black       5       7        NaN  Automatic
# 15917                  Grigio  Part leather            NaN       5       7        NaN  Automatic
# 15918           Titanium-Grau  Full leather          Brown       5       5   3333/BHJ  Automatic
#
#       displacement cylinders weight     fuel consumption_comb consumption_city  \
# 0            1,422         3  1,220   Diesel              NaN              4.3
# 1            1,798         4  1,255  benzine              NaN              7.1
# 2            1,598       NaN    NaN   Diesel              NaN              4.4
# 3            1,422         3  1,195   Diesel              NaN              4.3
# 4            1,422         3    NaN   Diesel              NaN              4.6
# ...            ...       ...    ...      ...              ...              ...
# 15914        1,997         4  1,758   Diesel              NaN              6.2
# 15915        1,798         4  1,708  benzine              7.4              9.2
# 15916        1,997         4    NaN   Diesel              NaN              6.2
# 15917        1,997         4  1,758   Diesel              NaN              6.2
# 15918        1,798         4  1,685  benzine              NaN              8.7
#
#       consumption_country CO2_emission emission_class  \
# 0                     3.5           99         Euro 6
# 1                     4.7          129         Euro 6
# 2                     3.4           99         Euro 6
# 3                     3.5           99         Euro 6
# 4                     3.8          109         Euro 6
# ...                   ...          ...            ...
# 15914                 4.7          139            NaN
# 15915                 6.3          168            NaN
# 15916                 4.7          139   Euro 6d-TEMP
# 15917                 4.7          139         Euro 6
# 15918                 5.7          153         Euro 6
#
#                                                                                        comfort_convenience  \
# 0      Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill H...
# 1      Air conditioning,Automatic climate control,Hill Holder,Leather steering wheel,Lumbar support,Par...
# 2      Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Multi...
# 3      Air suspension,Armrest,Auxiliary heating,Electrical side mirrors,Heads-up display,Hill Holder,Le...
# 4      Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Leather s...
# ...                                                                                                    ...
# 15914  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
# 15915  Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electri...
# 15916  Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically heated windshield...
# 15917  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
# 15918  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
#
#                                                                                entertainment  \
# 0                                     Bluetooth,Hands-free equipment,On-board computer,Radio
# 1                        Bluetooth,Hands-free equipment,On-board computer,Radio,Sound system
# 2                                                                      MP3,On-board computer
# 3      Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB
# 4                   Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB
# ...                                                                                      ...
# 15914               Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,USB
# 15915                                 Bluetooth,Digital radio,Hands-free equipment,Radio,USB
# 15916                                 Bluetooth,Hands-free equipment,On-board computer,Radio
# 15917                                                      Bluetooth,Digital radio,Radio,USB
# 15918                                                                                    USB
#
#                                                           Extras  \
# 0                 Alloy wheels,Catalytic Converter,Voice Control
# 1        Alloy wheels,Sport seats,Sport suspension,Voice Control
# 2                                     Alloy wheels,Voice Control
# 3                         Alloy wheels,Sport seats,Voice Control
# 4      Alloy wheels,Sport package,Sport suspension,Voice Control
# ...                                                          ...
# 15914                                  Alloy wheels,Touch screen
# 15915                    Alloy wheels,Touch screen,Voice Control
# 15916                                               Alloy wheels
# 15917                                  Alloy wheels,Touch screen
# 15918                                  Alloy wheels,Touch screen
#
#                                                                                            safety_security
# 0      ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog...
# 1      ABS,Central door lock,Central door lock with remote control,Daytime running lights,Driver-side a...
# 2      ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Imm...
# 3      ABS,Alarm system,Central door lock with remote control,Driver drowsiness detection,Driver-side a...
# 4      ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Iso...
# ...                                                                                                    ...
# 15914  ABS,Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stabil...
# 15915  ABS,Adaptive Cruise Control,Blind spot monitor,Central door lock,Daytime running lights,Driver-s...
# 15916  ABS,Adaptive Cruise Control,Blind spot monitor,Central door lock,Daytime running lights,Driver-s...
# 15917  ABS,Blind spot monitor,Driver-side airbag,Electronic stability control,Emergency brake assistant...
# 15918  ABS,Blind spot monitor,Daytime running lights,Driver-side airbag,Electronic stability control,Em...
#
# [15919 rows x 35 columns]

# %%
data["consumption_country"].value_counts(dropna=False)
# Out:
# NaN    2376
# 4.2    1178
# 3.7    1089
# 4.4     898
# 4.5     848
# 3.8     802
# 3.9     777
# 4.7     615
# 4.1     592
# 4       589
# 3.5     525
# 4.3     520
# 4.6     516
# 3.6     486
# 4.9     481
# 3.1     481
# 3.3     457
# 3.4     353
# 4.8     341
# 5.3     278
# 5.4     239
# 5.1     232
# 5.7     204
# 3.2     180
# 5.6     154
# 3       142
# 5       130
# 5.2     117
# 6.3      52
# 6        42
# 5.5      36
# 10       33
# 5.8      30
# 7.7      20
# 6.6      19
# 2.9      16
# 6.4      15
# 2.8       9
# 0         9
# 7.3       4
# 6.5       4
# 44        4
# 7.1       3
# 7         3
# 7.8       2
# 35        2
# 37        2
# 6.9       2
# 6.7       2
# 5.9       2
# 6.1       2
# 1         1
# 2         1
# 8.6       1
# 42        1
# 8         1
# 7.6       1
# Name: consumption_country, dtype: int64

# %% [markdown]
# ### CO2 Emission inceleyelim.

# %%
temp = df['CO2 Emission'].copy()   # 2436 eksik değer var.

# %%
data["CO2_emission"] = temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data["CO2_emission"].value_counts(dropna=False)
# Out:
# NaN    2436
# 120     740
# 99      545
# 97      537
# 104     501
#        ...
# 990       1
# 183       1
# 13        1
# 180       1
# 177       1
# Name: CO2_emission, Length: 120, dtype: int64

# %% [markdown]
# ### Emission Class inceleyelim.

# %%
temp = df['Emission Class'].copy()

# %%
data["emission_class"] = temp.apply(pd.Series)[0].str.extract("(\w.+)")

# %%
data["emission_class"].value_counts(dropna=False)   # 3628 eksik değer var.
# Out:
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64

# %% [markdown]
# ### Comfort & Convenience inceleyelim. Bu feature ile ilgili olarak araçlarda burada geçen özelliklerin olup olmadığına göre sütunlar oluşturacağız.

# %%
df['\nComfort & Convenience\n'] = [",".join(item) if type(item)==list else item for item in df['\nComfort & Convenience\n']]

data["comfort_convenience"] = df['\nComfort & Convenience\n'].str.extract("(\w.+)").copy()  # 920 eksik veri var.

# %%
data["comfort_convenience"].str.get_dummies(sep=",")
# Out:
#        Air conditioning  \
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 15914                 1
# 15915                 1
# 15916                 1
# 15917                 1
# 15918                 1
#
#        Air suspension  \
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
# ...               ...
# 15914               0
# 15915               0
# 15916               0
# 15917               0
# 15918               0
#
#        Armrest  \
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ...        ...
# 15914        0
# 15915        0
# 15916        1
# 15917        0
# 15918        0
#
#        Automatic climate control  \
# 0                              1
# 1                              1
# 2                              0
# 3                              0
# 4                              1
# ...                          ...
# 15914                          1
# 15915                          1
# 15916                          1
# 15917                          1
# 15918                          1
#
#        Auxiliary heating  \
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  0
# 15916                  0
# 15917                  0
# 15918                  0
#
#        Cruise control  \
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   0
# ...               ...
# 15914               1
# 15915               1
# 15916               1
# 15917               1
# 15918               1
#
#        Electric Starter  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Electric tailgate  \
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  1
# 15916                  1
# 15917                  0
# 15918                  1
#
#        Electrical side mirrors  \
# 0                            1
# 1                            0
# 2                            1
# 3                            1
# 4                            1
# ...                        ...
# 15914                        1
# 15915                        1
# 15916                        1
# 15917                        1
# 15918                        1
#
#        Electrically adjustable seats  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              1
# 15915                              0
# 15916                              0
# 15917                              1
# 15918                              1
#
#        Electrically heated windshield  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              0
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Heads-up display  \
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 1
# 15916                 1
# 15917                 0
# 15918                 0
#
#        Heated steering wheel  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 15914                      0
# 15915                      1
# 15916                      1
# 15917                      0
# 15918                      0
#
#        Hill Holder  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            0
# 15917            0
# 15918            1
#
#        Keyless central door lock  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 15914                          1
# 15915                          1
# 15916                          0
# 15917                          0
# 15918                          0
#
#        Leather seats  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Leather steering wheel  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 15914                       1
# 15915                       1
# 15916                       1
# 15917                       1
# 15918                       1
#
#        Light sensor  \
# 0                 1
# 1                 0
# 2                 0
# 3                 1
# 4                 1
# ...             ...
# 15914             1
# 15915             1
# 15916             1
# 15917             1
# 15918             0
#
#        Lumbar support  \
# 0                   0
# 1                   1
# 2                   0
# 3                   1
# 4                   0
# ...               ...
# 15914               0
# 15915               1
# 15916               0
# 15917               0
# 15918               0
#
#        Massage seats  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              1
# 15915              0
# 15916              1
# 15917              0
# 15918              0
#
#        Multi-function steering wheel  \
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...
# 15914                              1
# 15915                              0
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Navigation system  \
# 0                      1
# 1                      0
# 2                      1
# 3                      1
# 4                      0
# ...                  ...
# 15914                  1
# 15915                  1
# 15916                  1
# 15917                  0
# 15918                  1
#
#        Panorama roof  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              1
# 15917              0
# 15918              0
#
#        Park Distance Control  \
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          1
# ...                      ...
# 15914                      1
# 15915                      1
# 15916                      1
# 15917                      1
# 15918                      0
#
#        Parking assist system camera  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 15914                             0
# 15915                             1
# 15916                             1
# 15917                             0
# 15918                             0
#
#        Parking assist system self-steering  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              0
# 15915                              1
# 15916                              0
# 15917                              0
# 15918                              0
#
#        Parking assist system sensors front  \
# 0                                  0
# 1                                  0
# 2                                  1
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              1
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Parking assist system sensors rear  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  0
# 4                                  1
# ...                              ...
# 15914                              1
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Power windows  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 15914              1
# 15915              1
# 15916              1
# 15917              1
# 15918              1
#
#        Rain sensor  \
# 0                1
# 1                0
# 2                0
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            1
# 15917            0
# 15918            0
#
#        Seat heating  \
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0
# ...             ...
# 15914             0
# 15915             1
# 15916             1
# 15917             0
# 15918             1
#
#        Seat ventilation  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 1
# 15917                 0
# 15918                 0
#
#        Split rear seats  \
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0
# ...                 ...
# 15914                 1
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Start-stop system  \
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 15914                  1
# 15915                  0
# 15916                  0
# 15917                  1
# 15918                  0
#
#        Sunroof  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 15914        0
# 15915        1
# 15916        1
# 15917        0
# 15918        0
#
#        Tinted windows  \
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 15914               1
# 15915               0
# 15916               0
# 15917               0
# 15918               0
#
#        Wind deflector  \
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 15914               0
# 15915               0
# 15916               0
# 15917               0
# 15918               0
#
#        Windshield
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 15914           0
# 15915           0
# 15916           0
# 15917           0
# 15918           0
#
# [15919 rows x 38 columns]

# %%
comfort = data["comfort_convenience"].str.get_dummies(sep=",")

# %%
data.join(comfort)  # bunu en son çalıştıralım.
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 2         Audi
# 3         Audi
# 4         Audi
# ...        ...
# 15914  Renault
# 15915  Renault
# 15916  Renault
# 15917  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1
# ...       ...
# 15914  Espace
# 15915  Espace
# 15916  Espace
# 15917  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
# ...         ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 2      1.6
# 3      1.4
# 4      1.4
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 2        VAT deductible
# 3                  None
# 4                  None
# ...                 ...
# 15914    VAT deductible
# 15915    VAT deductible
# 15916    VAT deductible
# 15917    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 2      83450
# 3      73000
# 4      16200
# ...      ...
# 15914
# 15915   9900
# 15916     15
# 15917     10
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914           NaN
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             NaN
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         NaN
# 15915         1.0
# 15916         1.0
# 15917         NaN
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 2          85.0
# 3          66.0
# 4          66.0
# ...         ...
# 15914     147.0
# 15915     165.0
# 15916     146.0
# 15917     147.0
# 15918     165.0
#
#       vehicle_condition  \
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
# ...                 ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
#
#       previous_owners  \
# 0                   2
# 1                 NaN
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 15914             NaN
# 15915               1
# 15916               1
# 15917             NaN
# 15918               1
#
#       Inspection_new  \
# 0                Yes
# 1                NaN
# 2                NaN
# 3                NaN
# 4                Yes
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916            Yes
# 15917            NaN
# 15918            Yes
#
#       body_color  \
# 0          Black
# 1            Red
# 2          Black
# 3          Brown
# 4          Black
# ...          ...
# 15914       Grey
# 15915       Grey
# 15916      White
# 15917       Grey
# 15918       Grey
#
#       paintwork  \
# 0      Metallic
# 1           NaN
# 2      Metallic
# 3      Metallic
# 4      Metallic
# ...         ...
# 15914  Metallic
# 15915  Metallic
# 15916       NaN
# 15917       NaN
# 15918  Metallic
#
#           body_color_original  \
# 0               Mythosschwarz
# 1                         NaN
# 2      mythosschwarz metallic
# 3                         NaN
# 4      Mythosschwarz Metallic
# ...                       ...
# 15914            Grigio scuro
# 15915              Stahl-Grau
# 15916             arktis-weiß
# 15917                  Grigio
# 15918           Titanium-Grau
#
#          upholstery  \
# 0             Cloth
# 1             Cloth
# 2             Cloth
# 3               NaN
# 4             Cloth
# ...             ...
# 15914           NaN
# 15915         Cloth
# 15916  Full leather
# 15917  Part leather
# 15918  Full leather
#
#       interior_color  \
# 0              Black
# 1               Grey
# 2              Black
# 3                NaN
# 4              Black
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916          Black
# 15917            NaN
# 15918          Brown
#
#       door_nr  \
# 0           5
# 1           3
# 2           4
# 3           3
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       5
# 15917       5
# 15918       5
#
#       seat_nr  \
# 0           5
# 1           4
# 2           4
# 3           4
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       7
# 15917       7
# 15918       5
#
#       model_code  \
# 0       0588/BDF
# 1       0588/BCY
# 2            NaN
# 3            NaN
# 4       0588/BDF
# ...          ...
# 15914        NaN
# 15915   0000/000
# 15916        NaN
# 15917        NaN
# 15918   3333/BHJ
#
#             gear  \
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# ...          ...
# 15914  Automatic
# 15915  Automatic
# 15916  Automatic
# 15917  Automatic
# 15918  Automatic
#
#       displacement  \
# 0            1,422
# 1            1,798
# 2            1,598
# 3            1,422
# 4            1,422
# ...            ...
# 15914        1,997
# 15915        1,798
# 15916        1,997
# 15917        1,997
# 15918        1,798
#
#       cylinders  \
# 0             3
# 1             4
# 2           NaN
# 3             3
# 4             3
# ...         ...
# 15914         4
# 15915         4
# 15916         4
# 15917         4
# 15918         4
#
#       weight  \
# 0      1,220
# 1      1,255
# 2        NaN
# 3      1,195
# 4        NaN
# ...      ...
# 15914  1,758
# 15915  1,708
# 15916    NaN
# 15917  1,758
# 15918  1,685
#
#           fuel  \
# 0       Diesel
# 1      benzine
# 2       Diesel
# 3       Diesel
# 4       Diesel
# ...        ...
# 15914   Diesel
# 15915  benzine
# 15916   Diesel
# 15917   Diesel
# 15918  benzine
#
#       consumption_comb  \
# 0                  3.8
# 1                  5.6
# 2                  3.8
# 3                  3.8
# 4                  4.1
# ...                ...
# 15914              5.3
# 15915              7.4
# 15916              5.3
# 15917              5.3
# 15918              6.8
#
#       consumption_city  \
# 0                  4.3
# 1                  7.1
# 2                  4.4
# 3                  4.3
# 4                  4.6
# ...                ...
# 15914              6.2
# 15915              9.2
# 15916              6.2
# 15917              6.2
# 15918              8.7
#
#       consumption_country  \
# 0                     3.5
# 1                     4.7
# 2                     3.4
# 3                     3.5
# 4                     3.8
# ...                   ...
# 15914                 4.7
# 15915                 6.3
# 15916                 4.7
# 15917                 4.7
# 15918                 5.7
#
#       CO2_emission  \
# 0               99
# 1              129
# 2               99
# 3               99
# 4              109
# ...            ...
# 15914          139
# 15915          168
# 15916          139
# 15917          139
# 15918          153
#
#       emission_class  \
# 0             Euro 6
# 1             Euro 6
# 2             Euro 6
# 3             Euro 6
# 4             Euro 6
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916   Euro 6d-TEMP
# 15917         Euro 6
# 15918         Euro 6
#
#                  comfort_convenience  \
# 0      Air conditioning,Armrest,A...
# 1      Air conditioning,Automatic...
# 2      Air conditioning,Cruise co...
# 3      Air suspension,Armrest,Aux...
# 4      Air conditioning,Armrest,A...
# ...                              ...
# 15914  Air conditioning,Automatic...
# 15915  Air conditioning,Automatic...
# 15916  Air conditioning,Armrest,A...
# 15917  Air conditioning,Automatic...
# 15918  Air conditioning,Automatic...
#
#                        entertainment  \
# 0      Bluetooth,Hands-free equip...
# 1      Bluetooth,Hands-free equip...
# 2              MP3,On-board computer
# 3      Bluetooth,CD player,Hands-...
# 4      Bluetooth,CD player,Hands-...
# ...                              ...
# 15914  Bluetooth,Digital radio,Ha...
# 15915  Bluetooth,Digital radio,Ha...
# 15916  Bluetooth,Hands-free equip...
# 15917  Bluetooth,Digital radio,Ra...
# 15918                            USB
#
#                               Extras  \
# 0      Alloy wheels,Catalytic Con...
# 1      Alloy wheels,Sport seats,S...
# 2         Alloy wheels,Voice Control
# 3      Alloy wheels,Sport seats,V...
# 4      Alloy wheels,Sport package...
# ...                              ...
# 15914      Alloy wheels,Touch screen
# 15915  Alloy wheels,Touch screen,...
# 15916                   Alloy wheels
# 15917      Alloy wheels,Touch screen
# 15918      Alloy wheels,Touch screen
#
#                      safety_security  \
# 0      ABS,Central door lock,Dayt...
# 1      ABS,Central door lock,Cent...
# 2      ABS,Central door lock,Dayt...
# 3      ABS,Alarm system,Central d...
# 4      ABS,Central door lock,Driv...
# ...                              ...
# 15914  ABS,Central door lock,Cent...
# 15915  ABS,Adaptive Cruise Contro...
# 15916  ABS,Adaptive Cruise Contro...
# 15917  ABS,Blind spot monitor,Dri...
# 15918  ABS,Blind spot monitor,Day...
#
#        Air conditioning  \
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 15914                 1
# 15915                 1
# 15916                 1
# 15917                 1
# 15918                 1
#
#        Air suspension  \
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
# ...               ...
# 15914               0
# 15915               0
# 15916               0
# 15917               0
# 15918               0
#
#        Armrest  \
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ...        ...
# 15914        0
# 15915        0
# 15916        1
# 15917        0
# 15918        0
#
#        Automatic climate control  \
# 0                              1
# 1                              1
# 2                              0
# 3                              0
# 4                              1
# ...                          ...
# 15914                          1
# 15915                          1
# 15916                          1
# 15917                          1
# 15918                          1
#
#        Auxiliary heating  \
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  0
# 15916                  0
# 15917                  0
# 15918                  0
#
#        Cruise control  \
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   0
# ...               ...
# 15914               1
# 15915               1
# 15916               1
# 15917               1
# 15918               1
#
#        Electric Starter  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Electric tailgate  \
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  1
# 15916                  1
# 15917                  0
# 15918                  1
#
#        Electrical side mirrors  \
# 0                            1
# 1                            0
# 2                            1
# 3                            1
# 4                            1
# ...                        ...
# 15914                        1
# 15915                        1
# 15916                        1
# 15917                        1
# 15918                        1
#
#        Electrically adjustable seats  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              1
# 15915                              0
# 15916                              0
# 15917                              1
# 15918                              1
#
#        Electrically heated windshield  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              0
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Heads-up display  \
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 1
# 15916                 1
# 15917                 0
# 15918                 0
#
#        Heated steering wheel  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 15914                      0
# 15915                      1
# 15916                      1
# 15917                      0
# 15918                      0
#
#        Hill Holder  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            0
# 15917            0
# 15918            1
#
#        Keyless central door lock  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 15914                          1
# 15915                          1
# 15916                          0
# 15917                          0
# 15918                          0
#
#        Leather seats  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Leather steering wheel  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 15914                       1
# 15915                       1
# 15916                       1
# 15917                       1
# 15918                       1
#
#        Light sensor  \
# 0                 1
# 1                 0
# 2                 0
# 3                 1
# 4                 1
# ...             ...
# 15914             1
# 15915             1
# 15916             1
# 15917             1
# 15918             0
#
#        Lumbar support  \
# 0                   0
# 1                   1
# 2                   0
# 3                   1
# 4                   0
# ...               ...
# 15914               0
# 15915               1
# 15916               0
# 15917               0
# 15918               0
#
#        Massage seats  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              1
# 15915              0
# 15916              1
# 15917              0
# 15918              0
#
#        Multi-function steering wheel  \
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...
# 15914                              1
# 15915                              0
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Navigation system  \
# 0                      1
# 1                      0
# 2                      1
# 3                      1
# 4                      0
# ...                  ...
# 15914                  1
# 15915                  1
# 15916                  1
# 15917                  0
# 15918                  1
#
#        Panorama roof  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              1
# 15917              0
# 15918              0
#
#        Park Distance Control  \
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          1
# ...                      ...
# 15914                      1
# 15915                      1
# 15916                      1
# 15917                      1
# 15918                      0
#
#        Parking assist system camera  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 15914                             0
# 15915                             1
# 15916                             1
# 15917                             0
# 15918                             0
#
#        Parking assist system self-steering  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              0
# 15915                              1
# 15916                              0
# 15917                              0
# 15918                              0
#
#        Parking assist system sensors front  \
# 0                                  0
# 1                                  0
# 2                                  1
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              1
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Parking assist system sensors rear  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  0
# 4                                  1
# ...                              ...
# 15914                              1
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Power windows  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 15914              1
# 15915              1
# 15916              1
# 15917              1
# 15918              1
#
#        Rain sensor  \
# 0                1
# 1                0
# 2                0
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            1
# 15917            0
# 15918            0
#
#        Seat heating  \
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0
# ...             ...
# 15914             0
# 15915             1
# 15916             1
# 15917             0
# 15918             1
#
#        Seat ventilation  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 1
# 15917                 0
# 15918                 0
#
#        Split rear seats  \
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0
# ...                 ...
# 15914                 1
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Start-stop system  \
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 15914                  1
# 15915                  0
# 15916                  0
# 15917                  1
# 15918                  0
#
#        Sunroof  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 15914        0
# 15915        1
# 15916        1
# 15917        0
# 15918        0
#
#        Tinted windows  \
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 15914               1
# 15915               0
# 15916               0
# 15917               0
# 15918               0
#
#        Wind deflector  \
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 15914               0
# 15915               0
# 15916               0
# 15917               0
# 15918               0
#
#        Windshield
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 15914           0
# 15915           0
# 15916           0
# 15917           0
# 15918           0
#
# [15919 rows x 73 columns]

# %% [markdown]
# ### 2. yöntem olarak herbir eleman için olanlara 1 olmayanlara 0 atayarak da aynı sonuca ulaşabiliriz.

# %%
data["air_conditioning"] = np.where(temp[0].str.contains("Air conditioning"), 1, 0)  

data["air_conditioning"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: air_conditioning, Length: 15919, dtype: int32

# %%
data.head(3)
# Out:
#    make  \
# 0  Audi
# 1  Audi
# 2  Audi
#
#   model  \
# 0    A1
# 1    A1
# 2    A1
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#     cc  \
# 0  1.4
# 1  1.8
# 2  1.6
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
#
#    registration  \
# 0        2016.0
# 1        2017.0
# 2        2016.0
#
#    prev_owner  \
# 0         2.0
# 1         NaN
# 2         1.0
#
#   previous_owners  \
# 0               2
# 1             NaN
# 2               1
#
#   Next_Inspection  \
# 0            2021
# 1             NaN
# 2             NaN
#
#   Inspection_new  \
# 0            Yes
# 1            NaN
# 2            NaN
#
#   guarante  \
# 0      NaN
# 1      NaN
# 2      NaN
#
#   first_registration  \
# 0               2016
# 1               2017
# 2               2016
#
#   body_color  \
# 0      Black
# 1        Red
# 2      Black
#
#   paintwork  \
# 0  Metallic
# 1       NaN
# 2  Metallic
#
#       body_color_original  \
# 0           Mythosschwarz
# 1                     NaN
# 2  mythosschwarz metallic
#
#   upholstery  \
# 0      Cloth
# 1      Cloth
# 2      Cloth
#
#   interior_color  \
# 0          Black
# 1           Grey
# 2          Black
#
#      body  \
# 0  Sedans
# 1  Sedans
# 2  Sedans
#
#   door_nr  \
# 0       5
# 1       3
# 2       4
#
#   seat_nr  \
# 0       5
# 1       4
# 2       4
#
#   model_code  \
# 0   0588/BDF
# 1   0588/BCY
# 2        NaN
#
#         gear  \
# 0  Automatic
# 1  Automatic
# 2  Automatic
#
#   displacement  \
# 0        1,422
# 1        1,798
# 2        1,598
#
#   cylinders  \
# 0         3
# 1         4
# 2       NaN
#
#   weight  \
# 0  1,220
# 1  1,255
# 2    NaN
#
#   drive_chain  \
# 0       front
# 1       front
# 2       front
#
#                           fuel  \
# 0  Diesel (Particulate Filter)
# 1                     Gasoline
# 2  Diesel (Particulate Filter)
#
#   consumption_comb  \
# 0              3.8
# 1              5.6
# 2              3.8
#
#   consumption_city  \
# 0              4.3
# 1              7.1
# 2              4.4
#
#   consumption_country  \
# 0                 3.5
# 1                 4.7
# 2                 3.4
#
#   CO2_emission  \
# 0           99
# 1          129
# 2           99
#
#   emission_class  \
# 0         Euro 6
# 1         Euro 6
# 2         Euro 6
#
#    air_conditioning  \
# 0                 1
# 1                 1
# 2                 1
#
#    cruise_control  \
# 0               1
# 1               0
# 2               1
#
#    automatic_climate_control
# 0                          1
# 1                          1
# 2                          0

# %%
data["cruise_control"] = np.where(temp[0].str.contains("Cruise control"), 1, 0)  

data["cruise_control"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: cruise_control, Length: 15919, dtype: int32

# %%
data["automatic_climate_control"] = np.where(temp[0].str.contains("Automatic climate control"), 1, 0)  

data["automatic_climate_control"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: automatic_climate_control, Length: 15919, dtype: int32

# %%
data["armrest"] = np.where(temp[0].str.contains("Armrest"), 1, 0)  

data["armrest"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 15914    0
# 15915    0
# 15916    1
# 15917    0
# 15918    0
# Name: armrest, Length: 15919, dtype: int32

# %%
data["electrical_side_mirrors"] = np.where(temp[0].str.contains("Electrical side mirrors"), 1, 0)  

data["electrical_side_mirrors"]

# %%
data["navigation_system"] = np.where(temp[0].str.contains("Navigation system"), 1, 0)  

data["navigation_system"]

# %%
data["multifunction_steering_wheel"] = np.where(temp[0].str.contains("Multi-function steering wheel"), 1, 0)  

data["multifunction_steering_wheel"]

# %%
data["power_windows"] = np.where(temp[0].str.contains("Power windows"), 1, 0)  

data["power_windows"]

# %%
data["sunroof"] = np.where(temp[0].str.contains("Sunroof"), 1, 0)  

data["sunroof"]

# %%
data["leather_steering_wheel "] = np.where(temp[0].str.contains("Leather steering wheel"), 1, 0)  

data["leather_steering_wheel "]

# %%
data["park_distance_control"] = np.where(temp[0].str.contains("Park Distance Control"), 1, 0)  

data["park_distance_control"]

# %%
data["hill_holder"] = np.where(temp[0].str.contains("Hill Holder"), 1, 0)  

data["hill_holder"]

# %%
data["light_sensor"] = np.where(temp[0].str.contains("Light sensor"), 1, 0)  

data["light_sensor"]

# %%
data["electrically_heated_windshield"] = np.where(temp[0].str.contains("Electrically heated windshield"), 1, 0)  

data["electrically_heated_windshield"]

# %%
data["electrically_adjustable_seats"] = np.where(temp[0].str.contains("Electrically adjustable seats"), 1, 0)  

data["electrically_adjustable_seats"]

# %%
data["electrical_side_mirrors"] = np.where(temp[0].str.contains("Electrical side mirrors"), 1, 0)  

data["electrical_side_mirrors"]

# %%
data["seat_ventilation"] = np.where(temp[0].str.contains("Seat ventilation"), 1, 0)  

data["seat_ventilation"]

# %%
data["light_sensor"] = np.where(temp[0].str.contains("Light sensor"), 1, 0)  

data["light_sensor"]

# %%
data["rain_sensor"] = np.where(temp[0].str.contains("Rain sensor"), 1, 0)  

data["rain_sensor"]

# %%
data["split_rear_seats"] = np.where(temp[0].str.contains("Split rear seats"), 1, 0)  

data["split_rear_seats"]

# %%
data["electric_tailgate"] = np.where(temp[0].str.contains("Electric tailgate"), 1, 0)  

data["electric_tailgate"]

# %%
data["keyless_central_door_lock"] = np.where(temp[0].str.contains("Keyless central door lock"), 1, 0)  

data["keyless_central_door_lock"]

# %%
data["parking_assist_system_sensors_front"] = np.where(temp[0].str.contains("Parking assist system sensors front"), 1, 0)  

data["parking_assist_system_sensors_front"]

# %% [markdown]
# ### Entertainment & Media inceleyelim. Bu feature ile ilgili olarak araçlarda burada geçen özelliklerin olup olmadığına göre sütunlar oluşturacağız.

# %%
df['\nEntertainment & Media\n'] = [",".join(item) if type(item)==list else item for item in df['\nEntertainment & Media\n']]

data['entertainment'] = df['\nEntertainment & Media\n'].str.extract("(\w.+)").copy()

# %%
data['entertainment'].str.get_dummies(sep=",")
# Out:
#        Bluetooth  \
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
# ...          ...
# 15914          1
# 15915          1
# 15916          1
# 15917          1
# 15918          0
#
#        CD player  \
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1
# ...          ...
# 15914          0
# 15915          0
# 15916          0
# 15917          0
# 15918          0
#
#        Digital radio  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              1
# 15915              1
# 15916              0
# 15917              1
# 15918              0
#
#        Hands-free equipment  \
# 0                         1
# 1                         1
# 2                         0
# 3                         1
# 4                         1
# ...                     ...
# 15914                     1
# 15915                     1
# 15916                     1
# 15917                     0
# 15918                     0
#
#        MP3  \
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
# ...    ...
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
#
#        On-board computer  \
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 15914                  1
# 15915                  0
# 15916                  1
# 15917                  0
# 15918                  0
#
#        Radio  \
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1
# ...      ...
# 15914      1
# 15915      1
# 15916      1
# 15917      1
# 15918      0
#
#        Sound system  \
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
#        Television  \
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 15914           0
# 15915           0
# 15916           0
# 15917           0
# 15918           0
#
#        USB
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
# ...    ...
# 15914    1
# 15915    1
# 15916    0
# 15917    1
# 15918    1
#
# [15919 rows x 10 columns]

# %%
entert = data['entertainment'].str.get_dummies(sep=",")

# %%
data.join(entert)   # bunu en son çalıştıralım.
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 2         Audi
# 3         Audi
# 4         Audi
# ...        ...
# 15914  Renault
# 15915  Renault
# 15916  Renault
# 15917  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1
# ...       ...
# 15914  Espace
# 15915  Espace
# 15916  Espace
# 15917  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
# ...         ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 2      1.6
# 3      1.4
# 4      1.4
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 2        VAT deductible
# 3                  None
# 4                  None
# ...                 ...
# 15914    VAT deductible
# 15915    VAT deductible
# 15916    VAT deductible
# 15917    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 2      83450
# 3      73000
# 4      16200
# ...      ...
# 15914
# 15915   9900
# 15916     15
# 15917     10
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914           NaN
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             NaN
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         NaN
# 15915         1.0
# 15916         1.0
# 15917         NaN
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 2          85.0
# 3          66.0
# 4          66.0
# ...         ...
# 15914     147.0
# 15915     165.0
# 15916     146.0
# 15917     147.0
# 15918     165.0
#
#       vehicle_condition  \
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
# ...                 ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
#
#       previous_owners  \
# 0                   2
# 1                 NaN
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 15914             NaN
# 15915               1
# 15916               1
# 15917             NaN
# 15918               1
#
#       Inspection_new  \
# 0                Yes
# 1                NaN
# 2                NaN
# 3                NaN
# 4                Yes
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916            Yes
# 15917            NaN
# 15918            Yes
#
#       body_color  \
# 0          Black
# 1            Red
# 2          Black
# 3          Brown
# 4          Black
# ...          ...
# 15914       Grey
# 15915       Grey
# 15916      White
# 15917       Grey
# 15918       Grey
#
#       paintwork  \
# 0      Metallic
# 1           NaN
# 2      Metallic
# 3      Metallic
# 4      Metallic
# ...         ...
# 15914  Metallic
# 15915  Metallic
# 15916       NaN
# 15917       NaN
# 15918  Metallic
#
#           body_color_original  \
# 0               Mythosschwarz
# 1                         NaN
# 2      mythosschwarz metallic
# 3                         NaN
# 4      Mythosschwarz Metallic
# ...                       ...
# 15914            Grigio scuro
# 15915              Stahl-Grau
# 15916             arktis-weiß
# 15917                  Grigio
# 15918           Titanium-Grau
#
#          upholstery  \
# 0             Cloth
# 1             Cloth
# 2             Cloth
# 3               NaN
# 4             Cloth
# ...             ...
# 15914           NaN
# 15915         Cloth
# 15916  Full leather
# 15917  Part leather
# 15918  Full leather
#
#       interior_color  \
# 0              Black
# 1               Grey
# 2              Black
# 3                NaN
# 4              Black
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916          Black
# 15917            NaN
# 15918          Brown
#
#       door_nr  \
# 0           5
# 1           3
# 2           4
# 3           3
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       5
# 15917       5
# 15918       5
#
#       seat_nr  \
# 0           5
# 1           4
# 2           4
# 3           4
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       7
# 15917       7
# 15918       5
#
#       model_code  \
# 0       0588/BDF
# 1       0588/BCY
# 2            NaN
# 3            NaN
# 4       0588/BDF
# ...          ...
# 15914        NaN
# 15915   0000/000
# 15916        NaN
# 15917        NaN
# 15918   3333/BHJ
#
#             gear  \
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# ...          ...
# 15914  Automatic
# 15915  Automatic
# 15916  Automatic
# 15917  Automatic
# 15918  Automatic
#
#       displacement  \
# 0            1,422
# 1            1,798
# 2            1,598
# 3            1,422
# 4            1,422
# ...            ...
# 15914        1,997
# 15915        1,798
# 15916        1,997
# 15917        1,997
# 15918        1,798
#
#       cylinders  \
# 0             3
# 1             4
# 2           NaN
# 3             3
# 4             3
# ...         ...
# 15914         4
# 15915         4
# 15916         4
# 15917         4
# 15918         4
#
#       weight  \
# 0      1,220
# 1      1,255
# 2        NaN
# 3      1,195
# 4        NaN
# ...      ...
# 15914  1,758
# 15915  1,708
# 15916    NaN
# 15917  1,758
# 15918  1,685
#
#           fuel  \
# 0       Diesel
# 1      benzine
# 2       Diesel
# 3       Diesel
# 4       Diesel
# ...        ...
# 15914   Diesel
# 15915  benzine
# 15916   Diesel
# 15917   Diesel
# 15918  benzine
#
#       consumption_comb  \
# 0                  3.8
# 1                  5.6
# 2                  3.8
# 3                  3.8
# 4                  4.1
# ...                ...
# 15914              5.3
# 15915              7.4
# 15916              5.3
# 15917              5.3
# 15918              6.8
#
#       consumption_city  \
# 0                  4.3
# 1                  7.1
# 2                  4.4
# 3                  4.3
# 4                  4.6
# ...                ...
# 15914              6.2
# 15915              9.2
# 15916              6.2
# 15917              6.2
# 15918              8.7
#
#       consumption_country  \
# 0                     3.5
# 1                     4.7
# 2                     3.4
# 3                     3.5
# 4                     3.8
# ...                   ...
# 15914                 4.7
# 15915                 6.3
# 15916                 4.7
# 15917                 4.7
# 15918                 5.7
#
#       CO2_emission  \
# 0               99
# 1              129
# 2               99
# 3               99
# 4              109
# ...            ...
# 15914          139
# 15915          168
# 15916          139
# 15917          139
# 15918          153
#
#       emission_class  \
# 0             Euro 6
# 1             Euro 6
# 2             Euro 6
# 3             Euro 6
# 4             Euro 6
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916   Euro 6d-TEMP
# 15917         Euro 6
# 15918         Euro 6
#
#                  comfort_convenience  \
# 0      Air conditioning,Armrest,A...
# 1      Air conditioning,Automatic...
# 2      Air conditioning,Cruise co...
# 3      Air suspension,Armrest,Aux...
# 4      Air conditioning,Armrest,A...
# ...                              ...
# 15914  Air conditioning,Automatic...
# 15915  Air conditioning,Automatic...
# 15916  Air conditioning,Armrest,A...
# 15917  Air conditioning,Automatic...
# 15918  Air conditioning,Automatic...
#
#                        entertainment  \
# 0      Bluetooth,Hands-free equip...
# 1      Bluetooth,Hands-free equip...
# 2              MP3,On-board computer
# 3      Bluetooth,CD player,Hands-...
# 4      Bluetooth,CD player,Hands-...
# ...                              ...
# 15914  Bluetooth,Digital radio,Ha...
# 15915  Bluetooth,Digital radio,Ha...
# 15916  Bluetooth,Hands-free equip...
# 15917  Bluetooth,Digital radio,Ra...
# 15918                            USB
#
#                               Extras  \
# 0      Alloy wheels,Catalytic Con...
# 1      Alloy wheels,Sport seats,S...
# 2         Alloy wheels,Voice Control
# 3      Alloy wheels,Sport seats,V...
# 4      Alloy wheels,Sport package...
# ...                              ...
# 15914      Alloy wheels,Touch screen
# 15915  Alloy wheels,Touch screen,...
# 15916                   Alloy wheels
# 15917      Alloy wheels,Touch screen
# 15918      Alloy wheels,Touch screen
#
#                      safety_security  \
# 0      ABS,Central door lock,Dayt...
# 1      ABS,Central door lock,Cent...
# 2      ABS,Central door lock,Dayt...
# 3      ABS,Alarm system,Central d...
# 4      ABS,Central door lock,Driv...
# ...                              ...
# 15914  ABS,Central door lock,Cent...
# 15915  ABS,Adaptive Cruise Contro...
# 15916  ABS,Adaptive Cruise Contro...
# 15917  ABS,Blind spot monitor,Dri...
# 15918  ABS,Blind spot monitor,Day...
#
#        Bluetooth  \
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
# ...          ...
# 15914          1
# 15915          1
# 15916          1
# 15917          1
# 15918          0
#
#        CD player  \
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1
# ...          ...
# 15914          0
# 15915          0
# 15916          0
# 15917          0
# 15918          0
#
#        Digital radio  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              1
# 15915              1
# 15916              0
# 15917              1
# 15918              0
#
#        Hands-free equipment  \
# 0                         1
# 1                         1
# 2                         0
# 3                         1
# 4                         1
# ...                     ...
# 15914                     1
# 15915                     1
# 15916                     1
# 15917                     0
# 15918                     0
#
#        MP3  \
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
# ...    ...
# 15914    0
# 15915    0
# 15916    0
# 15917    0
# 15918    0
#
#        On-board computer  \
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 15914                  1
# 15915                  0
# 15916                  1
# 15917                  0
# 15918                  0
#
#        Radio  \
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1
# ...      ...
# 15914      1
# 15915      1
# 15916      1
# 15917      1
# 15918      0
#
#        Sound system  \
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
#        Television  \
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 15914           0
# 15915           0
# 15916           0
# 15917           0
# 15918           0
#
#        USB
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
# ...    ...
# 15914    1
# 15915    1
# 15916    0
# 15917    1
# 15918    1
#
# [15919 rows x 45 columns]

# %% [markdown]
# ### 2. yöntem olarak herbir eleman için olanlara 1 olmayanlara 0 atayarak da aynı sonuca ulaşabiliriz.

# %%
data["bluetooth"] = np.where(temp[0].str.contains("Bluetooth"), 1, 0)  

data["bluetooth"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    0
# Name: Bluetooth, Length: 15919, dtype: int32

# %%
data["handsfree_equipment"] = np.where(temp[0].str.contains("Hands-free equipment"), 1, 0)  

data["handsfree_equipment"]

# %%
data["onboard_computer"] = np.where(temp[0].str.contains("On-board computer"), 1, 0)  

data["onboard_computer"]

# %%
data["radio"] = np.where(temp[0].str.contains("Radio"), 1, 0)  

data["radio"]

# %%
data["CD_player"] = np.where(temp[0].str.contains("CD player"), 1, 0)  

data["CD_player"]

# %%
data["television"] = np.where(temp[0].str.contains("Television"), 1, 0)  

data["television"]

# %%
data["digital_radio"] = np.where(temp[0].str.contains("Digital radio"), 1, 0)  

data["digital_radio"]

# %%
data["MP3"] = np.where(temp[0].str.contains("MP3"), 1, 0)  

data["MP3"]

# %%
data["sound_system"] = np.where(temp[0].str.contains("Sound system"), 1, 0)  

data["sound_system"]

# %%
data["USB"] = np.where(temp[0].str.contains("USB"), 1, 0)  

data["USB"]

# %% [markdown]
# ### Extras inceleyelim.

# %%
df['\nExtras\n'] = [",".join(item) if type(item)==list else item for item in df['\nExtras\n']]

data['Extras'] = df['\nExtras\n'].str.extract("(\w.+)").copy()

# %%
data['Extras'].str.get_dummies(sep=",")
# Out:
#        Alloy wheels  \
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 15914             1
# 15915             1
# 15916             1
# 15917             1
# 15918             1
#
#        Cab or rented Car  \
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  0
# 15916                  0
# 15917                  0
# 15918                  0
#
#        Catalytic Converter  \
# 0                        1
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 15914                    0
# 15915                    0
# 15916                    0
# 15917                    0
# 15918                    0
#
#        Handicapped enabled  \
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 15914                    0
# 15915                    0
# 15916                    0
# 15917                    0
# 15918                    0
#
#        Right hand drive  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Roof rack  \
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 15914          0
# 15915          0
# 15916          0
# 15917          0
# 15918          0
#
#        Shift paddles  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Ski bag  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 15914        0
# 15915        0
# 15916        0
# 15917        0
# 15918        0
#
#        Sliding door  \
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
#        Sport package  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Sport seats  \
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# ...            ...
# 15914            0
# 15915            0
# 15916            0
# 15917            0
# 15918            0
#
#        Sport suspension  \
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Touch screen  \
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 15914             1
# 15915             1
# 15916             0
# 15917             1
# 15918             1
#
#        Trailer hitch  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Tuned car  \
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 15914          0
# 15915          0
# 15916          0
# 15917          0
# 15918          0
#
#        Voice Control  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 15914              0
# 15915              1
# 15916              0
# 15917              0
# 15918              0
#
#        Winter tyres
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
# [15919 rows x 17 columns]

# %%
extra = data['Extras'].str.get_dummies(sep=",")

data.join(extra )

# %%
data.join(extra )   # bunu en son çalıştıralım.
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 2         Audi
# 3         Audi
# 4         Audi
# ...        ...
# 15914  Renault
# 15915  Renault
# 15916  Renault
# 15917  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1
# ...       ...
# 15914  Espace
# 15915  Espace
# 15916  Espace
# 15917  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
# ...         ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 2      1.6
# 3      1.4
# 4      1.4
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 2        VAT deductible
# 3                  None
# 4                  None
# ...                 ...
# 15914    VAT deductible
# 15915    VAT deductible
# 15916    VAT deductible
# 15917    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 2      83450
# 3      73000
# 4      16200
# ...      ...
# 15914
# 15915   9900
# 15916     15
# 15917     10
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914           NaN
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             NaN
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         NaN
# 15915         1.0
# 15916         1.0
# 15917         NaN
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 2          85.0
# 3          66.0
# 4          66.0
# ...         ...
# 15914     147.0
# 15915     165.0
# 15916     146.0
# 15917     147.0
# 15918     165.0
#
#       vehicle_condition  \
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
# ...                 ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
#
#       previous_owners  \
# 0                   2
# 1                 NaN
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 15914             NaN
# 15915               1
# 15916               1
# 15917             NaN
# 15918               1
#
#       Inspection_new  \
# 0                Yes
# 1                NaN
# 2                NaN
# 3                NaN
# 4                Yes
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916            Yes
# 15917            NaN
# 15918            Yes
#
#       body_color  \
# 0          Black
# 1            Red
# 2          Black
# 3          Brown
# 4          Black
# ...          ...
# 15914       Grey
# 15915       Grey
# 15916      White
# 15917       Grey
# 15918       Grey
#
#       paintwork  \
# 0      Metallic
# 1           NaN
# 2      Metallic
# 3      Metallic
# 4      Metallic
# ...         ...
# 15914  Metallic
# 15915  Metallic
# 15916       NaN
# 15917       NaN
# 15918  Metallic
#
#           body_color_original  \
# 0               Mythosschwarz
# 1                         NaN
# 2      mythosschwarz metallic
# 3                         NaN
# 4      Mythosschwarz Metallic
# ...                       ...
# 15914            Grigio scuro
# 15915              Stahl-Grau
# 15916             arktis-weiß
# 15917                  Grigio
# 15918           Titanium-Grau
#
#          upholstery  \
# 0             Cloth
# 1             Cloth
# 2             Cloth
# 3               NaN
# 4             Cloth
# ...             ...
# 15914           NaN
# 15915         Cloth
# 15916  Full leather
# 15917  Part leather
# 15918  Full leather
#
#       interior_color  \
# 0              Black
# 1               Grey
# 2              Black
# 3                NaN
# 4              Black
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916          Black
# 15917            NaN
# 15918          Brown
#
#       door_nr  \
# 0           5
# 1           3
# 2           4
# 3           3
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       5
# 15917       5
# 15918       5
#
#       seat_nr  \
# 0           5
# 1           4
# 2           4
# 3           4
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       7
# 15917       7
# 15918       5
#
#       model_code  \
# 0       0588/BDF
# 1       0588/BCY
# 2            NaN
# 3            NaN
# 4       0588/BDF
# ...          ...
# 15914        NaN
# 15915   0000/000
# 15916        NaN
# 15917        NaN
# 15918   3333/BHJ
#
#             gear  \
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# ...          ...
# 15914  Automatic
# 15915  Automatic
# 15916  Automatic
# 15917  Automatic
# 15918  Automatic
#
#       displacement  \
# 0            1,422
# 1            1,798
# 2            1,598
# 3            1,422
# 4            1,422
# ...            ...
# 15914        1,997
# 15915        1,798
# 15916        1,997
# 15917        1,997
# 15918        1,798
#
#       cylinders  \
# 0             3
# 1             4
# 2           NaN
# 3             3
# 4             3
# ...         ...
# 15914         4
# 15915         4
# 15916         4
# 15917         4
# 15918         4
#
#       weight  \
# 0      1,220
# 1      1,255
# 2        NaN
# 3      1,195
# 4        NaN
# ...      ...
# 15914  1,758
# 15915  1,708
# 15916    NaN
# 15917  1,758
# 15918  1,685
#
#           fuel  \
# 0       Diesel
# 1      benzine
# 2       Diesel
# 3       Diesel
# 4       Diesel
# ...        ...
# 15914   Diesel
# 15915  benzine
# 15916   Diesel
# 15917   Diesel
# 15918  benzine
#
#       consumption_comb  \
# 0                  3.8
# 1                  5.6
# 2                  3.8
# 3                  3.8
# 4                  4.1
# ...                ...
# 15914              5.3
# 15915              7.4
# 15916              5.3
# 15917              5.3
# 15918              6.8
#
#       consumption_city  \
# 0                  4.3
# 1                  7.1
# 2                  4.4
# 3                  4.3
# 4                  4.6
# ...                ...
# 15914              6.2
# 15915              9.2
# 15916              6.2
# 15917              6.2
# 15918              8.7
#
#       consumption_country  \
# 0                     3.5
# 1                     4.7
# 2                     3.4
# 3                     3.5
# 4                     3.8
# ...                   ...
# 15914                 4.7
# 15915                 6.3
# 15916                 4.7
# 15917                 4.7
# 15918                 5.7
#
#       CO2_emission  \
# 0               99
# 1              129
# 2               99
# 3               99
# 4              109
# ...            ...
# 15914          139
# 15915          168
# 15916          139
# 15917          139
# 15918          153
#
#       emission_class  \
# 0             Euro 6
# 1             Euro 6
# 2             Euro 6
# 3             Euro 6
# 4             Euro 6
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916   Euro 6d-TEMP
# 15917         Euro 6
# 15918         Euro 6
#
#                  comfort_convenience  \
# 0      Air conditioning,Armrest,A...
# 1      Air conditioning,Automatic...
# 2      Air conditioning,Cruise co...
# 3      Air suspension,Armrest,Aux...
# 4      Air conditioning,Armrest,A...
# ...                              ...
# 15914  Air conditioning,Automatic...
# 15915  Air conditioning,Automatic...
# 15916  Air conditioning,Armrest,A...
# 15917  Air conditioning,Automatic...
# 15918  Air conditioning,Automatic...
#
#                        entertainment  \
# 0      Bluetooth,Hands-free equip...
# 1      Bluetooth,Hands-free equip...
# 2              MP3,On-board computer
# 3      Bluetooth,CD player,Hands-...
# 4      Bluetooth,CD player,Hands-...
# ...                              ...
# 15914  Bluetooth,Digital radio,Ha...
# 15915  Bluetooth,Digital radio,Ha...
# 15916  Bluetooth,Hands-free equip...
# 15917  Bluetooth,Digital radio,Ra...
# 15918                            USB
#
#                               Extras  \
# 0      Alloy wheels,Catalytic Con...
# 1      Alloy wheels,Sport seats,S...
# 2         Alloy wheels,Voice Control
# 3      Alloy wheels,Sport seats,V...
# 4      Alloy wheels,Sport package...
# ...                              ...
# 15914      Alloy wheels,Touch screen
# 15915  Alloy wheels,Touch screen,...
# 15916                   Alloy wheels
# 15917      Alloy wheels,Touch screen
# 15918      Alloy wheels,Touch screen
#
#                      safety_security  \
# 0      ABS,Central door lock,Dayt...
# 1      ABS,Central door lock,Cent...
# 2      ABS,Central door lock,Dayt...
# 3      ABS,Alarm system,Central d...
# 4      ABS,Central door lock,Driv...
# ...                              ...
# 15914  ABS,Central door lock,Cent...
# 15915  ABS,Adaptive Cruise Contro...
# 15916  ABS,Adaptive Cruise Contro...
# 15917  ABS,Blind spot monitor,Dri...
# 15918  ABS,Blind spot monitor,Day...
#
#        Alloy wheels  \
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 15914             1
# 15915             1
# 15916             1
# 15917             1
# 15918             1
#
#        Cab or rented Car  \
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  0
# 15916                  0
# 15917                  0
# 15918                  0
#
#        Catalytic Converter  \
# 0                        1
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 15914                    0
# 15915                    0
# 15916                    0
# 15917                    0
# 15918                    0
#
#        Handicapped enabled  \
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 15914                    0
# 15915                    0
# 15916                    0
# 15917                    0
# 15918                    0
#
#        Right hand drive  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Roof rack  \
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 15914          0
# 15915          0
# 15916          0
# 15917          0
# 15918          0
#
#        Shift paddles  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Ski bag  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 15914        0
# 15915        0
# 15916        0
# 15917        0
# 15918        0
#
#        Sliding door  \
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
#        Sport package  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Sport seats  \
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# ...            ...
# 15914            0
# 15915            0
# 15916            0
# 15917            0
# 15918            0
#
#        Sport suspension  \
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Touch screen  \
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 15914             1
# 15915             1
# 15916             0
# 15917             1
# 15918             1
#
#        Trailer hitch  \
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 15914              0
# 15915              0
# 15916              0
# 15917              0
# 15918              0
#
#        Tuned car  \
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 15914          0
# 15915          0
# 15916          0
# 15917          0
# 15918          0
#
#        Voice Control  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 15914              0
# 15915              1
# 15916              0
# 15917              0
# 15918              0
#
#        Winter tyres
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
# [15919 rows x 52 columns]

# %% [markdown]
# ### 2. yöntem olarak herbir eleman için olanlara 1 olmayanlara 0 atayarak da aynı sonuca ulaşabiliriz.

# %%
data["alloy_wheels"] = np.where(temp[0].str.contains("Alloy wheels"), 1, 0)  

data["alloy_wheels"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
# Name: alloy_wheels, Length: 15919, dtype: int32

# %%
data["touch_screen"] = np.where(temp[0].str.contains("Touch screen"), 1, 0)  

data["touch_screen"]

# %%
data["voice_control"] = np.where(temp[0].str.contains("Voice Control"), 1, 0)  

data["voice_control"]

# %%
data["winter_tyres"] = np.where(temp[0].str.contains("Winter tyres"), 1, 0)  

data["winter_tyres"]

# %%
data["roof_rack"] = np.where(temp[0].str.contains("Roof rack"), 1, 0)  

data["roof_rack"]

# %%
data["sport_package"] = np.where(temp[0].str.contains("Sport package"), 1, 0)  

data["sport_package"]

# %%
data["catalytic_converter"] = np.where(temp[0].str.contains("Catalytic Converter"), 1, 0)  

data["catalytic_converter"]

# %%
data["ski_bag"] = np.where(temp[0].str.contains("Ski bag"), 1, 0)  

data["ski_bag"]

# %%
data["sport_suspension"] = np.where(temp[0].str.contains("Sport suspension"), 1, 0)  

data["sport_suspension"]

# %%
data["trailer_hitch"] = np.where(temp[0].str.contains("Trailer hitch"), 1, 0)  

data["trailer_hitch"]

# %%
data["shift_paddles"] = np.where(temp[0].str.contains("Shift paddles"), 1, 0)  

data["shift_paddles"]

# %% [markdown]
# ### Safety & Security inceleyelim.

# %%
df['\nSafety & Security\n'] = [",".join(item) if type(item)==list else item for item in df['\nSafety & Security\n']]

data['safety_security'] = df['\nSafety & Security\n'].str.extract("(\w.+)").copy()

# %%
safety = data['safety_security'].str.get_dummies(sep=",")

# %%
data.join(safety)     # bunu en son çalıştıralım.
# Out:
#           make  \
# 0         Audi
# 1         Audi
# 2         Audi
# 3         Audi
# 4         Audi
# ...        ...
# 15914  Renault
# 15915  Renault
# 15916  Renault
# 15917  Renault
# 15918  Renault
#
#         model  \
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1
# ...       ...
# 15914  Espace
# 15915  Espace
# 15916  Espace
# 15917  Espace
# 15918  Espace
#
#       body_type  \
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
# ...         ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
#
#         cc  \
# 0      1.4
# 1      1.8
# 2      1.6
# 3      1.4
# 4      1.4
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
#        price  \
# 0      15770
# 1      14500
# 2      14640
# 3      14500
# 4      16790
# ...      ...
# 15914  39950
# 15915  39885
# 15916  39875
# 15917  39700
# 15918  40999
#
#                     vat  \
# 0        VAT deductible
# 1      Price negotiable
# 2        VAT deductible
# 3                  None
# 4                  None
# ...                 ...
# 15914    VAT deductible
# 15915    VAT deductible
# 15916    VAT deductible
# 15917    VAT deductible
# 15918    VAT deductible
#
#           km  \
# 0      56013
# 1      80000
# 2      83450
# 3      73000
# 4      16200
# ...      ...
# 15914
# 15915   9900
# 15916     15
# 15917     10
# 15918
#
#        registration  \
# 0            2016.0
# 1            2017.0
# 2            2016.0
# 3            2016.0
# 4            2016.0
# ...             ...
# 15914           NaN
# 15915        2019.0
# 15916        2019.0
# 15917        2019.0
# 15918        2019.0
#
#        prev_owner  \
# 0             2.0
# 1             NaN
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 15914         NaN
# 15915         1.0
# 15916         1.0
# 15917         NaN
# 15918         1.0
#
#        power_hp  \
# 0          66.0
# 1         141.0
# 2          85.0
# 3          66.0
# 4          66.0
# ...         ...
# 15914     147.0
# 15915     165.0
# 15916     146.0
# 15917     147.0
# 15918     165.0
#
#       vehicle_condition  \
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
# ...                 ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
#
#       previous_owners  \
# 0                   2
# 1                 NaN
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 15914             NaN
# 15915               1
# 15916               1
# 15917             NaN
# 15918               1
#
#       Inspection_new  \
# 0                Yes
# 1                NaN
# 2                NaN
# 3                NaN
# 4                Yes
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916            Yes
# 15917            NaN
# 15918            Yes
#
#       body_color  \
# 0          Black
# 1            Red
# 2          Black
# 3          Brown
# 4          Black
# ...          ...
# 15914       Grey
# 15915       Grey
# 15916      White
# 15917       Grey
# 15918       Grey
#
#       paintwork  \
# 0      Metallic
# 1           NaN
# 2      Metallic
# 3      Metallic
# 4      Metallic
# ...         ...
# 15914  Metallic
# 15915  Metallic
# 15916       NaN
# 15917       NaN
# 15918  Metallic
#
#           body_color_original  \
# 0               Mythosschwarz
# 1                         NaN
# 2      mythosschwarz metallic
# 3                         NaN
# 4      Mythosschwarz Metallic
# ...                       ...
# 15914            Grigio scuro
# 15915              Stahl-Grau
# 15916             arktis-weiß
# 15917                  Grigio
# 15918           Titanium-Grau
#
#          upholstery  \
# 0             Cloth
# 1             Cloth
# 2             Cloth
# 3               NaN
# 4             Cloth
# ...             ...
# 15914           NaN
# 15915         Cloth
# 15916  Full leather
# 15917  Part leather
# 15918  Full leather
#
#       interior_color  \
# 0              Black
# 1               Grey
# 2              Black
# 3                NaN
# 4              Black
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916          Black
# 15917            NaN
# 15918          Brown
#
#       door_nr  \
# 0           5
# 1           3
# 2           4
# 3           3
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       5
# 15917       5
# 15918       5
#
#       seat_nr  \
# 0           5
# 1           4
# 2           4
# 3           4
# 4           5
# ...       ...
# 15914       5
# 15915       5
# 15916       7
# 15917       7
# 15918       5
#
#       model_code  \
# 0       0588/BDF
# 1       0588/BCY
# 2            NaN
# 3            NaN
# 4       0588/BDF
# ...          ...
# 15914        NaN
# 15915   0000/000
# 15916        NaN
# 15917        NaN
# 15918   3333/BHJ
#
#             gear  \
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# ...          ...
# 15914  Automatic
# 15915  Automatic
# 15916  Automatic
# 15917  Automatic
# 15918  Automatic
#
#       displacement  \
# 0            1,422
# 1            1,798
# 2            1,598
# 3            1,422
# 4            1,422
# ...            ...
# 15914        1,997
# 15915        1,798
# 15916        1,997
# 15917        1,997
# 15918        1,798
#
#       cylinders  \
# 0             3
# 1             4
# 2           NaN
# 3             3
# 4             3
# ...         ...
# 15914         4
# 15915         4
# 15916         4
# 15917         4
# 15918         4
#
#       weight  \
# 0      1,220
# 1      1,255
# 2        NaN
# 3      1,195
# 4        NaN
# ...      ...
# 15914  1,758
# 15915  1,708
# 15916    NaN
# 15917  1,758
# 15918  1,685
#
#           fuel  \
# 0       Diesel
# 1      benzine
# 2       Diesel
# 3       Diesel
# 4       Diesel
# ...        ...
# 15914   Diesel
# 15915  benzine
# 15916   Diesel
# 15917   Diesel
# 15918  benzine
#
#       consumption_comb  \
# 0                  3.8
# 1                  5.6
# 2                  3.8
# 3                  3.8
# 4                  4.1
# ...                ...
# 15914              5.3
# 15915              7.4
# 15916              5.3
# 15917              5.3
# 15918              6.8
#
#       consumption_city  \
# 0                  4.3
# 1                  7.1
# 2                  4.4
# 3                  4.3
# 4                  4.6
# ...                ...
# 15914              6.2
# 15915              9.2
# 15916              6.2
# 15917              6.2
# 15918              8.7
#
#       consumption_country  \
# 0                     3.5
# 1                     4.7
# 2                     3.4
# 3                     3.5
# 4                     3.8
# ...                   ...
# 15914                 4.7
# 15915                 6.3
# 15916                 4.7
# 15917                 4.7
# 15918                 5.7
#
#       CO2_emission  \
# 0               99
# 1              129
# 2               99
# 3               99
# 4              109
# ...            ...
# 15914          139
# 15915          168
# 15916          139
# 15917          139
# 15918          153
#
#       emission_class  \
# 0             Euro 6
# 1             Euro 6
# 2             Euro 6
# 3             Euro 6
# 4             Euro 6
# ...              ...
# 15914            NaN
# 15915            NaN
# 15916   Euro 6d-TEMP
# 15917         Euro 6
# 15918         Euro 6
#
#                  comfort_convenience  \
# 0      Air conditioning,Armrest,A...
# 1      Air conditioning,Automatic...
# 2      Air conditioning,Cruise co...
# 3      Air suspension,Armrest,Aux...
# 4      Air conditioning,Armrest,A...
# ...                              ...
# 15914  Air conditioning,Automatic...
# 15915  Air conditioning,Automatic...
# 15916  Air conditioning,Armrest,A...
# 15917  Air conditioning,Automatic...
# 15918  Air conditioning,Automatic...
#
#                        entertainment  \
# 0      Bluetooth,Hands-free equip...
# 1      Bluetooth,Hands-free equip...
# 2              MP3,On-board computer
# 3      Bluetooth,CD player,Hands-...
# 4      Bluetooth,CD player,Hands-...
# ...                              ...
# 15914  Bluetooth,Digital radio,Ha...
# 15915  Bluetooth,Digital radio,Ha...
# 15916  Bluetooth,Hands-free equip...
# 15917  Bluetooth,Digital radio,Ra...
# 15918                            USB
#
#                               Extras  \
# 0      Alloy wheels,Catalytic Con...
# 1      Alloy wheels,Sport seats,S...
# 2         Alloy wheels,Voice Control
# 3      Alloy wheels,Sport seats,V...
# 4      Alloy wheels,Sport package...
# ...                              ...
# 15914      Alloy wheels,Touch screen
# 15915  Alloy wheels,Touch screen,...
# 15916                   Alloy wheels
# 15917      Alloy wheels,Touch screen
# 15918      Alloy wheels,Touch screen
#
#                      safety_security  \
# 0      ABS,Central door lock,Dayt...
# 1      ABS,Central door lock,Cent...
# 2      ABS,Central door lock,Dayt...
# 3      ABS,Alarm system,Central d...
# 4      ABS,Central door lock,Driv...
# ...                              ...
# 15914  ABS,Central door lock,Cent...
# 15915  ABS,Adaptive Cruise Contro...
# 15916  ABS,Adaptive Cruise Contro...
# 15917  ABS,Blind spot monitor,Dri...
# 15918  ABS,Blind spot monitor,Day...
#
#        ABS  \
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 15914    1
# 15915    1
# 15916    1
# 15917    1
# 15918    1
#
#        Adaptive Cruise Control  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 15914                        0
# 15915                        1
# 15916                        1
# 15917                        0
# 15918                        0
#
#        Adaptive headlights  \
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 15914                    0
# 15915                    0
# 15916                    0
# 15917                    0
# 15918                    0
#
#        Alarm system  \
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0
# ...             ...
# 15914             0
# 15915             0
# 15916             0
# 15917             0
# 15918             0
#
#        Blind spot monitor  \
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 15914                   0
# 15915                   1
# 15916                   1
# 15917                   1
# 15918                   1
#
#        Central door lock  \
# 0                      1
# 1                      1
# 2                      1
# 3                      0
# 4                      1
# ...                  ...
# 15914                  1
# 15915                  1
# 15916                  1
# 15917                  0
# 15918                  0
#
#        Central door lock with remote control  \
# 0                                  0
# 1                                  1
# 2                                  0
# 3                                  1
# 4                                  0
# ...                              ...
# 15914                              1
# 15915                              0
# 15916                              0
# 15917                              0
# 15918                              0
#
#        Daytime running lights  \
# 0                           1
# 1                           1
# 2                           1
# 3                           0
# 4                           0
# ...                       ...
# 15914                       0
# 15915                       1
# 15916                       1
# 15917                       0
# 15918                       1
#
#        Driver drowsiness detection  \
# 0                                0
# 1                                0
# 2                                0
# 3                                1
# 4                                0
# ...                            ...
# 15914                            0
# 15915                            0
# 15916                            0
# 15917                            0
# 15918                            0
#
#        Driver-side airbag  \
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 15914                   1
# 15915                   1
# 15916                   1
# 15917                   1
# 15918                   1
#
#        Electronic stability control  \
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 1
# ...                             ...
# 15914                             1
# 15915                             1
# 15916                             1
# 15917                             1
# 15918                             1
#
#        Emergency brake assistant  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 15914                          1
# 15915                          1
# 15916                          1
# 15917                          1
# 15918                          1
#
#        Emergency system  \
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
#        Fog lights  \
# 0               1
# 1               0
# 2               0
# 3               0
# 4               1
# ...           ...
# 15914           0
# 15915           0
# 15916           0
# 15917           0
# 15918           0
#
#        Head airbag  \
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# ...            ...
# 15914            1
# 15915            0
# 15916            0
# 15917            0
# 15918            0
#
#        Immobilizer  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            1
# 15917            0
# 15918            1
#
#        Isofix  \
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 15914       1
# 15915       1
# 15916       1
# 15917       1
# 15918       1
#
#        LED Daytime Running Lights  \
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 15914                           1
# 15915                           1
# 15916                           1
# 15917                           0
# 15918                           1
#
#        LED Headlights  \
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 15914               1
# 15915               1
# 15916               1
# 15917               1
# 15918               0
#
#        Lane departure warning system  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 15914                              1
# 15915                              1
# 15916                              1
# 15917                              0
# 15918                              0
#
#        Night view assist  \
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 15914                  0
# 15915                  0
# 15916                  0
# 15917                  0
# 15918                  0
#
#        Passenger-side airbag  \
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ...                      ...
# 15914                      1
# 15915                      1
# 15916                      1
# 15917                      1
# 15918                      1
#
#        Power steering  \
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 15914               1
# 15915               1
# 15916               1
# 15917               1
# 15918               1
#
#        Rear airbag  \
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 15914            1
# 15915            0
# 15916            0
# 15917            0
# 15918            0
#
#        Side airbag  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 15914            1
# 15915            1
# 15916            1
# 15917            1
# 15918            1
#
#        Tire pressure monitoring system  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...
# 15914                              1
# 15915                              1
# 15916                              0
# 15917                              1
# 15918                              1
#
#        Traction control  \
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 15914                 1
# 15915                 1
# 15916                 1
# 15917                 0
# 15918                 0
#
#        Traffic sign recognition  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 15914                         1
# 15915                         1
# 15916                         1
# 15917                         1
# 15918                         1
#
#        Xenon headlights
# 0                     1
# 1                     1
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 15914                 0
# 15915                 0
# 15916                 0
# 15917                 0
# 15918                 0
#
# [15919 rows x 64 columns]

# %% [markdown]
# ### 2. yöntem olarak herbir eleman için olanlara 1 olmayanlara 0 atayarak da aynı sonuca ulaşabiliriz.

# %%
data["ABS"] = np.where(temp[0].str.contains("ABS"), 1, 0)  

data["ABS"]

# %%
data["central_door_lock"] = np.where(temp[0].str.contains("Central door lock"), 1, 0)  

data["central_door_lock"]

# %%
data["daytime_running_lights"] = np.where(temp[0].str.contains("Daytime running lights"), 1, 0)  

data["daytime_running_lights"]

# %%
data["driverside_airbag"] = np.where(temp[0].str.contains("Driver-side airbag"), 1, 0)  

data["driverside_airbag"]

# %%
data["fog_lights"] = np.where(temp[0].str.contains("Fog lights"), 1, 0)  

data["fog_lights"]

# %%
data["xenon_headlights"] = np.where(temp[0].str.contains("Xenon headlights"), 1, 0)  

data["xenon_headlights"]

# %%
data["immobilizer"] = np.where(temp[0].str.contains("Immobilizer"), 1, 0)  

data["immobilizer"]

# %%
data["isofix"] = np.where(temp[0].str.contains("Isofix"), 1, 0)  

data["isofix"]

# %%
data["passengerside_airbag"] = np.where(temp[0].str.contains("Passenger-side airbag"), 1, 0)  

data["passengerside_airbag"]

# %%
data["power_steering"] = np.where(temp[0].str.contains("Power steering"), 1, 0)  

data["power_steering"]

# %%
data["side_airbag"] = np.where(temp[0].str.contains("Side airbag"), 1, 0)  

data["side_airbag"]

# %%
data["tire_pressure_monitoring_system"] = np.where(temp[0].str.contains("Tire pressure monitoring system"), 1, 0)  

data["tire_pressure_monitoring_system"]

# %%
data["traction_control"] = np.where(temp[0].str.contains("Traction control"), 1, 0)  

data["traction_control"]

# %% [markdown]
# ### Description inceleyelim. Bu sütundaki bilgilerin hem dil olarak hem de içerik olarak çok karmaşık bir yapısı olduğundan dolayı bu sütunu düşeceğiz.

# %% [markdown]
# ### Emission Label inceleyelim.

# %%
temp = df['Emission Label'].copy()    # 11974 eksik veri var. Buda çok yüksek bir rakam. Marka model registration dan doldurulabilir.

# %%
data["emission_label"] = temp.apply(pd.Series)[0].str.extract("(\S+)")

# %%
data["emission_label"].value_counts(dropna=False)
# Out:
# NaN    11974
# 4       3553
# 1        381
# 5          8
# 3          2
# 2          1
# Name: emission_label, dtype: int64

# %% [markdown]
# ### Gears inceleyelim.

# %%
temp = df['Gears'].copy()    # 4712 veri eksik.

# %%
data["gears"] = temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data["gears"].value_counts(dropna=False)
# Out:
# 6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 50        1
# 2         1
# Name: gears, dtype: int64

# %% [markdown]
# ### Country version inceleyelim.

# %%
temp = df['Country version'].copy()   # 8333 eksik veri var.

# %%
data["country"] = temp.apply(pd.Series)[0].str.extract("(\w+)")

# %%
data["country"].value_counts(dropna=False)
# Out:
# NaN            8333
# Germany        4502
# Italy          1038
# European        507
# Netherlands     464
# Spain           325
# Belgium         314
# Austria         208
# Czech            52
# Poland           49
# France           38
# Denmark          33
# Hungary          28
# Japan             8
# Croatia           4
# Slovakia          4
# Sweden            3
# Bulgaria          2
# Romania           2
# Serbia            1
# Egypt             1
# Slovenia          1
# Luxembourg        1
# Switzerland       1
# Name: country, dtype: int64

# %%
data.drop("country", axis=1, inplace=True)

# %% [markdown]
# ### Electricity consumption inceleyelim.

# %%
temp = df['Electricity consumption'].copy()   # 137 veri var. Kullanışlı değil. Bu sütunu sileceğiz.

# %%
data["cons_elec"] = temp.apply(pd.Series)[0].str.extract("(\d+)")

# %%
data["cons_elec"].value_counts(dropna=False)
# Out:
# NaN    15782
# 0        137
# Name: cons_elec, dtype: int64

# %% [markdown]
# ### Last Service Date inceleyelim.

# %%
temp = df['Last Service Date'].copy()   # 15353 eksik veri var. Sileceğiz.

# %%
data["Last_Serv"] = temp.apply(pd.Series)[0].str.extract('(\d{4})')

# %%
data["Last_Serv"].value_counts(dropna=False)
# Out:
# NaN     15353
# 2019      316
# 2018      216
# 2017       28
# 2016        6
# Name: Last_Serv, dtype: int64

# %% [markdown]
# ### Other Fuel Types inceleyelim. Veri içeriği boş ve silinecek.

# %%
temp = df['Other Fuel Types'].copy()

# %% [markdown]
# ### Availability inceleyelim.

# %%
temp = df['Availability'].copy()  # 15284 eksik veri var. silinecek.

# %%
data["availability"] = temp.apply(pd.Series)[0].str.extract('(\d{1,3})')

# %%
data["availability"].value_counts(dropna=False)
# Out:
# NaN    15284
# 90       196
# 120      182
# 1         51
# 3         35
# 5         35
# 14        24
# 180       24
# 7         20
# 150       18
# 2         16
# 60        13
# 42        10
# 21         8
# 4          2
# 6          1
# Name: availability, dtype: int64

# %% [markdown]
# ### Last Timing Belt Service Date inceleyelim.

# %%
temp = df['Last Timing Belt Service Date'].copy()   # 15903 veri eksik. Düşelim.

# %%
data["belt_serv"] = temp.apply(pd.Series)[0].str.extract('(\d{4})')

# %%
data["belt_serv"] .value_counts(dropna=False)
# Out:
# NaN     15903
# 2018        5
# 2019        5
# 1900        2
# 2016        2
# 1970        1
# 2017        1
# Name: belt_serv, dtype: int64

# %% [markdown]
# ### Available from inceleyelim. Bu sütunun ne işe yaradığını anlamadım.

# %%
temp = df['Available from'].copy()  # 15647 eksik veri var.

# %%
data["available"] = temp.apply(pd.Series)[0].str.extract('(\d{2}/\d{2}/\d{2})')

# %%
data["available"].value_counts(dropna=False)
# Out:
# NaN         15647
# 31/08/19       98
# 30/07/19       25
# 15/08/19       24
# 16/09/19       14
# 29/06/19       12
# 01/07/19       11
# 28/06/19       10
# 19/08/19        7
# 10/09/19        6
# 27/06/19        5
# 10/11/19        5
# 26/06/19        5
# 08/07/19        4
# 01/08/19        3
# 25/10/19        3
# 15/07/19        3
# 05/07/19        2
# 20/07/19        2
# 30/06/19        2
# 04/07/19        2
# 05/08/19        2
# 24/08/19        2
# 16/07/19        2
# 30/09/19        1
# 18/08/19        1
# 03/08/19        1
# 29/09/19        1
# 29/07/19        1
# 06/12/19        1
# 02/07/19        1
# 16/08/19        1
# 10/10/19        1
# 01/09/19        1
# 27/07/19        1
# 18/07/19        1
# 31/10/19        1
# 24/09/19        1
# 17/08/19        1
# 14/09/19        1
# 10/12/19        1
# 19/07/19        1
# 11/08/19        1
# 24/07/19        1
# 05/12/19        1
# 10/07/19        1
# 03/12/19        1
# Name: available, dtype: int64

# %%
data.head(4)
# Out:
#    make  \
# 0  Audi
# 1  Audi
# 2  Audi
# 3  Audi
#
#   model  \
# 0    A1
# 1    A1
# 2    A1
# 3    A1
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
# 3    Sedans
#
#     cc  \
# 0  1.4
# 1  1.8
# 2  1.6
# 3  1.4
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
# 3  14500
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
# 3              None
#
#       km  \
# 0  56013
# 1  80000
# 2  83450
# 3  73000
#
#    registration  \
# 0        2016.0
# 1        2017.0
# 2        2016.0
# 3        2016.0
#
#    prev_owner  \
# 0         2.0
# 1         NaN
# 2         1.0
# 3         1.0
#
#    power_hp  \
# 0      66.0
# 1     141.0
# 2      85.0
# 3      66.0
#
#   vehicle_condition  \
# 0              Used
# 1              Used
# 2              Used
# 3              Used
#
#   previous_owners  \
# 0               2
# 1             NaN
# 2               1
# 3               1
#
#   Inspection_new  \
# 0            Yes
# 1            NaN
# 2            NaN
# 3            NaN
#
#   body_color  \
# 0      Black
# 1        Red
# 2      Black
# 3      Brown
#
#   paintwork  \
# 0  Metallic
# 1       NaN
# 2  Metallic
# 3  Metallic
#
#       body_color_original  \
# 0           Mythosschwarz
# 1                     NaN
# 2  mythosschwarz metallic
# 3                     NaN
#
#   upholstery  \
# 0      Cloth
# 1      Cloth
# 2      Cloth
# 3        NaN
#
#   interior_color  \
# 0          Black
# 1           Grey
# 2          Black
# 3            NaN
#
#   door_nr  \
# 0       5
# 1       3
# 2       4
# 3       3
#
#   seat_nr  \
# 0       5
# 1       4
# 2       4
# 3       4
#
#   model_code  \
# 0   0588/BDF
# 1   0588/BCY
# 2        NaN
# 3        NaN
#
#         gear  \
# 0  Automatic
# 1  Automatic
# 2  Automatic
# 3  Automatic
#
#   displacement  \
# 0        1,422
# 1        1,798
# 2        1,598
# 3        1,422
#
#   cylinders  \
# 0         3
# 1         4
# 2       NaN
# 3         3
#
#   weight  \
# 0  1,220
# 1  1,255
# 2    NaN
# 3  1,195
#
#       fuel  \
# 0   Diesel
# 1  benzine
# 2   Diesel
# 3   Diesel
#
#   consumption_comb  \
# 0              3.8
# 1              5.6
# 2              3.8
# 3              3.8
#
#   consumption_city  \
# 0              4.3
# 1              7.1
# 2              4.4
# 3              4.3
#
#   consumption_country  \
# 0                 3.5
# 1                 4.7
# 2                 3.4
# 3                 3.5
#
#   CO2_emission  \
# 0           99
# 1          129
# 2           99
# 3           99
#
#   emission_class  \
# 0         Euro 6
# 1         Euro 6
# 2         Euro 6
# 3         Euro 6
#
#              comfort_convenience  \
# 0  Air conditioning,Armrest,A...
# 1  Air conditioning,Automatic...
# 2  Air conditioning,Cruise co...
# 3  Air suspension,Armrest,Aux...
#
#                    entertainment  \
# 0  Bluetooth,Hands-free equip...
# 1  Bluetooth,Hands-free equip...
# 2          MP3,On-board computer
# 3  Bluetooth,CD player,Hands-...
#
#                           Extras  \
# 0  Alloy wheels,Catalytic Con...
# 1  Alloy wheels,Sport seats,S...
# 2     Alloy wheels,Voice Control
# 3  Alloy wheels,Sport seats,V...
#
#                  safety_security
# 0  ABS,Central door lock,Dayt...
# 1  ABS,Central door lock,Cent...
# 2  ABS,Central door lock,Dayt...
# 3  ABS,Alarm system,Central d...

# %%
data.to_csv("Autoscout_data_cleaning.csv", index=False)
