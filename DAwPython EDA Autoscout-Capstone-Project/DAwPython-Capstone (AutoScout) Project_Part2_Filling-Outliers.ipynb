# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 10)
pd.set_option('display.max_colwidth', 50)

# %%
data = pd.read_csv('AutoScout_data_cleaning.csv')
data.head(3)
# Out:
#    make  \
# 0  Audi
# 1  Audi
# 2  Audi
#
#   model  \
# 0    A1
# 1    A1
# 2    A1
#
#   body_type  \
# 0    Sedans
# 1    Sedans
# 2    Sedans
#
#     cc  \
# 0  1.4
# 1  1.8
# 2  1.6
#
#    price  \
# 0  15770
# 1  14500
# 2  14640
#
#                 vat  \
# 0    VAT deductible
# 1  Price negotiable
# 2    VAT deductible
#
#         km  \
# 0  56013.0
# 1  80000.0
# 2  83450.0
#
#    registration  \
# 0        2016.0
# 1        2017.0
# 2        2016.0
#
#    prev_owner  \
# 0         2.0
# 1         NaN
# 2         1.0
#
#    power_hp  \
# 0      66.0
# 1     141.0
# 2      85.0
#
#   vehicle_condition  \
# 0              Used
# 1              Used
# 2              Used
#
#    previous_owners  \
# 0              2.0
# 1              NaN
# 2              1.0
#
#   Inspection_new  \
# 0            Yes
# 1            NaN
# 2            NaN
#
#   body_color  \
# 0      Black
# 1        Red
# 2      Black
#
#   paintwork  \
# 0  Metallic
# 1       NaN
# 2  Metallic
#
#       body_color_original  \
# 0           Mythosschwarz
# 1                     NaN
# 2  mythosschwarz metallic
#
#   upholstery  \
# 0      Cloth
# 1      Cloth
# 2      Cloth
#
#   interior_color  \
# 0          Black
# 1           Grey
# 2          Black
#
#    door_nr  \
# 0      5.0
# 1      3.0
# 2      4.0
#
#    seat_nr  \
# 0      5.0
# 1      4.0
# 2      4.0
#
#   model_code  \
# 0   0588/BDF
# 1   0588/BCY
# 2        NaN
#
#         gear  \
# 0  Automatic
# 1  Automatic
# 2  Automatic
#
#   displacement  \
# 0        1,422
# 1        1,798
# 2        1,598
#
#    cylinders  \
# 0        3.0
# 1        4.0
# 2        NaN
#
#   weight  \
# 0  1,220
# 1  1,255
# 2    NaN
#
#       fuel  \
# 0   Diesel
# 1  benzine
# 2   Diesel
#
#    consumption_comb  \
# 0               3.8
# 1               5.6
# 2               3.8
#
#    consumption_city  \
# 0               4.3
# 1               7.1
# 2               4.4
#
#    consumption_country  \
# 0                  3.5
# 1                  4.7
# 2                  3.4
#
#    CO2_emission  \
# 0          99.0
# 1         129.0
# 2          99.0
#
#   emission_class  \
# 0         Euro 6
# 1         Euro 6
# 2         Euro 6
#
#                                  comfort_convenience  \
# 0  Air conditioning,Armrest,Automatic climate con...
# 1  Air conditioning,Automatic climate control,Hil...
# 2  Air conditioning,Cruise control,Electrical sid...
#
#                                        entertainment  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
#
#                                      safety_security  \
# 0  ABS,Central door lock,Daytime running lights,D...
# 1  ABS,Central door lock,Central door lock with r...
# 2  ABS,Central door lock,Daytime running lights,D...
#
#    gears
# 0    NaN
# 1    7.0
# 2    NaN

# %%
# data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make                 15919 non-null  object
#  1   model                15919 non-null  object
#  2   body_type            15859 non-null  object
#  3   cc                   10851 non-null  float64
#  4   price                15919 non-null  int64
#  5   vat                  11406 non-null  object
#  6   km                   14895 non-null  float64
#  7   registration         14322 non-null  float64
#  8   prev_owner           9091 non-null   float64
#  9   power_hp             15831 non-null  float64
#  10  vehicle_condition    15917 non-null  object
#  11  previous_owners      9279 non-null   float64
#  12  Inspection_new       3932 non-null   object
#  13  body_color           15322 non-null  object
#  14  paintwork            10147 non-null  object
#  15  body_color_original  12145 non-null  object
#  16  upholstery           12199 non-null  object
#  17  interior_color       10049 non-null  object
#  18  door_nr              15707 non-null  float64
#  19  seat_nr              14942 non-null  float64
#  20  model_code           4978 non-null   object
#  21  gear                 15919 non-null  object
#  22  displacement         15384 non-null  object
#  23  cylinders            10239 non-null  float64
#  24  weight               8943 non-null   object
#  25  fuel                 15919 non-null  object
#  26  consumption_comb     13994 non-null  float64
#  27  consumption_city     13483 non-null  float64
#  28  consumption_country  13543 non-null  float64
#  29  CO2_emission         13483 non-null  float64
#  30  emission_class       12291 non-null  object
#  31  comfort_convenience  14999 non-null  object
#  32  entertainment        14545 non-null  object
#  33  Extras               12957 non-null  object
#  34  safety_security      14937 non-null  object
# dtypes: float64(13), int64(1), object(21)
# memory usage: 4.3+ MB

# %% [markdown]
# ### "make" sütununda verilerde eksik yok.

# %%
# data["make"].value_counts(dropna=False)
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: make, dtype: int64

# %%
sns.barplot(x="make", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="make", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "model" sütununda verilerde eksik yok.

# %%
# data["model"].value_counts(dropna=False)
# Out:
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: model, dtype: int64

# %%
sns.barplot(x="model", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="model", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "price" sütununda verilerde eksik yok.

# %%
# data["price"].value_counts(dropna=False)
# Out:
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 31940      1
# 15540      1
# 21649      1
# 27790      1
# 34815      1
# Name: price, Length: 2956, dtype: int64

# %%
data["price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### "body_type" sütununda 60 eksik değer var. Bunları "model" bazında "body_type" mode() ile doldurdum.

# %%
# data["body_type"].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
# data[~data["body_type"].notna()][["model","registration","model_code","body_type"]]

# %% [raw]
# # 1.yöntem:
#
# # data["body_type"] = data["body_type"].fillna(data["body_type"].mode()[0])

# %% [raw]
# # 2. yöntem: Bütün eksik body_type lara karşı gelen modeller için uygulamamız gerekir.
#
# # data.loc[data["model"]=="A3","body_type"].fillna(data[data["model"]=="A3"]["body_type"].mode()[0])

# %% [raw]
# # 3. yöntem:
#
# for group in list(data["model"].unique()):
#     cond = data["model"] == group
#     mode = list(data[cond]["body_type"].mode())
#     if mode != []:
#         data.loc[cond, "body_type"] = data.loc[cond, "body_type"].fillna(data[cond]["body_type"].mode()[0])
#     else :
#         data.loc[cond, "body_type"] = data.loc[cond, "body_type"].fillna(data["body_type"].mode()[0])

# %%
# 4. yöntem :

f= lambda x : x.mode().iloc[0]

data["body_type"] = data["body_type"].fillna(data.groupby("model")["body_type"].transform(f))

# %%
# data["body_type"].value_counts(dropna=False)  # 1.yöntemi kullanırsak.
# Out:
# Sedans           7963
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
# data["body_type"].value_counts(dropna=False)   # 3. ve 4. yöntemi kullanırsak aynı sonuca ulaşıyoruzb
# Out:
# Sedans           7925
# Station wagon    3563
# Compact          3155
# Van               809
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
sns.barplot(x="body_type", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="body_type", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "vehicle_condition" sütununda 2 eksik değer var. Değer sayısı az olduğundan dolayı "km", "price" ve "model" göre bazında manuel olarak used ile doldurdum.

# %%
# data["vehicle_condition"].value_counts(dropna=False)
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: vehicle_condition, dtype: int64

# %%
# data.loc[~data["vehicle_condition"].notna()]
# Out:
#       make model body_type   cc  price  vat  \
# 2765  Audi    A3    Sedans  2.0  17900  NaN
# 5237  Audi    A3    Sedans  1.6  25400  NaN
#
#             km  registration  prev_owner  \
# 2765  115137.0        2016.0         NaN
# 5237       NaN           NaN         NaN
#
#       power_hp vehicle_condition  \
# 2765     110.0               NaN
# 5237      85.0               NaN
#
#       previous_owners Inspection_new body_color  \
# 2765              NaN            NaN      White
# 5237              NaN            NaN       Grey
#
#      paintwork body_color_original upholstery  \
# 2765       NaN                 NaN      Cloth
# 5237       NaN                 NaN      Cloth
#
#      interior_color  door_nr  seat_nr  \
# 2765          Other      5.0      5.0
# 5237          Other      5.0      5.0
#
#      model_code       gear displacement  \
# 2765        NaN  Automatic        1,968
# 5237        NaN  Automatic        1,598
#
#       cylinders weight    fuel  \
# 2765        4.0    NaN  Diesel
# 5237        4.0    NaN  Diesel
#
#       consumption_comb  consumption_city  \
# 2765               4.5               5.3
# 5237               3.9               4.1
#
#       consumption_country  CO2_emission  \
# 2765                  4.1         118.0
# 5237                  3.7         103.0
#
#      emission_class comfort_convenience  \
# 2765         Euro 6    Air conditioning
# 5237         Euro 6    Air conditioning
#
#                        entertainment  \
# 2765  Bluetooth,Hands-free equipment
# 5237  Bluetooth,Hands-free equipment
#
#                                          Extras  \
# 2765  Alloy wheels,Sport seats,Sport suspension
# 5237                               Alloy wheels
#
#                                                                                           safety_security
# 2765  ABS,Central door lock,Driver-side airbag,Isofix,Passenger-side airbag,Power steering,Side airbag...
# 5237  ABS,Central door lock,Driver-side airbag,Isofix,Passenger-side airbag,Power steering,Side airbag...

# %%
data.loc[~data["vehicle_condition"].notna(), "vehicle_condition"] = data.loc[~data["vehicle_condition"].notna(), "vehicle_condition"].fillna("Used")

# %%
# data["vehicle_condition"].value_counts(dropna=False)
# Out:
# Used              11098
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: vehicle_condition, dtype: int64

# %%
sns.barplot(x="vehicle_condition", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="vehicle_condition", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "km" sütununda 1024 eksik değer var. Bunları önce "vehicle_condition" new olanları 0 ile doldurdum. Sonrasında ise "model", "body_type" ve "vehicle_condition" göre gruplandırıp "km" mean() ile doldurdum.

# %%
# data["km"].value_counts(dropna=False)
# Out:
# 10.0        1045
# NaN         1024
# 1.0          367
# 5.0          170
# 50.0         148
#             ...
# 160542.0       1
# 20719.0        1
# 91910.0        1
# 39860.0        1
# 57889.0        1
# Name: km, Length: 6690, dtype: int64

# %%
data.loc[(~data["km"].notna()) & (data["vehicle_condition"]=="New"),"km"] = 0

# %%
# data.loc[(~data["km"].notna())]
# Out:
#           make   model body_type   cc  price  \
# 981       Audi      A1    Sedans  1.4  20999
# 983       Audi      A1    Sedans  1.4  20999
# 1075      Audi      A1    Sedans  1.4  19999
# 1904      Audi      A1    Sedans  NaN  27650
# 1934      Audi      A1    Sedans  NaN  28499
# ...        ...     ...       ...  ...    ...
# 15782  Renault  Espace       Van  1.6  34150
# 15806  Renault  Espace       Van  NaN  40999
# 15837  Renault  Espace       Van  NaN  47450
# 15844  Renault  Espace       Van  NaN  46666
# 15918  Renault  Espace       Van  NaN  40999
#
#                   vat  km  registration  \
# 981    VAT deductible NaN        2018.0
# 983    VAT deductible NaN        2018.0
# 1075   VAT deductible NaN        2018.0
# 1904   VAT deductible NaN        2019.0
# 1934   VAT deductible NaN        2019.0
# ...               ...  ..           ...
# 15782  VAT deductible NaN        2018.0
# 15806  VAT deductible NaN        2019.0
# 15837  VAT deductible NaN        2019.0
# 15844  VAT deductible NaN        2019.0
# 15918  VAT deductible NaN        2019.0
#
#        prev_owner  power_hp vehicle_condition  \
# 981           1.0      66.0    Pre-registered
# 983           1.0      66.0    Pre-registered
# 1075          1.0      66.0    Pre-registered
# 1904          NaN      85.0    Pre-registered
# 1934          1.0      85.0    Pre-registered
# ...           ...       ...               ...
# 15782         NaN     118.0    Pre-registered
# 15806         1.0     165.0     Demonstration
# 15837         1.0     118.0    Pre-registered
# 15844         1.0     147.0     Demonstration
# 15918         1.0     165.0     Demonstration
#
#        previous_owners Inspection_new  \
# 981                1.0            NaN
# 983                1.0            NaN
# 1075               1.0            NaN
# 1904               NaN            NaN
# 1934               1.0            NaN
# ...                ...            ...
# 15782              NaN            NaN
# 15806              1.0            Yes
# 15837              1.0            NaN
# 15844              1.0            Yes
# 15918              1.0            Yes
#
#       body_color  paintwork body_color_original  \
# 981        White  Uni/basic     BIANCO GHIACCIO
# 983         Grey  Uni/basic      Grigio Freccia
# 1075       White  Uni/basic     BIANCO GHIACCIO
# 1904       White   Metallic              Bianco
# 1934        Grey   Metallic      Grigio Chronos
# ...          ...        ...                 ...
# 15782       Grey   Metallic        Grigio scuro
# 15806      Black   Metallic         Black Pearl
# 15837      Black   Metallic      amethyst black
# 15844      Black   Metallic         Black Pearl
# 15918       Grey   Metallic       Titanium-Grau
#
#          upholstery interior_color  door_nr  \
# 981             NaN            NaN      5.0
# 983             NaN            NaN      5.0
# 1075            NaN            NaN      5.0
# 1904          Cloth          Black      5.0
# 1934            NaN            NaN      5.0
# ...             ...            ...      ...
# 15782  Full leather          Beige      5.0
# 15806  Full leather          Brown      5.0
# 15837  Full leather          Black      5.0
# 15844  Full leather           Grey      5.0
# 15918  Full leather          Brown      5.0
#
#        seat_nr model_code       gear  \
# 981        4.0        NaN  Automatic
# 983        4.0        NaN  Automatic
# 1075       4.0        NaN  Automatic
# 1904       4.0        NaN  Automatic
# 1934       5.0        NaN  Automatic
# ...        ...        ...        ...
# 15782      7.0        NaN  Automatic
# 15806      5.0   3333/BHJ  Automatic
# 15837      5.0        NaN  Automatic
# 15844      5.0   3333/BKQ  Automatic
# 15918      5.0   3333/BHJ  Automatic
#
#       displacement  cylinders weight     fuel  \
# 981          1,422        NaN    NaN   Diesel
# 983          1,422        NaN    NaN   Diesel
# 1075         1,422        NaN    NaN   Diesel
# 1904           999        3.0  1,255  benzine
# 1934           999        NaN    NaN  benzine
# ...            ...        ...    ...      ...
# 15782        1,598        4.0  1,659   Diesel
# 15806        1,798        4.0  1,685  benzine
# 15837        1,598        4.0  1,734   Diesel
# 15844        1,997        4.0  1,840   Diesel
# 15918        1,798        4.0  1,685  benzine
#
#        consumption_comb  consumption_city  \
# 981                 NaN               NaN
# 983                 NaN               NaN
# 1075                NaN               NaN
# 1904                4.8               5.8
# 1934                NaN               NaN
# ...                 ...               ...
# 15782               4.7               5.1
# 15806               6.8               8.7
# 15837               4.7               5.1
# 15844               5.7               6.1
# 15918               6.8               8.7
#
#        consumption_country  CO2_emission  \
# 981                    NaN           NaN
# 983                    NaN           NaN
# 1075                   NaN           NaN
# 1904                   4.2         108.0
# 1934                   NaN           NaN
# ...                    ...           ...
# 15782                  4.4         120.0
# 15806                  5.7         153.0
# 15837                  4.4         123.0
# 15844                  5.3         148.0
# 15918                  5.7         153.0
#
#       emission_class  \
# 981           Euro 6
# 983           Euro 6
# 1075          Euro 6
# 1904          Euro 6
# 1934             NaN
# ...              ...
# 15782            NaN
# 15806         Euro 6
# 15837         Euro 6
# 15844         Euro 6
# 15918         Euro 6
#
#                                                                                        comfort_convenience  \
# 981      Air conditioning,Automatic climate control,Electrical side mirrors,Power windows,Split rear seats
# 983                              Air conditioning,Automatic climate control,Power windows,Split rear seats
# 1075                             Air conditioning,Automatic climate control,Power windows,Split rear seats
# 1904   Air conditioning,Automatic climate control,Electrical side mirrors,Leather steering wheel,Multi-...
# 1934   Air conditioning,Automatic climate control,Electrical side mirrors,Park Distance Control,Parking...
# ...                                                                                                    ...
# 15782  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
# 15806  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
# 15837  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
# 15844  Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Electric tailg...
# 15918  Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electric...
#
#                                                                       entertainment  \
# 981                                                                             NaN
# 983                                                                             NaN
# 1075                                                                            NaN
# 1904                                                            Bluetooth,Radio,USB
# 1934                                                                      Bluetooth
# ...                                                                             ...
# 15782                                         Bluetooth,MP3,On-board computer,Radio
# 15806                                                                           USB
# 15837  Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB
# 15844                                                                           USB
# 15918                                                                           USB
#
#                                               Extras  \
# 981                                     Alloy wheels
# 983                                     Alloy wheels
# 1075                                    Alloy wheels
# 1904                                    Alloy wheels
# 1934                                    Alloy wheels
# ...                                              ...
# 15782                                   Alloy wheels
# 15806                      Alloy wheels,Touch screen
# 15837  Alloy wheels,Catalytic Converter,Touch screen
# 15844                      Alloy wheels,Touch screen
# 15918                      Alloy wheels,Touch screen
#
#                                                                                            safety_security
# 981    Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stability ...
# 983    Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stability ...
# 1075   Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stability ...
# 1904   ABS,Central door lock,Driver-side airbag,Electronic stability control,Emergency brake assistant,...
# 1934   ABS,Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stabil...
# ...                                                                                                    ...
# 15782  ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Pas...
# 15806  ABS,Blind spot monitor,Daytime running lights,Driver-side airbag,Electronic stability control,Em...
# 15837  ABS,Adaptive Cruise Control,Blind spot monitor,Daytime running lights,Driver-side airbag,Electro...
# 15844  ABS,Blind spot monitor,Daytime running lights,Driver-side airbag,Electronic stability control,Em...
# 15918  ABS,Blind spot monitor,Daytime running lights,Driver-side airbag,Electronic stability control,Em...
#
# [175 rows x 35 columns]

# %%
f= lambda x : x.mean()        

data["km"] = data["km"].fillna(data.groupby(["model","body_type","vehicle_condition"])["km"].transform(f))

# %%
data["km"] = np.round(data["km"], 1)

# %%
# data[~data["km"].notna()]
# Out:
#           make  \
# 7622      Opel
# 9519      Opel
# 15430  Renault
# 15545  Renault
#
#         model  \
# 7622    Astra
# 9519    Corsa
# 15430  Espace
# 15545  Espace
#
#          body_type  \
# 7622         Coupe
# 9519   Transporter
# 15430       Sedans
# 15545       Sedans
#
#         cc  \
# 7622   NaN
# 9519   1.2
# 15430  NaN
# 15545  NaN
#
#        price  \
# 7622   29990
# 9519    9700
# 15430  30900
# 15545  30900
#
#                   vat  \
# 7622   VAT deductible
# 9519              NaN
# 15430             NaN
# 15545             NaN
#
#        km  \
# 7622  NaN
# 9519  NaN
# 15430 NaN
# 15545 NaN
#
#        registration  \
# 7622         2019.0
# 9519         2019.0
# 15430        2018.0
# 15545        2018.0
#
#        prev_owner  \
# 7622          1.0
# 9519          NaN
# 15430         NaN
# 15545         NaN
#
#        power_hp  \
# 7622      110.0
# 9519       51.0
# 15430     118.0
# 15545     118.0
#
#       vehicle_condition  \
# 7622      Demonstration
# 9519     Employee's car
# 15430    Pre-registered
# 15545    Pre-registered
#
#        previous_owners  \
# 7622               1.0
# 9519               NaN
# 15430              NaN
# 15545              NaN
#
#       Inspection_new  \
# 7622             NaN
# 9519             NaN
# 15430            NaN
# 15545            NaN
#
#       body_color  \
# 7622        Blue
# 9519         Red
# 15430      White
# 15545      White
#
#        paintwork  \
# 7622    Metallic
# 9519   Uni/basic
# 15430  Uni/basic
# 15545  Uni/basic
#
#       body_color_original  \
# 7622         tiefsee blau
# 9519                Rosso
# 15430              Bianco
# 15545              Bianco
#
#          upholstery  \
# 7622          Cloth
# 9519          Cloth
# 15430  Part leather
# 15545  Part leather
#
#       interior_color  \
# 7622           Other
# 9519            Grey
# 15430          Black
# 15545          Black
#
#        door_nr  \
# 7622       5.0
# 9519       5.0
# 15430      5.0
# 15545      5.0
#
#        seat_nr  \
# 7622       NaN
# 9519       4.0
# 15430      7.0
# 15545      7.0
#
#       model_code  \
# 7622         NaN
# 9519         NaN
# 15430        NaN
# 15545        NaN
#
#             gear  \
# 7622   Automatic
# 9519      Manual
# 15430  Automatic
# 15545  Automatic
#
#       displacement  \
# 7622         1,399
# 9519         1,229
# 15430        1,600
# 15545        1,600
#
#        cylinders  \
# 7622         4.0
# 9519         4.0
# 15430        4.0
# 15545        4.0
#
#       weight  \
# 7622   1,350
# 9519   1,163
# 15430    NaN
# 15545    NaN
#
#           fuel  \
# 7622   benzine
# 9519   benzine
# 15430   Diesel
# 15545   Diesel
#
#        consumption_comb  \
# 7622                5.8
# 9519                5.3
# 15430               NaN
# 15545               NaN
#
#        consumption_city  \
# 7622                7.4
# 9519                6.6
# 15430               NaN
# 15545               NaN
#
#        consumption_country  \
# 7622                   4.9
# 9519                   4.5
# 15430                  NaN
# 15545                  NaN
#
#        CO2_emission  \
# 7622          134.0
# 9519          124.0
# 15430           NaN
# 15545           NaN
#
#       emission_class  \
# 7622          Euro 6
# 9519          Euro 6
# 15430            NaN
# 15545            NaN
#
#                                      comfort_convenience  \
# 7622   Air conditioning,Armrest,Automatic climate con...
# 9519                      Air conditioning,Power windows
# 15430  Air conditioning,Automatic climate control,Cru...
# 15545  Air conditioning,Automatic climate control,Cru...
#
#                                            entertainment  \
# 7622                  Bluetooth,Hands-free equipment,USB
# 9519                                               Radio
# 15430  Bluetooth,Hands-free equipment,MP3,On-board co...
# 15545  Bluetooth,Hands-free equipment,MP3,On-board co...
#
#                           Extras  \
# 7622         Catalytic Converter
# 9519                Touch screen
# 15430  Alloy wheels,Touch screen
# 15545  Alloy wheels,Touch screen
#
#                                          safety_security  \
# 7622   ABS,Adaptive headlights,Central door lock,Dayt...
# 9519   ABS,Central door lock,Driver-side airbag,Elect...
# 15430  ABS,Central door lock,Daytime running lights,D...
# 15545  ABS,Central door lock,Daytime running lights,D...
#
#        gears
# 7622     NaN
# 9519     5.0
# 15430    6.0
# 15545    6.0

# %%
# data.groupby(["model", "body_type", "vehicle_condition"]).km.describe().head(100)

# %%
data.loc[(~data["km"].notna()) & (data["vehicle_condition"]=="Demonstration"),"km"] = 0
data.loc[(~data["km"].notna()) & (data["vehicle_condition"]=="Pre-registered"),"km"] = 10
data.loc[(~data["km"].notna()) & (data["vehicle_condition"]=="Employee's car"),"km"] = 2000

# %%
# data.groupby(["model", "body_type", "vehicle_condition"]).price.describe()  #"registration" ilave edilebilir.
# Out:
#                                            count  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration        75.0
#                        Employee's car       79.0
#                        New                 248.0
#                        Pre-registered       19.0
#                        Used                618.0
# ...                                          ...
# Insignia Station wagon Employee's car      115.0
#                        New                 206.0
#                        Pre-registered       51.0
#                        Used               1138.0
#          Van           Employee's car        1.0
#
#                                                   mean  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      23404.546667
#                        Employee's car     19955.455696
#                        New                23432.568548
#                        Pre-registered     23055.000000
#                        Used               16758.276699
# ...                                                ...
# Insignia Station wagon Employee's car     21677.852174
#                        New                31780.373786
#                        Pre-registered     31558.666667
#                        Used               18001.152021
#          Van           Employee's car     20980.000000
#
#                                                   std  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      4097.006937
#                        Employee's car     3803.376017
#                        New                3523.311326
#                        Pre-registered     2307.272921
#                        Used               3180.778682
# ...                                               ...
# Insignia Station wagon Employee's car     2255.544841
#                        New                5634.808637
#                        Pre-registered     4564.469199
#                        Used               5038.105438
#          Van           Employee's car             NaN
#
#                                               min  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      14900.0
#                        Employee's car     13500.0
#                        New                16220.0
#                        Pre-registered     20885.0
#                        Used                9950.0
# ...                                           ...
# Insignia Station wagon Employee's car     18490.0
#                        New                21992.0
#                        Pre-registered     20890.0
#                        Used                8290.0
#          Van           Employee's car     20980.0
#
#                                                25%  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      20970.00
#                        Employee's car     16684.50
#                        New                20800.75
#                        Pre-registered     21435.00
#                        Used               14890.00
# ...                                            ...
# Insignia Station wagon Employee's car     19945.00
#                        New                26571.25
#                        Pre-registered     29995.00
#                        Used               14050.00
#          Van           Employee's car     20980.00
#
#                                               50%  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      22900.0
#                        Employee's car     19700.0
#                        New                22492.5
#                        Pre-registered     22140.0
#                        Used               15955.0
# ...                                           ...
# Insignia Station wagon Employee's car     21390.0
#                        New                32022.0
#                        Pre-registered     31500.0
#                        Used               17870.0
#          Van           Employee's car     20980.0
#
#                                                75%  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      26985.00
#                        Employee's car     22495.00
#                        New                27002.50
#                        Pre-registered     23552.50
#                        Used               18433.00
# ...                                            ...
# Insignia Station wagon Employee's car     22890.00
#                        New                36129.50
#                        Pre-registered     33336.00
#                        Used               21386.75
#          Van           Employee's car     20980.00
#
#                                               max
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      29197.0
#                        Employee's car     28600.0
#                        New                31990.0
#                        Pre-registered     28875.0
#                        Used               28900.0
# ...                                           ...
# Insignia Station wagon Employee's car     32500.0
#                        New                52120.0
#                        Pre-registered     40450.0
#                        Used               44970.0
#          Van           Employee's car     20980.0
#
# [156 rows x 8 columns]

# %%
data["km"].plot();

# %%
sns.boxplot(x=data.km)
# Out:
# <AxesSubplot:xlabel='km'>

# %% [markdown]
# Burada aykırı olabilecek değerleri belirledim.
#
# Q1 = data.km.quantile(0.25)
# Q3 = data.km.quantile(0.75)
# IQR = Q3-Q1
#
# down_lev= Q1-1.5*IQR
# up_lev= Q3+1.5*IQR
#
# (data.km< down_lev) | (data.km > up_lev)
#
# outlier = ((data.km< down_lev) | (data.km > up_lev))
#
# data[outlier]   # outlier olanları getirir.

# %% [markdown]
# Bu yöntem ile outlier olanları direkt olarak silebiliriz.
#
# clean_data = data[~outlier]
#
# clean_data.shape

# %%
Bu yöntem ile outlier olanları ortalama ile doldurabiliriz.

data.km.mean()

data[outlier] = data.km.mean()

# %%
Bu yöntem ile outlier olanlara baskılama yöntemini uyguluyorum yanı üst tarafta olanları üst değere
alt tarafta olanları ise alt tarafa eşitliyorum.

data.loc[(data.km < down_lev), "km"] = down_lev

data.loc[(data.km > up_lev), "km"] = up_lev

# %% [markdown]
# ### "vat" sütununda 4513 eksik veri var. Bu veri diğer değişkenlerden bağımsız olduğundan dolayı herhangi bir sütun ile ilişkilendirilemedi. Bu özellik satın alan kişinin VAT indiriminden yararlanıp yararlanamayacağı ve arabanın registration ile ilgili olabileceğinden "vat" mode() ile doldurdum.

# %%
# data["vat"].value_counts(dropna=False)
# Out:
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %%
# data[~data["vat"].notna()].groupby(["model", "body_type", "vehicle_condition"]).price.describe()  # 4513 eksik veri var.
# Out:
#                                           count          mean          std      min      25%  \
# model    body_type     vehicle_condition
# A1       Compact       Employee's car       9.0  22753.333333  6209.092124  13500.0  16900.0
#                        New                 28.0  20807.785714  3514.105991  16220.0  18670.0
#                        Pre-registered       5.0  21760.000000   813.633824  20990.0  21190.0
#                        Used               215.0  15785.423256  2333.688421  11100.0  14425.0
#          Other         Used                 1.0  23490.000000          NaN  23490.0  23490.0
# ...                                         ...           ...          ...      ...      ...
# Insignia Station wagon Demonstration       11.0  32386.363636  5699.382901  19200.0  28985.0
#                        Employee's car      15.0  22607.333333  2257.402004  20900.0  21090.0
#                        New                 36.0  28041.888889  4728.323368  21992.0  24203.0
#                        Pre-registered       7.0  32728.571429  2308.473006  30000.0  31150.0
#                        Used               238.0  16468.344538  4148.735883   9000.0  13857.5
#
#                                               50%       75%      max
# model    body_type     vehicle_condition
# A1       Compact       Employee's car     22990.0  28400.00  28600.0
#                        New                20091.0  21870.75  29181.0
#                        Pre-registered     21490.0  22140.00  22990.0
#                        Used               15500.0  16462.00  28750.0
#          Other         Used               23490.0  23490.00  23490.0
# ...                                           ...       ...      ...
# Insignia Station wagon Demonstration      34490.0  36390.00  38590.0
#                        Employee's car     22500.0  22940.00  29900.0
#                        New                26682.0  30474.25  39977.0
#                        Pre-registered     32500.0  33700.00  36900.0
#                        Used               15594.5  18800.00  33900.0
#
# [112 rows x 8 columns]

# %%
# data[data["vat"].notna()].groupby(["model", "body_type", "vehicle_condition"]).price.describe()
# Out:
#                                           count          mean          std      min       25%  \
# model    body_type     vehicle_condition
# A1       Compact       Demonstration       75.0  23404.546667  4097.006937  14900.0  20970.00
#                        Employee's car      70.0  19595.728571  3275.708278  15444.0  16682.25
#                        New                220.0  23766.631818  3389.017250  17330.0  21165.00
#                        Pre-registered      14.0  23517.500000  2508.375777  20885.0  21435.00
#                        Used               403.0  17277.292804  3442.815152   9950.0  14969.50
# ...                                         ...           ...          ...      ...       ...
# Insignia Station wagon Employee's car     100.0  21538.430000  2233.193194  18490.0  19900.00
#                        New                170.0  32572.052941  5502.435370  22167.0  27950.00
#                        Pre-registered      44.0  31372.545455  4819.147177  20890.0  29733.75
#                        Used               900.0  18406.494444  5174.766642   8290.0  14480.00
#          Van           Employee's car       1.0  20980.000000          NaN  20980.0  20980.00
#
#                                               50%       75%      max
# model    body_type     vehicle_condition
# A1       Compact       Demonstration      22900.0  26985.00  29197.0
#                        Employee's car     19225.0  21893.75  27400.0
#                        New                22590.0  27380.00  31990.0
#                        Pre-registered     23475.0  25257.50  28875.0
#                        Used               16445.0  19900.00  28900.0
# ...                                           ...       ...      ...
# Insignia Station wagon Employee's car     20990.0  22760.00  32500.0
#                        New                33236.5  36860.25  52120.0
#                        Pre-registered     31200.0  33051.75  40450.0
#                        Used               18470.0  21800.00  44970.0
#          Van           Employee's car     20980.0  20980.00  20980.0
#
# [141 rows x 8 columns]

# %%
data["vat"] = data["vat"].fillna(data["vat"].mode()[0])

# %%
# data["vat"].value_counts(dropna=False)
# Out:
# VAT deductible      15493
# Price negotiable      426
# Name: vat, dtype: int64

# %% [markdown]
# ### "registration" sütununda 1597 eksik veri var. Eksik verileri tamamlarken öncelikle "registration" dolu olanların yıllara göre "km" olarak ortalamalarını aldım. Ayrıca toplam yıllık ortalamanın 35000 olduğunu gördüm. Sonrasında ise 2018 ve 2019 yıllarının ortalaması olan 10000 km ve tüm veri setinin yıllara göre ortalaması olan 35000 km ye göre doldurma işlemi yaptım. "km"<10000 olanları 2019 yılı ile doldurdum. Sonrasında kalanları ise km/35000 yaparak buradan bir sayı buldum ve bunu 2019 yılından çıkararak çıkan yıl değeri ile doldurdum.

# %%
# data["registration"].value_counts(dropna=False)
# Out:
# 2018.0    4522
# 2016.0    3674
# 2017.0    3273
# 2019.0    2853
# NaN       1597
# Name: registration, dtype: int64

# %%
# data.loc[(~data["registration"].notna()) & (data["model_code"].notna()) & (data["km"]==0), ["model","body_type","model_code"]].head(100) # & (data["vehicle_condition"]=="New"),"km"]
# Out:
#           model      body_type model_code
# 977          A1        Compact   0588/BHM
# 1064         A1        Compact   0588/BDB
# 1098         A1        Compact   0588/BHM
# 1395         A1         Sedans   0588/AUJ
# 1467         A1        Compact   0588/BHM
# 1698         A1        Compact   0588/BHM
# 2000         A1        Compact   0588/BNP
# 2014         A1        Compact   0588/BHM
# 2015         A1        Compact   0588/BNP
# 2097         A1        Compact   0588/BHM
# 2113         A1        Compact   0588/BHM
# 2124         A1        Compact   0588/BHM
# 2168         A1        Compact   0588/BHM
# 2180         A1        Compact   0588/BHM
# 2269         A1        Compact   0588/BHM
# 2338         A1        Compact   0588/BHM
# 2343         A1        Compact   0588/BDB
# 2546         A1        Compact   0588/BHM
# 3753         A3  Station wagon   0588/BHX
# 3812         A3         Sedans   0588/BIB
# 3884         A3  Station wagon   0588/BHX
# 4198         A3  Station wagon   0588/BHX
# 4394         A3         Sedans   0588/BIB
# 4520         A3  Station wagon   0588/BHX
# 4924         A3  Station wagon   0588/BHX
# 4993         A3         Sedans   0588/BHX
# 4994         A3         Sedans   0588/BLH
# 4995         A3         Sedans   0588/BLH
# 5016         A3         Sedans   0588/BLL
# 5021         A3         Sedans   0588/BLL
# 5022         A3         Sedans   0588/000
# 5063         A3  Station wagon   0588/BHX
# 5098         A3  Station wagon   0588/BLL
# 5100         A3         Sedans   0588/BHX
# 5128         A3  Station wagon   0588/BHX
# 5148         A3         Sedans   0588/BHX
# 5151         A3         Sedans   0588/BHX
# 5152         A3         Sedans   0588/BHX
# 5158         A3         Sedans   0588/BHX
# 5195         A3  Station wagon   0588/BLL
# 5209         A3         Sedans   0588/BLL
# 5268         A3  Station wagon   0588/BHX
# 5286         A3  Station wagon   0588/BHX
# 5293         A3         Sedans   0588/BLH
# 5327         A3  Station wagon   0588/BHX
# 5341         A3  Station wagon   0588/BHX
# 5347         A3  Station wagon   0000/000
# 5348         A3  Station wagon   0588/BHX
# 5349         A3         Sedans   0588/BLH
# 5350         A3  Station wagon   0000/000
# 5370         A3  Station wagon   0588/BHX
# 5435         A3  Station wagon   0588/BHX
# 5498         A3         Sedans   0588/BLH
# 5505         A3         Sedans   0588/BLH
# 5513         A3  Station wagon   0588/BHX
# 5514         A3  Station wagon   0588/BHX
# 5524         A3  Station wagon   0000/000
# 5546         A3         Sedans   0588/BLH
# 5548         A3         Sedans   0588/BLH
# 5553         A3  Station wagon   0588/BHX
# 5580         A3  Station wagon   0588/BHX
# 5583         A3  Station wagon   0588/BHX
# 5584         A3  Station wagon   0588/BHX
# 5638         A3  Station wagon   0588/BHX
# 5640         A3         Sedans   0588/BAD
# 5655         A3  Station wagon   0588/BLL
# 5671         A3  Station wagon   0588/BHX
# 5697         A3         Sedans   0588/BLL
# 5699         A3  Station wagon   0588/BLL
# 7598      Astra  Station wagon   1844/AEV
# 7632      Astra  Station wagon   0035/BHW
# 7637      Astra  Station wagon   0035/BHV
# 7723      Astra  Station wagon   0035/BHM
# 7765      Astra  Station wagon   0035/BHM
# 7769      Astra         Sedans   0035/BFN
# 7775      Astra         Sedans   0035/BFM
# 7828      Astra         Sedans   0035/BFM
# 7890      Astra         Sedans   0035/BFM
# 7911      Astra  Station wagon   0035/BFJ
# 7915      Astra         Sedans   1844/AEA
# 8009      Astra  Station wagon   1844/AEQ
# 8016      Astra  Station wagon   0035/BFJ
# 8098      Astra         Sedans   0035/BFL
# 8113      Astra         Sedans   1844/AEC
# 9810      Corsa        Compact   0035/BBZ
# 9862      Corsa        Compact   1844/ADJ
# 9885      Corsa        Compact   0035/BCB
# 9903      Corsa        Compact   0035/BCB
# 9920      Corsa         Sedans   1844/ADJ
# 10036     Corsa        Compact   0035/BCB
# 10167     Corsa        Compact   1844/ADF
# 10189     Corsa         Sedans   0035/BBZ
# 10256     Corsa         Sedans   0035/BBZ
# 10259     Corsa        Compact   0035/BBZ
# 10300     Corsa        Compact   0035/BCL
# 11805  Insignia         Sedans   1844/AAB
# 11941  Insignia         Sedans   1844/AAB
# 12115  Insignia         Sedans   1844/AAA
# 12116  Insignia         Sedans   1844/AAA
# 12242  Insignia         Sedans   1844/AAA

# %%
data.loc[(~data["registration"].notna())&(data["km"]<10000), ["registration"]] = 2019    # 2018 ve 2019 yıllarının ortalamasını toplayıp 2 ye böldüğümüzde 10000 buldum.

data.loc[(~data["registration"].notna()), ["registration"]] = (2019 - data["km"]//35000)  # 4 yılın ortalamasına baktığımızda 35000 km buldum.

# %%
# data["registration"].value_counts(dropna=False)
# Out:
# 2018.0    4527
# 2019.0    4441
# 2016.0    3674
# 2017.0    3277
# Name: registration, dtype: int64

# %%
# data.loc[(data["model_code"]=="0588/BNO")&(~data["registration"].notna()), "registration"] = 2019  # bu model arabaların 2019 model olduğunu gördük.

# data.loc[(data["model_code"]=="0588/BNN")&(~data["registration"].notna()), "registration"] = 2019   # bu model arabaların 2019 model olduğunu gördük.

# data.loc[(data["model_code"]=="3333/BJR")&(~data["registration"].notna()), "registration"] = 2019  # bu model arabaların 2019 model 

# data.loc[(data["vehicle_condition"]=="New")&(~data["registration"].notna())&(data["km"]<2000), ["registration"]]=2019

# registration dolu olan 2019 model orabaların km mean() 2000 olduğunu gördüm.
# Ve registration boş olanlardan aynı zamanda new olan ve  km si 2000 den küçük olanlara 2019 yılı atadım.

# data.loc[(~data["registration"].notna())&(data["km"]<2000), ["registration"]] = 2019

# registration dolu olan 2019 model orabaların km mean() 18000 olduğunu gördüm.
# Ve registration boş olanlardan km si 2000 den küçük olanlara 2019 yılı atadım.

# data.loc[(~data["registration"].notna())&(data["km"]<18000), ["registration"]] = 2018

# registration dolu olan 2018 model orabaların km mean() 18000 olduğunu gördüm.
# Ve registration boş olanlardan km si 18000 den küçük olanlara 2018 yılı atadım.

# data.loc[(~data["registration"].notna())&(data["km"]<42000), ["registration"]] = 2017

# registration dolu olan 2017 model orabaların km mean() 42000 olduğunu gördüm.
# Ve registration boş olanlardan km si 42000 den küçük olanlara 2017 yılı atadım.

# data.loc[~data["registration"].notna(),["registration"]] = 2016

# geri kalan boş değerleri de 2016 yılı ile doldurdum.

# %%
# data["registration"].value_counts(dropna=False)
# Out:
# 2018.0    4531
# 2019.0    4425
# 2016.0    3681
# 2017.0    3282
# Name: registration, dtype: int64

# %%
# data.loc[~data["registration"].notna()]["km"].mean()  # registration eksik olanların km olarak ortalaması.
# Out:
# 593.0224787819358

# %%
# data.loc[data["registration"].notna()]["km"].mean()  # registration dolu olanların km olarak ortalaması.
# Out:
# 35058.30276058325

# %%
# data.loc[(data["registration"].notna())&(data["registration"]==2019)]["km"].mean()  # registration 2019 olanların km olarak ortalaması.
# Out:
# 1999.6694758608462

# %%
# data.loc[(data["registration"].notna())&(data["registration"]==2018)]["km"].mean()  # registration 2018 olanların km olarak ortalaması.
# Out:
# 17985.679221107577

# %%
# data.loc[(data["registration"].notna())&(data["registration"]==2017)]["km"].mean() # registration 2017 olanların km olarak ortalaması.
# Out:
# 41753.96848220789

# %%
# data.loc[(data["registration"].notna())&(data["registration"]==2016)]["km"].mean()  # registration 2016 olanların km olarak ortalaması.
# Out:
# 77442.52095808383

# %%
# data[data["registration"].notna()].groupby(["model", "registration", "vehicle_condition"]).km.describe().head(50)
# Out:
#                                       count          mean           std      min       25%  \
# model registration vehicle_condition
# A1    2016.0       Employee's car       5.0  48103.800000  30327.711242  26792.0  27000.00
#                    Used               624.0  54382.193910  26268.406892   3150.0  35202.75
#       2017.0       Demonstration        6.0  22963.500000  17802.676830  11940.0  15327.25
#                    Employee's car       8.0  17377.750000   5795.687282   9767.0  11816.75
#                    Pre-registered       1.0     10.000000           NaN     10.0     10.00
#                    Used               417.0  26086.731415  18740.903960    200.0  14300.00
#       2018.0       Demonstration       18.0   9860.666667   5351.243594   1050.0   5200.00
#                    Employee's car     131.0  12199.404580   7558.408070      1.0   6319.50
#                    Pre-registered      17.0    434.204152   1206.701934      9.0     80.00
#                    Used               578.0  14589.496540   7867.173729     10.0   8098.50
#       2019.0       Demonstration      108.0   3798.750000   2519.333665     10.0   2500.00
#                    Employee's car      52.0   4692.371860   4498.792418      1.0    536.25
#                    New                183.0      5.349727     23.982780      0.0      0.00
#                    Pre-registered     128.0     97.177849    320.710405      1.0      6.00
#                    Used               185.0   2864.691892   3824.875155      1.0     20.00
# A2    2018.0       Employee's car       1.0  26166.000000           NaN  26166.0  26166.00
# A3    2016.0       Employee's car       8.0  56954.625000  26796.572462   7790.0  40700.00
#                    Used               810.0  90420.275309  36408.836898     35.0  63014.50
#       2017.0       Demonstration        5.0  27950.000000   9145.354012  16000.0  23000.00
#                    Employee's car      32.0  31584.750000  14949.531463     59.0  23750.00
#                    Used               638.0  44593.115987  27748.116927     15.0  25783.50
#       2018.0       Demonstration       16.0  12801.187500  10920.150153   1015.0   4562.25
#                    Employee's car     157.0  18197.566879   8303.326959      1.0  12000.00
#                    New                  1.0      7.000000           NaN      7.0      7.00
#                    Pre-registered      17.0   1421.764706   3974.791528      1.0     10.00
#                    Used               586.0  19202.484478  11466.789776      1.0  12151.00
#       2019.0       Demonstration       41.0   4971.878049   3092.353369     50.0   3000.00
#                    Employee's car      31.0   3869.451613   5402.688028     10.0    100.00
#                    New                 23.0     27.217391     36.339256      0.0      7.00
#                    Pre-registered     278.0    226.564262    974.453785      1.0     10.00
#                    Used               146.0   4389.342466  12986.967706      1.0     27.00
# Astra 2016.0       Employee's car       1.0  95000.000000           NaN  95000.0  95000.00
#                    Used               518.0  89122.942085  42132.114849  10027.0  57938.50
#       2017.0       Demonstration        1.0  68500.000000           NaN  68500.0  68500.00
#                    Employee's car      12.0  52783.000000  20954.520302  14300.0  38500.00
#                    Pre-registered       1.0   4000.000000           NaN   4000.0   4000.00
#                    Used               573.0  49971.043630  31337.081636     30.0  25000.00
#       2018.0       Demonstration       16.0   7319.937500   7499.404034    100.0   2160.50
#                    Employee's car     121.0  23088.033058   8072.127016     50.0  20040.00
#                    Pre-registered       3.0    816.666667    728.583100     50.0    475.00
#                    Used               587.0  21869.556233  11413.991791      5.0  14000.00
#       2019.0       Demonstration      148.0   3042.470793   2867.687031      3.0    315.25
#                    Employee's car      18.0   5451.055556   2971.349713    431.0   4355.25
#                    New                 18.0     35.111111    116.192482      0.0      1.00
#                    Pre-registered     121.0     83.826241    369.355544      2.0     10.00
#                    Used               149.0   5041.100671   8275.775541      1.0    700.00
# Clio  2016.0       Demonstration        1.0  35000.000000           NaN  35000.0  35000.00
#                    Employee's car       1.0  60892.000000           NaN  60892.0  60892.00
#                    Pre-registered       1.0     10.000000           NaN     10.0     10.00
#                    Used               409.0  68832.716381  35535.497242     50.0  42504.00
#
#                                           50%            75%       max
# model registration vehicle_condition
# A1    2016.0       Employee's car     27000.0   67278.000000   92449.0
#                    Used               50000.0   65500.000000  192000.0
#       2017.0       Demonstration      16378.5   18425.000000   59000.0
#                    Employee's car     18900.0   20795.500000   24400.0
#                    Pre-registered        10.0      10.000000      10.0
#                    Used               21000.0   32700.000000  148257.0
#       2018.0       Demonstration       9261.0   14560.000000   18900.0
#                    Employee's car     10000.0   18475.000000   28319.0
#                    Pre-registered        80.0     135.823529    5000.0
#                    Used               13009.5   20868.000000   47000.0
#       2019.0       Demonstration       3006.0    5000.000000   12700.0
#                    Employee's car      4750.0    6925.000000   18000.0
#                    New                    0.0      10.000000     300.0
#                    Pre-registered        10.0      50.000000    3000.0
#                    Used                 500.0    5000.000000   15500.0
# A2    2018.0       Employee's car     26166.0   26166.000000   26166.0
# A3    2016.0       Employee's car     58481.0   81095.750000   85100.0
#                    Used               88129.0  113150.000000  291800.0
#       2017.0       Demonstration      27500.0   33750.000000   39500.0
#                    Employee's car     32000.0   41959.000000   60000.0
#                    Used               36746.0   57244.500000  158000.0
#       2018.0       Demonstration       9850.0   21020.750000   38400.0
#                    Employee's car     19440.0   24500.000000   35970.0
#                    New                    7.0       7.000000       7.0
#                    Pre-registered        15.0     100.000000   15378.0
#                    Used               18000.0   24255.250000  136000.0
#       2019.0       Demonstration       5000.0    6000.000000   14000.0
#                    Employee's car       500.0    5900.000000   18000.0
#                    New                    7.0      32.500000     100.0
#                    Pre-registered        10.0      80.000000    8000.0
#                    Used                 101.0    5000.000000  127022.0
# Astra 2016.0       Employee's car     95000.0   95000.000000   95000.0
#                    Used               84896.5  112388.000000  260000.0
#       2017.0       Demonstration      68500.0   68500.000000   68500.0
#                    Employee's car     49506.0   69450.000000   83200.0
#                    Pre-registered      4000.0    4000.000000    4000.0
#                    Used               44179.0   69190.000000  188000.0
#       2018.0       Demonstration       2499.0   13514.750000   22700.0
#                    Employee's car     25561.0   28889.000000   35616.0
#                    Pre-registered       900.0    1200.000000    1500.0
#                    Used               21379.0   28419.000000   67500.0
#       2019.0       Demonstration       2725.5    4999.000000   13542.0
#                    Employee's car      5957.5    7413.250000   11707.0
#                    New                   10.0      13.750000     500.0
#                    Pre-registered        10.0      20.000000    3024.0
#                    Used                3000.0    7000.000000   88000.0
# Clio  2016.0       Demonstration      35000.0   35000.000000   35000.0
#                    Employee's car     60892.0   60892.000000   60892.0
#                    Pre-registered        10.0      10.000000      10.0
#                    Used               64103.0   92130.000000  163500.0

# %%
# data[data["registration"].notna()].groupby(["model", "registration", "vehicle_condition"])

# %%
sns.barplot(x="registration", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="registration", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "prev_owners" sütununda 6828 eksik veri var. Bunu 2 şekilde doldurabiliriz. Burada önce "vehicle_condition" new olanları 0 ile doldurdum. Sonra kalanları ise "registration", "vehicle_condition" göre gruplandırıp "prev_owners" mode() ile doldurdum.

# %%
# data["prev_owner"].value_counts(dropna=False)
# Out:
# 1.0    8294
# NaN    6828
# 2.0     778
# 3.0      17
# 4.0       2
# Name: prev_owner, dtype: int64

# %%
# data[data["prev_owner"].notna()].groupby("registration")["prev_owner"].mean()
# Out:
# registration
# 2016.0    1.172414
# 2017.0    1.155335
# 2018.0    1.024598
# 2019.0    1.006285
# Name: prev_owner, dtype: float64

# %%
data.loc[(~data["prev_owner"].notna()) & (data["vehicle_condition"]=="New"), "prev_owner"] = 0  # 1635 satır. 

# New olduklarından dolayı prev_owner 0 atadık.

# %%
# data[~data["prev_owner"].notna()].groupby("registration")["km"].mean()

# Sonrasında boş olanların registration göre km mean() hesapladık.
# Out:
# registration
# 2016.0    74932.490185
# 2017.0    42697.169564
# 2018.0    18098.776297
# 2019.0     2109.444040
# Name: km, dtype: float64

# %%
# data[data["prev_owner"].notna()].groupby(["registration","vehicle_condition"])["prev_owner"].describe()

# Yeni durumda registration göre prev_owner istatistik değerlerine baktım.
# Out:
#                                  count  \
# registration vehicle_condition
# 2016.0       Demonstration         1.0
#              Employee's car        9.0
#              Pre-registered        1.0
#              Used               2425.0
# 2017.0       Demonstration        22.0
#              Employee's car       28.0
#              Pre-registered        6.0
#              Used               1959.0
# 2018.0       Demonstration       100.0
#              Employee's car      541.0
#              New                   3.0
#              Pre-registered       99.0
#              Used               2308.0
# 2019.0       Demonstration       391.0
#              Employee's car       73.0
#              New                1647.0
#              Pre-registered      739.0
#              Used                374.0
#
#                                     mean  \
# registration vehicle_condition
# 2016.0       Demonstration      1.000000
#              Employee's car     1.000000
#              Pre-registered     1.000000
#              Used               1.173196
# 2017.0       Demonstration      1.136364
#              Employee's car     1.000000
#              Pre-registered     1.000000
#              Used               1.158244
# 2018.0       Demonstration      1.020000
#              Employee's car     1.016636
#              New                0.333333
#              Pre-registered     1.010101
#              Used               1.027296
# 2019.0       Demonstration      1.002558
#              Employee's car     1.013699
#              New                0.008500
#              Pre-registered     1.006766
#              Used               1.008021
#
#                                      std  \
# registration vehicle_condition
# 2016.0       Demonstration           NaN
#              Employee's car     0.000000
#              Pre-registered          NaN
#              Used               0.392408
# 2017.0       Demonstration      0.351250
#              Employee's car     0.000000
#              Pre-registered     0.000000
#              Used               0.378795
# 2018.0       Demonstration      0.140705
#              Employee's car     0.128021
#              New                0.577350
#              Pre-registered     0.100504
#              Used               0.162981
# 2019.0       Demonstration      0.050572
#              Employee's car     0.117041
#              New                0.091832
#              Pre-registered     0.082032
#              Used               0.089322
#
#                                 min  \
# registration vehicle_condition
# 2016.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2017.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2018.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
# 2019.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
#
#                                 25%  \
# registration vehicle_condition
# 2016.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2017.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2018.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
# 2019.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
#
#                                 50%  \
# registration vehicle_condition
# 2016.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2017.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2018.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
# 2019.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
#
#                                 75%  \
# registration vehicle_condition
# 2016.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2017.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               1.0
# 2018.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.5
#              Pre-registered     1.0
#              Used               1.0
# 2019.0       Demonstration      1.0
#              Employee's car     1.0
#              New                0.0
#              Pre-registered     1.0
#              Used               1.0
#
#                                 max
# registration vehicle_condition
# 2016.0       Demonstration      1.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               4.0
# 2017.0       Demonstration      2.0
#              Employee's car     1.0
#              Pre-registered     1.0
#              Used               4.0
# 2018.0       Demonstration      2.0
#              Employee's car     2.0
#              New                1.0
#              Pre-registered     2.0
#              Used               2.0
# 2019.0       Demonstration      2.0
#              Employee's car     2.0
#              New                1.0
#              Pre-registered     2.0
#              Used               2.0

# %%
# 1. yöntem olarak registration ve vehicle_condition göre gruplandırıp bunun prev_owner değerlerinin mode() nan değerlere atadım.

f= lambda x : x.mode().iloc[0]

data["prev_owner"] = data["prev_owner"].fillna(data.groupby(["registration","vehicle_condition"])["prev_owner"].transform(f))

# %%
# data["prev_owner"].value_counts(dropna=False)  # 1. yönteme göre çıkan değerler.
# Out:
# 1.0    13487
# 0.0     1635
# 2.0      778
# 3.0       17
# 4.0        2
# Name: prev_owner, dtype: int64

# %%
# data["prev_owner"].apply(np.round).value_counts(dropna=False)   # 1. yöntemde mode() yerine mean() kullanırsak çıkan değerler.
# Out:
# 1.0    13376
# 0.0     1635
# 2.0      866
# NaN       23
# 3.0       17
# 4.0        2
# Name: prev_owner, dtype: int64

# %%
# 2. yöntem olarak da prev_owner boş olanların registration=2019 olanlara 0, diğerlerine 1 atadım.

# data.loc[(~data["prev_owner"].notna()) & (data["registration"]== 2019),"prev_owner"] = 0

# data.loc[(~data["prev_owner"].notna()) & (data["registration"]< 2019),"prev_owner"] = 1

# %%
# data["prev_owner"].value_counts(dropna=False) # 2. yönteme göre de çıkan değerler aşağıdaki gibi oldu.
# Out:
# 1.0    12286
# 0.0     2836
# 2.0      778
# 3.0       17
# 4.0        2
# Name: prev_owner, dtype: int64

# %%
sns.barplot(x="prev_owner", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="prev_owner", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "power_hp" sütununda 88 eksik veri var. Öncelikle içinde çok düşük bazı değerlerin olduğunu gördüm(1, 4, 9). Ancak çok büyük değerler olan 239, 270, 294 gibi olanları incelediğimizde gerçekçi olduklarını gördüm. "Model", "body_type" ve "registration" göre gruplandırıp "power_hp" mean() değerlere baktım. 1,4 ve 9 olanları np.nan ile doldurdum. Burada eksik değerleri "model", "body_type" ve "registration" bazında bunları "power_hp" mode() ile doldurdum.

# %%
# data["power_hp"].value_counts(dropna=False)
# Out:
# 85.0     2542
# 66.0     2122
# 81.0     1402
# 100.0    1308
# 110.0    1112
# 70.0      888
# 125.0     707
# 51.0      695
# 55.0      569
# 118.0     516
# 92.0      466
# 121.0     392
# 147.0     380
# 77.0      345
# 56.0      286
# 54.0      276
# 103.0     253
# 87.0      232
# 165.0     194
# 88.0      177
# 60.0      160
# 162.0      98
# NaN        88
# 74.0       81
# 96.0       72
# 71.0       59
# 101.0      47
# 67.0       40
# 154.0      39
# 122.0      35
# 119.0      30
# 164.0      27
# 135.0      24
# 82.0       22
# 52.0       22
# 1.0        20
# 78.0       20
# 146.0      18
# 294.0      18
# 141.0      16
# 57.0       10
# 120.0       8
# 104.0       8
# 191.0       7
# 112.0       7
# 155.0       6
# 117.0       6
# 184.0       5
# 90.0        4
# 76.0        4
# 65.0        4
# 149.0       3
# 98.0        3
# 93.0        3
# 80.0        3
# 168.0       3
# 150.0       2
# 63.0        2
# 140.0       2
# 86.0        2
# 89.0        2
# 40.0        2
# 167.0       2
# 53.0        2
# 228.0       2
# 127.0       2
# 143.0       2
# 270.0       2
# 9.0         1
# 44.0        1
# 123.0       1
# 195.0       1
# 132.0       1
# 137.0       1
# 84.0        1
# 133.0       1
# 239.0       1
# 115.0       1
# 163.0       1
# 4.0         1
# 75.0        1
# Name: power_hp, dtype: int64

# %%
data.loc[(data["power_hp"]<50), "power_hp"] = np.nan

# %%
f= lambda x : x.mode().iloc[0]

data["power_hp"] = data["power_hp"].fillna(data.groupby(["model","body_type","registration"])["power_hp"].transform(f))

# %%
# data.groupby(["model","body_type","registration"])["power_hp"].mean().head(100)
# Out:
# model  body_type      registration
# A1     Compact        2016.0           72.940171
#                       2017.0           77.267081
#                       2018.0           71.382022
#                       2019.0           83.639257
#        Coupe          2016.0           70.000000
#                       2017.0           85.000000
#        Other          2017.0          140.000000
#                       2018.0           76.666667
#                       2019.0           75.000000
#        Sedans         2016.0           74.097686
#                       2017.0           73.936090
#                       2018.0           74.010799
#                       2019.0           82.442857
#        Station wagon  2016.0           74.600000
#                       2017.0           89.333333
#                       2018.0           69.727273
#                       2019.0           85.000000
#        Van            2019.0          147.000000
# A2     Off-Road       2018.0           85.000000
# A3     Compact        2016.0           90.462366
#                       2017.0           89.897436
#                       2018.0           85.896552
#                       2019.0           93.333333
#        Convertible    2016.0          110.000000
#                       2017.0          102.750000
#                       2018.0          157.666667
#        Coupe          2016.0           81.000000
#                       2017.0           85.000000
#        Other          2016.0           86.800000
#                       2017.0           95.500000
#                       2018.0           85.000000
#                       2019.0           85.000000
#        Sedans         2016.0           89.993837
#                       2017.0           88.645045
#                       2018.0           90.673239
#                       2019.0           90.693198
#        Station wagon  2016.0           91.835821
#                       2017.0           88.027778
#                       2018.0           89.562500
#                       2019.0           92.027027
# Astra  Compact        2016.0           87.300000
#                       2017.0           83.490909
#                       2018.0           82.564103
#                       2019.0           95.426230
#        Coupe          2016.0          103.000000
#                       2019.0          110.000000
#        Off-Road       2018.0          110.000000
#        Other          2016.0           80.000000
#                       2017.0           84.727273
#                       2018.0           88.722222
#                       2019.0           87.000000
#        Sedans         2016.0           88.073333
#                       2017.0           85.694779
#                       2018.0           91.681250
#                       2019.0           93.607784
#        Station wagon  2016.0           89.562691
#                       2017.0           88.216117
#                       2018.0          101.240964
#                       2019.0          103.381119
# Clio   Compact        2016.0           66.333333
#                       2017.0           76.069767
#                       2018.0           88.873134
#                       2019.0           59.435028
#        Coupe          2017.0          147.000000
#        Off-Road       2016.0           55.000000
#                       2019.0           87.000000
#        Other          2016.0           62.833333
#                       2017.0           64.142857
#                       2018.0           82.850000
#                       2019.0           57.000000
#        Sedans         2016.0           65.685714
#                       2017.0           62.783898
#                       2018.0           94.350318
#                       2019.0           61.086705
#        Station wagon  2016.0           63.515464
#                       2017.0           64.181818
#                       2018.0           67.948980
#                       2019.0           59.255814
#        Transporter    2016.0           59.454545
#                       2017.0           56.888889
#                       2018.0           55.333333
#                       2019.0           55.333333
#        Van            2017.0           55.000000
#                       2018.0           55.000000
# Corsa  Compact        2016.0           58.413146
#                       2017.0           62.649682
#                       2018.0           64.467422
#                       2019.0           60.862475
#        Coupe          2016.0           65.400000
#                       2017.0           54.800000
#                       2019.0           57.333333
#        Off-Road       2017.0           68.666667
#        Other          2016.0           66.000000
#                       2017.0           64.052632
#                       2018.0           66.020408
#                       2019.0           66.533333
#        Sedans         2016.0           57.361386
#                       2017.0           55.237374
#                       2018.0           59.049470
#                       2019.0           58.791667
# Name: power_hp, dtype: float64

# %%
# data.loc[(data["power_hp"]<50)|(data["power_hp"]>230)]
# Out:
#           make  \
# 3587      Audi
# 3590      Audi
# 3592      Audi
# 3593      Audi
# 3595      Audi
# 3596      Audi
# 3598      Audi
# 3599      Audi
# 3600      Audi
# 3601      Audi
# 3602      Audi
# 3603      Audi
# 3604      Audi
# 3605      Audi
# 3606      Audi
# 3608      Audi
# 3609      Audi
# 3610      Audi
# 3648      Audi
# 3649      Audi
# 3913      Audi
# 6005      Opel
# 6034      Opel
# 6946      Opel
# 7014      Opel
# 7016      Opel
# 7018      Opel
# 7019      Opel
# 8408      Opel
# 8857      Opel
# 9285      Opel
# 9287      Opel
# 9288      Opel
# 9289      Opel
# 9290      Opel
# 9292      Opel
# 9299      Opel
# 10468     Opel
# 10513     Opel
# 10579     Opel
# 10580     Opel
# 10610     Opel
# 13759  Renault
# 13885  Renault
# 15155  Renault
# 15156  Renault
#
#           model  \
# 3587         A3
# 3590         A3
# 3592         A3
# 3593         A3
# 3595         A3
# 3596         A3
# 3598         A3
# 3599         A3
# 3600         A3
# 3601         A3
# 3602         A3
# 3603         A3
# 3604         A3
# 3605         A3
# 3606         A3
# 3608         A3
# 3609         A3
# 3610         A3
# 3648         A3
# 3649         A3
# 3913         A3
# 6005      Astra
# 6034      Astra
# 6946      Astra
# 7014      Astra
# 7016      Astra
# 7018      Astra
# 7019      Astra
# 8408      Corsa
# 8857      Corsa
# 9285      Corsa
# 9287      Corsa
# 9288      Corsa
# 9289      Corsa
# 9290      Corsa
# 9292      Corsa
# 9299      Corsa
# 10468  Insignia
# 10513  Insignia
# 10579  Insignia
# 10580  Insignia
# 10610  Insignia
# 13759      Clio
# 13885      Clio
# 15155    Espace
# 15156    Espace
#
#            body_type  \
# 3587          Sedans
# 3590          Sedans
# 3592          Sedans
# 3593          Sedans
# 3595   Station wagon
# 3596          Sedans
# 3598          Sedans
# 3599          Sedans
# 3600          Sedans
# 3601          Sedans
# 3602          Sedans
# 3603          Sedans
# 3604          Sedans
# 3605          Sedans
# 3606          Sedans
# 3608          Sedans
# 3609          Sedans
# 3610          Sedans
# 3648          Sedans
# 3649         Compact
# 3913          Sedans
# 6005   Station wagon
# 6034   Station wagon
# 6946   Station wagon
# 7014          Sedans
# 7016          Sedans
# 7018          Sedans
# 7019          Sedans
# 8408         Compact
# 8857         Compact
# 9285          Sedans
# 9287          Sedans
# 9288          Sedans
# 9289          Sedans
# 9290          Sedans
# 9292          Sedans
# 9299          Sedans
# 10468  Station wagon
# 10513  Station wagon
# 10579  Station wagon
# 10580  Station wagon
# 10610  Station wagon
# 13759        Compact
# 13885        Compact
# 15155         Sedans
# 15156         Sedans
#
#         cc  \
# 3587   2.5
# 3590   NaN
# 3592   2.5
# 3593   2.5
# 3595   2.5
# 3596   2.5
# 3598   2.5
# 3599   2.5
# 3600   2.5
# 3601   2.5
# 3602   2.5
# 3603   2.5
# 3604   2.5
# 3605   2.5
# 3606   2.5
# 3608   2.5
# 3609   2.5
# 3610   2.5
# 3648   2.5
# 3649   2.5
# 3913   2.0
# 6005   1.0
# 6034   1.0
# 6946   1.6
# 7014   1.4
# 7016   1.4
# 7018   1.4
# 7019   1.4
# 8408   NaN
# 8857   1.0
# 9285   1.2
# 9287   1.2
# 9288   1.2
# 9289   1.2
# 9290   1.2
# 9292   1.2
# 9299   1.2
# 10468  1.6
# 10513  2.8
# 10579  1.6
# 10580  1.6
# 10610  1.6
# 13759  NaN
# 13885  1.2
# 15155  1.6
# 15156  1.6
#
#        price  \
# 3587   64900
# 3590   62900
# 3592   56900
# 3593   58500
# 3595   63900
# 3596   57400
# 3598   55000
# 3599   55000
# 3600   53000
# 3601   51900
# 3602   51900
# 3603   52000
# 3604   50000
# 3605   51999
# 3606   49900
# 3608   42500
# 3609   41000
# 3610   45890
# 3648   74600
# 3649   67600
# 3913   20440
# 6005   11600
# 6034   11600
# 6946   11900
# 7014   11700
# 7016   11700
# 7018   11700
# 7019   11700
# 8408   12435
# 8857    7650
# 9285    8300
# 9287    8300
# 9288    8300
# 9289    8300
# 9290    8300
# 9292    8300
# 9299    8300
# 10468  15300
# 10513  17990
# 10579  16400
# 10580  16400
# 10610  15300
# 13759   5890
# 13885   8990
# 15155  23800
# 15156  23800
#
#                     vat  \
# 3587     VAT deductible
# 3590     VAT deductible
# 3592     VAT deductible
# 3593     VAT deductible
# 3595     VAT deductible
# 3596   Price negotiable
# 3598     VAT deductible
# 3599     VAT deductible
# 3600     VAT deductible
# 3601     VAT deductible
# 3602     VAT deductible
# 3603     VAT deductible
# 3604     VAT deductible
# 3605     VAT deductible
# 3606     VAT deductible
# 3608   Price negotiable
# 3609     VAT deductible
# 3610     VAT deductible
# 3648     VAT deductible
# 3649     VAT deductible
# 3913     VAT deductible
# 6005     VAT deductible
# 6034     VAT deductible
# 6946     VAT deductible
# 7014     VAT deductible
# 7016     VAT deductible
# 7018     VAT deductible
# 7019     VAT deductible
# 8408     VAT deductible
# 8857     VAT deductible
# 9285     VAT deductible
# 9287     VAT deductible
# 9288     VAT deductible
# 9289     VAT deductible
# 9290     VAT deductible
# 9292     VAT deductible
# 9299     VAT deductible
# 10468    VAT deductible
# 10513    VAT deductible
# 10579    VAT deductible
# 10580    VAT deductible
# 10610    VAT deductible
# 13759    VAT deductible
# 13885    VAT deductible
# 15155    VAT deductible
# 15156    VAT deductible
#
#              km  \
# 3587    35000.0
# 3590      700.0
# 3592     5200.0
# 3593    10000.0
# 3595       10.0
# 3596    63000.0
# 3598    24000.0
# 3599    30000.0
# 3600     4000.0
# 3601    19000.0
# 3602    49000.0
# 3603    13963.0
# 3604    25000.0
# 3605    33000.0
# 3606    17234.0
# 3608    37333.0
# 3609    30000.0
# 3610    18700.0
# 3648    13000.0
# 3649    37747.0
# 3913    24000.0
# 6005    73860.0
# 6034    76010.0
# 6946    70090.0
# 7014    79993.0
# 7016    62384.0
# 7018    77272.0
# 7019    69035.0
# 8408    21050.0
# 8857      142.0
# 9285    58912.0
# 9287    53522.0
# 9288    60386.0
# 9289    59217.0
# 9290    51318.0
# 9292    53390.0
# 9299    47140.0
# 10468   77125.0
# 10513  145000.0
# 10579   78762.0
# 10580   68525.0
# 10610   62800.0
# 13759  134500.0
# 13885    9751.0
# 15155   56340.0
# 15156   69600.0
#
#        registration  \
# 3587         2018.0
# 3590         2019.0
# 3592         2018.0
# 3593         2018.0
# 3595         2019.0
# 3596         2018.0
# 3598         2017.0
# 3599         2018.0
# 3600         2018.0
# 3601         2017.0
# 3602         2018.0
# 3603         2018.0
# 3604         2018.0
# 3605         2017.0
# 3606         2018.0
# 3608         2016.0
# 3609         2016.0
# 3610         2018.0
# 3648         2018.0
# 3649         2017.0
# 3913         2017.0
# 6005         2017.0
# 6034         2017.0
# 6946         2017.0
# 7014         2017.0
# 7016         2017.0
# 7018         2017.0
# 7019         2017.0
# 8408         2018.0
# 8857         2019.0
# 9285         2017.0
# 9287         2017.0
# 9288         2017.0
# 9289         2017.0
# 9290         2017.0
# 9292         2017.0
# 9299         2017.0
# 10468        2017.0
# 10513        2016.0
# 10579        2017.0
# 10580        2017.0
# 10610        2017.0
# 13759        2016.0
# 13885        2017.0
# 15155        2017.0
# 15156        2017.0
#
#        prev_owner  \
# 3587          1.0
# 3590          1.0
# 3592          1.0
# 3593          1.0
# 3595          1.0
# 3596          1.0
# 3598          1.0
# 3599          1.0
# 3600          1.0
# 3601          1.0
# 3602          1.0
# 3603          1.0
# 3604          1.0
# 3605          1.0
# 3606          1.0
# 3608          1.0
# 3609          1.0
# 3610          1.0
# 3648          1.0
# 3649          1.0
# 3913          1.0
# 6005          1.0
# 6034          1.0
# 6946          1.0
# 7014          1.0
# 7016          1.0
# 7018          1.0
# 7019          1.0
# 8408          1.0
# 8857          0.0
# 9285          1.0
# 9287          1.0
# 9288          1.0
# 9289          1.0
# 9290          1.0
# 9292          1.0
# 9299          1.0
# 10468         1.0
# 10513         1.0
# 10579         1.0
# 10580         1.0
# 10610         1.0
# 13759         1.0
# 13885         1.0
# 15155         1.0
# 15156         1.0
#
#        power_hp  \
# 3587      294.0
# 3590      294.0
# 3592      294.0
# 3593      294.0
# 3595      294.0
# 3596      294.0
# 3598      294.0
# 3599      294.0
# 3600      294.0
# 3601      294.0
# 3602      294.0
# 3603      294.0
# 3604      294.0
# 3605      294.0
# 3606      294.0
# 3608      270.0
# 3609      270.0
# 3610      294.0
# 3648      294.0
# 3649      294.0
# 3913        9.0
# 6005        1.0
# 6034        1.0
# 6946        1.0
# 7014        1.0
# 7016        1.0
# 7018        1.0
# 7019        1.0
# 8408       44.0
# 8857       40.0
# 9285        1.0
# 9287        1.0
# 9288        1.0
# 9289        1.0
# 9290        1.0
# 9292        1.0
# 9299        1.0
# 10468       1.0
# 10513     239.0
# 10579       1.0
# 10580       1.0
# 10610       1.0
# 13759      40.0
# 13885       4.0
# 15155       1.0
# 15156       1.0
#
#       vehicle_condition  \
# 3587               Used
# 3590               Used
# 3592               Used
# 3593               Used
# 3595               Used
# 3596               Used
# 3598               Used
# 3599               Used
# 3600               Used
# 3601               Used
# 3602               Used
# 3603               Used
# 3604               Used
# 3605               Used
# 3606               Used
# 3608               Used
# 3609               Used
# 3610               Used
# 3648               Used
# 3649               Used
# 3913               Used
# 6005               Used
# 6034               Used
# 6946               Used
# 7014               Used
# 7016               Used
# 7018               Used
# 7019               Used
# 8408               Used
# 8857                New
# 9285               Used
# 9287               Used
# 9288               Used
# 9289               Used
# 9290               Used
# 9292               Used
# 9299               Used
# 10468              Used
# 10513              Used
# 10579              Used
# 10580              Used
# 10610              Used
# 13759              Used
# 13885              Used
# 15155              Used
# 15156              Used
#
#        previous_owners  \
# 3587               NaN
# 3590               NaN
# 3592               1.0
# 3593               NaN
# 3595               1.0
# 3596               NaN
# 3598               NaN
# 3599               NaN
# 3600               NaN
# 3601               NaN
# 3602               1.0
# 3603               NaN
# 3604               NaN
# 3605               1.0
# 3606               NaN
# 3608               NaN
# 3609               NaN
# 3610               1.0
# 3648               1.0
# 3649               1.0
# 3913               NaN
# 6005               1.0
# 6034               1.0
# 6946               1.0
# 7014               1.0
# 7016               1.0
# 7018               1.0
# 7019               1.0
# 8408               1.0
# 8857               NaN
# 9285               1.0
# 9287               1.0
# 9288               1.0
# 9289               1.0
# 9290               1.0
# 9292               1.0
# 9299               1.0
# 10468              1.0
# 10513              1.0
# 10579              1.0
# 10580              1.0
# 10610              1.0
# 13759              NaN
# 13885              NaN
# 15155              1.0
# 15156              1.0
#
#       Inspection_new  \
# 3587             NaN
# 3590             NaN
# 3592             NaN
# 3593             NaN
# 3595             NaN
# 3596             NaN
# 3598             NaN
# 3599             NaN
# 3600             NaN
# 3601             NaN
# 3602             NaN
# 3603             NaN
# 3604             NaN
# 3605             NaN
# 3606             NaN
# 3608             NaN
# 3609             NaN
# 3610             NaN
# 3648             NaN
# 3649             NaN
# 3913             NaN
# 6005             NaN
# 6034             NaN
# 6946             NaN
# 7014             NaN
# 7016             NaN
# 7018             NaN
# 7019             NaN
# 8408             Yes
# 8857             NaN
# 9285             NaN
# 9287             NaN
# 9288             NaN
# 9289             NaN
# 9290             NaN
# 9292             NaN
# 9299             NaN
# 10468            NaN
# 10513            NaN
# 10579            NaN
# 10580            NaN
# 10610            NaN
# 13759            NaN
# 13885            NaN
# 15155            NaN
# 15156            NaN
#
#       body_color  \
# 3587        Grey
# 3590        Grey
# 3592        Grey
# 3593       White
# 3595       Black
# 3596        Blue
# 3598       Black
# 3599        Grey
# 3600       Black
# 3601       Black
# 3602      Silver
# 3603        Grey
# 3604        Grey
# 3605       White
# 3606       Black
# 3608        Grey
# 3609        Blue
# 3610       White
# 3648       Black
# 3649       White
# 3913       Black
# 6005       Black
# 6034      Silver
# 6946       Black
# 7014      Silver
# 7016       Black
# 7018       Black
# 7019       Black
# 8408       White
# 8857        Grey
# 9285       Black
# 9287      Silver
# 9288      Silver
# 9289      Silver
# 9290      Silver
# 9292      Silver
# 9299       Black
# 10468      Black
# 10513        Red
# 10579     Silver
# 10580     Silver
# 10610     Silver
# 13759      White
# 13885       Grey
# 15155       Grey
# 15156      Black
#
#       paintwork  \
# 3587        NaN
# 3590        NaN
# 3592        NaN
# 3593        NaN
# 3595   Metallic
# 3596   Metallic
# 3598   Metallic
# 3599        NaN
# 3600        NaN
# 3601        NaN
# 3602   Metallic
# 3603        NaN
# 3604        NaN
# 3605        NaN
# 3606        NaN
# 3608   Metallic
# 3609        NaN
# 3610        NaN
# 3648        NaN
# 3649   Metallic
# 3913        NaN
# 6005        NaN
# 6034        NaN
# 6946        NaN
# 7014        NaN
# 7016        NaN
# 7018        NaN
# 7019        NaN
# 8408        NaN
# 8857   Metallic
# 9285        NaN
# 9287        NaN
# 9288        NaN
# 9289        NaN
# 9290        NaN
# 9292        NaN
# 9299        NaN
# 10468       NaN
# 10513       NaN
# 10579       NaN
# 10580       NaN
# 10610       NaN
# 13759  Metallic
# 13885  Metallic
# 15155       NaN
# 15156       NaN
#
#            body_color_original  \
# 3587                       NaN
# 3590                       NaN
# 3592           DAYTONA PERLATO
# 3593                       NaN
# 3595               Mytoss nero
# 3596                       NaN
# 3598                       NaN
# 3599                       NaN
# 3600                       NaN
# 3601                       NaN
# 3602                       NaN
# 3603                       NaN
# 3604                       NaN
# 3605                       NaN
# 3606                       NaN
# 3608                       NaN
# 3609                       NaN
# 3610                       NaN
# 3648             Mythosschwarz
# 3649   Gletscherweiss Metallic
# 3913                       NaN
# 6005                      Nero
# 6034                   Argento
# 6946                      Nero
# 7014                   Argento
# 7016                      Nero
# 7018                      Nero
# 7019                      Nero
# 8408   SchneeWeiss/SummitWhite
# 8857               Star Silver
# 9285                      Nero
# 9287                   Argento
# 9288                   Argento
# 9289                   Argento
# 9290                   Argento
# 9292                   Argento
# 9299                      Nero
# 10468                     Nero
# 10513        Lavarot brilliant
# 10579                  Argento
# 10580                  Argento
# 10610                  Argento
# 13759                      NaN
# 13885                     GRIS
# 15155                   Grigio
# 15156                     Nero
#
#          upholstery  \
# 3587            NaN
# 3590            NaN
# 3592   Full leather
# 3593            NaN
# 3595   Part leather
# 3596   Full leather
# 3598            NaN
# 3599            NaN
# 3600            NaN
# 3601            NaN
# 3602   Full leather
# 3603            NaN
# 3604            NaN
# 3605   Full leather
# 3606            NaN
# 3608            NaN
# 3609            NaN
# 3610            NaN
# 3648   Full leather
# 3649   Full leather
# 3913            NaN
# 6005            NaN
# 6034            NaN
# 6946            NaN
# 7014            NaN
# 7016            NaN
# 7018            NaN
# 7019            NaN
# 8408          Cloth
# 8857          Other
# 9285            NaN
# 9287            NaN
# 9288            NaN
# 9289            NaN
# 9290            NaN
# 9292            NaN
# 9299            NaN
# 10468           NaN
# 10513  Full leather
# 10579           NaN
# 10580           NaN
# 10610           NaN
# 13759         Black
# 13885           NaN
# 15155           NaN
# 15156           NaN
#
#       interior_color  \
# 3587             NaN
# 3590             NaN
# 3592           Black
# 3593             NaN
# 3595           Black
# 3596           Black
# 3598             NaN
# 3599             NaN
# 3600             NaN
# 3601             NaN
# 3602           Black
# 3603             NaN
# 3604             NaN
# 3605           Black
# 3606             NaN
# 3608             NaN
# 3609             NaN
# 3610             NaN
# 3648            Grey
# 3649           Black
# 3913             NaN
# 6005             NaN
# 6034             NaN
# 6946             NaN
# 7014             NaN
# 7016             NaN
# 7018             NaN
# 7019             NaN
# 8408           Black
# 8857             NaN
# 9285             NaN
# 9287             NaN
# 9288             NaN
# 9289             NaN
# 9290             NaN
# 9292             NaN
# 9299             NaN
# 10468            NaN
# 10513          Black
# 10579            NaN
# 10580            NaN
# 10610            NaN
# 13759            NaN
# 13885            NaN
# 15155            NaN
# 15156            NaN
#
#        door_nr  \
# 3587       5.0
# 3590       5.0
# 3592       5.0
# 3593       5.0
# 3595       5.0
# 3596       5.0
# 3598       5.0
# 3599       4.0
# 3600       4.0
# 3601       5.0
# 3602       5.0
# 3603       5.0
# 3604       5.0
# 3605       5.0
# 3606       5.0
# 3608       5.0
# 3609       5.0
# 3610       5.0
# 3648       4.0
# 3649       5.0
# 3913       NaN
# 6005       5.0
# 6034       5.0
# 6946       5.0
# 7014       5.0
# 7016       5.0
# 7018       5.0
# 7019       5.0
# 8408       5.0
# 8857       3.0
# 9285       5.0
# 9287       5.0
# 9288       5.0
# 9289       5.0
# 9290       5.0
# 9292       5.0
# 9299       5.0
# 10468      5.0
# 10513      4.0
# 10579      5.0
# 10580      5.0
# 10610      5.0
# 13759      5.0
# 13885      5.0
# 15155      5.0
# 15156      5.0
#
#        seat_nr  \
# 3587       5.0
# 3590       5.0
# 3592       5.0
# 3593       5.0
# 3595       5.0
# 3596       5.0
# 3598       5.0
# 3599       5.0
# 3600       5.0
# 3601       5.0
# 3602       5.0
# 3603       5.0
# 3604       5.0
# 3605       5.0
# 3606       5.0
# 3608       5.0
# 3609       5.0
# 3610       5.0
# 3648       5.0
# 3649       5.0
# 3913       NaN
# 6005       5.0
# 6034       5.0
# 6946       5.0
# 7014       5.0
# 7016       5.0
# 7018       5.0
# 7019       5.0
# 8408       5.0
# 8857       NaN
# 9285       5.0
# 9287       5.0
# 9288       5.0
# 9289       5.0
# 9290       5.0
# 9292       5.0
# 9299       5.0
# 10468      5.0
# 10513      5.0
# 10579      5.0
# 10580      5.0
# 10610      5.0
# 13759      5.0
# 13885      5.0
# 15155      5.0
# 15156      5.0
#
#       model_code  \
# 3587         NaN
# 3590         NaN
# 3592         NaN
# 3593         NaN
# 3595         NaN
# 3596         NaN
# 3598         NaN
# 3599         NaN
# 3600         NaN
# 3601         NaN
# 3602         NaN
# 3603         NaN
# 3604         NaN
# 3605         NaN
# 3606         NaN
# 3608         NaN
# 3609         NaN
# 3610         NaN
# 3648         NaN
# 3649         NaN
# 3913         NaN
# 6005         NaN
# 6034         NaN
# 6946         NaN
# 7014         NaN
# 7016         NaN
# 7018         NaN
# 7019         NaN
# 8408         NaN
# 8857         NaN
# 9285         NaN
# 9287         NaN
# 9288         NaN
# 9289         NaN
# 9290         NaN
# 9292         NaN
# 9299         NaN
# 10468        NaN
# 10513        NaN
# 10579        NaN
# 10580        NaN
# 10610        NaN
# 13759        NaN
# 13885        NaN
# 15155        NaN
# 15156        NaN
#
#                  gear  \
# 3587   Semi-automatic
# 3590   Semi-automatic
# 3592   Semi-automatic
# 3593   Semi-automatic
# 3595   Semi-automatic
# 3596   Semi-automatic
# 3598   Semi-automatic
# 3599   Semi-automatic
# 3600   Semi-automatic
# 3601   Semi-automatic
# 3602   Semi-automatic
# 3603   Semi-automatic
# 3604   Semi-automatic
# 3605   Semi-automatic
# 3606   Semi-automatic
# 3608   Semi-automatic
# 3609   Semi-automatic
# 3610   Semi-automatic
# 3648   Semi-automatic
# 3649   Semi-automatic
# 3913        Automatic
# 6005        Automatic
# 6034        Automatic
# 6946           Manual
# 7014           Manual
# 7016           Manual
# 7018           Manual
# 7019           Manual
# 8408        Automatic
# 8857           Manual
# 9285           Manual
# 9287           Manual
# 9288           Manual
# 9289           Manual
# 9290           Manual
# 9292           Manual
# 9299           Manual
# 10468       Automatic
# 10513       Automatic
# 10579       Automatic
# 10580       Automatic
# 10610       Automatic
# 13759          Manual
# 13885          Manual
# 15155       Automatic
# 15156       Automatic
#
#       displacement  \
# 3587         2,480
# 3590         2,480
# 3592         2,480
# 3593         2,480
# 3595         2,480
# 3596         2,480
# 3598         2,480
# 3599         2,480
# 3600         2,480
# 3601         2,480
# 3602         2,480
# 3603         2,480
# 3604         2,480
# 3605         2,480
# 3606         2,480
# 3608         2,480
# 3609         2,480
# 3610         2,480
# 3648         2,480
# 3649         2,480
# 3913           NaN
# 6005           998
# 6034           998
# 6946         1,598
# 7014         1,364
# 7016         1,364
# 7018         1,364
# 7019         1,364
# 8408         1,364
# 8857           973
# 9285         1,229
# 9287         1,229
# 9288         1,229
# 9289         1,229
# 9290         1,229
# 9292         1,229
# 9299         1,229
# 10468        1,598
# 10513          NaN
# 10579        1,598
# 10580        1,598
# 10610        1,598
# 13759        1,461
# 13885          NaN
# 15155        1,589
# 15156        1,589
#
#        cylinders  \
# 3587         5.0
# 3590         5.0
# 3592         5.0
# 3593         5.0
# 3595         5.0
# 3596         5.0
# 3598         5.0
# 3599         5.0
# 3600         5.0
# 3601         5.0
# 3602         5.0
# 3603         5.0
# 3604         5.0
# 3605         5.0
# 3606         5.0
# 3608         5.0
# 3609         5.0
# 3610         5.0
# 3648         5.0
# 3649         5.0
# 3913         NaN
# 6005         NaN
# 6034         NaN
# 6946         NaN
# 7014         NaN
# 7016         NaN
# 7018         NaN
# 7019         NaN
# 8408         4.0
# 8857         NaN
# 9285         NaN
# 9287         NaN
# 9288         NaN
# 9289         NaN
# 9290         NaN
# 9292         NaN
# 9299         NaN
# 10468        NaN
# 10513        NaN
# 10579        NaN
# 10580        NaN
# 10610        NaN
# 13759        NaN
# 13885        NaN
# 15155        NaN
# 15156        NaN
#
#       weight  \
# 3587   1,585
# 3590   1,585
# 3592   1,585
# 3593   1,585
# 3595   1,585
# 3596   1,585
# 3598   1,585
# 3599   1,590
# 3600   1,590
# 3601   1,585
# 3602   1,585
# 3603   1,585
# 3604   1,585
# 3605   1,585
# 3606   1,585
# 3608   1,595
# 3609   1,595
# 3610   1,585
# 3648   1,490
# 3649   1,485
# 3913     NaN
# 6005     NaN
# 6034     NaN
# 6946     NaN
# 7014     NaN
# 7016     NaN
# 7018     NaN
# 7019     NaN
# 8408     NaN
# 8857     840
# 9285     NaN
# 9287     NaN
# 9288     NaN
# 9289     NaN
# 9290     NaN
# 9292     NaN
# 9299     NaN
# 10468    NaN
# 10513    NaN
# 10579    NaN
# 10580    NaN
# 10610    NaN
# 13759    NaN
# 13885    NaN
# 15155    NaN
# 15156    NaN
#
#           fuel  \
# 3587   benzine
# 3590   benzine
# 3592   benzine
# 3593   benzine
# 3595   benzine
# 3596   benzine
# 3598   benzine
# 3599   benzine
# 3600   benzine
# 3601   benzine
# 3602   benzine
# 3603   benzine
# 3604   benzine
# 3605   benzine
# 3606   benzine
# 3608   benzine
# 3609   benzine
# 3610   benzine
# 3648   benzine
# 3649   benzine
# 3913    Diesel
# 6005   benzine
# 6034   benzine
# 6946    Diesel
# 7014   benzine
# 7016   benzine
# 7018   benzine
# 7019   benzine
# 8408   benzine
# 8857   benzine
# 9285   benzine
# 9287   benzine
# 9288   benzine
# 9289   benzine
# 9290   benzine
# 9292   benzine
# 9299   benzine
# 10468   Diesel
# 10513  benzine
# 10579   Diesel
# 10580   Diesel
# 10610   Diesel
# 13759   Diesel
# 13885  benzine
# 15155   Diesel
# 15156   Diesel
#
#        consumption_comb  \
# 3587                8.3
# 3590                8.3
# 3592                8.3
# 3593                8.3
# 3595                8.3
# 3596                8.3
# 3598                8.3
# 3599                8.3
# 3600                8.3
# 3601                8.3
# 3602                8.3
# 3603                8.3
# 3604                8.3
# 3605                8.3
# 3606                8.3
# 3608                8.1
# 3609                8.1
# 3610                8.3
# 3648                8.3
# 3649                8.3
# 3913                NaN
# 6005                NaN
# 6034                NaN
# 6946                NaN
# 7014                NaN
# 7016                NaN
# 7018                NaN
# 7019                NaN
# 8408                NaN
# 8857                NaN
# 9285                NaN
# 9287                NaN
# 9288                NaN
# 9289                NaN
# 9290                NaN
# 9292                NaN
# 9299                NaN
# 10468               NaN
# 10513              11.0
# 10579               NaN
# 10580               NaN
# 10610               NaN
# 13759               3.3
# 13885               NaN
# 15155               NaN
# 15156               NaN
#
#        consumption_city  \
# 3587               11.0
# 3590               11.0
# 3592               11.0
# 3593               11.0
# 3595               11.0
# 3596               11.0
# 3598               11.0
# 3599               11.0
# 3600               11.0
# 3601               11.0
# 3602               11.0
# 3603               11.0
# 3604               11.0
# 3605               11.0
# 3606               11.0
# 3608               11.0
# 3609               11.0
# 3610               11.0
# 3648               11.0
# 3649               11.0
# 3913                NaN
# 6005                NaN
# 6034                NaN
# 6946                NaN
# 7014                NaN
# 7016                NaN
# 7018                NaN
# 7019                NaN
# 8408                NaN
# 8857                NaN
# 9285                NaN
# 9287                NaN
# 9288                NaN
# 9289                NaN
# 9290                NaN
# 9292                NaN
# 9299                NaN
# 10468               NaN
# 10513              16.0
# 10579               NaN
# 10580               NaN
# 10610               NaN
# 13759               3.5
# 13885               NaN
# 15155               NaN
# 15156               NaN
#
#        consumption_country  \
# 3587                   6.6
# 3590                   6.6
# 3592                   6.6
# 3593                   6.6
# 3595                   6.6
# 3596                   6.6
# 3598                   6.6
# 3599                   6.5
# 3600                   6.5
# 3601                   6.6
# 3602                   6.6
# 3603                   6.6
# 3604                   6.6
# 3605                   6.6
# 3606                   6.6
# 3608                   6.3
# 3609                   6.3
# 3610                   6.6
# 3648                   6.5
# 3649                   6.6
# 3913                   NaN
# 6005                   NaN
# 6034                   NaN
# 6946                   NaN
# 7014                   NaN
# 7016                   NaN
# 7018                   NaN
# 7019                   NaN
# 8408                   NaN
# 8857                   NaN
# 9285                   NaN
# 9287                   NaN
# 9288                   NaN
# 9289                   NaN
# 9290                   NaN
# 9292                   NaN
# 9299                   NaN
# 10468                  NaN
# 10513                  8.0
# 10579                  NaN
# 10580                  NaN
# 10610                  NaN
# 13759                  3.1
# 13885                  NaN
# 15155                  NaN
# 15156                  NaN
#
#        CO2_emission  \
# 3587          189.0
# 3590          194.0
# 3592          189.0
# 3593          189.0
# 3595          189.0
# 3596          189.0
# 3598          189.0
# 3599          188.0
# 3600          188.0
# 3601          189.0
# 3602          189.0
# 3603          189.0
# 3604          189.0
# 3605          189.0
# 3606          189.0
# 3608          189.0
# 3609          189.0
# 3610          189.0
# 3648          188.0
# 3649          189.0
# 3913            NaN
# 6005            NaN
# 6034            NaN
# 6946            NaN
# 7014            NaN
# 7016            NaN
# 7018            NaN
# 7019            NaN
# 8408            NaN
# 8857            NaN
# 9285            NaN
# 9287            NaN
# 9288            NaN
# 9289            NaN
# 9290            NaN
# 9292            NaN
# 9299            NaN
# 10468           NaN
# 10513         253.0
# 10579           NaN
# 10580           NaN
# 10610           NaN
# 13759          85.0
# 13885           NaN
# 15155           NaN
# 15156           NaN
#
#       emission_class  \
# 3587          Euro 6
# 3590    Euro 6d-TEMP
# 3592          Euro 6
# 3593          Euro 6
# 3595          Euro 6
# 3596          Euro 6
# 3598          Euro 6
# 3599          Euro 6
# 3600          Euro 6
# 3601          Euro 6
# 3602          Euro 6
# 3603          Euro 6
# 3604          Euro 6
# 3605          Euro 6
# 3606          Euro 6
# 3608          Euro 6
# 3609          Euro 6
# 3610          Euro 6
# 3648          Euro 6
# 3649          Euro 6
# 3913             NaN
# 6005             NaN
# 6034             NaN
# 6946             NaN
# 7014             NaN
# 7016             NaN
# 7018             NaN
# 7019             NaN
# 8408             NaN
# 8857             NaN
# 9285             NaN
# 9287             NaN
# 9288             NaN
# 9289             NaN
# 9290             NaN
# 9292             NaN
# 9299             NaN
# 10468            NaN
# 10513         Euro 6
# 10579            NaN
# 10580            NaN
# 10610            NaN
# 13759         Euro 6
# 13885            NaN
# 15155            NaN
# 15156            NaN
#
#                                      comfort_convenience  \
# 3587   Air conditioning,Seat ventilation,Split rear s...
# 3590   Air conditioning,Seat ventilation,Split rear s...
# 3592   Air conditioning,Air suspension,Armrest,Automa...
# 3593   Air conditioning,Seat ventilation,Split rear s...
# 3595   Air conditioning,Armrest,Automatic climate con...
# 3596   Air conditioning,Air suspension,Armrest,Automa...
# 3598   Air conditioning,Seat ventilation,Split rear s...
# 3599   Air conditioning,Seat ventilation,Split rear s...
# 3600   Air conditioning,Air suspension,Armrest,Automa...
# 3601   Air conditioning,Armrest,Automatic climate con...
# 3602   Air conditioning,Armrest,Automatic climate con...
# 3603   Air conditioning,Air suspension,Automatic clim...
# 3604   Air conditioning,Automatic climate control,Cru...
# 3605   Air conditioning,Armrest,Automatic climate con...
# 3606   Air conditioning,Seat ventilation,Split rear s...
# 3608   Air conditioning,Seat ventilation,Split rear s...
# 3609   Air conditioning,Armrest,Automatic climate con...
# 3610   Air conditioning,Seat ventilation,Split rear s...
# 3648   Air conditioning,Armrest,Automatic climate con...
# 3649   Air conditioning,Armrest,Automatic climate con...
# 3913                                                 NaN
# 6005   Air conditioning,Electrical side mirrors,Leath...
# 6034   Air conditioning,Electrical side mirrors,Leath...
# 6946   Air conditioning,Automatic climate control,Cru...
# 7014   Air conditioning,Automatic climate control,Cru...
# 7016   Air conditioning,Automatic climate control,Cru...
# 7018   Air conditioning,Automatic climate control,Cru...
# 7019   Air conditioning,Automatic climate control,Cru...
# 8408   Air conditioning,Cruise control,Electrically h...
# 8857                                    Air conditioning
# 9285   Air conditioning,Automatic climate control,Cru...
# 9287   Air conditioning,Automatic climate control,Cru...
# 9288   Air conditioning,Automatic climate control,Cru...
# 9289   Air conditioning,Automatic climate control,Cru...
# 9290   Air conditioning,Automatic climate control,Cru...
# 9292   Air conditioning,Automatic climate control,Cru...
# 9299   Air conditioning,Automatic climate control,Cru...
# 10468  Air conditioning,Automatic climate control,Cru...
# 10513  Air conditioning,Armrest,Automatic climate con...
# 10579  Air conditioning,Automatic climate control,Cru...
# 10580  Air conditioning,Automatic climate control,Cru...
# 10610  Air conditioning,Automatic climate control,Cru...
# 13759                     Air conditioning,Power windows
# 13885                                      Power windows
# 15155  Air conditioning,Automatic climate control,Cru...
# 15156  Air conditioning,Automatic climate control,Cru...
#
#                                            entertainment  \
# 3587                                               Radio
# 3590                                     Bluetooth,Radio
# 3592   Bluetooth,CD player,Digital radio,Hands-free e...
# 3593                                               Radio
# 3595   Bluetooth,CD player,Digital radio,Hands-free e...
# 3596   Bluetooth,CD player,Hands-free equipment,On-bo...
# 3598                                               Radio
# 3599                                               Radio
# 3600   Bluetooth,CD player,Digital radio,Hands-free e...
# 3601   Bluetooth,Digital radio,Hands-free equipment,M...
# 3602   Bluetooth,Digital radio,Hands-free equipment,M...
# 3603   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 3604   Bluetooth,CD player,Hands-free equipment,On-bo...
# 3605   Bluetooth,CD player,Digital radio,Hands-free e...
# 3606                                               Radio
# 3608                                           Bluetooth
# 3609           Bluetooth,Digital radio,On-board computer
# 3610                                               Radio
# 3648                   CD player,On-board computer,Radio
# 3649                   CD player,On-board computer,Radio
# 3913                                                 NaN
# 6005               Bluetooth,On-board computer,Radio,USB
# 6034               Bluetooth,On-board computer,Radio,USB
# 6946     Bluetooth,CD player,On-board computer,Radio,USB
# 7014                                     CD player,Radio
# 7016                                     CD player,Radio
# 7018                                     CD player,Radio
# 7019                                     CD player,Radio
# 8408   Bluetooth,CD player,Hands-free equipment,On-bo...
# 8857                                                 NaN
# 9285     Bluetooth,CD player,On-board computer,Radio,USB
# 9287     Bluetooth,CD player,On-board computer,Radio,USB
# 9288     Bluetooth,CD player,On-board computer,Radio,USB
# 9289     Bluetooth,CD player,On-board computer,Radio,USB
# 9290     Bluetooth,CD player,On-board computer,Radio,USB
# 9292     Bluetooth,CD player,On-board computer,Radio,USB
# 9299     Bluetooth,CD player,On-board computer,Radio,USB
# 10468    Bluetooth,CD player,On-board computer,Radio,USB
# 10513  Bluetooth,CD player,Digital radio,Hands-free e...
# 10579    Bluetooth,CD player,On-board computer,Radio,USB
# 10580    Bluetooth,CD player,On-board computer,Radio,USB
# 10610    Bluetooth,CD player,On-board computer,Radio,USB
# 13759                                                NaN
# 13885                                  On-board computer
# 15155    Bluetooth,CD player,On-board computer,Radio,USB
# 15156    Bluetooth,CD player,On-board computer,Radio,USB
#
#                                                   Extras  \
# 3587                                        Alloy wheels
# 3590                                        Alloy wheels
# 3592   Alloy wheels,Shift paddles,Sport package,Sport...
# 3593                                        Alloy wheels
# 3595   Alloy wheels,Shift paddles,Ski bag,Sport packa...
# 3596   Alloy wheels,Sport seats,Sport suspension,Tune...
# 3598                                        Alloy wheels
# 3599                                        Alloy wheels
# 3600   Alloy wheels,Catalytic Converter,Shift paddles...
# 3601   Alloy wheels,Catalytic Converter,Shift paddles...
# 3602   Alloy wheels,Shift paddles,Sport package,Sport...
# 3603   Alloy wheels,Sliding door,Sport package,Sport ...
# 3604   Alloy wheels,Shift paddles,Sport package,Sport...
# 3605   Alloy wheels,Catalytic Converter,Shift paddles...
# 3606                                        Alloy wheels
# 3608                                        Alloy wheels
# 3609   Alloy wheels,Shift paddles,Sport package,Sport...
# 3610                                        Alloy wheels
# 3648           Alloy wheels,Sport seats,Sport suspension
# 3649   Alloy wheels,Roof rack,Sport seats,Sport suspe...
# 3913                                                 NaN
# 6005                                                 NaN
# 6034                                                 NaN
# 6946                                                 NaN
# 7014                                                 NaN
# 7016                                                 NaN
# 7018                                                 NaN
# 7019                                                 NaN
# 8408                            Alloy wheels,Sport seats
# 8857                                        Alloy wheels
# 9285                                                 NaN
# 9287                                                 NaN
# 9288                                                 NaN
# 9289                                                 NaN
# 9290                                                 NaN
# 9292                                                 NaN
# 9299                                                 NaN
# 10468                                                NaN
# 10513  Alloy wheels,Roof rack,Shift paddles,Sport pac...
# 10579                                                NaN
# 10580                                                NaN
# 10610                                                NaN
# 13759                                                NaN
# 13885                                                NaN
# 15155                                                NaN
# 15156                                                NaN
#
#                                          safety_security  \
# 3587   Adaptive Cruise Control,Alarm system,Central d...
# 3590   ABS,Adaptive Cruise Control,Alarm system,Centr...
# 3592   ABS,Adaptive Cruise Control,Adaptive headlight...
# 3593   Adaptive Cruise Control,Alarm system,Central d...
# 3595   ABS,Adaptive Cruise Control,Adaptive headlight...
# 3596   ABS,Adaptive Cruise Control,Adaptive headlight...
# 3598   Adaptive Cruise Control,Alarm system,Central d...
# 3599   Adaptive Cruise Control,Alarm system,Central d...
# 3600   Adaptive Cruise Control,Adaptive headlights,Al...
# 3601   ABS,Adaptive Cruise Control,Adaptive headlight...
# 3602   ABS,Adaptive Cruise Control,Alarm system,Centr...
# 3603   Adaptive Cruise Control,Adaptive headlights,Al...
# 3604   ABS,Adaptive Cruise Control,Alarm system,Centr...
# 3605   ABS,Adaptive Cruise Control,Adaptive headlight...
# 3606   Adaptive Cruise Control,Alarm system,Central d...
# 3608   ABS,Alarm system,Central door lock,Driver-side...
# 3609   ABS,Adaptive Cruise Control,Alarm system,Centr...
# 3610   Adaptive Cruise Control,Alarm system,Central d...
# 3648   ABS,Alarm system,Central door lock,Driver-side...
# 3649   ABS,Alarm system,Central door lock,Driver-side...
# 3913                                                 NaN
# 6005   Alarm system,Central door lock,Driver-side air...
# 6034   Alarm system,Central door lock,Driver-side air...
# 6946   Central door lock,Driver-side airbag,Electroni...
# 7014   Driver-side airbag,Electronic stability contro...
# 7016   Driver-side airbag,Electronic stability contro...
# 7018   Driver-side airbag,Electronic stability contro...
# 7019   Driver-side airbag,Electronic stability contro...
# 8408   ABS,Central door lock,Daytime running lights,D...
# 8857   ABS,Central door lock,Driver-side airbag,Immob...
# 9285   Alarm system,Central door lock,Driver-side air...
# 9287   Alarm system,Central door lock,Driver-side air...
# 9288   Alarm system,Central door lock,Driver-side air...
# 9289   Alarm system,Central door lock,Driver-side air...
# 9290   Alarm system,Central door lock,Driver-side air...
# 9292   Alarm system,Central door lock,Driver-side air...
# 9299   Alarm system,Central door lock,Driver-side air...
# 10468  Alarm system,Central door lock,Driver-side air...
# 10513  ABS,Adaptive Cruise Control,Blind spot monitor...
# 10579  Alarm system,Central door lock,Driver-side air...
# 10580  Alarm system,Central door lock,Driver-side air...
# 10610  Alarm system,Central door lock,Driver-side air...
# 13759  ABS,Central door lock,Driver-side airbag,Immob...
# 13885  ABS,Driver-side airbag,Immobilizer,Passenger-s...
# 15155  Alarm system,Central door lock,Driver-side air...
# 15156  Alarm system,Central door lock,Driver-side air...
#
#        gears
# 3587     7.0
# 3590     7.0
# 3592     7.0
# 3593     7.0
# 3595     7.0
# 3596     7.0
# 3598     7.0
# 3599     7.0
# 3600     7.0
# 3601     7.0
# 3602     7.0
# 3603     7.0
# 3604     7.0
# 3605     7.0
# 3606     7.0
# 3608     7.0
# 3609     7.0
# 3610     7.0
# 3648     7.0
# 3649     7.0
# 3913     NaN
# 6005     NaN
# 6034     NaN
# 6946     NaN
# 7014     NaN
# 7016     NaN
# 7018     NaN
# 7019     NaN
# 8408     5.0
# 8857     5.0
# 9285     NaN
# 9287     NaN
# 9288     NaN
# 9289     NaN
# 9290     NaN
# 9292     NaN
# 9299     NaN
# 10468    NaN
# 10513    NaN
# 10579    NaN
# 10580    NaN
# 10610    NaN
# 13759    5.0
# 13885    NaN
# 15155    NaN
# 15156    NaN

# %%
# data.loc[data["power_hp"].notna()].groupby(["model","body_type","registration"])["power_hp"].describe()
# Out:
#                                      count  \
# model    body_type     registration
# A1       Compact       2016.0        234.0
#                        2017.0        161.0
#                        2018.0        269.0
#                        2019.0        373.0
#          Coupe         2016.0          1.0
# ...                                    ...
# Insignia Station wagon 2016.0        435.0
#                        2017.0        305.0
#                        2018.0        481.0
#                        2019.0        390.0
#          Van           2018.0          1.0
#
#                                            mean  \
# model    body_type     registration
# A1       Compact       2016.0         72.940171
#                        2017.0         77.267081
#                        2018.0         71.371747
#                        2019.0         83.745308
#          Coupe         2016.0         70.000000
# ...                                         ...
# Insignia Station wagon 2016.0        110.416092
#                        2017.0        112.114754
#                        2018.0        116.609148
#                        2019.0        126.141026
#          Van           2018.0        121.000000
#
#                                            std  \
# model    body_type     registration
# A1       Compact       2016.0        10.038373
#                        2017.0        12.012888
#                        2018.0        10.450099
#                        2019.0        12.670642
#          Coupe         2016.0              NaN
# ...                                        ...
# Insignia Station wagon 2016.0        15.543879
#                        2017.0        19.466147
#                        2018.0         9.870043
#                        2019.0        20.770706
#          Van           2018.0              NaN
#
#                                        min  \
# model    body_type     registration
# A1       Compact       2016.0         60.0
#                        2017.0         60.0
#                        2018.0         60.0
#                        2019.0         70.0
#          Coupe         2016.0         70.0
# ...                                    ...
# Insignia Station wagon 2016.0         88.0
#                        2017.0          1.0
#                        2018.0        100.0
#                        2019.0         81.0
#          Van           2018.0        121.0
#
#                                        25%  \
# model    body_type     registration
# A1       Compact       2016.0         66.0
#                        2017.0         70.0
#                        2018.0         66.0
#                        2019.0         85.0
#          Coupe         2016.0         70.0
# ...                                    ...
# Insignia Station wagon 2016.0        100.0
#                        2017.0        100.0
#                        2018.0        103.0
#                        2019.0        104.0
#          Van           2018.0        121.0
#
#                                        50%  \
# model    body_type     registration
# A1       Compact       2016.0         70.0
#                        2017.0         70.0
#                        2018.0         70.0
#                        2019.0         85.0
#          Coupe         2016.0         70.0
# ...                                    ...
# Insignia Station wagon 2016.0        100.0
#                        2017.0        121.0
#                        2018.0        121.0
#                        2019.0        125.0
#          Van           2018.0        121.0
#
#                                        75%  \
# model    body_type     registration
# A1       Compact       2016.0         81.5
#                        2017.0         92.0
#                        2018.0         70.0
#                        2019.0         85.0
#          Coupe         2016.0         70.0
# ...                                    ...
# Insignia Station wagon 2016.0        125.0
#                        2017.0        125.0
#                        2018.0        125.0
#                        2019.0        147.0
#          Van           2018.0        121.0
#
#                                        max
# model    body_type     registration
# A1       Compact       2016.0        110.0
#                        2017.0        110.0
#                        2018.0        141.0
#                        2019.0        147.0
#          Coupe         2016.0         70.0
# ...                                    ...
# Insignia Station wagon 2016.0        239.0
#                        2017.0        184.0
#                        2018.0        125.0
#                        2019.0        191.0
#          Van           2018.0        121.0
#
# [153 rows x 8 columns]

# %%
# data["power_hp"].value_counts(dropna=False)
# Out:
# 85.0     2544
# 66.0     2124
# 81.0     1403
# 100.0    1313
# 110.0    1113
# 70.0      889
# 125.0     710
# 51.0      695
# 55.0      592
# 118.0     548
# 92.0      466
# 121.0     394
# 147.0     380
# 77.0      353
# 56.0      290
# 54.0      276
# 103.0     253
# 87.0      234
# 165.0     196
# 88.0      177
# 60.0      160
# 162.0      98
# 74.0       81
# 96.0       72
# 71.0       59
# 101.0      47
# 67.0       40
# 154.0      39
# 122.0      35
# 119.0      30
# 164.0      27
# 135.0      24
# 52.0       22
# 82.0       22
# 78.0       20
# 1.0        20
# 146.0      18
# 294.0      18
# 141.0      16
# 57.0       10
# 120.0       8
# 104.0       8
# 191.0       7
# 112.0       7
# 155.0       6
# 117.0       6
# 184.0       5
# 76.0        4
# 65.0        4
# 90.0        4
# 80.0        3
# 98.0        3
# 168.0       3
# 93.0        3
# 149.0       3
# 150.0       2
# 89.0        2
# 63.0        2
# 86.0        2
# 53.0        2
# 270.0       2
# 127.0       2
# 228.0       2
# 40.0        2
# 143.0       2
# 167.0       2
# 140.0       2
# 239.0       1
# 44.0        1
# 195.0       1
# 132.0       1
# 133.0       1
# 115.0       1
# 163.0       1
# 9.0         1
# 4.0         1
# 84.0        1
# 137.0       1
# 123.0       1
# 75.0        1
# Name: power_hp, dtype: int64

# %%
# data["power_hp"].plot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="power_hp", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "Inspection_new" sütununda 11987 eksik veri var. Burada eksik değerleri model, registration, vehicle_condition göre gruplandırıp bunların price olarak istatistik değerlerini incelediğimizde mua. yapılmayanların used özellikte araçlar olduğunu ve bunların fiyatlarının az da olsa mua. yapılanlara göre daha düşük olduğunu gördüm. Dolayısıyla eksik değerleri muayenesi yeni olmayan olarak değerlendirip bunları No ile doldurdum.

# %%
# data["Inspection_new"].value_counts(dropna=False)
# Out:
# NaN    11987
# Yes     3932
# Name: Inspection_new, dtype: int64

# %%
# data.loc[data["Inspection_new"].notna()].groupby(["model","registration","vehicle_condition"])["price"].describe()
# Out:
#                                          count  \
# model    registration vehicle_condition
# A1       2016.0       Used               223.0
#          2017.0       Demonstration        2.0
#                       Pre-registered       1.0
#                       Used                96.0
#          2018.0       Demonstration       10.0
#                       Employee's car      36.0
#                       Pre-registered       2.0
#                       Used               222.0
#          2019.0       Demonstration       49.0
#                       Employee's car      17.0
#                       New                103.0
#                       Pre-registered       5.0
#                       Used                22.0
# A3       2016.0       Used               154.0
#          2017.0       Demonstration        1.0
#                       Used               101.0
#          2018.0       Demonstration       13.0
#                       Employee's car       8.0
#                       Pre-registered       1.0
#                       Used                62.0
#          2019.0       Demonstration       25.0
#                       Employee's car       5.0
#                       New                108.0
#                       Pre-registered      20.0
#                       Used                21.0
# Astra    2016.0       Used               178.0
#          2017.0       Used               154.0
#          2018.0       Demonstration        1.0
#                       Employee's car      18.0
#                       Used               205.0
#          2019.0       Demonstration       32.0
#                       Employee's car      16.0
#                       New                 81.0
#                       Pre-registered      58.0
#                       Used                56.0
# Clio     2016.0       Used                34.0
#          2017.0       Used                36.0
#          2018.0       Demonstration        8.0
#                       Employee's car      23.0
#                       New                  1.0
#                       Pre-registered       9.0
#                       Used                70.0
#          2019.0       Demonstration        4.0
#                       New                 17.0
#                       Pre-registered      30.0
#                       Used                 5.0
# Corsa    2016.0       Used               131.0
#          2017.0       Used                64.0
#          2018.0       Demonstration        3.0
#                       Employee's car      14.0
#                       Pre-registered       6.0
#                       Used               133.0
#          2019.0       Demonstration       23.0
#                       Employee's car       9.0
#                       New                 50.0
#                       Pre-registered     173.0
#                       Used                63.0
# Espace   2016.0       Used                35.0
#          2017.0       Used                 6.0
#          2018.0       Demonstration        8.0
#                       Employee's car      11.0
#                       Pre-registered       1.0
#                       Used                22.0
#          2019.0       Demonstration       15.0
#                       Employee's car       1.0
#                       New                 16.0
#                       Pre-registered      54.0
#                       Used                 8.0
# Insignia 2016.0       Used               157.0
#          2017.0       Demonstration        3.0
#                       Employee's car       1.0
#                       Used               127.0
#          2018.0       Demonstration        1.0
#                       Employee's car      31.0
#                       Pre-registered       1.0
#                       Used               277.0
#          2019.0       Demonstration       44.0
#                       Employee's car       1.0
#                       New                 76.0
#                       Pre-registered      11.0
#                       Used                13.0
#
#                                                  mean  \
# model    registration vehicle_condition
# A1       2016.0       Used               14466.551570
#          2017.0       Demonstration      14390.000000
#                       Pre-registered     19980.000000
#                       Used               16649.395833
#          2018.0       Demonstration      17747.900000
#                       Employee's car     18591.750000
#                       Pre-registered     19060.000000
#                       Used               17736.225225
#          2019.0       Demonstration      24361.673469
#                       Employee's car     22363.352941
#                       New                22159.572816
#                       Pre-registered     20645.000000
#                       Used               24638.000000
# A3       2016.0       Used               15960.350649
#          2017.0       Demonstration      21900.000000
#                       Used               19210.425743
#          2018.0       Demonstration      21523.538462
#                       Employee's car     21906.125000
#                       Pre-registered     23770.000000
#                       Used               21413.129032
#          2019.0       Demonstration      25283.160000
#                       Employee's car     25788.000000
#                       New                23732.935185
#                       Pre-registered     25250.800000
#                       Used               25462.380952
# Astra    2016.0       Used               11869.230337
#          2017.0       Used               12700.331169
#          2018.0       Demonstration      18450.000000
#                       Employee's car     16974.055556
#                       Used               17198.917073
#          2019.0       Demonstration      26346.875000
#                       Employee's car     20088.750000
#                       New                22439.049383
#                       Pre-registered     21112.258621
#                       Used               20284.732143
# Clio     2016.0       Used               10776.411765
#          2017.0       Used               10938.722222
#          2018.0       Demonstration      20954.125000
#                       Employee's car     15284.347826
#                       New                15928.000000
#                       Pre-registered     17898.555556
#                       Used               15014.785714
#          2019.0       Demonstration      22175.750000
#                       New                11667.764706
#                       Pre-registered     11682.100000
#                       Used               12643.400000
# Corsa    2016.0       Used                8256.809160
#          2017.0       Used               10433.390625
#          2018.0       Demonstration      13260.333333
#                       Employee's car     13353.000000
#                       Pre-registered     11231.500000
#                       Used               13064.406015
#          2019.0       Demonstration      15544.652174
#                       Employee's car     14937.666667
#                       New                14287.120000
#                       Pre-registered     12755.872832
#                       Used               14645.841270
# Espace   2016.0       Used               22110.942857
#          2017.0       Used               27593.166667
#          2018.0       Demonstration      36568.250000
#                       Employee's car     31351.272727
#                       Pre-registered     38990.000000
#                       Used               32182.454545
#          2019.0       Demonstration      43050.400000
#                       Employee's car     45990.000000
#                       New                33632.812500
#                       Pre-registered     35492.703704
#                       Used               31861.250000
# Insignia 2016.0       Used               14293.292994
#          2017.0       Demonstration      19316.666667
#                       Employee's car     21980.000000
#                       Used               18058.338583
#          2018.0       Demonstration      22450.000000
#                       Employee's car     22089.483871
#                       Pre-registered     23990.000000
#                       Used               21962.682310
#          2019.0       Demonstration      35756.568182
#                       Employee's car     26890.000000
#                       New                30238.184211
#                       Pre-registered     37139.090909
#                       Used               34513.769231
#
#                                                  std  \
# model    registration vehicle_condition
# A1       2016.0       Used               1896.890760
#          2017.0       Demonstration       565.685425
#                       Pre-registered             NaN
#                       Used               2240.831836
#          2018.0       Demonstration      3091.445130
#                       Employee's car     2235.655869
#                       Pre-registered     2941.564210
#                       Used               2292.585613
#          2019.0       Demonstration      3561.283760
#                       Employee's car     2949.277220
#                       New                2791.494412
#                       Pre-registered     4438.492143
#                       Used               3086.888694
# A3       2016.0       Used               1737.699469
#          2017.0       Demonstration              NaN
#                       Used               1874.522410
#          2018.0       Demonstration      1113.895313
#                       Employee's car     1468.818810
#                       Pre-registered             NaN
#                       Used               1267.088692
#          2019.0       Demonstration      1235.258936
#                       Employee's car     1236.778072
#                       New                1745.041184
#                       Pre-registered     1060.403975
#                       Used               1069.754013
# Astra    2016.0       Used               2474.354278
#          2017.0       Used               1709.852480
#          2018.0       Demonstration              NaN
#                       Employee's car     1509.242329
#                       Used               1628.566607
#          2019.0       Demonstration      3994.193849
#                       Employee's car     2122.212289
#                       New                4040.691546
#                       Pre-registered     4904.210545
#                       Used               3922.031276
# Clio     2016.0       Used               2797.964543
#          2017.0       Used               2957.978688
#          2018.0       Demonstration      8817.140473
#                       Employee's car     1043.144617
#                       New                        NaN
#                       Pre-registered     4391.420417
#                       Used               3392.575341
#          2019.0       Demonstration      3546.539005
#                       New                2299.761252
#                       Pre-registered     2759.014159
#                       Used               3282.792683
# Corsa    2016.0       Used               1662.794132
#          2017.0       Used               1862.134111
#          2018.0       Demonstration      1238.559782
#                       Employee's car     1267.551243
#                       Pre-registered     2283.720276
#                       Used               1312.609707
#          2019.0       Demonstration      2069.066184
#                       Employee's car      583.221870
#                       New                2122.742226
#                       Pre-registered     2633.031911
#                       Used               2098.447093
# Espace   2016.0       Used               3644.595337
#          2017.0       Used               3912.613981
#          2018.0       Demonstration      2615.550297
#                       Employee's car     2956.863679
#                       Pre-registered             NaN
#                       Used               3373.756529
#          2019.0       Demonstration      4548.108536
#                       Employee's car             NaN
#                       New                6453.178020
#                       Pre-registered     4234.924230
#                       Used               3062.531341
# Insignia 2016.0       Used               2069.591798
#          2017.0       Demonstration       929.157324
#                       Employee's car             NaN
#                       Used               2362.727517
#          2018.0       Demonstration              NaN
#                       Employee's car     1820.533253
#                       Pre-registered             NaN
#                       Used               1839.652092
#          2019.0       Demonstration      3132.388437
#                       Employee's car             NaN
#                       New                5017.679104
#                       Pre-registered     2344.992343
#                       Used               3131.512365
#
#                                              min  \
# model    registration vehicle_condition
# A1       2016.0       Used                9950.0
#          2017.0       Demonstration      13990.0
#                       Pre-registered     19980.0
#                       Used               12490.0
#          2018.0       Demonstration      14900.0
#                       Employee's car     15444.0
#                       Pre-registered     16980.0
#                       Used               13980.0
#          2019.0       Demonstration      15550.0
#                       Employee's car     15990.0
#                       New                17250.0
#                       Pre-registered     16985.0
#                       Used               19890.0
# A3       2016.0       Used               10990.0
#          2017.0       Demonstration      21900.0
#                       Used               14960.0
#          2018.0       Demonstration      20466.0
#                       Employee's car     19990.0
#                       Pre-registered     23770.0
#                       Used               17996.0
#          2019.0       Demonstration      22980.0
#                       Employee's car     24890.0
#                       New                19078.0
#                       Pre-registered     23990.0
#                       Used               23044.0
# Astra    2016.0       Used                7280.0
#          2017.0       Used                9890.0
#          2018.0       Demonstration      18450.0
#                       Employee's car     14450.0
#                       Used               12489.0
#          2019.0       Demonstration      16990.0
#                       Employee's car     17850.0
#                       New                13945.0
#                       Pre-registered     14275.0
#                       Used               15500.0
# Clio     2016.0       Used                7300.0
#          2017.0       Used                8200.0
#          2018.0       Demonstration       9990.0
#                       Employee's car     10690.0
#                       New                15928.0
#                       Pre-registered     10270.0
#                       Used                8990.0
#          2019.0       Demonstration      18680.0
#                       New                 9990.0
#                       Pre-registered      9870.0
#                       Used               10777.0
# Corsa    2016.0       Used                6290.0
#          2017.0       Used                6950.0
#          2018.0       Demonstration      11890.0
#                       Employee's car      9946.0
#                       Pre-registered      9508.0
#                       Used                8880.0
#          2019.0       Demonstration      10470.0
#                       Employee's car     13750.0
#                       New                 9245.0
#                       Pre-registered      9290.0
#                       Used                9950.0
# Espace   2016.0       Used               12614.0
#          2017.0       Used               23400.0
#          2018.0       Demonstration      31990.0
#                       Employee's car     29385.0
#                       Pre-registered     38990.0
#                       Used               27850.0
#          2019.0       Demonstration      35780.0
#                       Employee's car     45990.0
#                       New                28465.0
#                       Pre-registered     28975.0
#                       Used               28890.0
# Insignia 2016.0       Used                9350.0
#          2017.0       Demonstration      18250.0
#                       Employee's car     21980.0
#                       Used               11450.0
#          2018.0       Demonstration      22450.0
#                       Employee's car     17490.0
#                       Pre-registered     23990.0
#                       Used               16980.0
#          2019.0       Demonstration      26379.0
#                       Employee's car     26890.0
#                       New                24315.0
#                       Pre-registered     33450.0
#                       Used               29980.0
#
#                                               25%  \
# model    registration vehicle_condition
# A1       2016.0       Used               12990.00
#          2017.0       Demonstration      14190.00
#                       Pre-registered     19980.00
#                       Used               14987.50
#          2018.0       Demonstration      15960.00
#                       Employee's car     16558.00
#                       Pre-registered     18020.00
#                       Used               16217.50
#          2019.0       Demonstration      21490.00
#                       Employee's car     20590.00
#                       New                20288.00
#                       Pre-registered     16985.00
#                       Used               21942.50
# A3       2016.0       Used               14920.00
#          2017.0       Demonstration      21900.00
#                       Used               17840.00
#          2018.0       Demonstration      20550.00
#                       Employee's car     20780.00
#                       Pre-registered     23770.00
#                       Used               20841.25
#          2019.0       Demonstration      24420.00
#                       Employee's car     24890.00
#                       New                22388.00
#                       Pre-registered     24590.00
#                       Used               24970.00
# Astra    2016.0       Used               10051.00
#          2017.0       Used               11592.25
#          2018.0       Demonstration      18450.00
#                       Employee's car     15450.00
#                       Used               15450.00
#          2019.0       Demonstration      24390.00
#                       Employee's car     19352.50
#                       New                18965.00
#                       Pre-registered     17510.00
#                       Used               17965.00
# Clio     2016.0       Used                8490.00
#          2017.0       Used                9216.75
#          2018.0       Demonstration      10590.00
#                       Employee's car     15485.00
#                       New                15928.00
#                       Pre-registered     15928.00
#                       Used               14099.25
#          2019.0       Demonstration      19355.00
#                       New                10946.00
#                       Pre-registered     10792.50
#                       Used               10990.00
# Corsa    2016.0       Used                7385.00
#          2017.0       Used                8690.00
#          2018.0       Demonstration      12740.50
#                       Employee's car     13442.50
#                       Pre-registered      9790.25
#                       Used               12870.00
#          2019.0       Demonstration      14940.00
#                       Employee's car     14825.00
#                       New                13663.00
#                       Pre-registered     10689.00
#                       Used               13920.00
# Espace   2016.0       Used               20990.00
#          2017.0       Used               24740.00
#          2018.0       Demonstration      34930.00
#                       Employee's car     29385.00
#                       Pre-registered     38990.00
#                       Used               29918.75
#          2019.0       Demonstration      40999.00
#                       Employee's car     45990.00
#                       New                30340.00
#                       Pre-registered     32123.75
#                       Used               28890.00
# Insignia 2016.0       Used               12890.00
#          2017.0       Demonstration      19000.00
#                       Employee's car     21980.00
#                       Used               16807.50
#          2018.0       Demonstration      22450.00
#                       Employee's car     20965.00
#                       Pre-registered     23990.00
#                       Used               20740.00
#          2019.0       Demonstration      33586.25
#                       Employee's car     26890.00
#                       New                25820.00
#                       Pre-registered     35450.00
#                       Used               31990.00
#
#                                              50%  \
# model    registration vehicle_condition
# A1       2016.0       Used               13950.0
#          2017.0       Demonstration      14390.0
#                       Pre-registered     19980.0
#                       Used               15867.5
#          2018.0       Demonstration      16664.5
#                       Employee's car     18333.0
#                       Pre-registered     19060.0
#                       Used               16812.0
#          2019.0       Demonstration      22989.0
#                       Employee's car     21740.0
#                       New                22350.0
#                       Pre-registered     20420.0
#                       Used               24695.0
# A3       2016.0       Used               15930.0
#          2017.0       Demonstration      21900.0
#                       Used               18980.0
#          2018.0       Demonstration      20980.0
#                       Employee's car     21944.5
#                       Pre-registered     23770.0
#                       Used               21461.0
#          2019.0       Demonstration      24980.0
#                       Employee's car     24900.0
#                       New                23900.0
#                       Pre-registered     24740.0
#                       Used               25420.0
# Astra    2016.0       Used               10950.0
#          2017.0       Used               12460.0
#          2018.0       Demonstration      18450.0
#                       Employee's car     17174.5
#                       Used               17880.0
#          2019.0       Demonstration      26685.0
#                       Employee's car     19940.0
#                       New                22590.0
#                       Pre-registered     18889.0
#                       Used               18790.0
# Clio     2016.0       Used                9640.0
#          2017.0       Used                9535.0
#          2018.0       Demonstration      26666.0
#                       Employee's car     15485.0
#                       New                15928.0
#                       Pre-registered     16290.0
#                       Used               15720.0
#          2019.0       Demonstration      22234.0
#                       New                11222.0
#                       Pre-registered     11175.0
#                       Used               11480.0
# Corsa    2016.0       Used                7600.0
#          2017.0       Used               10985.0
#          2018.0       Demonstration      13591.0
#                       Employee's car     13985.0
#                       Pre-registered      9880.5
#                       Used               13290.0
#          2019.0       Demonstration      15979.0
#                       Employee's car     14980.0
#                       New                14213.0
#                       Pre-registered     10990.0
#                       Used               15290.0
# Espace   2016.0       Used               21990.0
#          2017.0       Used               27139.5
#          2018.0       Demonstration      37080.0
#                       Employee's car     29990.0
#                       Pre-registered     38990.0
#                       Used               31790.0
#          2019.0       Demonstration      42560.0
#                       Employee's car     45990.0
#                       New                31417.5
#                       Pre-registered     34572.5
#                       Used               32230.0
# Insignia 2016.0       Used               14490.0
#          2017.0       Demonstration      19750.0
#                       Employee's car     21980.0
#                       Used               18390.0
#          2018.0       Demonstration      22450.0
#                       Employee's car     21980.0
#                       Pre-registered     23990.0
#                       Used               21950.0
#          2019.0       Demonstration      35984.5
#                       Employee's car     26890.0
#                       New                29010.0
#                       Pre-registered     37450.0
#                       Used               33890.0
#
#                                               75%  \
# model    registration vehicle_condition
# A1       2016.0       Used               15869.50
#          2017.0       Demonstration      14590.00
#                       Pre-registered     19980.00
#                       Used               17984.50
#          2018.0       Demonstration      17425.00
#                       Employee's car     20767.25
#                       Pre-registered     20100.00
#                       Used               19620.00
#          2019.0       Demonstration      27995.00
#                       Employee's car     24880.00
#                       New                22725.00
#                       Pre-registered     20990.00
#                       Used               27407.50
# A3       2016.0       Used               17485.00
#          2017.0       Demonstration      21900.00
#                       Used               20990.00
#          2018.0       Demonstration      22440.00
#                       Employee's car     23052.50
#                       Pre-registered     23770.00
#                       Used               21790.00
#          2019.0       Demonstration      26590.00
#                       Employee's car     26890.00
#                       New                24688.00
#                       Pre-registered     26290.00
#                       Used               26015.00
# Astra    2016.0       Used               14472.50
#          2017.0       Used               12980.00
#          2018.0       Demonstration      18450.00
#                       Employee's car     18215.00
#                       Used               18490.00
#          2019.0       Demonstration      28957.50
#                       Employee's car     19940.00
#                       New                24535.00
#                       Pre-registered     23940.00
#                       Used               21097.50
# Clio     2016.0       Used               13482.50
#          2017.0       Used               10855.00
#          2018.0       Demonstration      27777.00
#                       Employee's car     15485.00
#                       New                15928.00
#                       Pre-registered     19589.00
#                       Used               15990.00
#          2019.0       Demonstration      25054.75
#                       New                11290.00
#                       Pre-registered     11410.00
#                       Used               11480.00
# Corsa    2016.0       Used                7925.00
#          2017.0       Used               11950.00
#          2018.0       Demonstration      13945.50
#                       Employee's car     13990.00
#                       Pre-registered     12910.00
#                       Used               13900.00
#          2019.0       Demonstration      16860.00
#                       Employee's car     15490.00
#                       New                16287.50
#                       Pre-registered     15889.00
#                       Used               15985.00
# Espace   2016.0       Used               24925.00
#          2017.0       Used               29314.75
#          2018.0       Demonstration      38882.00
#                       Employee's car     31490.00
#                       Pre-registered     38990.00
#                       Used               34162.50
#          2019.0       Demonstration      45623.00
#                       Employee's car     45990.00
#                       New                34297.50
#                       Pre-registered     37775.00
#                       Used               32930.00
# Insignia 2016.0       Used               15500.00
#          2017.0       Demonstration      19850.00
#                       Employee's car     21980.00
#                       Used               19490.00
#          2018.0       Demonstration      22450.00
#                       Employee's car     23725.00
#                       Pre-registered     23990.00
#                       Used               23880.00
#          2019.0       Demonstration      37990.00
#                       Employee's car     26890.00
#                       New                33805.00
#                       Pre-registered     38720.00
#                       Used               35990.00
#
#                                              max
# model    registration vehicle_condition
# A1       2016.0       Used               18880.0
#          2017.0       Demonstration      14790.0
#                       Pre-registered     19980.0
#                       Used               21490.0
#          2018.0       Demonstration      23880.0
#                       Employee's car     22900.0
#                       Pre-registered     21140.0
#                       Used               23829.0
#          2019.0       Demonstration      29197.0
#                       Employee's car     27370.0
#                       New                29190.0
#                       Pre-registered     27845.0
#                       Used               28990.0
# A3       2016.0       Used               18790.0
#          2017.0       Demonstration      21900.0
#                       Used               21999.0
#          2018.0       Demonstration      23490.0
#                       Employee's car     23680.0
#                       Pre-registered     23770.0
#                       Used               23770.0
#          2019.0       Demonstration      27400.0
#                       Employee's car     27370.0
#                       New                27449.0
#                       Pre-registered     27488.0
#                       Used               26999.0
# Astra    2016.0       Used               15999.0
#          2017.0       Used               17890.0
#          2018.0       Demonstration      18450.0
#                       Employee's car     18980.0
#                       Used               18990.0
#          2019.0       Demonstration      31990.0
#                       Employee's car     27450.0
#                       New                34900.0
#                       Pre-registered     32440.0
#                       Used               30750.0
# Clio     2016.0       Used               15990.0
#          2017.0       Used               17990.0
#          2018.0       Demonstration      27777.0
#                       Employee's car     16390.0
#                       New                15928.0
#                       Pre-registered     24170.0
#                       Used               29850.0
#          2019.0       Demonstration      25555.0
#                       New                18087.0
#                       Pre-registered     22600.0
#                       Used               18490.0
# Corsa    2016.0       Used               13450.0
#          2017.0       Used               13880.0
#          2018.0       Demonstration      14300.0
#                       Employee's car     14680.0
#                       Pre-registered     14440.0
#                       Used               15790.0
#          2019.0       Demonstration      18490.0
#                       Employee's car     15490.0
#                       New                17540.0
#                       Pre-registered     17990.0
#                       Used               18480.0
# Espace   2016.0       Used               27500.0
#          2017.0       Used               33900.0
#          2018.0       Demonstration      38888.0
#                       Employee's car     37989.0
#                       Pre-registered     38990.0
#                       Used               41900.0
#          2019.0       Demonstration      54120.0
#                       Employee's car     45990.0
#                       New                50170.0
#                       Pre-registered     48490.0
#                       Used               37900.0
# Insignia 2016.0       Used               17990.0
#          2017.0       Demonstration      19950.0
#                       Employee's car     21980.0
#                       Used               21990.0
#          2018.0       Demonstration      22450.0
#                       Employee's car     24590.0
#                       Pre-registered     23990.0
#                       Used               24700.0
#          2019.0       Demonstration      40989.0
#                       Employee's car     26890.0
#                       New                52120.0
#                       Pre-registered     40450.0
#                       Used               39949.0

# %%
# data.loc[~data["Inspection_new"].notna()].groupby(["model","registration","vehicle_condition"])["price"].describe()
# Out:
#                                          count  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car       5.0
#                       Used               401.0
#          2017.0       Demonstration        4.0
#                       Employee's car       8.0
#                       Used               323.0
# ...                                        ...
# Insignia 2019.0       Demonstration      117.0
#                       Employee's car       4.0
#                       New                293.0
#                       Pre-registered      52.0
#                       Used                59.0
#
#                                                  mean  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car     16740.000000
#                       Used               14474.623441
#          2017.0       Demonstration      17414.750000
#                       Employee's car     18943.750000
#                       Used               16549.117647
# ...                                               ...
# Insignia 2019.0       Demonstration      34939.649573
#                       Employee's car     28572.500000
#                       New                31096.184300
#                       Pre-registered     30689.557692
#                       Used               31260.745763
#
#                                                  std  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car     2609.214441
#                       Used               1865.071488
#          2017.0       Demonstration      1935.974410
#                       Employee's car     2014.312626
#                       Used               2151.746899
# ...                                              ...
# Insignia 2019.0       Demonstration      3714.650773
#                       Employee's car     5890.078522
#                       New                6204.521285
#                       Pre-registered     3259.828243
#                       Used               5008.888364
#
#                                              min  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car     13500.0
#                       Used                8999.0
#          2017.0       Demonstration      15869.0
#                       Employee's car     15750.0
#                       Used               10999.0
# ...                                          ...
# Insignia 2019.0       Demonstration      22999.0
#                       Employee's car     19900.0
#                       New                19902.0
#                       Pre-registered     22990.0
#                       Used               21900.0
#
#                                               25%  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car     14300.00
#                       Used               13380.00
#          2017.0       Demonstration      15952.25
#                       Employee's car     18712.50
#                       Used               15195.00
# ...                                           ...
# Insignia 2019.0       Demonstration      32990.00
#                       Employee's car     27400.00
#                       New                25692.00
#                       Pre-registered     28937.50
#                       Used               27095.00
#
#                                              50%  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car     18500.0
#                       Used               13999.0
#          2017.0       Demonstration      16900.0
#                       Employee's car     19700.0
#                       Used               15850.0
# ...                                          ...
# Insignia 2019.0       Demonstration      35150.0
#                       Employee's car     30945.0
#                       New                30990.0
#                       Pre-registered     29995.0
#                       Used               30800.0
#
#                                              75%  \
# model    registration vehicle_condition
# A1       2016.0       Employee's car     18700.0
#                       Used               15490.0
#          2017.0       Demonstration      18362.5
#                       Employee's car     19887.5
#                       Used               17900.0
# ...                                          ...
# Insignia 2019.0       Demonstration      37599.0
#                       Employee's car     32117.5
#                       New                35990.0
#                       Pre-registered     32995.0
#                       Used               35095.0
#
#                                              max
# model    registration vehicle_condition
# A1       2016.0       Employee's car     18700.0
#                       Used               19900.0
#          2017.0       Demonstration      19990.0
#                       Employee's car     20800.0
#                       Used               23490.0
# ...                                          ...
# Insignia 2019.0       Demonstration      40990.0
#                       Employee's car     32500.0
#                       New                49884.0
#                       Pre-registered     39490.0
#                       Used               44970.0
#
# [109 rows x 8 columns]

# %%
data.loc[~data["Inspection_new"].notna(), "Inspection_new"] = "No"

# %%
# data["Inspection_new"].value_counts(dropna=False)
# Out:
# No     11987
# Yes     3932
# Name: Inspection_new, dtype: int64

# %%
sns.barplot(x="Inspection_new", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="Inspection_new", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "body_color" sütununda 597 eksik veri var. Eksik değerlerin hangi "model" ve "body_type" olduklarına baktık. "Body_type" eksik olanların fiyatları daha yüksek olduğundan tercih edilen renkler olabileceğini değerlendirdim. Eksik değerleri  "model" göre en çok tercih edilen renkler ile doldurdum. ve sonrasında tercih edilmeyen renkleri gruplandırdım. Diğerlerini olduğu gibi bıraktım.

# %%
# data["body_color"].value_counts(dropna=False)
# Out:
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64

# %%
# data[~data["body_color"].notna()][["model","body_type"]].value_counts()  # boş olanların hangi model ve type olduklarına baktım.
# Out:
# model     body_type
# Insignia  Station wagon    103
#           Sedans           103
# Astra     Station wagon     75
# A3        Sedans            60
# Astra     Sedans            52
# A1        Compact           44
#           Sedans            29
# Clio      Compact           24
# Corsa     Compact           19
# Espace    Van               14
# Clio      Station wagon     13
# Astra     Compact           10
# Corsa     Sedans             9
# A3        Station wagon      7
# Clio      Sedans             7
# Insignia  Other              6
# A3        Compact            5
# Insignia  Off-Road           4
# Espace    Coupe              2
#           Station wagon      2
#           Sedans             2
# Astra     Other              2
# Clio      Transporter        2
# Insignia  Compact            1
#           Coupe              1
# A3        Other              1
# dtype: int64

# %%
# data.loc[~data["body_color"].notna()].groupby(["model","body_type"])["price"].describe()   # "registration" ilave edilebilir.
# Out:
#                         count  \
# model    body_type
# A1       Compact         44.0
#          Sedans          29.0
# A3       Compact          5.0
#          Other            1.0
#          Sedans          60.0
#          Station wagon    7.0
# Astra    Compact         10.0
#          Other            2.0
#          Sedans          52.0
#          Station wagon   75.0
# Clio     Compact         24.0
#          Sedans           7.0
#          Station wagon   13.0
#          Transporter      2.0
# Corsa    Compact         19.0
#          Sedans           9.0
# Espace   Coupe            2.0
#          Sedans           2.0
#          Station wagon    2.0
#          Van             14.0
# Insignia Compact          1.0
#          Coupe            1.0
#          Off-Road         4.0
#          Other            6.0
#          Sedans         103.0
#          Station wagon  103.0
#
#                                 mean  \
# model    body_type
# A1       Compact        20291.840909
#          Sedans         20377.310345
# A3       Compact        23464.000000
#          Other          12550.000000
#          Sedans         22490.133333
#          Station wagon  23365.857143
# Astra    Compact        16636.600000
#          Other           9507.500000
#          Sedans         19019.846154
#          Station wagon  18895.013333
# Clio     Compact        13734.541667
#          Sedans         13958.857143
#          Station wagon  12232.230769
#          Transporter     8390.000000
# Corsa    Compact        11166.263158
#          Sedans         11116.888889
# Espace   Coupe          30567.000000
#          Sedans         25995.000000
#          Station wagon  33810.000000
#          Van            32822.428571
# Insignia Compact        19900.000000
#          Coupe          17094.000000
#          Off-Road       32854.750000
#          Other          18556.666667
#          Sedans         25789.184466
#          Station wagon  26716.689320
#
#                                 std  \
# model    body_type
# A1       Compact        3456.615867
#          Sedans         3872.914693
# A3       Compact        4847.017021
#          Other                  NaN
#          Sedans         2531.806480
#          Station wagon  1541.732189
# Astra    Compact        1098.444881
#          Other          1438.962300
#          Sedans         3885.477498
#          Station wagon  4124.452932
# Clio     Compact        2655.964395
#          Sedans         4441.847905
#          Station wagon  2350.712770
#          Transporter    1414.213562
# Corsa    Compact        1855.313626
#          Sedans         2421.023102
# Espace   Coupe          5052.985058
#          Sedans            0.000000
#          Station wagon  6335.676759
#          Van            7726.647514
# Insignia Compact                NaN
#          Coupe                  NaN
#          Off-Road       1387.646058
#          Other          1784.944444
#          Sedans         4709.351872
#          Station wagon  5362.412137
#
#                             min  \
# model    body_type
# A1       Compact        15100.0
#          Sedans         12980.0
# A3       Compact        14990.0
#          Other          12550.0
#          Sedans         14999.0
#          Station wagon  21854.0
# Astra    Compact        15816.0
#          Other           8490.0
#          Sedans          9990.0
#          Station wagon   8440.0
# Clio     Compact         9890.0
#          Sedans          9971.0
#          Station wagon   9900.0
#          Transporter     7390.0
# Corsa    Compact         6450.0
#          Sedans          6490.0
# Espace   Coupe          26994.0
#          Sedans         25995.0
#          Station wagon  29330.0
#          Van            22990.0
# Insignia Compact        19900.0
#          Coupe          17094.0
#          Off-Road       31505.0
#          Other          15990.0
#          Sedans         14490.0
#          Station wagon   9500.0
#
#                              25%  \
# model    body_type
# A1       Compact        17844.00
#          Sedans         17900.00
# A3       Compact        24542.00
#          Other          12550.00
#          Sedans         20950.00
#          Station wagon  22092.00
# Astra    Compact        15890.00
#          Other           8998.75
#          Sedans         16793.50
#          Station wagon  16940.50
# Clio     Compact        11162.50
#          Sedans         10136.00
#          Station wagon  10564.00
#          Transporter     7890.00
# Corsa    Compact        10220.50
#          Sedans         10083.00
# Espace   Coupe          28780.50
#          Sedans         25995.00
#          Station wagon  31570.00
#          Van            26115.00
# Insignia Compact        19900.00
#          Coupe          17094.00
#          Off-Road       32135.00
#          Other          17497.50
#          Sedans         22995.00
#          Station wagon  23522.50
#
#                             50%  \
# model    body_type
# A1       Compact        19944.5
#          Sedans         20900.0
# A3       Compact        25228.0
#          Other          12550.0
#          Sedans         22311.0
#          Station wagon  23044.0
# Astra    Compact        16159.0
#          Other           9507.5
#          Sedans         18430.0
#          Station wagon  18450.0
# Clio     Compact        14506.0
#          Sedans         13990.0
#          Station wagon  11050.0
#          Transporter     8390.0
# Corsa    Compact        11100.0
#          Sedans         10900.0
# Espace   Coupe          30567.0
#          Sedans         25995.0
#          Station wagon  33810.0
#          Van            32025.0
# Insignia Compact        19900.0
#          Coupe          17094.0
#          Off-Road       32569.0
#          Other          18690.0
#          Sedans         25268.0
#          Station wagon  25862.0
#
#                              75%  \
# model    body_type
# A1       Compact        22020.00
#          Sedans         22390.00
# A3       Compact        25272.00
#          Other          12550.00
#          Sedans         24430.25
#          Station wagon  24529.50
# Astra    Compact        16864.50
#          Other          10016.25
#          Sedans         22315.00
#          Station wagon  21780.00
# Clio     Compact        15933.50
#          Sedans         15789.50
#          Station wagon  14987.00
#          Transporter     8890.00
# Corsa    Compact        12533.00
#          Sedans         11950.00
# Espace   Coupe          32353.50
#          Sedans         25995.00
#          Station wagon  36050.00
#          Van            36745.50
# Insignia Compact        19900.00
#          Coupe          17094.00
#          Off-Road       33288.75
#          Other          19650.00
#          Sedans         28570.00
#          Station wagon  29736.00
#
#                             max
# model    body_type
# A1       Compact        29181.0
#          Sedans         28500.0
# A3       Compact        27288.0
#          Other          12550.0
#          Sedans         27250.0
#          Station wagon  25420.0
# Astra    Compact        18599.0
#          Other          10525.0
#          Sedans         26290.0
#          Station wagon  27948.0
# Clio     Compact        17390.0
#          Sedans         21900.0
#          Station wagon  16990.0
#          Transporter     9390.0
# Corsa    Compact        14489.0
#          Sedans         14900.0
# Espace   Coupe          34140.0
#          Sedans         25995.0
#          Station wagon  38290.0
#          Van            45990.0
# Insignia Compact        19900.0
#          Coupe          17094.0
#          Off-Road       34776.0
#          Other          20900.0
#          Sedans         37285.0
#          Station wagon  39990.0

# %%
# data.loc[data["body_color"].notna()].groupby(["model","body_type"])["price"].describe()
# Out:
#                          count  \
# model    body_type
# A1       Compact         995.0
#          Coupe             2.0
#          Other            13.0
#          Sedans         1509.0
#          Station wagon    21.0
#          Van               1.0
# A2       Off-Road          1.0
# A3       Compact         177.0
#          Convertible       8.0
#          Coupe             4.0
#          Other            15.0
#          Sedans         2545.0
#          Station wagon   275.0
# Astra    Compact         175.0
#          Coupe             2.0
#          Off-Road          1.0
#          Other            65.0
#          Sedans         1001.0
#          Station wagon  1143.0
# Clio     Compact         460.0
#          Coupe             1.0
#          Off-Road          2.0
#          Other            51.0
#          Sedans          926.0
#          Station wagon   324.0
#          Transporter      27.0
#          Van               2.0
# Corsa    Compact        1213.0
#          Coupe            13.0
#          Off-Road          3.0
#          Other            87.0
#          Sedans          866.0
#          Transporter       7.0
#          Van               2.0
# Duster   Off-Road         34.0
# Espace   Compact           6.0
#          Off-Road          8.0
#          Other             8.0
#          Sedans           19.0
#          Station wagon    89.0
#          Transporter      52.0
#          Van             789.0
# Insignia Compact          26.0
#          Off-Road          3.0
#          Other            42.0
#          Sedans          797.0
#          Station wagon  1511.0
#          Van               1.0
#
#                                 mean  \
# model    body_type
# A1       Compact        19140.621106
#          Coupe          14925.000000
#          Other          22026.153846
#          Sedans         18597.990060
#          Station wagon  17811.380952
#          Van            29000.000000
# A2       Off-Road       28200.000000
# A3       Compact        18899.062147
#          Convertible    27905.375000
#          Coupe          17745.000000
#          Other          20910.666667
#          Sedans         21124.352063
#          Station wagon  20616.098182
# Astra    Compact        16174.800000
#          Coupe          22240.000000
#          Off-Road       18590.000000
#          Other          13998.369231
#          Sedans         15804.390609
#          Station wagon  15558.244094
# Clio     Compact        12593.030435
#          Coupe          17990.000000
#          Off-Road       12845.000000
#          Other          12105.823529
#          Sedans         11945.757019
#          Station wagon  11082.509259
#          Transporter     8497.592593
#          Van             9650.000000
# Corsa    Compact        11800.640561
#          Coupe           8772.307692
#          Off-Road        8166.666667
#          Other           9761.149425
#          Sedans         10196.312933
#          Transporter     7650.000000
#          Van             7900.000000
# Duster   Off-Road       13230.176471
# Espace   Compact        30046.666667
#          Off-Road       25762.500000
#          Other          29608.875000
#          Sedans         30479.526316
#          Station wagon  27168.696629
#          Transporter    22606.480769
#          Van            30891.405577
# Insignia Compact        28924.307692
#          Off-Road       24913.333333
#          Other          18203.666667
#          Sedans         20678.590966
#          Station wagon  21165.484447
#          Van            20980.000000
#
#                                  std  \
# model    body_type
# A1       Compact         4594.831094
#          Coupe           1378.858223
#          Other           3413.633300
#          Sedans          4458.098472
#          Station wagon   4360.610089
#          Van                     NaN
# A2       Off-Road                NaN
# A3       Compact         6823.451513
#          Convertible    13457.660155
#          Coupe            962.652585
#          Other           4178.308726
#          Sedans          4866.976418
#          Station wagon   4714.906727
# Astra    Compact         6225.676641
#          Coupe          10960.155108
#          Off-Road                NaN
#          Other           2337.634839
#          Sedans          4367.318732
#          Station wagon   5281.987259
# Clio     Compact         4149.706628
#          Coupe                   NaN
#          Off-Road        7276.128778
#          Other           3011.480724
#          Sedans          4618.155538
#          Station wagon   3050.163187
#          Transporter     1354.923366
#          Van              353.553391
# Corsa    Compact         3095.374780
#          Coupe           1578.993107
#          Off-Road         461.880215
#          Other           2080.574879
#          Sedans          2635.781344
#          Transporter     2271.930163
#          Van                0.000000
# Duster   Off-Road        1622.404678
# Espace   Compact        10287.634649
#          Off-Road        5385.347183
#          Other           7949.339873
#          Sedans          7842.602816
#          Station wagon   8757.351045
#          Transporter     4226.833096
#          Van             8741.162019
# Insignia Compact        11374.186078
#          Off-Road       10825.203616
#          Other           5621.259974
#          Sedans          7493.340441
#          Station wagon   7797.776775
#          Van                     NaN
#
#                             min  \
# model    body_type
# A1       Compact         9950.0
#          Coupe          13950.0
#          Other          16590.0
#          Sedans          8999.0
#          Station wagon  12950.0
#          Van            29000.0
# A2       Off-Road       28200.0
# A3       Compact        12900.0
#          Convertible    10893.0
#          Coupe          16990.0
#          Other          15300.0
#          Sedans         10550.0
#          Station wagon   5555.0
# Astra    Compact         8450.0
#          Coupe          14490.0
#          Off-Road       18590.0
#          Other           8740.0
#          Sedans          6500.0
#          Station wagon    255.0
# Clio     Compact         5800.0
#          Coupe          17990.0
#          Off-Road        7700.0
#          Other           7500.0
#          Sedans          5445.0
#          Station wagon   5900.0
#          Transporter     5900.0
#          Van             9400.0
# Corsa    Compact          120.0
#          Coupe           6900.0
#          Off-Road        7900.0
#          Other            331.0
#          Sedans            13.0
#          Transporter     5250.0
#          Van             7900.0
# Duster   Off-Road       10850.0
# Espace   Compact        17900.0
#          Off-Road       14900.0
#          Other          17500.0
#          Sedans         18999.0
#          Station wagon  16900.0
#          Transporter    14999.0
#          Van            12614.0
# Insignia Compact        10350.0
#          Off-Road       12750.0
#          Other          10600.0
#          Sedans          8600.0
#          Station wagon   8290.0
#          Van            20980.0
#
#                              25%  \
# model    body_type
# A1       Compact        15700.00
#          Coupe          14437.50
#          Other          21490.00
#          Sedans         15250.00
#          Station wagon  15750.00
#          Van            29000.00
# A2       Off-Road       28200.00
# A3       Compact        14450.00
#          Convertible    20675.00
#          Coupe          16990.00
#          Other          17825.00
#          Sedans         17980.00
#          Station wagon  17890.00
# Astra    Compact        12636.00
#          Coupe          18365.00
#          Off-Road       18590.00
#          Other          12900.00
#          Sedans         12750.00
#          Station wagon  11500.00
# Clio     Compact         9999.00
#          Coupe          17990.00
#          Off-Road       10272.50
#          Other           9990.00
#          Sedans          8800.00
#          Station wagon   8900.00
#          Transporter     7795.00
#          Van             9525.00
# Corsa    Compact         8990.00
#          Coupe           7500.00
#          Off-Road        7900.00
#          Other           8500.00
#          Sedans          8199.25
#          Transporter     5525.00
#          Van             7900.00
# Duster   Off-Road       11925.00
# Espace   Compact        22422.50
#          Off-Road       24300.00
#          Other          24967.50
#          Sedans         25490.00
#          Station wagon  20455.00
#          Transporter    19787.50
#          Van            24900.00
# Insignia Compact        19400.00
#          Off-Road       20625.00
#          Other          14222.50
#          Sedans         15940.00
#          Station wagon  14995.00
#          Van            20980.00
#
#                             50%  \
# model    body_type
# A1       Compact        18000.0
#          Coupe          14925.0
#          Other          22490.0
#          Sedans         16999.0
#          Station wagon  16422.0
#          Van            29000.0
# A2       Off-Road       28200.0
# A3       Compact        17550.0
#          Convertible    25750.0
#          Coupe          17495.0
#          Other          20200.0
#          Sedans         20999.0
#          Station wagon  20590.0
# Astra    Compact        14900.0
#          Coupe          22240.0
#          Off-Road       18590.0
#          Other          14890.0
#          Sedans         15325.0
#          Station wagon  14990.0
# Clio     Compact        11299.0
#          Coupe          17990.0
#          Off-Road       12845.0
#          Other          10990.0
#          Sedans         10095.0
#          Station wagon  10450.0
#          Transporter     8490.0
#          Van             9650.0
# Corsa    Compact        11220.0
#          Coupe           8500.0
#          Off-Road        7900.0
#          Other           9400.0
#          Sedans          9692.5
#          Transporter     7450.0
#          Van             7900.0
# Duster   Off-Road       13189.0
# Espace   Compact        28745.0
#          Off-Road       26775.0
#          Other          30400.0
#          Sedans         28990.0
#          Station wagon  23950.0
#          Transporter    21000.0
#          Van            29950.0
# Insignia Compact        33995.0
#          Off-Road       28500.0
#          Other          17145.0
#          Sedans         19300.0
#          Station wagon  19990.0
#          Van            20980.0
#
#                              75%  \
# model    body_type
# A1       Compact        22399.50
#          Coupe          15412.50
#          Other          23490.00
#          Sedans         21500.00
#          Station wagon  19640.00
#          Van            29000.00
# A2       Off-Road       28200.00
# A3       Compact        20810.00
#          Convertible    31412.50
#          Coupe          18250.00
#          Other          23495.00
#          Sedans         23500.00
#          Station wagon  23590.00
# Astra    Compact        17490.00
#          Coupe          26115.00
#          Off-Road       18590.00
#          Other          14990.00
#          Sedans         17900.00
#          Station wagon  17990.00
# Clio     Compact        14990.00
#          Coupe          17990.00
#          Off-Road       15417.50
#          Other          15620.00
#          Sedans         13950.00
#          Station wagon  11925.00
#          Transporter     9276.00
#          Van             9775.00
# Corsa    Compact        14350.00
#          Coupe          10500.00
#          Off-Road        8300.00
#          Other           9912.50
#          Sedans         11396.75
#          Transporter     9650.00
#          Van             7900.00
# Duster   Off-Road       14399.00
# Espace   Compact        38367.50
#          Off-Road       28262.50
#          Other          34000.00
#          Sedans         31850.00
#          Station wagon  31490.00
#          Transporter    25250.00
#          Van            35500.00
# Insignia Compact        38484.00
#          Off-Road       30995.00
#          Other          18900.00
#          Sedans         22865.00
#          Station wagon  23890.00
#          Van            20980.00
#
#                             max
# model    body_type
# A1       Compact        31990.0
#          Coupe          15900.0
#          Other          26900.0
#          Sedans         37900.0
#          Station wagon  28999.0
#          Van            29000.0
# A2       Off-Road       28200.0
# A3       Compact        67600.0
#          Convertible    56100.0
#          Coupe          19000.0
#          Other          28490.0
#          Sedans         74600.0
#          Station wagon  63900.0
# Astra    Compact        39433.0
#          Coupe          29990.0
#          Off-Road       18590.0
#          Other          18990.0
#          Sedans         32950.0
#          Station wagon  34900.0
# Clio     Compact        29740.0
#          Coupe          17990.0
#          Off-Road       17990.0
#          Other          16590.0
#          Sedans         31500.0
#          Station wagon  20800.0
#          Transporter    10798.0
#          Van             9900.0
# Corsa    Compact        18622.0
#          Coupe          11100.0
#          Off-Road        8700.0
#          Other          17250.0
#          Sedans         18490.0
#          Transporter    10500.0
#          Van             7900.0
# Duster   Off-Road       16033.0
# Espace   Compact        43000.0
#          Off-Road       32900.0
#          Other          42681.0
#          Sedans         48498.0
#          Station wagon  52990.0
#          Transporter    32700.0
#          Van            68320.0
# Insignia Compact        49884.0
#          Off-Road       33490.0
#          Other          37999.0
#          Sedans         49350.0
#          Station wagon  52120.0
#          Van            20980.0

# %%
f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler modele göre en çok tercih edilen black, grey, white ile dolduruldu.

data["body_color"] = data["body_color"].fillna(data.groupby(["model"])["body_color"].transform(f))

# %%
data["body_color"] = data["body_color"].apply(lambda x : "other" if x in ["Brown", "Green", "Beige", "Yellow","Violet","Bronze", "Orange" ,"Gold"] else x)

# %%
# data["body_color"].value_counts(dropna=False)
# Out:
# Black     3957
# Grey      3771
# White     3525
# Silver    1647
# Blue      1431
# Red        957
# other      631
# Name: body_color, dtype: int64

# %%
sns.barplot(x="body_color", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="body_color", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "paintwork" sütunundaki nan değerleri dolduralım. 5772 eksik veri var. Burada eksik değerleri model, body_type ve registration göre gruplandırıp bunların price değerlerini incelediğimde ne kadar başka faktörlerde olsa boş olanların fiyatlarının dolu olanlara göre düşük olduğunu gördüm. Ancak buradan bunların metallic olmayanlar olabileceğini değerlendirmeme rağmen "model" e göre gruplandırıp "paintwork" mode() ile doldurdum. Ama bunların aksine  metallic olmayan olarak doldurup sonrasında bunun etkisi ile karşılaştırma yapılabilir!!!

# %%
# data["paintwork"].value_counts(dropna=False)
# Out:
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paintwork, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]   

data["paintwork"] = data["paintwork"].fillna(data.groupby(["model"])["paintwork"].transform(f))

# %%
# data.loc[~data["paintwork"].notna()].groupby(["model","body_type","registration"])["price"].describe()
# Out:
#                                      count  \
# model    body_type     registration
# A1       Compact       2016.0         58.0
#                        2017.0         52.0
#                        2018.0         58.0
#                        2019.0        143.0
#          Other         2017.0          1.0
# ...                                    ...
# Insignia Sedans        2019.0        131.0
#          Station wagon 2016.0        118.0
#                        2017.0        121.0
#                        2018.0         70.0
#                        2019.0        141.0
#
#                                              mean  \
# model    body_type     registration
# A1       Compact       2016.0        14007.948276
#                        2017.0        15750.115385
#                        2018.0        17514.982759
#                        2019.0        22176.181818
#          Other         2017.0        23490.000000
# ...                                           ...
# Insignia Sedans        2019.0        27755.167939
#          Station wagon 2016.0        13113.618644
#                        2017.0        17142.016529
#                        2018.0        21348.485714
#                        2019.0        31057.531915
#
#                                              std  \
# model    body_type     registration
# A1       Compact       2016.0        1921.948777
#                        2017.0        1218.357825
#                        2018.0        2363.896378
#                        2019.0        3268.530931
#          Other         2017.0                NaN
# ...                                          ...
# Insignia Sedans        2019.0        4897.482573
#          Station wagon 2016.0        2062.133195
#                        2017.0        2653.186261
#                        2018.0        1817.755167
#                        2019.0        5044.213659
#
#                                          min  \
# model    body_type     registration
# A1       Compact       2016.0        10490.0
#                        2017.0        12490.0
#                        2018.0        14220.0
#                        2019.0        15550.0
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Sedans        2019.0        19902.0
#          Station wagon 2016.0         8290.0
#                        2017.0        10000.0
#                        2018.0        17980.0
#                        2019.0        21992.0
#
#                                           25%  \
# model    body_type     registration
# A1       Compact       2016.0        12942.50
#                        2017.0        15810.00
#                        2018.0        15816.75
#                        2019.0        19880.00
#          Other         2017.0        23490.00
# ...                                       ...
# Insignia Sedans        2019.0        24052.50
#          Station wagon 2016.0        11792.50
#                        2017.0        15300.00
#                        2018.0        19900.00
#                        2019.0        26565.00
#
#                                          50%  \
# model    body_type     registration
# A1       Compact       2016.0        13820.0
#                        2017.0        15850.0
#                        2018.0        16825.0
#                        2019.0        21490.0
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Sedans        2019.0        26125.0
#          Station wagon 2016.0        12990.0
#                        2017.0        16890.0
#                        2018.0        20950.0
#                        2019.0        31459.0
#
#                                           75%  \
# model    body_type     registration
# A1       Compact       2016.0        15423.75
#                        2017.0        15850.00
#                        2018.0        18333.00
#                        2019.0        23475.00
#          Other         2017.0        23490.00
# ...                                       ...
# Insignia Sedans        2019.0        31947.00
#          Station wagon 2016.0        14480.00
#                        2017.0        19490.00
#                        2018.0        22960.00
#                        2019.0        35291.00
#
#                                          max
# model    body_type     registration
# A1       Compact       2016.0        18400.0
#                        2017.0        21490.0
#                        2018.0        23650.0
#                        2019.0        29181.0
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Sedans        2019.0        40990.0
#          Station wagon 2016.0        17990.0
#                        2017.0        21990.0
#                        2018.0        24690.0
#                        2019.0        42475.0
#
# [129 rows x 8 columns]

# %%
# data.loc[data["paintwork"].notna()].groupby(["model","body_type","registration"])["price"].describe()
# Out:
#                                      count  \
# model    body_type     registration
# A1       Compact       2016.0        176.0
#                        2017.0        109.0
#                        2018.0        212.0
#                        2019.0        231.0
#          Coupe         2016.0          1.0
# ...                                    ...
# Insignia Station wagon 2016.0        317.0
#                        2017.0        187.0
#                        2018.0        411.0
#                        2019.0        249.0
#          Van           2018.0          1.0
#
#                                              mean  \
# model    body_type     registration
# A1       Compact       2016.0        14705.909091
#                        2017.0        17009.596330
#                        2018.0        18861.650943
#                        2019.0        24581.268398
#          Coupe         2016.0        13950.000000
# ...                                           ...
# Insignia Station wagon 2016.0        13937.823344
#                        2017.0        17625.267380
#                        2018.0        22103.270073
#                        2019.0        33892.008032
#          Van           2018.0        20980.000000
#
#                                              std  \
# model    body_type     registration
# A1       Compact       2016.0        1878.043907
#                        2017.0        2285.750003
#                        2018.0        2674.019324
#                        2019.0        3188.683209
#          Coupe         2016.0                NaN
# ...                                          ...
# Insignia Station wagon 2016.0        2376.566802
#                        2017.0        2667.300902
#                        2018.0        1667.739215
#                        2019.0        4726.217014
#          Van           2018.0                NaN
#
#                                          min  \
# model    body_type     registration
# A1       Compact       2016.0         9950.0
#                        2017.0        10999.0
#                        2018.0        13980.0
#                        2019.0        17880.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Station wagon 2016.0         8913.0
#                        2017.0         8990.0
#                        2018.0        17500.0
#                        2019.0        19900.0
#          Van           2018.0        20980.0
#
#                                           25%  \
# model    body_type     registration
# A1       Compact       2016.0        13500.00
#                        2017.0        15450.00
#                        2018.0        16448.75
#                        2019.0        21990.00
#          Coupe         2016.0        13950.00
# ...                                       ...
# Insignia Station wagon 2016.0        12500.00
#                        2017.0        16195.00
#                        2018.0        20890.00
#                        2019.0        29995.00
#          Van           2018.0        20980.00
#
#                                          50%  \
# model    body_type     registration
# A1       Compact       2016.0        14330.0
#                        2017.0        15960.0
#                        2018.0        17515.0
#                        2019.0        23480.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Station wagon 2016.0        13980.0
#                        2017.0        18250.0
#                        2018.0        21980.0
#                        2019.0        33989.0
#          Van           2018.0        20980.0
#
#                                          75%  \
# model    body_type     registration
# A1       Compact       2016.0        15637.5
#                        2017.0        18950.0
#                        2018.0        21482.5
#                        2019.0        27765.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Station wagon 2016.0        15400.0
#                        2017.0        18950.0
#                        2018.0        23490.0
#                        2019.0        37450.0
#          Van           2018.0        20980.0
#
#                                          max
# model    body_type     registration
# A1       Compact       2016.0        18900.0
#                        2017.0        22150.0
#                        2018.0        23829.0
#                        2019.0        31990.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Station wagon 2016.0        31318.0
#                        2017.0        21980.0
#                        2018.0        31500.0
#                        2019.0        52120.0
#          Van           2018.0        20980.0
#
# [136 rows x 8 columns]

# %%
# data["paintwork"].value_counts(dropna=False)
# Out:
# Metallic       15549
# Uni/basic        364
# Perl effect        6
# Name: paintwork, dtype: int64

# %%
sns.barplot(x="paintwork", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="paintwork", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "body_color_original" sütununda 3774 eksik veri var. Burada eksik değerleri "model", "body_type" ve "registration" göre gruplandırıp bunların price değerlerini incelediğimde ne kadar başka faktörlerde olsa boş olanların fiyatlarının birbirine yakın olduğunu gördüm. Ancak içerideki veri çeşitliliği ve bunun fiyata olabilecek etkisi göz önüne alındığında düşürdüm.

# %%
# data["body_color_original"].value_counts(dropna=False).head(50)
# Out:
# NaN                        3774
# Onyx Schwarz                389
# Bianco                      282
# Argon Silber                273
# Quarz Grau                  266
# Mythosschwarz Metallic      256
# wählbar                     237
# Brillantschwarz             216
# Gris                        204
# Nero                        196
# Grigio                      191
# Licht Grau                  184
# Blanco                      155
# Tiefsee Blau                139
# onyx schwarz                134
# Florettsilber Metallic      131
# Misanorot Perleffekt        128
# Negro                       123
# Argento                     120
# Lava Rot                    119
# SchneeWeiss/SummitWhite     108
# Schnee Weiß                  95
# Mythosschwarz                94
# Argonsilber                  90
# Azul                         89
# Ibisweiß                     87
# Schneeweiß                   84
# Nanograu Metallic            84
# quarz grau                   82
# argon silber                 79
# Cortinaweiss                 78
# brillantschwarz              72
# Gletscherweiss Metallic      71
# schwarz                      70
# Grigio scuro                 70
# Grijs                        70
# Rojo                         70
# Gletscherweiß Metallic       69
# licht grau                   65
# schneeweiss                  65
# Arktis-Weiß                  65
# Schwarz                      62
# Black Pearl                  62
# grey                         62
# Argon silber                 61
# mythosschwarz                60
# Titanium-Grau                59
# Cortinaweiß                  59
# blanc                        55
# Schneeweiss                  55
# Name: body_color_original, dtype: int64

# %%
# data.loc[~data["body_color_original"].notna()].groupby(["model","body_type","registration"])["price"].describe()
# Out:
#                                      count  \
# model    body_type     registration
# A1       Compact       2016.0         46.0
#                        2017.0         46.0
#                        2018.0         14.0
#                        2019.0         32.0
#          Coupe         2016.0          1.0
# ...                                    ...
# Insignia Sedans        2019.0         55.0
#          Station wagon 2016.0        128.0
#                        2017.0         72.0
#                        2018.0         32.0
#                        2019.0         46.0
#
#                                              mean  \
# model    body_type     registration
# A1       Compact       2016.0        14388.043478
#                        2017.0        15852.152174
#                        2018.0        17549.928571
#                        2019.0        20783.343750
#          Coupe         2016.0        13950.000000
# ...                                           ...
# Insignia Sedans        2019.0        27893.454545
#          Station wagon 2016.0        13602.656250
#                        2017.0        16469.277778
#                        2018.0        21882.218750
#                        2019.0        28604.173913
#
#                                              std  \
# model    body_type     registration
# A1       Compact       2016.0        1121.298096
#                        2017.0         756.988007
#                        2018.0        2222.278819
#                        2019.0        3058.532883
#          Coupe         2016.0                NaN
# ...                                          ...
# Insignia Sedans        2019.0        4540.804753
#          Station wagon 2016.0        2624.521138
#                        2017.0        2848.511251
#                        2018.0        1266.197170
#                        2019.0        4640.041419
#
#                                          min  \
# model    body_type     registration
# A1       Compact       2016.0        10490.0
#                        2017.0        14400.0
#                        2018.0        15700.0
#                        2019.0        16220.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Sedans        2019.0        19902.0
#          Station wagon 2016.0         8913.0
#                        2017.0        10000.0
#                        2018.0        18900.0
#                        2019.0        21992.0
#
#                                           25%  \
# model    body_type     registration
# A1       Compact       2016.0        13900.00
#                        2017.0        15507.50
#                        2018.0        16137.25
#                        2019.0        19078.00
#          Coupe         2016.0        13950.00
# ...                                       ...
# Insignia Sedans        2019.0        24049.50
#          Station wagon 2016.0        11975.00
#                        2017.0        15400.00
#                        2018.0        20974.25
#                        2019.0        24847.50
#
#                                          50%  \
# model    body_type     registration
# A1       Compact       2016.0        14990.0
#                        2017.0        15850.0
#                        2018.0        16900.0
#                        2019.0        20463.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Sedans        2019.0        27804.0
#          Station wagon 2016.0        13165.0
#                        2017.0        16182.0
#                        2018.0        21900.0
#                        2019.0        27575.0
#
#                                           75%  \
# model    body_type     registration
# A1       Compact       2016.0        14990.00
#                        2017.0        15850.00
#                        2018.0        17470.00
#                        2019.0        21870.75
#          Coupe         2016.0        13950.00
# ...                                       ...
# Insignia Sedans        2019.0        31702.00
#          Station wagon 2016.0        15224.75
#                        2017.0        18524.75
#                        2018.0        22900.00
#                        2019.0        32724.25
#
#                                          max
# model    body_type     registration
# A1       Compact       2016.0        15850.0
#                        2017.0        19000.0
#                        2018.0        23650.0
#                        2019.0        29181.0
#          Coupe         2016.0        13950.0
# ...                                      ...
# Insignia Sedans        2019.0        37875.0
#          Station wagon 2016.0        31318.0
#                        2017.0        21500.0
#                        2018.0        23990.0
#                        2019.0        36900.0
#
# [104 rows x 8 columns]

# %%
# data.loc[data["body_color_original"].notna()].groupby(["model","body_type","registration"])["price"].describe()
# Out:
#                                      count  \
# model    body_type     registration
# A1       Compact       2016.0        188.0
#                        2017.0        115.0
#                        2018.0        256.0
#                        2019.0        342.0
#          Other         2017.0          1.0
# ...                                    ...
# Insignia Station wagon 2016.0        307.0
#                        2017.0        236.0
#                        2018.0        449.0
#                        2019.0        344.0
#          Van           2018.0          1.0
#
#                                              mean  \
# model    body_type     registration
# A1       Compact       2016.0        14568.356383
#                        2017.0        16903.069565
#                        2018.0        18628.281250
#                        2019.0        23930.994152
#          Other         2017.0        23490.000000
# ...                                           ...
# Insignia Station wagon 2016.0        13760.771987
#                        2017.0        17730.173729
#                        2018.0        22001.351893
#                        2019.0        33437.296512
#          Van           2018.0        20980.000000
#
#                                              std  \
# model    body_type     registration
# A1       Compact       2016.0        2057.016149
#                        2017.0        2357.774321
#                        2018.0        2679.038992
#                        2019.0        3332.321228
#          Other         2017.0                NaN
# ...                                          ...
# Insignia Station wagon 2016.0        2187.072985
#                        2017.0        2544.392247
#                        2018.0        1737.389396
#                        2019.0        4801.730723
#          Van           2018.0                NaN
#
#                                          min  \
# model    body_type     registration
# A1       Compact       2016.0         9950.0
#                        2017.0        10999.0
#                        2018.0        13980.0
#                        2019.0        15550.0
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Station wagon 2016.0         8290.0
#                        2017.0         8990.0
#                        2018.0        17500.0
#                        2019.0        19900.0
#          Van           2018.0        20980.0
#
#                                          25%  \
# model    body_type     registration
# A1       Compact       2016.0        13400.0
#                        2017.0        15465.0
#                        2018.0        16445.0
#                        2019.0        21392.5
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Station wagon 2016.0        12485.0
#                        2017.0        15965.0
#                        2018.0        20850.0
#                        2019.0        29987.5
#          Van           2018.0        20980.0
#
#                                          50%  \
# model    body_type     registration
# A1       Compact       2016.0        13965.0
#                        2017.0        15960.0
#                        2018.0        16980.0
#                        2019.0        22885.0
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Station wagon 2016.0        13970.0
#                        2017.0        17990.0
#                        2018.0        21900.0
#                        2019.0        33899.0
#          Van           2018.0        20980.0
#
#                                           75%  \
# model    body_type     registration
# A1       Compact       2016.0        15982.50
#                        2017.0        18690.00
#                        2018.0        20986.25
#                        2019.0        27380.00
#          Other         2017.0        23490.00
# ...                                       ...
# Insignia Station wagon 2016.0        14990.00
#                        2017.0        19460.00
#                        2018.0        23490.00
#                        2019.0        36990.00
#          Van           2018.0        20980.00
#
#                                          max
# model    body_type     registration
# A1       Compact       2016.0        18900.0
#                        2017.0        22150.0
#                        2018.0        23829.0
#                        2019.0        31990.0
#          Other         2017.0        23490.0
# ...                                      ...
# Insignia Station wagon 2016.0        18400.0
#                        2017.0        21990.0
#                        2018.0        31500.0
#                        2019.0        52120.0
#          Van           2018.0        20980.0
#
# [144 rows x 8 columns]

# %%
# f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler modele göre en çok tercih renkler ile dolduruldum.

# data["body_color_original"] = data["body_color_original"].fillna(data.groupby(["model"])["body_color_original"].transform(f))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-137-da73c3cc030d> in <module>
#       1 f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler modele göre en çok tercih renkler ile dolduruldum.
#       2
# ----> 3 data["body_color_original"] = data["body_color_original"].fillna(data.groupby(["model"])["body_color_original"].transform(f))
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     505
#     506         if not isinstance(func, str):
# --> 507             return self._transform_general(func, *args, **kwargs)
#     508
#     509         elif func not in base.transform_kernel_allowlist:
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     530         for name, group in self:
#     531             object.__setattr__(group, "name", name)
# --> 532             res = func(group, *args, **kwargs)
#     533
#     534             if isinstance(res, (DataFrame, Series)):
#
# <ipython-input-137-da73c3cc030d> in <lambda>(x)
# ----> 1 f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler modele göre en çok tercih renkler ile dolduruldum.
#       2
#       3 data["body_color_original"] = data["body_color_original"].fillna(data.groupby(["model"])["body_color_original"].transform(f))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
# data.drop("body_color_original", axis=1, inplace=True)

# %% [markdown]
# ### "upholstery" sütununda 3720 eksik veri var. Ancak bazı değerlerin holstery ile ilgili değilde daha çok interior color ile ilgili olmasından dolayı bunların yerine np.nan atadım. Ve sonrasında eksikdeğer sayısı 4503 oldu. Sonrasında ise eksik değerleri  "model" göre "holstery" mode() ile doldurdum.

# %%
# data["upholstery"].value_counts(dropna=False).head(50)
# Out:
# Cloth           8423
# NaN             3720
# Part leather    1499
# Full leather    1009
# Black            491
# Other            368
# Grey             273
# Velour            60
# alcantara         57
# Brown             12
# Beige              3
# White              2
# Blue               2
# Name: upholstery, dtype: int64

# %%
data.loc[~((data["upholstery"]=="Cloth") | (data["upholstery"]=="Full leather") |(data["upholstery"]=="Part leather")|(data["upholstery"]=="Other")|(data["upholstery"]=="Velour") |(data["upholstery"]=="alcantara")), "upholstery"] = np.nan

# %%
# data["upholstery"].value_counts(dropna=False).head(50)
# Out:
# Cloth           8423
# NaN             4503
# Part leather    1499
# Full leather    1009
# Other            368
# Velour            60
# alcantara         57
# Name: upholstery, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]  

data["upholstery"]= data["upholstery"].fillna(data.groupby(["model"])["upholstery"].transform(f))

# %%
# data["upholstery"].value_counts(dropna=False).head(50)
# Out:
# Cloth           12552
# Part leather     1499
# Full leather     1383
# Other             368
# Velour             60
# alcantara          57
# Name: upholstery, dtype: int64

# %%
sns.barplot(x="upholstery", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="upholstery", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "interior_color" sütununda 7710 eksik veri var. Eksik veri oranı yüksek. Bu feature düşürdüm.

# %%
# data["interior_color"].value_counts(dropna=False).head(50)
# Out:
# Black     7710
# NaN       5870
# Grey      1103
# Other      960
# Brown      195
# Beige       51
# Blue        14
# White       11
# Yellow       4
# Orange       1
# Name: interior_color, dtype: int64

# %%
# data.drop("interior_color", axis=1, inplace=True)

# %% [markdown]
# ### "door_nr" sütununda 212 eksik veri var. "Model" göre en yüksek değer ile doldurdum. Ğrup sayısını azaltmak için 7 kapılı olanı 5, 1 kapılı olanı ise 2 ye atarak değişken sayısını düşürdüm.

# %%
# data["door_nr"].value_counts(dropna=False).head(50)
# Out:
# 5.0    11575
# 4.0     3079
# 3.0      832
# 2.0      219
# NaN      212
# 7.0        1
# 1.0        1
# Name: door_nr, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler modele göre en çok tercih edilen door_nr ile dolduruldum.

data["door_nr"]= data["door_nr"].fillna(data.groupby(["model"])["door_nr"].transform(f))  # "body_type" da ilave edilebilir.

# %%
# data["door_nr"]= data["door_nr"].fillna(data.groupby(["model"])["door_nr"].transform("mean")) yaptığımızda mode() farklı olarak 5 ve 4 te 30 artıp azalıyor.

# %%
data.loc[data["door_nr"]==7,"door_nr"] = 5

# %%
data.loc[data["door_nr"]== 1, "door_nr"] = 2

# %%
# data["door_nr"].value_counts(dropna=False).head(50)
# Out:
# 5.0    11788
# 4.0     3079
# 3.0      832
# 2.0      220
# Name: door_nr, dtype: int64

# %%
sns.barplot(x="door_nr", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="door_nr", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "seat_nr" sütununda 975 eksik veri var. "Model" bazında "seat_nr" mode() ile doldurdum. Sonrasında ise 6 koltuk olanı 5, 3 koltuk olanı ise 4 ye atarak değişken sayısını düşürdüm.

# %%
# data["seat_nr"].value_counts(dropna=False).head(50)
# Out:
# 5.0    13336
# 4.0     1125
# NaN      977
# 7.0      362
# 2.0      116
# 6.0        2
# 3.0        1
# Name: seat_nr, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerleri modele göre en çok tercih seat_nr ile dolduruldum.

data["seat_nr"]= data["seat_nr"].fillna(data.groupby(["model"])["seat_nr"].transform(f))

# %%
# data["seat_nr"].value_counts(dropna=False).head(50)
# Out:
# 5.0    14313
# 4.0     1125
# 7.0      362
# 2.0      116
# 6.0        2
# 3.0        1
# Name: seat_nr, dtype: int64

# %%
data.loc[data["seat_nr"]==3, "seat_nr"] = 4

# %%
data.loc[data["seat_nr"]==6, "seat_nr"] = 5

# %%
sns.barplot(x="seat_nr", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="seat_nr", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "model_code" sütununda 10941 eksik veri var. Drop yaptım.

# %%
# data.drop("model_code", axis=1, inplace=True)

# %% [markdown]
# ### "gear" sütununda eksik veri yok.

# %%
# data["gear"].value_counts(dropna=False).head(50)
# Out:
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gear, dtype: int64

# %%
sns.barplot(x="gear", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="gear", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "displacement" sütununda 535 eksik veri var. "model", "body_type" ve "registration" bazında"displecement" mean() baktığımızda 800-2500 arasında çıktığını gördüm. Bu aralığın dışında olan değerlerin yerine np.nan atandı. Daha sonra "Model" bazında "displacement" mode() ile doldurdum.

# %%
# data["displacement"].value_counts(dropna=False).tail(70)
# Out:
# 1,956     670
# 1,461     595
# 1,490     559
# NaN       535
# 1,422     467
# 1,197     353
# 898       351
# 1,395     320
# 1,968     301
# 1,149     288
# 1,618     212
# 1,798     210
# 1,498     196
# 1,600     130
# 1,248     110
# 1,997     103
# 1,364     102
# 1,400      90
# 998        72
# 1,500      50
# 2,000      46
# 1,000      40
# 1,998      25
# 2,480      20
# 1,200      18
# 1,984      18
# 899        11
# 1,397      11
# 160         6
# 929         5
# 1,499       5
# 997         4
# 1,596       4
# 900         4
# 139         4
# 1,396       3
# 1,199       3
# 1,599       3
# 1,589       2
# 1,300       2
# 1,495       2
# 995         2
# 1,496       1
# 122         1
# 2,967       1
# 1,239       1
# 1,568       1
# 1,533       1
# 15,898      1
# 140         1
# 1,995       1
# 1,350       1
# 1,686       1
# 1,369       1
# 1,333       1
# 1,896       1
# 973         1
# 996         1
# 16,000      1
# 1,856       1
# 890         1
# 1,584       1
# 1,368       1
# 1,390       1
# 1,696       1
# 1,580       1
# 1,100       1
# 1,195       1
# 1,800       1
# 1,198       1
# Name: displacement, dtype: int64

# %%
data["displacement"] = data["displacement"].str.replace(",","")

# %%
data["displacement"] = data["displacement"].astype("float")

# %%
# data.groupby(["model","body_type","registration"])["displacement"].mean().tail(100)
# Out:
# model     body_type      registration
# Astra     Sedans         2018.0          1300.541139
#                          2019.0          1264.448171
#           Station wagon  2016.0          1571.722045
#                          2017.0          1543.911111
#                          2018.0          1518.351438
#                          2019.0          1387.836879
# Clio      Compact        2016.0          1347.250000
#                          2017.0          1248.397590
#                          2018.0          1266.774436
#                          2019.0           954.343195
#           Coupe          2017.0          1618.000000
#           Off-Road       2016.0          1461.000000
#                          2019.0          1197.000000
#           Other          2016.0          1443.000000
#                          2017.0          1341.000000
#                          2018.0          1164.700000
#                          2019.0           937.333333
#           Sedans         2016.0          1367.538043
#                          2017.0          1364.518868
#                          2018.0          1340.555184
#                          2019.0          1013.023952
#           Station wagon  2016.0          1296.877778
#                          2017.0          1289.690722
#                          2018.0          1339.515464
#                          2019.0          1095.605263
#           Transporter    2016.0          1464.900000
#                          2017.0          1465.333333
#                          2018.0          1409.000000
#                          2019.0           981.666667
#           Van            2017.0          1461.000000
#                          2018.0          1461.000000
# Corsa     Compact        2016.0          1287.446602
#                          2017.0          1352.780645
#                          2018.0          1382.738506
#                          2019.0          1336.208748
#           Coupe          2016.0          1224.200000
#                          2017.0          1271.250000
#                          2019.0          1291.666667
#           Off-Road       2017.0          1400.000000
#           Other          2016.0          1398.000000
#                          2017.0          1373.315789
#                          2018.0          1393.163265
#                          2019.0          1369.133333
#           Sedans         2016.0          1279.934524
#                          2017.0          1290.378238
#                          2018.0          1337.378676
#                          2019.0          1332.941799
#           Transporter    2016.0          1248.000000
#                          2017.0          1300.000000
#                          2019.0          1229.000000
#           Van            2016.0          1229.000000
# Duster    Off-Road       2019.0          1695.030303
# Espace    Compact        2016.0          1608.000000
#                          2017.0          1598.000000
#                          2019.0          1798.000000
#           Coupe          2018.0                  NaN
#                          2019.0                  NaN
#           Off-Road       2016.0          1598.000000
#                          2017.0          1598.000000
#                          2018.0          1600.000000
#           Other          2016.0          1608.000000
#                          2017.0          1799.000000
#                          2018.0          1598.000000
#                          2019.0          1798.000000
#           Sedans         2016.0          1608.000000
#                          2017.0          1592.000000
#                          2018.0          1629.384615
#                          2019.0          1997.000000
#           Station wagon  2016.0          1601.265306
#                          2017.0          1621.333333
#                          2018.0          1740.857143
#                          2019.0          1897.416667
#           Transporter    2016.0          1599.714286
#                          2017.0          1598.000000
#                          2018.0          1598.000000
#                          2019.0          1997.000000
#           Van            2016.0          1601.918919
#                          2017.0          1611.125000
#                          2018.0          1657.916230
#                          2019.0          1808.472803
# Insignia  Compact        2016.0          1481.000000
#                          2017.0          1698.500000
#                          2018.0          1599.000000
#                          2019.0          1565.666667
#           Coupe          2017.0                  NaN
#           Off-Road       2016.0          1956.000000
#                          2019.0          1818.666667
#           Other          2016.0          1598.000000
#                          2017.0          1594.838710
#                          2018.0          1686.285714
#                          2019.0          1669.428571
#           Sedans         2016.0          1645.083333
#                          2017.0          1639.506383
#                          2018.0          1620.872659
#                          2019.0          1645.811159
#           Station wagon  2016.0          1770.199531
#                          2017.0          1739.357860
#                          2018.0          1642.522388
#                          2019.0          1679.834688
#           Van            2018.0          1496.000000
# Name: displacement, dtype: float64

# %%
data.loc[(data.displacement > 2500) | (data.displacement <800), "displacement"] = np.nan

# %%
f= lambda x : x.mode().iloc[0]    

data["displacement"]= data["displacement"].fillna(data.groupby("model")["displacement"].transform(f))

# %%
# data["displacement"].value_counts(dropna=False).head(50)
# Out:
# 1598.0    5101
# 999.0     2467
# 1398.0    1389
# 1399.0     749
# 1461.0     701
# 1229.0     677
# 1956.0     670
# 1490.0     559
# 1422.0     467
# 1197.0     353
# 898.0      351
# 1395.0     320
# 1968.0     301
# 1149.0     288
# 1618.0     212
# 1798.0     210
# 1498.0     196
# 1600.0     130
# 1248.0     110
# 1997.0     103
# 1364.0     102
# 1400.0      90
# 998.0       72
# 1500.0      50
# 2000.0      46
# 1000.0      40
# 1998.0      25
# 2480.0      20
# 1200.0      18
# 1984.0      18
# 899.0       11
# 1397.0      11
# 1499.0       5
# 929.0        5
# 1596.0       4
# 997.0        4
# 900.0        4
# 1396.0       3
# 1199.0       3
# 1599.0       3
# 1589.0       2
# 995.0        2
# 1300.0       2
# 1495.0       2
# 1390.0       1
# 1584.0       1
# 1568.0       1
# 1368.0       1
# 890.0        1
# 1239.0       1
# Name: displacement, dtype: int64

# %%
data["displacement"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### "cylinders" sütununda 5689 eksik veri var. "Model" ve "body_type"  göre "cylinders" mean() ile doldurdum ve sonra np.round ile yuvarladım. Daha sonra 1 ve 2 olanları 3 e, 6 ve 8 olanları ise 5 atadım.

# %%
# data["cylinders"].value_counts(dropna=False).head(50)
# Out:
# 4.0    8105
# NaN    5680
# 3.0    2104
# 5.0      22
# 6.0       3
# 8.0       2
# 2.0       2
# 1.0       1
# Name: cylinders, dtype: int64

# %%
f= lambda x : x.mean()    # Bunun ile eksik değerler modele göre en çok displacement ile doldurdum.

data["cylinders"]= data["cylinders"].fillna(data.groupby(["model","body_type"])["cylinders"].transform(f)).apply(np.round)

# %%
data["cylinders"] = data["cylinders"].fillna(method="ffill")

# %%
data.loc[data.cylinders < 3, "cylinders"] = 3
data.loc[data.cylinders > 5, "cylinders"] = 5

# %%
# data["cylinders"].value_counts(dropna=False)
# Out:
# 4.0    12925
# 3.0     2967
# 5.0       27
# Name: cylinders, dtype: int64

# %%
sns.barplot(x="cylinders", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="cylinders", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "weight" sütununda 6976 eksik veri var. "body_type" göre "weight" mode() ile doldurdum.

# %%
data["weight"]= data["weight"].str.replace(",","").astype("float")

# %%
# data["weight"].value_counts(dropna=False).tail(80)
# Out:
# 1870.0    1
# 840.0     1
# 1150.0    1
# 1343.0    1
# 1181.0    1
# 1430.0    1
# 1281.0    1
# 1791.0    1
# 2240.0    1
# 1598.0    1
# 1058.0    1
# 1761.0    1
# 1939.0    1
# 1143.0    1
# 1420.0    1
# 2295.0    1
# 1705.0    1
# 1720.0    1
# 1650.0    1
# 1030.0    1
# 1397.0    1
# 1885.0    1
# 1333.0    1
# 1507.0    1
# 1294.0    1
# 1258.0    1
# 1291.0    1
# 1277.0    1
# 1505.0    1
# 1213.0    1
# 1217.0    1
# 1648.0    1
# 1167.0    1
# 1252.0    1
# 1713.0    1
# 1206.0    1
# 1189.0    1
# 1905.0    1
# 1366.0    1
# 1724.0    1
# 1257.0    1
# 1649.0    1
# 1382.0    1
# 2044.0    1
# 1267.0    1
# 1645.0    1
# 2355.0    1
# 1492.0    1
# 1785.0    1
# 1591.0    1
# 1283.0    1
# 1169.0    1
# 1792.0    1
# 2110.0    1
# 1575.0    1
# 1254.0    1
# 1819.0    1
# 1374.0    1
# 1548.0    1
# 1565.0    1
# 1471.0    1
# 1302.0    1
# 1161.0    1
# 1379.0    1
# 1711.0    1
# 1891.0    1
# 1394.0    1
# 1017.0    1
# 1009.0    1
# 1132.0    1
# 1847.0    1
# 1797.0    1
# 1950.0    1
# 900.0     1
# 1272.0    1
# 1476.0    1
# 1589.0    1
# 1555.0    1
# 1683.0    1
# 1159.0    1
# Name: weight, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    

data["weight"]= data["weight"].fillna(data.groupby(["body_type"])["weight"].transform(f))

# %%
# data["weight"].value_counts(dropna=False)
# Out:
# 1163.0    5332
# 1487.0    1913
# 1734.0     573
# 1360.0     356
# 1165.0     301
#           ...
# 1797.0       1
# 1950.0       1
# 900.0        1
# 1272.0       1
# 1159.0       1
# Name: weight, Length: 433, dtype: int64

# %%
data["weight"].plot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=data.weight)
# Out:
# <AxesSubplot:xlabel='weight'>

# %% [markdown]
# ### "fuel" sütununda eksik veri yok. Burada tüm veriyi 4 grupta topladım.

# %%
# data["fuel"].value_counts(dropna=False).head(50)
# Out:
# benzine     8551
# Diesel      7299
# LPG/CNG       53
# Liquid        10
# Electric       5
# Domestic       1
# Name: fuel, dtype: int64

# %%
data.loc[data["fuel"]== "LPG/CNG","fuel"] = "lpg"
data.loc[data["fuel"]== "Domestic","fuel"] = "lpg"
data.loc[data["fuel"]== "Liquid","fuel"] = "lpg"

# %%
# data["fuel"].value_counts(dropna=False).head(50)
# Out:
# benzine     8551
# Diesel      7299
# lpg           64
# Electric       5
# Name: fuel, dtype: int64

# %%
sns.barplot(x="fuel", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="fuel", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "consumption_comb" sütununda 1925 eksik veri var. Bazı olağan dışından yüksek ve düşük veriler vardı. Bunları inceledikten sonra "model" ve "registration" bazında "consumption_comb" mean() bakarak 4 ve 10 arasında toplandığını gördüm. ve bunların dışında kalan değerleri np.nan ile atadım. Sonrasında ise "body_type" ve "cylinders" göre "consumption_comb" mean() ile doldurdum.

# %%
# data["consumption_comb"].value_counts(dropna=False).head(50)
# Out:
# NaN     1925
# 5.4      770
# 3.9      733
# 4.0      714
# 5.1      657
# 4.4      623
# 5.6      618
# 4.7      602
# 3.8      585
# 5.0      551
# 4.8      546
# 4.5      526
# 5.2      455
# 4.6      445
# 4.2      435
# 4.9      393
# 5.5      380
# 5.3      380
# 5.9      369
# 3.7      369
# 4.1      342
# 5.7      342
# 6.0      331
# 3.3      326
# 4.3      307
# 3.5      307
# 6.2      216
# 3.6      194
# 6.3      181
# 6.1      175
# 5.8      164
# 6.6      148
# 3.4      143
# 6.8      136
# 6.4       75
# 3.0       69
# 7.4       66
# 6.7       45
# 6.5       43
# 7.1       39
# 10.0      34
# 6.9       27
# 3.2       25
# 8.3       20
# 7.6       14
# 7.0       10
# 3.1        7
# 7.8        6
# 7.2        6
# 8.0        5
# Name: consumption_comb, dtype: int64

# %%
# data.groupby(["model","registration"])["consumption_comb"].mean()
# Out:
# model     registration
# A1        2016.0          4.222576
#           2017.0          4.283463
#           2018.0          4.241818
#           2019.0          4.994333
# A2        2018.0          4.900000
# A3        2016.0          4.213738
#           2017.0          4.245013
#           2018.0          4.438116
#           2019.0          4.730565
# Astra     2016.0          4.367798
#           2017.0          4.307098
#           2018.0          4.830202
#           2019.0          5.282581
# Clio      2016.0          4.342644
#           2017.0          4.624801
#           2018.0          5.125651
#           2019.0          5.085392
# Corsa     2016.0          5.011060
#           2017.0          5.180911
#           2018.0          5.400180
#           2019.0          5.857137
# Duster    2019.0          9.680450
# Espace    2016.0          4.884412
#           2017.0          5.488924
#           2018.0          5.488044
#           2019.0          6.048798
# Insignia  2016.0          4.929927
#           2017.0          4.975845
#           2018.0          5.537728
#           2019.0          5.740912
# Name: consumption_comb, dtype: float64

# %%
data.loc[ (data.consumption_comb>10) | (data.consumption_comb<4), "consumption_comb"] = np.nan

# %%
f= lambda x : x.mean()   

data["consumption_comb"]= data["consumption_comb"].fillna(data.groupby(["body_type","cylinders"])["consumption_comb"].transform(f))

# %%
# data["consumption_comb"].value_counts(dropna=False).tail(50)
# Out:
# 4.636667     280
# 5.461717     269
# 5.237677     223
# 6.200000     216
# 6.300000     181
# 6.100000     175
# 4.622297     170
# 5.800000     164
# 6.600000     148
# 5.541970     146
# 6.800000     136
# 4.563271      92
# 6.400000      75
# 7.400000      66
# 4.894419      57
# 6.700000      45
# 6.500000      43
# 4.491709      42
# 7.100000      39
# 5.069122      35
# 10.000000     34
# 6.900000      27
# 4.642187      21
# 8.300000      21
# 7.600000      14
# 7.000000      10
# 4.650000      10
# 4.777447       9
# 4.764114       6
# 4.780000       6
# 7.200000       6
# 5.212000       6
# 7.800000       6
# 4.712037       5
# 8.000000       5
# 8.600000       4
# 8.135294       4
# 7.900000       3
# 8.700000       3
# 8.100000       2
# 8.400777       2
# 7.300000       2
# NaN            1
# 8.136842       1
# 9.100000       1
# 7.500000       1
# 7.600000       1
# 5.491711       1
# 5.157143       1
# 4.566667       1
# Name: consumption_comb, dtype: int64

# %%
data["consumption_comb"] = data["consumption_comb"].fillna(method="ffill")  # 1 tane nan değer vardı onları doldurdum.

# %%
data["consumption_comb"] = np.round(data["consumption_comb"], 1)

# %%
data["consumption_comb"].plot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=data.consumption_comb)
# Out:
# <AxesSubplot:xlabel='consumption_comb'>

# %% [markdown]
# ### "CO2_emission" sütununda 2436 eksik veri var. Bazı olağandan yüksek ve düşük veriler vardı. Bunları inceledikten sonra "model" ve "body_type" bazında "CO2_emission" mean() bakarak 80 ve 200 arasında toplandığını gördüm. Ve bunların dışında kalan değerlere np.nan ile atadım.  Sonrasında "body_type" ve "cylinders" göre "CO2_emission" mean() ile doldurdum.

# %%
# data["CO2_emission"].value_counts(dropna=False).head(50)
# Out:
# NaN      2436
# 120.0     740
# 99.0      545
# 97.0      537
# 104.0     501
# 102.0     477
# 103.0     445
# 114.0     382
# 124.0     372
# 108.0     362
# 107.0     362
# 119.0     361
# 106.0     349
# 128.0     329
# 126.0     282
# 85.0      275
# 118.0     270
# 110.0     266
# 127.0     257
# 117.0     254
# 111.0     237
# 113.0     235
# 109.0     234
# 139.0     224
# 140.0     218
# 129.0     213
# 135.0     202
# 105.0     202
# 92.0      198
# 130.0     180
# 123.0     178
# 150.0     174
# 112.0     171
# 143.0     171
# 95.0      161
# 116.0     157
# 141.0     156
# 98.0      151
# 133.0     145
# 136.0     145
# 137.0     133
# 125.0     132
# 134.0     130
# 145.0     126
# 149.0     117
# 153.0     113
# 147.0     109
# 101.0     105
# 132.0     100
# 115.0      86
# Name: CO2_emission, dtype: int64

# %%
# data.groupby(["model","body_type"])["CO2_emission"].mean()
# Out:
# model     body_type
# A1        Compact          106.398099
#           Coupe             97.000000
#           Other            107.375000
#           Sedans           102.979669
#           Station wagon    103.800000
#           Van                     NaN
# A2        Off-Road                NaN
# A3        Compact          109.213740
#           Convertible      123.857143
#           Coupe            100.750000
#           Other            108.750000
#           Sedans           108.879008
#           Station wagon    110.722008
# Astra     Compact          107.383838
#           Coupe            144.000000
#           Off-Road         128.000000
#           Other            112.085106
#           Sedans           116.177704
#           Station wagon    115.320736
# Clio      Compact          114.941476
#           Coupe            140.000000
#           Off-Road         125.000000
#           Other            115.600000
#           Sedans           111.614489
#           Station wagon    108.245734
#           Transporter      101.200000
#           Van                     NaN
# Corsa     Compact          130.462633
#           Coupe            112.400000
#           Off-Road         119.666667
#           Other            123.693333
#           Sedans           125.763661
#           Transporter      112.166667
#           Van                     NaN
# Duster    Off-Road         171.666667
# Espace    Compact          137.666667
#           Coupe                   NaN
#           Off-Road         120.600000
#           Other            131.333333
#           Sedans           136.000000
#           Station wagon    131.903614
#           Transporter      120.940000
#           Van              135.880872
# Insignia  Compact          128.277778
#           Coupe                   NaN
#           Off-Road         154.666667
#           Other            112.315789
#           Sedans           130.679720
#           Station wagon    138.292075
#           Van                     NaN
# Name: CO2_emission, dtype: float64

# %%
# data.loc[(data.CO2_emission>200) | (data.CO2_emission<80)]

# %%
data.loc[ (data.CO2_emission>200) | (data.CO2_emission<80), "CO2_emission"] = np.nan

# %%
f= lambda x : x.mean()    # Bunun ile eksik değerler modele göre en çok displacement ile doldurdum.

data["CO2_emission"]= data["CO2_emission"].fillna(data.groupby(["body_type","cylinders"])["CO2_emission"].transform(f))

# %%
# data["CO2_emission"].value_counts(dropna=False).tail(50)

# %%
data["CO2_emission"] = data["CO2_emission"].fillna(method="ffill")  # 2 tane eksik değeri doldurdum.

# %%
data["CO2_emission"] = np.round(data["CO2_emission"], 1)

# %%
# data["CO2_emission"].value_counts(dropna=False).tail(50)
# Out:
# 172.0    25
# 96.0     22
# 89.0     19
# 189.0    19
# 157.0    18
# 158.0    17
# 169.0    15
# 88.0     15
# 156.0    14
# 164.0    13
# 161.0    10
# 170.0    10
# 175.0     8
# 166.0     8
# 155.0     8
# 159.0     7
# 188.0     7
# 174.0     6
# 87.0      6
# 197.0     4
# 12.0      4
# 194.0     3
# 36.0      3
# 5.0       3
# 199.0     2
# 84.0      2
# 162.0     2
# 0.0       2
# 1.0       2
# 191.0     2
# 14.0      2
# 167.0     2
# 160.0     1
# 183.0     1
# 331.0     1
# 180.0     1
# 253.0     1
# 190.0     1
# 181.0     1
# 80.0      1
# 177.0     1
# 165.0     1
# 193.0     1
# 239.0     1
# 13.0      1
# 171.0     1
# 184.0     1
# 51.0      1
# 990.0     1
# 45.0      1
# Name: CO2_emission, dtype: int64

# %%
# data["CO2_emission"].plot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=data.CO2_emission)
# Out:
# <AxesSubplot:xlabel='CO2_emission'>

# %% [markdown]
# ### "emission_class" sütununda 3628 eksik veri var. "body_type" göre "emission_class" mean() ile doldurdum.

# %%
# data["emission_class"].value_counts(dropna=False).head(50)
# Out:
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler body_type göre emission_class mode() ile doldurdum.

data["emission_class"] = data["emission_class"].fillna(data.groupby(["body_type"])["emission_class"].transform(f))

# %%
# data["emission_class"].value_counts(dropna=False).head(50)
# Out:
# Euro 6          13757
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             50
# Name: emission_class, dtype: int64

# %%
# data.loc[data["emission_class"].notna()].groupby(["model","body_type"])["registration"].describe()
# Out:
#                          count  \
# model    body_type
# A1       Compact         857.0
#          Coupe             1.0
#          Other             4.0
#          Sedans         1173.0
#          Station wagon    19.0
# A2       Off-Road          1.0
# A3       Compact         131.0
#          Convertible       7.0
#          Coupe             4.0
#          Other            11.0
#          Sedans         2217.0
#          Station wagon   246.0
# Astra    Compact         101.0
#          Coupe             1.0
#          Off-Road          1.0
#          Other            45.0
#          Sedans          786.0
#          Station wagon   950.0
# Clio     Compact         324.0
#          Coupe             1.0
#          Off-Road          2.0
#          Other            26.0
#          Sedans          716.0
#          Station wagon   272.0
#          Transporter      10.0
# Corsa    Compact         944.0
#          Coupe            11.0
#          Off-Road          3.0
#          Other            73.0
#          Sedans          702.0
#          Transporter       6.0
# Duster   Off-Road         32.0
# Espace   Compact           3.0
#          Off-Road          5.0
#          Other             6.0
#          Sedans           14.0
#          Station wagon    83.0
#          Transporter      46.0
#          Van             530.0
# Insignia Compact          18.0
#          Off-Road          2.0
#          Other            36.0
#          Sedans          603.0
#          Station wagon  1268.0
#
#                                mean  \
# model    body_type
# A1       Compact        2017.738623
#          Coupe          2016.000000
#          Other          2018.250000
#          Sedans         2017.449275
#          Station wagon  2017.473684
# A2       Off-Road       2018.000000
# A3       Compact        2016.732824
#          Convertible    2017.285714
#          Coupe          2016.250000
#          Other          2017.545455
#          Sedans         2017.488949
#          Station wagon  2017.678862
# Astra    Compact        2017.386139
#          Coupe          2019.000000
#          Off-Road       2018.000000
#          Other          2017.733333
#          Sedans         2017.688295
#          Station wagon  2017.403158
# Clio     Compact        2017.719136
#          Coupe          2017.000000
#          Off-Road       2017.500000
#          Other          2017.653846
#          Sedans         2017.534916
#          Station wagon  2017.205882
#          Transporter    2017.300000
# Corsa    Compact        2018.005297
#          Coupe          2016.909091
#          Off-Road       2017.000000
#          Other          2017.904110
#          Sedans         2017.531339
#          Transporter    2017.500000
# Duster   Off-Road       2019.000000
# Espace   Compact        2017.000000
#          Off-Road       2017.000000
#          Other          2017.333333
#          Sedans         2018.142857
#          Station wagon  2016.879518
#          Transporter    2016.456522
#          Van            2017.575472
# Insignia Compact        2018.222222
#          Off-Road       2017.500000
#          Other          2017.222222
#          Sedans         2017.611940
#          Station wagon  2017.485016
#
#                              std  \
# model    body_type
# A1       Compact        1.166837
#          Coupe               NaN
#          Other          0.500000
#          Sedans         1.102368
#          Station wagon  0.904828
# A2       Off-Road            NaN
# A3       Compact        0.934998
#          Convertible    0.755929
#          Coupe          0.500000
#          Other          1.213560
#          Sedans         1.101357
#          Station wagon  1.214924
# Astra    Compact        0.989649
#          Coupe               NaN
#          Off-Road            NaN
#          Other          0.809040
#          Sedans         1.014941
#          Station wagon  1.096306
# Clio     Compact        1.136832
#          Coupe               NaN
#          Off-Road       2.121320
#          Other          0.628796
#          Sedans         1.039181
#          Station wagon  0.991608
#          Transporter    1.337494
# Corsa    Compact        1.060709
#          Coupe          1.136182
#          Off-Road       0.000000
#          Other          0.729619
#          Sedans         1.047251
#          Transporter    1.643168
# Duster   Off-Road       0.000000
# Espace   Compact        1.732051
#          Off-Road       0.000000
#          Other          1.211060
#          Sedans         0.534522
#          Station wagon  1.119643
#          Transporter    0.780499
#          Van            1.191876
# Insignia Compact        1.215370
#          Off-Road       2.121320
#          Other          0.721550
#          Sedans         1.005957
#          Station wagon  1.126111
#
#                            min  \
# model    body_type
# A1       Compact        2016.0
#          Coupe          2016.0
#          Other          2018.0
#          Sedans         2016.0
#          Station wagon  2016.0
# A2       Off-Road       2018.0
# A3       Compact        2016.0
#          Convertible    2016.0
#          Coupe          2016.0
#          Other          2016.0
#          Sedans         2016.0
#          Station wagon  2016.0
# Astra    Compact        2016.0
#          Coupe          2019.0
#          Off-Road       2018.0
#          Other          2016.0
#          Sedans         2016.0
#          Station wagon  2016.0
# Clio     Compact        2016.0
#          Coupe          2017.0
#          Off-Road       2016.0
#          Other          2016.0
#          Sedans         2016.0
#          Station wagon  2016.0
#          Transporter    2016.0
# Corsa    Compact        2016.0
#          Coupe          2016.0
#          Off-Road       2017.0
#          Other          2016.0
#          Sedans         2016.0
#          Transporter    2016.0
# Duster   Off-Road       2019.0
# Espace   Compact        2016.0
#          Off-Road       2017.0
#          Other          2016.0
#          Sedans         2017.0
#          Station wagon  2016.0
#          Transporter    2016.0
#          Van            2016.0
# Insignia Compact        2016.0
#          Off-Road       2016.0
#          Other          2016.0
#          Sedans         2016.0
#          Station wagon  2016.0
#
#                             25%  \
# model    body_type
# A1       Compact        2017.00
#          Coupe          2016.00
#          Other          2018.00
#          Sedans         2016.00
#          Station wagon  2017.00
# A2       Off-Road       2018.00
# A3       Compact        2016.00
#          Convertible    2017.00
#          Coupe          2016.00
#          Other          2016.50
#          Sedans         2016.00
#          Station wagon  2017.00
# Astra    Compact        2017.00
#          Coupe          2019.00
#          Off-Road       2018.00
#          Other          2017.00
#          Sedans         2017.00
#          Station wagon  2016.00
# Clio     Compact        2017.00
#          Coupe          2017.00
#          Off-Road       2016.75
#          Other          2017.25
#          Sedans         2017.00
#          Station wagon  2016.00
#          Transporter    2016.00
# Corsa    Compact        2017.00
#          Coupe          2016.00
#          Off-Road       2017.00
#          Other          2018.00
#          Sedans         2017.00
#          Transporter    2016.00
# Duster   Off-Road       2019.00
# Espace   Compact        2016.00
#          Off-Road       2017.00
#          Other          2016.25
#          Sedans         2018.00
#          Station wagon  2016.00
#          Transporter    2016.00
#          Van            2016.00
# Insignia Compact        2017.25
#          Off-Road       2016.75
#          Other          2017.00
#          Sedans         2017.00
#          Station wagon  2016.00
#
#                            50%  \
# model    body_type
# A1       Compact        2018.0
#          Coupe          2016.0
#          Other          2018.0
#          Sedans         2018.0
#          Station wagon  2018.0
# A2       Off-Road       2018.0
# A3       Compact        2016.0
#          Convertible    2017.0
#          Coupe          2016.0
#          Other          2018.0
#          Sedans         2018.0
#          Station wagon  2018.0
# Astra    Compact        2017.0
#          Coupe          2019.0
#          Off-Road       2018.0
#          Other          2018.0
#          Sedans         2018.0
#          Station wagon  2017.0
# Clio     Compact        2018.0
#          Coupe          2017.0
#          Off-Road       2017.5
#          Other          2018.0
#          Sedans         2018.0
#          Station wagon  2017.0
#          Transporter    2017.0
# Corsa    Compact        2018.0
#          Coupe          2017.0
#          Off-Road       2017.0
#          Other          2018.0
#          Sedans         2018.0
#          Transporter    2017.5
# Duster   Off-Road       2019.0
# Espace   Compact        2016.0
#          Off-Road       2017.0
#          Other          2017.5
#          Sedans         2018.0
#          Station wagon  2016.0
#          Transporter    2016.0
#          Van            2018.0
# Insignia Compact        2019.0
#          Off-Road       2017.5
#          Other          2017.0
#          Sedans         2018.0
#          Station wagon  2018.0
#
#                             75%  \
# model    body_type
# A1       Compact        2019.00
#          Coupe          2016.00
#          Other          2018.25
#          Sedans         2018.00
#          Station wagon  2018.00
# A2       Off-Road       2018.00
# A3       Compact        2017.00
#          Convertible    2018.00
#          Coupe          2016.25
#          Other          2018.50
#          Sedans         2018.00
#          Station wagon  2019.00
# Astra    Compact        2018.00
#          Coupe          2019.00
#          Off-Road       2018.00
#          Other          2018.00
#          Sedans         2019.00
#          Station wagon  2018.00
# Clio     Compact        2019.00
#          Coupe          2017.00
#          Off-Road       2018.25
#          Other          2018.00
#          Sedans         2018.00
#          Station wagon  2018.00
#          Transporter    2018.75
# Corsa    Compact        2019.00
#          Coupe          2017.00
#          Off-Road       2017.00
#          Other          2018.00
#          Sedans         2018.00
#          Transporter    2019.00
# Duster   Off-Road       2019.00
# Espace   Compact        2017.50
#          Off-Road       2017.00
#          Other          2018.00
#          Sedans         2018.00
#          Station wagon  2018.00
#          Transporter    2017.00
#          Van            2019.00
# Insignia Compact        2019.00
#          Off-Road       2018.25
#          Other          2017.00
#          Sedans         2018.00
#          Station wagon  2018.00
#
#                            max
# model    body_type
# A1       Compact        2019.0
#          Coupe          2016.0
#          Other          2019.0
#          Sedans         2019.0
#          Station wagon  2019.0
# A2       Off-Road       2018.0
# A3       Compact        2019.0
#          Convertible    2018.0
#          Coupe          2017.0
#          Other          2019.0
#          Sedans         2019.0
#          Station wagon  2019.0
# Astra    Compact        2019.0
#          Coupe          2019.0
#          Off-Road       2018.0
#          Other          2019.0
#          Sedans         2019.0
#          Station wagon  2019.0
# Clio     Compact        2019.0
#          Coupe          2017.0
#          Off-Road       2019.0
#          Other          2018.0
#          Sedans         2019.0
#          Station wagon  2019.0
#          Transporter    2019.0
# Corsa    Compact        2019.0
#          Coupe          2019.0
#          Off-Road       2017.0
#          Other          2019.0
#          Sedans         2019.0
#          Transporter    2019.0
# Duster   Off-Road       2019.0
# Espace   Compact        2019.0
#          Off-Road       2017.0
#          Other          2019.0
#          Sedans         2019.0
#          Station wagon  2019.0
#          Transporter    2019.0
#          Van            2019.0
# Insignia Compact        2019.0
#          Off-Road       2019.0
#          Other          2019.0
#          Sedans         2019.0
#          Station wagon  2019.0

# %%
# data.loc[~data["emission_class"].notna()].groupby(["model","body_type"])["registration"].describe()

# %%
sns.barplot(x="emission_class", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="emission_class", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "gears" sütununda  4712 eksik veri var. Bazı olağandan yüksek ve düşük veriler vardı. Bunları inceledikten sonra "model","body_type","registration" bazında "gears" mean() ile bakarak 5 ve 7 arasında toplandığını gördüm. Bunların dışında kalan değerlerden 8 olanın gerçek hayatta insignia modeline ait olanının olduğunu gördüm. Bu model dışında kalan değerlere np.nan ile atadım. Sonrasında ise "body_type" göre "gears" mode() ile doldurdum.

# %%
# data["gears"].value_counts(dropna=False).head(50)
# Out:
# 6.0     5822
# NaN     4712
# 5.0     3239
# 7.0     1908
# 8.0      224
# 9.0        6
# 4.0        2
# 1.0        2
# 3.0        2
# 50.0       1
# 2.0        1
# Name: gears, dtype: int64

# %%
# data.loc[(data["gears"]>7) | (data["gears"]<5)]
# Out:
#           make  \
# 215       Audi
# 1033      Audi
# 8921      Opel
# 9812      Opel
# 10151     Opel
# ...        ...
# 15824  Renault
# 15827  Renault
# 15845  Renault
# 15869  Renault
# 15876  Renault
#
#         model  \
# 215        A1
# 1033       A1
# 8921    Corsa
# 9812    Corsa
# 10151   Corsa
# ...       ...
# 15824  Espace
# 15827  Espace
# 15845  Espace
# 15869  Espace
# 15876  Espace
#
#       body_type  \
# 215     Compact
# 1033     Sedans
# 8921    Compact
# 9812     Sedans
# 10151   Compact
# ...         ...
# 15824       Van
# 15827       Van
# 15845       Van
# 15869       Van
# 15876       Van
#
#         cc  \
# 215    1.0
# 1033   1.0
# 8921   1.4
# 9812   1.2
# 10151  1.4
# ...    ...
# 15824  1.8
# 15827  1.8
# 15845  2.0
# 15869  2.0
# 15876  1.8
#
#        price  \
# 215    16880
# 1033   20500
# 8921   11000
# 9812    9880
# 10151  14770
# ...      ...
# 15824  52711
# 15827  52711
# 15845  46660
# 15869  49100
# 15876  48765
#
#                   vat  \
# 215    VAT deductible
# 1033   VAT deductible
# 8921   VAT deductible
# 9812   VAT deductible
# 10151  VAT deductible
# ...               ...
# 15824  VAT deductible
# 15827  VAT deductible
# 15845  VAT deductible
# 15869  VAT deductible
# 15876  VAT deductible
#
#             km  \
# 215     6680.0
# 1033    3000.0
# 8921   24000.0
# 9812   19247.0
# 10151      5.0
# ...        ...
# 15824     11.0
# 15827     11.0
# 15845     11.0
# 15869     11.0
# 15876     11.0
#
#        registration  \
# 215          2017.0
# 1033         2018.0
# 8921         2018.0
# 9812         2018.0
# 10151        2019.0
# ...             ...
# 15824        2019.0
# 15827        2019.0
# 15845        2019.0
# 15869        2019.0
# 15876        2019.0
#
#        prev_owner  \
# 215           1.0
# 1033          1.0
# 8921          1.0
# 9812          1.0
# 10151         0.0
# ...           ...
# 15824         0.0
# 15827         0.0
# 15845         0.0
# 15869         0.0
# 15876         0.0
#
#        power_hp  \
# 215        70.0
# 1033       60.0
# 8921       66.0
# 9812       51.0
# 10151      66.0
# ...         ...
# 15824     165.0
# 15827     165.0
# 15845     118.0
# 15869     146.0
# 15876     165.0
#
#       vehicle_condition  \
# 215                Used
# 1033     Employee's car
# 8921               Used
# 9812               Used
# 10151               New
# ...                 ...
# 15824               New
# 15827               New
# 15845               New
# 15869               New
# 15876               New
#
#        previous_owners  \
# 215                1.0
# 1033               1.0
# 8921               1.0
# 9812               NaN
# 10151              NaN
# ...                ...
# 15824              NaN
# 15827              NaN
# 15845              NaN
# 15869              NaN
# 15876              NaN
#
#       Inspection_new  \
# 215              Yes
# 1033              No
# 8921              No
# 9812              No
# 10151             No
# ...              ...
# 15824             No
# 15827             No
# 15845             No
# 15869             No
# 15876             No
#
#       body_color  \
# 215         Blue
# 1033        Grey
# 8921        Blue
# 9812        Grey
# 10151       Grey
# ...          ...
# 15824       Grey
# 15827       Grey
# 15845      White
# 15869      White
# 15876      White
#
#       paintwork  \
# 215    Metallic
# 1033   Metallic
# 8921   Metallic
# 9812   Metallic
# 10151  Metallic
# ...         ...
# 15824  Metallic
# 15827  Metallic
# 15845  Metallic
# 15869  Metallic
# 15876  Metallic
#
#          upholstery  \
# 215           Cloth
# 1033          Cloth
# 8921          Cloth
# 9812          Cloth
# 10151         Cloth
# ...             ...
# 15824  Part leather
# 15827  Part leather
# 15845  Part leather
# 15869  Part leather
# 15876  Part leather
#
#        door_nr  \
# 215        5.0
# 1033       5.0
# 8921       5.0
# 9812       5.0
# 10151      4.0
# ...        ...
# 15824      5.0
# 15827      5.0
# 15845      5.0
# 15869      5.0
# 15876      5.0
#
#        seat_nr  \
# 215        4.0
# 1033       5.0
# 8921       5.0
# 9812       5.0
# 10151      5.0
# ...        ...
# 15824      5.0
# 15827      5.0
# 15845      5.0
# 15869      5.0
# 15876      5.0
#
#                  gear  \
# 215         Automatic
# 1033        Automatic
# 8921   Semi-automatic
# 9812           Manual
# 10151       Automatic
# ...               ...
# 15824       Automatic
# 15827       Automatic
# 15845       Automatic
# 15869       Automatic
# 15876       Automatic
#
#        displacement  \
# 215           999.0
# 1033          999.0
# 8921         1398.0
# 9812         1229.0
# 10151        1398.0
# ...             ...
# 15824        1798.0
# 15827        1798.0
# 15845        1997.0
# 15869        1997.0
# 15876        1798.0
#
#        cylinders  \
# 215          3.0
# 1033         4.0
# 8921         4.0
# 9812         4.0
# 10151        4.0
# ...          ...
# 15824        4.0
# 15827        4.0
# 15845        4.0
# 15869        4.0
# 15876        4.0
#
#        weight  \
# 215    1163.0
# 1033   1650.0
# 8921   1163.0
# 9812   1163.0
# 10151  1163.0
# ...       ...
# 15824  1608.0
# 15827  1608.0
# 15845  1733.0
# 15869  1740.0
# 15876  1608.0
#
#           fuel  \
# 215    benzine
# 1033   benzine
# 8921   benzine
# 9812   benzine
# 10151  benzine
# ...        ...
# 15824  benzine
# 15827  benzine
# 15845   Diesel
# 15869   Diesel
# 15876  benzine
#
#        consumption_comb  \
# 215             4.40000
# 1033            4.90000
# 8921            4.80000
# 9812            5.04536
# 10151           5.90000
# ...                 ...
# 15824           7.40000
# 15827           7.40000
# 15845           5.10000
# 15869           5.30000
# 15876           7.40000
#
#        consumption_city  \
# 215                 5.2
# 1033                5.6
# 8921                5.8
# 9812                NaN
# 10151               7.5
# ...                 ...
# 15824               9.2
# 15827               9.2
# 15845               5.7
# 15869               6.2
# 15876               9.2
#
#        consumption_country  \
# 215                    3.9
# 1033                   4.5
# 8921                   4.1
# 9812                   NaN
# 10151                  5.1
# ...                    ...
# 15824                  6.3
# 15827                  6.3
# 15845                  4.8
# 15869                  4.7
# 15876                  6.3
#
#        CO2_emission  \
# 215       104.00000
# 1033      129.00000
# 8921      112.00000
# 9812      115.26864
# 10151     136.00000
# ...             ...
# 15824     135.87563
# 15827     135.87563
# 15845     135.87563
# 15869     135.87563
# 15876     135.87563
#
#       emission_class  \
# 215           Euro 6
# 1033          Euro 6
# 8921         Euro 6d
# 9812          Euro 6
# 10151   Euro 6d-TEMP
# ...              ...
# 15824         Euro 6
# 15827         Euro 6
# 15845         Euro 6
# 15869         Euro 6
# 15876         Euro 6
#
#                                      comfort_convenience  \
# 215    Air conditioning,Armrest,Automatic climate con...
# 1033   Air conditioning,Armrest,Automatic climate con...
# 8921   Air conditioning,Light sensor,Multi-function s...
# 9812   Air conditioning,Light sensor,Navigation syste...
# 10151  Air conditioning,Cruise control,Electrically h...
# ...                                                  ...
# 15824  Air conditioning,Armrest,Automatic climate con...
# 15827  Air conditioning,Armrest,Automatic climate con...
# 15845  Air conditioning,Armrest,Automatic climate con...
# 15869  Air conditioning,Armrest,Automatic climate con...
# 15876  Air conditioning,Armrest,Automatic climate con...
#
#                                            entertainment  \
# 215    Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1033   Bluetooth,CD player,Digital radio,Hands-free e...
# 8921               Bluetooth,On-board computer,Radio,USB
# 9812                         Bluetooth,On-board computer
# 10151  Bluetooth,Hands-free equipment,On-board comput...
# ...                                                  ...
# 15824                                Digital radio,Radio
# 15827                                Digital radio,Radio
# 15845                                Digital radio,Radio
# 15869                                Digital radio,Radio
# 15876                                Digital radio,Radio
#
#                                                   Extras  \
# 215       Alloy wheels,Catalytic Converter,Voice Control
# 1033   Alloy wheels,Catalytic Converter,Voice Control...
# 8921                           Alloy wheels,Touch screen
# 9812                                        Alloy wheels
# 10151                          Alloy wheels,Touch screen
# ...                                                  ...
# 15824                         Alloy wheels,Voice Control
# 15827                         Alloy wheels,Voice Control
# 15845                         Alloy wheels,Voice Control
# 15869                         Alloy wheels,Voice Control
# 15876                         Alloy wheels,Voice Control
#
#                                          safety_security  \
# 215    ABS,Central door lock,Daytime running lights,D...
# 1033   ABS,Adaptive Cruise Control,Alarm system,Centr...
# 8921   ABS,Central door lock,Central door lock with r...
# 9812   ABS,Central door lock,Driver-side airbag,Fog l...
# 10151  ABS,Central door lock,Daytime running lights,D...
# ...                                                  ...
# 15824  ABS,Daytime running lights,Driver-side airbag,...
# 15827  ABS,Daytime running lights,Driver-side airbag,...
# 15845  ABS,Daytime running lights,Driver-side airbag,...
# 15869  ABS,Daytime running lights,Driver-side airbag,...
# 15876  ABS,Daytime running lights,Driver-side airbag,...
#
#        gears
# 215      8.0
# 1033     8.0
# 8921     1.0
# 9812     2.0
# 10151    8.0
# ...      ...
# 15824    9.0
# 15827    9.0
# 15845    3.0
# 15869    9.0
# 15876    9.0
#
# [238 rows x 33 columns]

# %%
# data.groupby(["model","body_type","registration"])["gears"].mean().tail(50)
# Out:
# model     body_type      registration
# Corsa     Van            2016.0               NaN
# Duster    Off-Road       2019.0          6.000000
# Espace    Compact        2016.0          7.000000
#                          2017.0               NaN
#                          2019.0          6.000000
#           Coupe          2018.0               NaN
#                          2019.0               NaN
#           Off-Road       2016.0               NaN
#                          2017.0          6.000000
#                          2018.0          5.000000
#           Other          2016.0          6.500000
#                          2017.0          6.000000
#                          2018.0          6.000000
#                          2019.0               NaN
#           Sedans         2016.0          7.000000
#                          2017.0               NaN
#                          2018.0          6.400000
#                          2019.0               NaN
#           Station wagon  2016.0          6.104167
#                          2017.0          6.454545
#                          2018.0          6.692308
#                          2019.0          6.300000
#           Transporter    2016.0          6.085714
#                          2017.0          6.000000
#                          2018.0          6.000000
#                          2019.0          6.000000
#           Van            2016.0          6.082707
#                          2017.0          6.122807
#                          2018.0          6.218487
#                          2019.0          6.418182
# Insignia  Compact        2016.0          6.000000
#                          2017.0          6.000000
#                          2018.0          6.000000
#                          2019.0          6.117647
#           Coupe          2017.0               NaN
#           Off-Road       2016.0               NaN
#                          2019.0          6.666667
#           Other          2016.0          6.000000
#                          2017.0          6.000000
#                          2018.0          6.400000
#                          2019.0          6.000000
#           Sedans         2016.0          6.010000
#                          2017.0          5.988889
#                          2018.0          6.118812
#                          2019.0          6.329004
#           Station wagon  2016.0          6.007042
#                          2017.0          6.342391
#                          2018.0          6.328767
#                          2019.0          6.473389
#           Van            2018.0          6.000000
# Name: gears, dtype: float64

# %%
data.loc[((data["gears"]==8) & (data["model"]!="Insignia")) | (data["gears"]< 5) | (data["gears"]>8), "gears"] = np.nan

# %%
f= lambda x : x.mode().iloc[0]    # Bunun ile eksik değerler body_type göre emission_class mode() ile doldurdum.

data["gears"] = data["gears"].fillna(data.groupby(["body_type"])["gears"].transform(f))

# %%
# data["gears"].value_counts(dropna=False).head(50)
# Out:
# 6.0    9514
# 5.0    4494
# 7.0    1908
# 8.0       3
# Name: gears, dtype: int64

# %%
sns.barplot(x="gears", y="price", data=data, saturation=0.5)
plt.xticks(rotation = 45);

# %%
sns.boxplot(x="gears", y="price", data=data)
plt.xticks(rotation = 45);

# %% [markdown]
# ### "comfort_convenience" sütununda 920 eksik veri var. body_type göre mode() ile doldurdum.

# %%
# data["comfort_convenience"].value_counts(dropna=False).head(50)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                             216
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                         134
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                                 130
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                             105
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                     92
# Air conditioning,Automatic climate control,Cruise control,Multi-function steering wheel,Park Distance Control,Power windows                                                                                                                                                                                                                                                                                                                                                                     89
# Air conditioning,Power windows,Seat ventilation,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                                82
# Air conditioning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                79
# Air conditioning,Seat ventilation,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                                              79
# Air conditioning,Electrical side mirrors,Hill Holder,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                                78
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                          77
# Air conditioning,Cruise control,Electrically heated windshield,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating                                                                                                                                     72
# Air conditioning,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Seat heating                                                                                                                                                                                                                                                              64
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Electric tailgate,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system     58
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                           57
# Air conditioning,Cruise control,Electrical side mirrors,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                             53
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                 53
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                                                  51
# Cruise control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  49
# Air conditioning,Cruise control,Hill Holder,Multi-function steering wheel,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                                                       48
# Cruise control,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                            48
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                               48
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                 45
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                    45
# Air conditioning,Electrical side mirrors,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                                            44
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                  44
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Keyless central door lock,Navigation system,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                 44
# Air conditioning,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                    42
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                                   41
# Air conditioning,Automatic climate control,Power windows,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                       40
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Start-stop system                                                                                                                                                                                                                                                                                         39
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Start-stop system                                                                                                                                                                                                         39
# Air conditioning,Automatic climate control                                                                                                                                                                                                                                                                                                                                                                                                                                                      39
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Electric tailgate,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                   38
# Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Hill Holder,Leather steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Start-stop system                                                                                                                                                                                                                                                     38
# Air conditioning,Automatic climate control,Cruise control                                                                                                                                                                                                                                                                                                                                                                                                                                       37
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                             36
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Start-stop system                                                                                                                                                                          36
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                       35
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                                   34
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                          33
# Air conditioning,Armrest,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                         31
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                         31
# Air conditioning,Cruise control,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                   31
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                         30
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                                                                            28
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                       28
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                  28
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Keyless central door lock,Leather steering wheel,Multi-function steering wheel,Navigation system,Power windows                                                                                                                                                                                                                                                                                                              28
# Name: comfort_convenience, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    

data["comfort_convenience"] = data["comfort_convenience"].fillna(data.groupby(["body_type"])["comfort_convenience"].transform(f))

# %%
# data["comfort_convenience"].value_counts(dropna=False).head(50)
# Out:
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                             468
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                                 436
# Air conditioning,Cruise control,Hill Holder,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                                                                                    180
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Electric tailgate,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system    178
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                         134
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                             105
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                     92
# Air conditioning,Automatic climate control,Cruise control,Multi-function steering wheel,Park Distance Control,Power windows                                                                                                                                                                                                                                                                                                                                                                     89
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Panorama roof,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                             88
# Air conditioning,Power windows,Seat ventilation,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                                82
# Air conditioning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                79
# Air conditioning,Seat ventilation,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                                              79
# Air conditioning,Electrical side mirrors,Hill Holder,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                                78
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                          77
# Air conditioning,Cruise control,Electrically heated windshield,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating                                                                                                                                     72
# Air conditioning,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Seat heating                                                                                                                                                                                                                                                              64
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                           57
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                 53
# Air conditioning,Cruise control,Electrical side mirrors,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                             53
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                                                  51
# Cruise control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  49
# Cruise control,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                            48
# Air conditioning,Cruise control,Hill Holder,Multi-function steering wheel,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                                                       48
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                               48
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                    45
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                 45
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                  44
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Keyless central door lock,Navigation system,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                 44
# Air conditioning,Automatic climate control                                                                                                                                                                                                                                                                                                                                                                                                                                                      44
# Air conditioning,Electrical side mirrors,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                                            44
# Air conditioning,Multi-function steering wheel,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                    42
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                                   41
# Air conditioning,Automatic climate control,Power windows,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                       40
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Start-stop system                                                                                                                                                                                                                                                                                         39
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Start-stop system                                                                                                                                                                                                         39
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Electric tailgate,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                   38
# Air conditioning,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Hill Holder,Leather steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Start-stop system                                                                                                                                                                                                                                                     38
# Air conditioning,Automatic climate control,Cruise control                                                                                                                                                                                                                                                                                                                                                                                                                                       37
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Start-stop system                                                                                                                                                                          36
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                             36
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                       35
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                                   34
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                          33
# Air conditioning,Armrest,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                         31
# Air conditioning,Cruise control,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                   31
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                                         31
# Air conditioning,Armrest,Automatic climate control,Electrical side mirrors,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                                                         30
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Keyless central door lock,Leather steering wheel,Multi-function steering wheel,Navigation system,Power windows                                                                                                                                                                                                                                                                                                              28
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                       28
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                                                                            28
# Name: comfort_convenience, dtype: int64

# %%
comfort = data["comfort_convenience"].str.get_dummies(sep=",")

data = data.join(comfort)  # bunu en son çalıştıralım.

# %%
data.drop("comfort_convenience", axis=1, inplace=True)

# %% [markdown]
# ### "entertainment" sütununda 1374 eksik veri var. body_type göre mode() ile doldurdum.

# %%
# data["entertainment"].value_counts(dropna=False).head(50)
# Out:
# NaN                                                                                                    1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                             1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                          982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                                783
# On-board computer,Radio                                                                                 487
# Radio                                                                                                   477
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,USB                                    465
# On-board computer                                                                                       461
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio                                    404
# Bluetooth,On-board computer,Radio                                                                       397
# Bluetooth,Hands-free equipment,On-board computer,Radio                                                  378
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB                   327
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio                                              295
# Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,USB                                285
# Bluetooth,Radio                                                                                         271
# Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB                            252
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio                                        240
# Bluetooth,On-board computer                                                                             232
# Bluetooth,Hands-free equipment,On-board computer,Radio,Sound system,USB                                 188
# Bluetooth,On-board computer,Radio,USB                                                                   180
# Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB     175
# Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB                  157
# Bluetooth,MP3,On-board computer,Radio,USB                                                               154
# Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,USB                   134
# Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB               130
# Bluetooth,Hands-free equipment,On-board computer                                                        130
# Bluetooth                                                                                               125
# Bluetooth,Hands-free equipment,MP3,On-board computer,USB                                                124
# Bluetooth,Hands-free equipment                                                                          121
# Bluetooth,CD player,MP3,On-board computer,Radio                                                         120
# Bluetooth,Hands-free equipment,On-board computer,USB                                                    115
# Bluetooth,Hands-free equipment,MP3,Radio,USB                                                            115
# CD player,On-board computer,Radio                                                                       113
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB                             110
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,Sound system,USB                       108
# Bluetooth,CD player,On-board computer,Radio,USB                                                         104
# Bluetooth,CD player,MP3,On-board computer,Radio,USB                                                     102
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system                        93
# Bluetooth,Hands-free equipment,Radio,USB                                                                 93
# Bluetooth,Digital radio,On-board computer,Radio,USB                                                      87
# Bluetooth,USB                                                                                            83
# Bluetooth,Hands-free equipment,Radio                                                                     83
# Hands-free equipment,On-board computer,Radio,USB                                                         81
# Bluetooth,Hands-free equipment,MP3,On-board computer                                                     79
# Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio                                 78
# Bluetooth,Radio,USB                                                                                      74
# CD player,MP3,On-board computer,Radio                                                                    73
# Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,USB          70
# Bluetooth,CD player,Radio,USB                                                                            65
# Bluetooth,CD player,On-board computer,Radio                                                              63
# Name: entertainment, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    

data["entertainment"] = data["entertainment"].fillna(data.groupby(["body_type"])["entertainment"].transform(f))

# %%
# data["entertainment"].value_counts(dropna=False).head(50)
# Out:
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                             1995
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                         1308
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                                783
# Bluetooth,Hands-free equipment,On-board computer,Radio                                                  513
# On-board computer,Radio                                                                                 487
# Radio                                                                                                   477
# On-board computer                                                                                       466
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,USB                                    465
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio                                    404
# Bluetooth,On-board computer,Radio                                                                       397
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB                   327
# Bluetooth,Hands-free equipment,On-board computer                                                        309
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio                                              295
# Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,USB                                285
# Bluetooth,Radio                                                                                         271
# Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB                            252
# Bluetooth,On-board computer                                                                             243
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio                                        240
# Bluetooth,Hands-free equipment,On-board computer,Radio,Sound system,USB                                 188
# Bluetooth,On-board computer,Radio,USB                                                                   180
# Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB     175
# Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB                  157
# Bluetooth,MP3,On-board computer,Radio,USB                                                               154
# Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,USB                   134
# Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB               130
# Bluetooth                                                                                               125
# Bluetooth,Hands-free equipment,MP3,On-board computer,USB                                                124
# Bluetooth,Hands-free equipment                                                                          121
# Bluetooth,CD player,MP3,On-board computer,Radio                                                         120
# Bluetooth,Hands-free equipment,On-board computer,USB                                                    115
# Bluetooth,Hands-free equipment,MP3,Radio,USB                                                            115
# CD player,On-board computer,Radio                                                                       113
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB                             110
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,Sound system,USB                       108
# Bluetooth,CD player,On-board computer,Radio,USB                                                         104
# Bluetooth,CD player,MP3,On-board computer,Radio,USB                                                     102
# Bluetooth,Hands-free equipment,Radio,USB                                                                 93
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system                        93
# Bluetooth,Digital radio,On-board computer,Radio,USB                                                      87
# Bluetooth,USB                                                                                            83
# Bluetooth,Hands-free equipment,Radio                                                                     83
# Hands-free equipment,On-board computer,Radio,USB                                                         81
# Bluetooth,Hands-free equipment,MP3,On-board computer                                                     79
# Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio                                 78
# Bluetooth,Radio,USB                                                                                      74
# CD player,MP3,On-board computer,Radio                                                                    73
# Bluetooth,CD player,Radio,USB                                                                            70
# Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,USB          70
# Bluetooth,CD player,On-board computer,Radio                                                              63
# On-board computer,Radio,USB                                                                              59
# Name: entertainment, dtype: int64

# %%
entertainment = data["entertainment"].str.get_dummies(sep=",")

data = data.join(entertainment)  # bunu en son çalıştıralım.

# %%
data.drop("entertainment", axis=1, inplace=True)

# %% [markdown]
# ### "Extras" sütununda 2962 eksik veri var. body_type göre mode() ile doldurdum.

# %%
# data["Extras"].value_counts(dropna=False).head(50)
# Out:
# Alloy wheels                                                                                        3245
# NaN                                                                                                 2962
# Alloy wheels,Touch screen                                                                            697
# Alloy wheels,Voice Control                                                                           577
# Alloy wheels,Touch screen,Voice Control                                                              541
# Alloy wheels,Roof rack                                                                               385
# Alloy wheels,Sport seats                                                                             380
# Roof rack                                                                                            337
# Alloy wheels,Catalytic Converter                                                                     271
# Alloy wheels,Sport seats,Sport suspension                                                            234
# Alloy wheels,Catalytic Converter,Touch screen                                                        228
# Alloy wheels,Sport seats,Voice Control                                                               226
# Catalytic Converter                                                                                  224
# Alloy wheels,Catalytic Converter,Voice Control                                                       203
# Alloy wheels,Roof rack,Touch screen,Voice Control                                                    192
# Alloy wheels,Sport suspension                                                                        177
# Touch screen                                                                                         169
# Alloy wheels,Roof rack,Touch screen                                                                  164
# Alloy wheels,Catalytic Converter,Touch screen,Voice Control                                          132
# Alloy wheels,Sport package                                                                           113
# Alloy wheels,Trailer hitch                                                                           112
# Alloy wheels,Sport suspension,Voice Control                                                          110
# Touch screen,Voice Control                                                                           104
# Alloy wheels,Sport seats,Touch screen                                                                 98
# Alloy wheels,Sport package,Sport seats,Sport suspension                                               94
# Alloy wheels,Roof rack,Sport seats                                                                    93
# Alloy wheels,Sport seats,Touch screen,Voice Control                                                   91
# Alloy wheels,Roof rack,Sport seats,Touch screen,Voice Control                                         87
# Voice Control                                                                                         85
# Alloy wheels,Sport package,Sport seats                                                                81
# Alloy wheels,Sport package,Sport seats,Sport suspension,Voice Control                                 68
# Alloy wheels,Catalytic Converter,Sport seats,Voice Control                                            67
# Alloy wheels,Cab or rented Car,Sport seats,Voice Control                                              62
# Alloy wheels,Roof rack,Voice Control                                                                  60
# Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Voice Control                                 57
# Alloy wheels,Sport seats,Sport suspension,Voice Control                                               57
# Catalytic Converter,Touch screen                                                                      55
# Alloy wheels,Catalytic Converter,Roof rack,Touch screen                                               53
# Roof rack,Touch screen                                                                                52
# Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen,Voice Control                                 50
# Roof rack,Touch screen,Voice Control                                                                  49
# Alloy wheels,Roof rack,Trailer hitch                                                                  47
# Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control      46
# Alloy wheels,Shift paddles                                                                            45
# Alloy wheels,Roof rack,Sport seats,Touch screen                                                       38
# Alloy wheels,Sport package,Sport seats,Voice Control                                                  38
# Cab or rented Car                                                                                     37
# Catalytic Converter,Touch screen,Voice Control                                                        34
# Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Voice Control                           34
# Roof rack,Voice Control                                                                               33
# Name: Extras, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    

data["Extras"] = data["Extras"].fillna(data.groupby(["body_type"])["Extras"].transform(f))

# %%
data["Extras"].value_counts(dropna=False).head(50)
# Out:
# Alloy wheels                                                                                        5903
# Alloy wheels,Touch screen                                                                            697
# Roof rack                                                                                            641
# Alloy wheels,Voice Control                                                                           577
# Alloy wheels,Touch screen,Voice Control                                                              541
# Alloy wheels,Roof rack                                                                               385
# Alloy wheels,Sport seats                                                                             380
# Alloy wheels,Catalytic Converter                                                                     271
# Alloy wheels,Sport seats,Sport suspension                                                            234
# Alloy wheels,Catalytic Converter,Touch screen                                                        228
# Alloy wheels,Sport seats,Voice Control                                                               226
# Catalytic Converter                                                                                  224
# Alloy wheels,Catalytic Converter,Voice Control                                                       203
# Alloy wheels,Roof rack,Touch screen,Voice Control                                                    192
# Alloy wheels,Sport suspension                                                                        177
# Touch screen                                                                                         169
# Alloy wheels,Roof rack,Touch screen                                                                  164
# Alloy wheels,Catalytic Converter,Touch screen,Voice Control                                          132
# Alloy wheels,Sport package                                                                           113
# Alloy wheels,Trailer hitch                                                                           112
# Alloy wheels,Sport suspension,Voice Control                                                          110
# Touch screen,Voice Control                                                                           104
# Alloy wheels,Sport seats,Touch screen                                                                 98
# Alloy wheels,Sport package,Sport seats,Sport suspension                                               94
# Alloy wheels,Roof rack,Sport seats                                                                    93
# Alloy wheels,Sport seats,Touch screen,Voice Control                                                   91
# Alloy wheels,Roof rack,Sport seats,Touch screen,Voice Control                                         87
# Voice Control                                                                                         85
# Alloy wheels,Sport package,Sport seats                                                                81
# Alloy wheels,Sport package,Sport seats,Sport suspension,Voice Control                                 68
# Alloy wheels,Catalytic Converter,Sport seats,Voice Control                                            67
# Alloy wheels,Cab or rented Car,Sport seats,Voice Control                                              62
# Alloy wheels,Roof rack,Voice Control                                                                  60
# Alloy wheels,Sport seats,Sport suspension,Voice Control                                               57
# Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Voice Control                                 57
# Catalytic Converter,Touch screen                                                                      55
# Alloy wheels,Catalytic Converter,Roof rack,Touch screen                                               53
# Roof rack,Touch screen                                                                                52
# Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen,Voice Control                                 50
# Roof rack,Touch screen,Voice Control                                                                  49
# Alloy wheels,Roof rack,Trailer hitch                                                                  47
# Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control      46
# Alloy wheels,Shift paddles                                                                            45
# Alloy wheels,Sport package,Sport seats,Voice Control                                                  38
# Alloy wheels,Roof rack,Sport seats,Touch screen                                                       38
# Cab or rented Car                                                                                     37
# Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Voice Control                           34
# Catalytic Converter,Touch screen,Voice Control                                                        34
# Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Voice Control             33
# Roof rack,Voice Control                                                                               33
# Name: Extras, dtype: int64

# %%
ekstra = data["Extras"].str.get_dummies(sep=",")

data = data.join(ekstra)  # bunu en son çalıştıralım.

# %%
data.drop("Extras", axis=1, inplace=True)

# %% [markdown]
# ### "safety_security" sütununda 982 eksik veri var. body_type göre mode() ile doldurdum.

# %%
# data["safety_security"].value_counts(dropna=False).head(50)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                       982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                              538
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                                         480
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                                                        275
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                   272
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                              228
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                                             220
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                                                     174
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                                          123
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                           114
# ABS,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Xenon headlights                                                                                                                                                                                                                                                                                                                 106
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                               84
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                   83
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                             82
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                                                                                            80
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control,Xenon headlights                                                                                                                                                                                                              79
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                       78
# ABS,Adaptive Cruise Control,Alarm system,Central door lock,Driver-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                                                                  76
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency system,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                   76
# ABS,Central door lock,Driver-side airbag,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control,Xenon headlights                                                                                                                                                                                                                                                                                         72
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                          71
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Immobilizer,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                                        66
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                                   65
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                     61
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                59
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                     58
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                54
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                           54
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                            52
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                                 52
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                      51
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Passenger-side airbag,Power steering,Side airbag                                                                                                                                                                                                                                                       49
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition                                                                                   49
# ABS,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Head airbag,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                          48
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                           45
# ABS,Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                              44
# ABS,Adaptive Cruise Control,Adaptive headlights,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition     43
# ABS,Adaptive headlights,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Emergency system,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                        43
# ABS,Adaptive headlights,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition                             41
# ABS,Central door lock,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Head airbag,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                             40
# ABS,Adaptive Cruise Control,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition                                    39
# ABS,Adaptive headlights,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                         39
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                                              38
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                             37
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                      36
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Xenon headlights                                                                                                                                                                                                          36
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Immobilizer,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                                         35
# ABS,Central door lock,Daytime running lights,Electronic stability control,Fog lights,Power steering,Side airbag                                                                                                                                                                                                                                                                                                            34
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Side airbag,Traction control                                                                                                                                                                                                                                              34
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Emergency system,Immobilizer,Isofix,Lane departure warning system,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                 33
# Name: safety_security, dtype: int64

# %%
f= lambda x : x.mode().iloc[0]    

data["safety_security"] = data["safety_security"].fillna(data.groupby(["body_type"])["safety_security"].transform(f))

# %%
# data["safety_security"].value_counts(dropna=False).head(50)
# Out:
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                              815
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                                         609
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                                                        600
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                   272
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                              228
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                                             220
# ABS,Adaptive headlights,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                           187
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                                                     174
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                                          123
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                           114
# ABS,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Xenon headlights                                                                                                                                                                                                                                                                                                                 106
# ABS,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Tire pressure monitoring system,Traction control,Traffic sign recognition                                                                                                      97
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                               84
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                   83
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                             82
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                                                                                            80
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control,Xenon headlights                                                                                                                                                                                                              79
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                       78
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency system,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                   76
# ABS,Adaptive Cruise Control,Alarm system,Central door lock,Driver-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                                                                  76
# ABS,Central door lock,Driver-side airbag,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control,Xenon headlights                                                                                                                                                                                                                                                                                         72
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                          71
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Immobilizer,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                                        66
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                                   65
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                     61
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                59
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                     58
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                54
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                           54
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                            52
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                                 52
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                      51
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition                                                                                   49
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Passenger-side airbag,Power steering,Side airbag                                                                                                                                                                                                                                                       49
# ABS,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Head airbag,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                          48
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                                           45
# ABS,Central door lock,Central door lock with remote control,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                              44
# ABS,Adaptive headlights,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Emergency system,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                        43
# ABS,Adaptive Cruise Control,Adaptive headlights,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition     43
# ABS,Adaptive headlights,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition                             41
# ABS,Central door lock,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Head airbag,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                             40
# ABS,Adaptive Cruise Control,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition                                    39
# ABS,Adaptive headlights,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                         39
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                                              38
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Side airbag,Traction control                                                                                                                                                                                                                                              37
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                             37
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Traction control                                                                                                                                                                                                                                                      36
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Xenon headlights                                                                                                                                                                                                          36
# ABS,Central door lock,Driver-side airbag,Electronic stability control,Immobilizer,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system                                                                                                                                                                                                                                                         35
# ABS,Central door lock,Daytime running lights,Electronic stability control,Fog lights,Power steering,Side airbag                                                                                                                                                                                                                                                                                                            34
# Name: safety_security, dtype: int64

# %%
safety = data["safety_security"].str.get_dummies(sep=",")

data = data.join(safety)  # bunu en son çalıştıralım.

# %%
data.drop("safety_security", axis=1, inplace=True)

# %% [markdown]
# ### "cc" sütunu "displacement" ile duplicated olduğundan dolayı düşüldü.

# %%
data.drop("cc", axis=1, inplace=True)

# %% [markdown]
# ### "previous_owners" sütunu "prev_owner" ile duplicated olduğundan dolayı düşüldü.

# %%
data.drop("previous_owners", axis=1, inplace=True)

# %% [markdown]
# ### "body_color_original" sütunu düşüldü.

# %%
data.drop("body_color_original", axis=1, inplace=True)

# %% [markdown]
# ### "interior_color" sütunu düşüldü.

# %%
data.drop("interior_color", axis=1, inplace=True)

# %% [markdown]
# ### "model_code" sütunu düşüldü.

# %%
data.drop("model_code", axis=1, inplace=True)

# %% [markdown]
# ### "consumption_city" sütunu düşüldü.

# %%
data.drop("consumption_city", axis=1, inplace=True)

# %% [markdown]
# ### "consumption_country" sütunu düşüldü.

# %%
data.drop("consumption_country", axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Columns: 119 entries, make to Xenon headlights
# dtypes: float64(12), int64(95), object(12)
# memory usage: 14.5+ MB

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.to_csv("Autoscout_data_filling-outlier.csv", index=False)
